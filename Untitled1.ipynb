# %% [markdown]
# <a href="https://colab.research.google.com/github/dnbaohan/graduation_thesis/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Library

# %%
# Install required libraries
# !pip install yfinance --quiet
# !pip install scikit-learn --quiet
# !pip install scikeras --quiet
# !pip install tensorflow pandas numpy matplotlib --quiet
# !pip install TA-Lib --quiet

# %%
# =========================
# Standard Libraries
# =========================
import os
import math
import warnings
from datetime import datetime, timedelta
import pywt
import tensorflow as tf
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import (
    mean_squared_error, mean_absolute_error,
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, confusion_matrix
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import f1_score


# =========================
# Numerical & Data Handling
# =========================
import numpy as np
import pandas as pd

# =========================
# Visualization
# =========================
import matplotlib.pyplot as plt

# =========================
# Signal Processing & Statistics
# =========================
import pywt
from scipy.fft import fft, ifft
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller

# =========================
# Financial Data & Indicators
# =========================
import yfinance as yf
import talib  # Technical Analysis Library

# =========================
# Machine Learning & Preprocessing
# =========================
from sklearn.model_selection import train_test_split,TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
from sklearn.metrics import (
    mean_squared_error, mean_absolute_error, r2_score,
    precision_score, recall_score, f1_score,
    roc_auc_score, average_precision_score,
    confusion_matrix, classification_report,
    balanced_accuracy_score
)
from sklearn.utils.class_weight import compute_class_weight

# =========================
# Imbalanced Learning
# =========================
from imblearn.over_sampling import SMOTE

# =========================
# Deep Learning (TensorFlow / Keras)
# =========================
import tensorflow as tf
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from tensorflow.keras.callbacks import (
    EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
)
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import (
    Input, Dense, Dropout, BatchNormalization, LayerNormalization,
    LSTM, GRU, Bidirectional,
    Conv1D, GlobalAveragePooling1D, GlobalMaxPooling1D,
    Attention, MultiHeadAttention, Concatenate
)

# =========================
# Configuration
# =========================
plt.rcParams["figure.figsize"] = (15, 8)
warnings.filterwarnings("ignore")
np.random.seed(0)
tf.random.set_seed(0)

# =========================
# Directory Setup
# =========================
os.makedirs("results/models", exist_ok=True)
os.makedirs("results/plots", exist_ok=True)

# %% [markdown]
# # Data

# %%
start_date = "2020-01-01"
end_date   = "2025-01-01"

tickers = {
    "VCB": "VCB.VN",
    "CTG": "CTG.VN",
    "BID": "BID.VN",
    "TCB": "TCB.VN",
}

# Download dữ liệu
stocks_data = {}
for ticker, symbol in tickers.items():
    df = yf.download(symbol, start=start_date, end=end_date)
    df = df[['Open', 'High', 'Low', 'Close', 'Volume']]
    stocks_data[symbol] = df
# Hiển thị dữ liệu của tất cả mã
for symbol, df in stocks_data.items():
    print(f"Dữ liệu cổ phiếu: {symbol}")
    print(df.head(10))



# Tạo DataFrame với giá đóng cửa cho từng cổ phiếu
df_close = pd.concat({tk: d['Close'] for tk, d in stocks_data.items()}, axis=1)
df_close.columns = df_close.columns.droplevel(0)  # Đổi tên cột sau khi concat

# Tính toán tỷ lệ log return hàng ngày
daily_log_returns = np.log(df_close / df_close.shift(1))

rows = []

for ticker in daily_log_returns.columns:

    # =========================
    # Base series
    # =========================
    close  = df_close[ticker]
    ret    = daily_log_returns[ticker]
    # Ensure volume, high, and low are Series by using .squeeze() and reindexing
    volume = stocks_data[ticker]["Volume"].squeeze().reindex(close.index)
    high   = stocks_data[ticker]["High"].squeeze().reindex(close.index)
    low    = stocks_data[ticker]["Low"].squeeze().reindex(close.index)

    df_feat = pd.DataFrame({
        "date": ret.index,
        "ticker": ticker,
        "return": ret,
        "return_lag1": ret.shift(1),
        "return_lag5": ret.shift(5),
        "return_lag10": ret.shift(10)
    })

    # =========================
    # 1. Volatility
    # =========================
    df_feat["volatility_21"] = ret.rolling(21).std() * np.sqrt(252)
    df_feat["Vol_5"]  = ret.rolling(5).std()
    df_feat["Vol_10"] = ret.rolling(10).std()
    df_feat["Vol_20"] = ret.rolling(20).std()
    # # sigma proxy (shift 1 để chỉ dùng thông tin quá khứ)
    # dft["sigma"] = dft["Vol_20"].shift(1).clip(lower=1e-6).astype(np.float32)
    # # target scaled
    # dft["y_scaled"] = (dft["target"] / dft["sigma"]).astype(np.float32)



    # =========================
    # 2. RSI
    # =========================
    df_feat["RSI_14"] = talib.RSI(close, timeperiod=14)

    # =========================
    # 3. MACD
    # =========================
    macd, macd_sig, _ = talib.MACD(close, 12, 26, 9)
    df_feat["MACD"] = macd
    df_feat["MACD_signal"] = macd_sig

    # =========================
    # 4. Bollinger Bands
    # =========================
    bb_up, bb_mid, bb_low = talib.BBANDS(close, timeperiod=20)
    df_feat["BB_upper"] = bb_up
    df_feat["BB_middle"] = bb_mid
    df_feat["BB_lower"] = bb_low
    df_feat["Boll_width"] = (bb_up - bb_low) / bb_mid
    df_feat["Boll_percB"] = (close - bb_low) / (bb_up - bb_low)

    # =========================
    # 5. Moving Averages
    # =========================
    df_feat["MA_5"]  = ret.rolling(5).mean()
    df_feat["EMA_12"] = ret.ewm(span=12, adjust=False).mean()
    df_feat["EMA_26"] = ret.ewm(span=26, adjust=False).mean()
    df_feat["Trend_20"] = ret.rolling(20).mean()

    # =========================
    # 6. Regime (High/Low vol)
    # =========================
    df_feat["Regime"] = (
        df_feat["Vol_20"] > df_feat["Vol_20"].rolling(60).mean()
    ).astype(int)

    # =========================
    # 7. OBV
    # =========================
    df_feat["OBV"] = talib.OBV(close, volume)

    # =========================
    # 8. Forward returns
    # =========================
    for k in [5, 10, 21]:
        df_feat[f"ret_{k}"] = np.log(close / close.shift(k))

    # =========================
    # 9. Momentum
    # =========================
    short_mom = close / close.shift(5) - 1
    long_mom  = close / close.shift(21) - 1

    df_feat["momentum_diff"] = short_mom - long_mom
    df_feat["momentum_90"] = close / close.shift(90) - 1


    # =========================
    # 10. MA / EMA ratios
    # =========================
    df_feat["SMA20_ratio"] = close / close.rolling(20).mean() - 1
    df_feat["SMA50_ratio"] = close / close.rolling(50).mean() - 1
    df_feat["EMA12_ratio"] = close / close.ewm(span=12).mean() - 1
    df_feat["EMA26_ratio"] = close / close.ewm(span=26).mean() - 1

    # =========================
    # 11. ATR (normalized)
    # =========================
    tr = np.maximum(
        high - low,
        np.maximum(
            (high - close.shift()).abs(),
            (low - close.shift()).abs()
        )
    )
    df_feat["ATR_14"] = tr.rolling(14).mean() / close

    # =========================
    # 12. Volume
    # =========================
    log_vol = np.log(volume.replace(0, np.nan))
    df_feat["Volume_diff"] = log_vol.diff()

    rows.append(df_feat)

# =========================
# Final feature table
# =========================
features = (
    pd.concat(rows)
    .sort_values(["ticker", "date"])
    .reset_index(drop=True)
)

# 7) Target = return ngày kế tiếp
features = features.sort_values(["ticker", "date"])
features["target"] = (
    features.groupby("ticker")["return"]
            .transform(lambda s: s.shift(-1).rolling(5).mean())
)


# 8) Làm sạch dữ liệu (bỏ tất cả NaN phát sinh)
df = features.dropna().reset_index(drop=True)

# Kiểm tra kết quả cuối cùng
print("Dataset cuối cùng:", df.shape)
print(df.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Dữ liệu cổ phiếu: VCB.VN
# Price               Open          High           Low         Close   Volume
# Ticker            VCB.VN        VCB.VN        VCB.VN        VCB.VN   VCB.VN
# Date
# 2020-01-02  39747.175948  40275.960743  39526.846687  40011.566406   870270
# 2020-01-03  40320.025537  40452.224643  39614.976562  39614.976562  1207844
# 2020-01-06  39306.516379  39438.715483  38557.402344  38557.402344  1982797
# 2020-01-07  38337.073175  38733.662732  37632.024213  38689.597656  2529103
# 2020-01-08  38293.009142  38733.663786  37984.549728  38337.074219  1897570
# 2020-01-09  38645.532893  39174.321558  38645.532893  39086.191406  2040337
# 2020-01-10  39086.190369  39835.304393  38733.662017  39438.714844  3596527
# 2020-01-13  39218.388128  39570.912625  39218.388128  39394.648438  3880278
# 2020-01-14  39438.717393  39659.042780  39262.453205  39394.648438  2255442
# 2020-01-15  39482.781137  39482.781137  39130.256652  39350.582031  3379031
# Dữ liệu cổ phiếu: CTG.VN
# Price               Open          High           Low         Close     Volume
# Ticker            CTG.VN        CTG.VN        CTG.VN        CTG.VN     CTG.VN
# Date
# 2020-01-02   9902.445536  10305.176411   9878.755371  10186.725586    9069367
# 2020-01-03  10305.176339  10352.556668  10068.275655  10091.965820    7565383
# 2020-01-06  10044.585754  10281.486443   9997.205423  10115.656250    6620064
# 2020-01-07  10234.105998  10352.556824  10163.035502  10281.486328    8879516
# 2020-01-08  10210.415569  10494.696579  10091.965712  10257.795898  136795825
# 2020-01-09  10352.556861  10707.907410  10352.556861  10636.836914   19592888
# 2020-01-10  10660.527017  11371.229076  10660.527017  11158.018555   31801609
# 2020-01-13  11039.567842  11371.229192  10992.188477  10992.188477   11155134
# 2020-01-14  11015.878267  11276.468147  10992.188103  11134.328125   44334358
# 2020-01-15  11134.328653  11229.089316  11015.878790  11181.708984    9147052
# Dữ liệu cổ phiếu: BID.VN
# Price               Open          High           Low         Close   Volume
# Ticker            BID.VN        BID.VN        BID.VN        BID.VN   BID.VN
# Date
# 2020-01-02  26527.793560  27219.823378  26470.124570  27046.816406  1496500
# 2020-01-03  27306.327921  27392.830441  26931.478516  26931.478516  1035726
# 2020-01-06  26931.477914  26931.477914  26412.455078  26412.455078  1362510
# 2020-01-07  26412.455668  26931.478516  26066.441724  26931.478516   903589
# 2020-01-08  26527.793472  27623.506219  26412.455492  27162.154297  2110812
# 2020-01-09  27537.004037  28776.890240  27450.499584  28632.716797  2697943
# 2020-01-10  28632.716571  29987.940746  28603.883042  29584.257812  2583418
# 2020-01-13  28776.890533  29699.596329  28546.214566  28892.228516   934201
# 2020-01-14  28892.228516  29699.596329  28776.890533  28892.228516  1461481
# 2020-01-15  28776.889191  29584.256967  28776.889191  29411.250000  1192387
# Dữ liệu cổ phiếu: TCB.VN
# Price               Open          High           Low         Close    Volume
# Ticker            TCB.VN        TCB.VN        TCB.VN        TCB.VN    TCB.VN
# Date
# 2020-01-02  10778.707216  10916.015588  10755.822487  10893.130859   2820080
# 2020-01-03  10938.900205  10961.784933  10824.476562  10824.476562   1513400
# 2020-01-06  10710.053459  10710.053459  10549.860352  10549.860352   2325980
# 2020-01-07  10549.859489  10618.513672  10526.974761  10618.513672   4920200
# 2020-01-08  10435.436487  10549.860133  10343.897570  10412.551758   3420780
# 2020-01-09  10526.975622  10572.745081  10458.321433  10549.860352   4019680
# 2020-01-10  10526.975694  10755.822991  10526.975694  10595.629883   7358220
# 2020-01-13  10526.974571  10595.628753  10412.550934  10504.089844   1784720
# 2020-01-14  10504.090784  10549.860243  10481.206055  10481.206055   4561960
# 2020-01-15  10481.206055  10526.975513  10435.436596  10481.206055  11830560
# Dataset cuối cùng: (4547, 36)
#         date  ticker    return  return_lag1  return_lag5  return_lag10  \
# 0 2020-05-19  BID.VN  0.005128     0.007742     0.001298      0.000000
# 1 2020-05-20  BID.VN  0.001278     0.005128     0.026873      0.019636
# 2 2020-05-21  BID.VN  0.013951     0.001278     0.002522      0.042154
# 3 2020-05-22  BID.VN -0.010127     0.013951    -0.028099      0.011913
# 4 2020-05-25  BID.VN  0.008866    -0.010127     0.007742      0.013072
#
#    volatility_21     Vol_5    Vol_10    Vol_20  ...    ret_21  momentum_diff  \
# 0       0.375966  0.019775  0.018367  0.024299  ...  0.047129      -0.033990
# 1       0.375977  0.014643  0.018239  0.024180  ...  0.045730      -0.058155
# 2       0.376159  0.016371  0.014162  0.017873  ...  0.067734      -0.070081
# 3       0.282645  0.008950  0.014767  0.016140  ...  0.124485      -0.114430
# 4       0.250277  0.009094  0.014517  0.016143  ...  0.091032      -0.076024
#
#    momentum_90  SMA20_ratio  SMA50_ratio  EMA12_ratio  EMA26_ratio    ATR_14  \
# 0    -0.166311     0.055117     0.077283     0.023980     0.041833  0.031056
# 1    -0.161670     0.053552     0.083257     0.021316     0.039838  0.030104
# 2    -0.133188     0.061214     0.100851     0.030013     0.050207  0.029867
# 3    -0.158458     0.046187     0.091636     0.016564     0.036581  0.029080
# 4    -0.158174     0.050679     0.101236     0.021591     0.042273  0.029184
#
#    Volume_diff        target
# 0    -0.100422 -2.285745e-03
# 1    -0.627118  6.938894e-18
# 2     1.010765  3.594464e-03
# 3    -0.774392  3.819332e-03
# 4    -0.250203  1.430943e-02
#
# [5 rows x 36 columns]

# %%
def adf_summary_full(df):
    results = []
    numeric_cols = df.select_dtypes(include=[np.number]).columns  # chỉ lấy cột số

    for col in numeric_cols:
        series = df[col].dropna()
        if len(series) < 20:  # bỏ qua cột có quá ít quan sát
            continue
        adf_result = adfuller(series, autolag='AIC')
        pval = adf_result[1]
        stat = adf_result[0]
        crit = adf_result[4]['5%']
        results.append({
            'Variable': col,
            'ADF Statistic': round(stat, 4),
            'p-value': round(pval, 4),
            '5% Critical Value': round(crit, 4),
            'Stationary': 'Yes' if pval < 0.05 else 'No'
        })

    return pd.DataFrame(results)

# Gọi hàm trên toàn bộ dataframe của bạn
adf_table_full = adf_summary_full(df)
print(adf_table_full)

df.columns
# Out:
#          Variable  ADF Statistic  p-value  5% Critical Value Stationary
# 0          return       -11.8925   0.0000            -2.8622        Yes
# 1     return_lag1       -11.9094   0.0000            -2.8622        Yes
# 2     return_lag5       -11.9292   0.0000            -2.8622        Yes
# 3    return_lag10       -12.0856   0.0000            -2.8622        Yes
# 4   volatility_21        -7.7038   0.0000            -2.8622        Yes
# 5           Vol_5        -7.0304   0.0000            -2.8622        Yes
# 6          Vol_10        -7.1426   0.0000            -2.8622        Yes
# 7          Vol_20        -7.8243   0.0000            -2.8622        Yes
# 8          RSI_14       -13.1756   0.0000            -2.8622        Yes
# 9            MACD       -10.8881   0.0000            -2.8622        Yes
# 10    MACD_signal       -10.1030   0.0000            -2.8622        Yes
# 11       BB_upper        -0.9483   0.7716            -2.8622         No
# 12      BB_middle        -0.6742   0.8533            -2.8622         No
# 13       BB_lower        -0.9027   0.7871            -2.8622         No
# 14     Boll_width        -9.9387   0.0000            -2.8622        Yes
# 15     Boll_percB       -16.6423   0.0000            -2.8622        Yes
# 16           MA_5       -10.5486   0.0000            -2.8622        Yes
# 17         EMA_12       -10.2036   0.0000            -2.8622        Yes
# 18         EMA_26        -9.4078   0.0000            -2.8622        Yes
# 19       Trend_20       -10.9190   0.0000            -2.8622        Yes
# 20         Regime       -11.1358   0.0000            -2.8622        Yes
# 21            OBV        -2.2195   0.1992            -2.8622         No
# 22          ret_5       -10.5486   0.0000            -2.8622        Yes
# 23         ret_10        -9.9360   0.0000            -2.8622        Yes
# 24         ret_21       -10.5904   0.0000            -2.8622        Yes
# 25  momentum_diff        -9.0520   0.0000            -2.8622        Yes
# 26    momentum_90        -6.4862   0.0000            -2.8622        Yes
# 27    SMA20_ratio       -10.5529   0.0000            -2.8622        Yes
# 28    SMA50_ratio        -9.7066   0.0000            -2.8622        Yes
# 29    EMA12_ratio       -10.1994   0.0000            -2.8622        Yes
# 30    EMA26_ratio        -9.3775   0.0000            -2.8622        Yes
# 31         ATR_14        -7.5531   0.0000            -2.8622        Yes
# 32    Volume_diff       -21.2388   0.0000            -2.8622        Yes
# 33         target       -10.5445   0.0000            -2.8622        Yes
# Index(['date', 'ticker', 'return', 'return_lag1', 'return_lag5',
#        'return_lag10', 'volatility_21', 'Vol_5', 'Vol_10', 'Vol_20', 'RSI_14',
#        'MACD', 'MACD_signal', 'BB_upper', 'BB_middle', 'BB_lower',
#        'Boll_width', 'Boll_percB', 'MA_5', 'EMA_12', 'EMA_26', 'Trend_20',
#        'Regime', 'OBV', 'ret_5', 'ret_10', 'ret_21', 'momentum_diff',
#        'momentum_90', 'SMA20_ratio', 'SMA50_ratio', 'EMA12_ratio',
#        'EMA26_ratio', 'ATR_14', 'Volume_diff', 'target'],
#       dtype='object')

# %% [markdown]
# # Transformer

# %%
# ---------- Positional Encoding ----------
class PositionalEncoding(tf.keras.layers.Layer):
    def __init__(self, position: int, d_model: int):
        super().__init__()
        pos = np.arange(position)[:, np.newaxis]
        i   = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        angle_rads  = pos * angle_rates
        angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
        angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.pos_encoding = tf.constant(angle_rads[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        return x + self.pos_encoding[:, :tf.shape(x)[1], :]

def transformer_encoder(x, num_heads, key_dim, ff_dim, dropout=0.2):
    attn_out = tf.keras.layers.MultiHeadAttention(
        num_heads=num_heads, key_dim=key_dim, dropout=dropout
    )(x, x)
    attn_out = tf.keras.layers.Dropout(dropout)(attn_out)
    x = tf.keras.layers.Add()([x, attn_out])
    x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(x)

    ff = tf.keras.layers.Dense(ff_dim, activation="relu")(x)
    ff = tf.keras.layers.Dropout(dropout)(ff)
    ff = tf.keras.layers.Dense(x.shape[-1])(ff)
    x = tf.keras.layers.Add()([x, ff])
    x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(x)
    return x

# %%
def build_transformer_multitask(
    input_shape,
    d_model=64,
    num_heads=4,
    ff_dim=128,
    num_blocks=3,
    dropout=0.2,
    use_conv_frontend=True
):
    """
    input_shape: (LOOKBACK, n_features)
    outputs:
      - y_reg_z: standardized return (regression)
      - y_up: probability of Up (classification)
    """
    inputs = tf.keras.Input(shape=input_shape)

    # Project features -> d_model
    x = tf.keras.layers.Dense(d_model)(inputs)

    # Optional local-pattern front-end (often helps for financial series)
    if use_conv_frontend:
        x = tf.keras.layers.Conv1D(filters=d_model, kernel_size=3, padding="causal", activation="relu")(x)
        x = tf.keras.layers.Dropout(dropout)(x)

    x = PositionalEncoding(position=input_shape[0], d_model=d_model)(x)

    key_dim = max(8, d_model // num_heads)
    for _ in range(num_blocks):
        x = transformer_encoder(x, num_heads=num_heads, key_dim=key_dim, ff_dim=ff_dim, dropout=dropout)

    x = tf.keras.layers.GlobalAveragePooling1D()(x)
    x = tf.keras.layers.Dropout(dropout)(x)

    # Head 1: regression on standardized target
    y_reg_z = tf.keras.layers.Dense(1, name="y_reg_z")(x)

    # Head 2: direction probability
    y_up = tf.keras.layers.Dense(1, activation="sigmoid", name="y_up")(x)

    return tf.keras.Model(inputs, [y_reg_z, y_up])

# %%
def make_weighted_bce(w_pos, w_neg):
    # w_pos applies to y_true==1, w_neg applies to y_true==0
    def weighted_bce(y_true, y_pred):
        bce = tf.keras.backend.binary_crossentropy(y_true, y_pred)
        w = y_true * w_pos + (1.0 - y_true) * w_neg
        return tf.reduce_mean(bce * w)
    return weighted_bce

# %%
import numpy as np
from sklearn.metrics import f1_score

def tune_threshold(y_true_bin, y_prob, lo=0.3, hi=0.7, n=81):
    ths = np.linspace(lo, hi, n)
    best_t, best_f1 = 0.5, -1
    for t in ths:
        f1 = f1_score(y_true_bin, (y_prob > t).astype(int), zero_division=0)
        if f1 > best_f1:
            best_f1, best_t = f1, t
    return best_t, best_f1

# %%
def create_sequences(X, y, seq_len):
    X_seq, y_seq = [], []
    for i in range(seq_len, len(X)):
        X_seq.append(X[i-seq_len:i])
        y_seq.append(y[i])
    return np.array(X_seq), np.array(y_seq)

LOOKBACK = 30
non_feature = ['date', 'ticker', 'target']
feature_cols = [c for c in df.columns if c not in non_feature]

df = df.copy()
df["date"] = pd.to_datetime(df["date"])

models, scalers, histories, splits, meta = {}, {}, {}, {}, {}


# -------------------
import tensorflow as tf
import numpy as np

def focal_loss(alpha=0.5, gamma=2.0):
    """Binary focal loss for collapse-prone classification."""
    def fl(y_true, y_pred):
        eps = tf.keras.backend.epsilon()
        y_pred = tf.clip_by_value(y_pred, eps, 1.0 - eps)
        ce = -(y_true * tf.math.log(y_pred) + (1.0 - y_true) * tf.math.log(1.0 - y_pred))
        p_t = y_true * y_pred + (1.0 - y_true) * (1.0 - y_pred)
        w = alpha * y_true + (1.0 - alpha) * (1.0 - y_true)
        return tf.reduce_mean(w * tf.pow((1.0 - p_t), gamma) * ce)
    return fl

def make_direction_labels_with_mask(y, vol_proxy, k=0.3):
    """
    y: target series (float)
    vol_proxy: volatility proxy at time t (must be past-only; shift outside if needed)
    k: noise filter strength; CTG thường hợp 0.25–0.40
    Returns:
      y_up (0/1), mask (0/1) -> mask=0 means ignore this sample for classification loss
    """
    vol_proxy = np.asarray(vol_proxy, dtype=np.float32)
    y = np.asarray(y, dtype=np.float32)

    thr = k * vol_proxy
    mask = np.isfinite(y) & np.isfinite(vol_proxy) & (np.abs(y) >= thr)
    y_up = (y > 0).astype(np.float32)

    return y_up, mask.astype(np.float32)
# --------------

for tk, dft in df.groupby("ticker"):
    dft = dft.sort_values("date").reset_index(drop=True)

    X = dft[feature_cols].values.astype(np.float32)
    y = dft["target"].values.astype(np.float32)

    if len(dft) < (LOOKBACK + 80):
        print(f"⚠️ {tk}: dữ liệu quá ít ({len(dft)} dòng) -> bỏ qua")
        continue

    split_index = int(len(dft) * 0.8)
    X_train_raw, X_test_raw = X[:split_index], X[split_index:]
    y_train_raw, y_test_raw = y[:split_index], y[split_index:]

    scaler = RobustScaler()
    X_train_scaled = scaler.fit_transform(X_train_raw)
    X_test_scaled  = scaler.transform(X_test_raw)

    X_train_seq, y_train_seq = create_sequences(X_train_scaled, y_train_raw, LOOKBACK)
    X_test_seq,  y_test_seq  = create_sequences(X_test_scaled,  y_test_raw,  LOOKBACK)

    # validation from tail of train
    val_size = max(1, int(0.2 * len(X_train_seq)))
    X_tr, y_tr = X_train_seq[:-val_size], y_train_seq[:-val_size]
    X_val, y_val = X_train_seq[-val_size:], y_train_seq[-val_size:]

    # ===== 1) Standardize y on train ONLY =====
    y_mu = float(np.mean(y_tr))
    y_sd = float(np.std(y_tr) + 1e-8)
    y_tr_z  = ((y_tr  - y_mu) / y_sd).astype(np.float32)
    y_val_z = ((y_val - y_mu) / y_sd).astype(np.float32)

    # direction labels
    y_tr_up  = (y_tr > 0).astype(np.float32)
    y_val_up = (y_val > 0).astype(np.float32)

    # ===== 2) Weighted BCE to reduce collapse/bias =====
    pos = float(y_tr_up.mean())          # P(Up)
    w_pos = 0.5 / (pos + 1e-8)
    w_neg = 0.5 / (1.0 - pos + 1e-8)
    w_bce = make_weighted_bce(w_pos=w_pos, w_neg=w_neg)

    # ===== 3) Build model =====
    model = build_transformer_multitask(
        input_shape=(LOOKBACK, X_train_seq.shape[2]),
        d_model=64,
        num_heads=4,
        ff_dim=128,
        num_blocks=3,
        dropout=0.2,
        use_conv_frontend=True
    )

    # optimizer: clipnorm improves stability a lot on noisy targets
    opt = Adam(learning_rate=1e-3, clipnorm=1.0)

    model.compile(
        optimizer=opt,
        loss={
            "y_reg_z": tf.keras.losses.Huber(delta=1.0),
            "y_up": w_bce
        },
        loss_weights={"y_reg_z": 1.0, "y_up": 0.5}  # you can try 0.3–0.8
    )

    early_stop = EarlyStopping(monitor="val_loss", patience=12, restore_best_weights=True)
    rlr = ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=5, min_lr=1e-5, verbose=1)

    print(f"\n===== Training Transformer (Improved) for {tk} | UpRatio={pos:.3f} =====")
    history = model.fit(
        X_tr, {"y_reg_z": y_tr_z, "y_up": y_tr_up},
        validation_data=(X_val, {"y_reg_z": y_val_z, "y_up": y_val_up}),
        epochs=120,
        batch_size=32,   # often better than 64 for financial series
        callbacks=[early_stop, rlr],
        verbose=1
    )

    models[tk] = model
    scalers[tk] = scaler
    histories[tk] = history
    splits[tk] = (X_train_seq, X_test_seq, y_train_seq, y_test_seq)
    meta[tk] = {"y_mu": y_mu, "y_sd": y_sd, "up_ratio": pos, "w_pos": w_pos, "w_neg": w_neg}

print("\nDone. Models trained for:", list(models.keys()))
# Out:
# ===== Training Transformer (Improved) for BID.VN | UpRatio=0.524 =====
# Epoch 1/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 22s 114ms/step - loss: 1.1041 - y_reg_z_loss: 0.7059 - y_up_loss: 0.7965 - val_loss: 0.5724 - val_y_reg_z_loss: 0.2604 - val_y_up_loss: 0.6735 - learning_rate: 0.0010
# Epoch 2/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.8272 - y_reg_z_loss: 0.4602 - y_up_loss: 0.7336 - val_loss: 0.5394 - val_y_reg_z_loss: 0.1975 - val_y_up_loss: 0.7163 - learning_rate: 0.0010
# Epoch 3/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.7790 - y_reg_z_loss: 0.4382 - y_up_loss: 0.6826 - val_loss: 0.5467 - val_y_reg_z_loss: 0.2016 - val_y_up_loss: 0.7318 - learning_rate: 0.0010
# Epoch 4/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.7728 - y_reg_z_loss: 0.4305 - y_up_loss: 0.6842 - val_loss: 0.5987 - val_y_reg_z_loss: 0.2593 - val_y_up_loss: 0.7566 - learning_rate: 0.0010
# Epoch 5/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - loss: 0.7117 - y_reg_z_loss: 0.3864 - y_up_loss: 0.6497 - val_loss: 0.6677 - val_y_reg_z_loss: 0.3731 - val_y_up_loss: 0.7241 - learning_rate: 0.0010
# Epoch 6/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - loss: 0.5072 - y_reg_z_loss: 0.2567 - y_up_loss: 0.5008 - val_loss: 0.4961 - val_y_reg_z_loss: 0.2165 - val_y_up_loss: 0.6067 - learning_rate: 0.0010
# Epoch 7/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.4757 - y_reg_z_loss: 0.2533 - y_up_loss: 0.4442 - val_loss: 0.3712 - val_y_reg_z_loss: 0.1367 - val_y_up_loss: 0.4719 - learning_rate: 0.0010
# Epoch 8/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.4734 - y_reg_z_loss: 0.2419 - y_up_loss: 0.4624 - val_loss: 0.3922 - val_y_reg_z_loss: 0.1516 - val_y_up_loss: 0.4939 - learning_rate: 0.0010
# Epoch 9/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.4378 - y_reg_z_loss: 0.2137 - y_up_loss: 0.4475 - val_loss: 0.3997 - val_y_reg_z_loss: 0.1525 - val_y_up_loss: 0.5125 - learning_rate: 0.0010
# Epoch 10/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.4188 - y_reg_z_loss: 0.2151 - y_up_loss: 0.4072 - val_loss: 0.4824 - val_y_reg_z_loss: 0.2196 - val_y_up_loss: 0.5493 - learning_rate: 0.0010
# Epoch 11/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 141ms/step - loss: 0.3836 - y_reg_z_loss: 0.1964 - y_up_loss: 0.3742 - val_loss: 0.4391 - val_y_reg_z_loss: 0.1940 - val_y_up_loss: 0.5254 - learning_rate: 0.0010
# Epoch 12/120
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.3899 - y_reg_z_loss: 0.1952 - y_up_loss: 0.3895
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.3907 - y_reg_z_loss: 0.1952 - y_up_loss: 0.3905 - val_loss: 0.4900 - val_y_reg_z_loss: 0.2157 - val_y_up_loss: 0.5738 - learning_rate: 0.0010
# Epoch 13/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.3667 - y_reg_z_loss: 0.1842 - y_up_loss: 0.3645 - val_loss: 0.5097 - val_y_reg_z_loss: 0.2317 - val_y_up_loss: 0.6084 - learning_rate: 5.0000e-04
# Epoch 14/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.3593 - y_reg_z_loss: 0.1876 - y_up_loss: 0.3428 - val_loss: 0.5058 - val_y_reg_z_loss: 0.2337 - val_y_up_loss: 0.6050 - learning_rate: 5.0000e-04
# Epoch 15/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.3206 - y_reg_z_loss: 0.1584 - y_up_loss: 0.3237 - val_loss: 0.5951 - val_y_reg_z_loss: 0.2821 - val_y_up_loss: 0.6739 - learning_rate: 5.0000e-04
# Epoch 16/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.3384 - y_reg_z_loss: 0.1707 - y_up_loss: 0.3347 - val_loss: 0.6184 - val_y_reg_z_loss: 0.2826 - val_y_up_loss: 0.7368 - learning_rate: 5.0000e-04
# Epoch 17/120
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.3100 - y_reg_z_loss: 0.1545 - y_up_loss: 0.3111
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.3114 - y_reg_z_loss: 0.1545 - y_up_loss: 0.3131 - val_loss: 0.5904 - val_y_reg_z_loss: 0.2745 - val_y_up_loss: 0.6883 - learning_rate: 5.0000e-04
# Epoch 18/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - loss: 0.3177 - y_reg_z_loss: 0.1631 - y_up_loss: 0.3085 - val_loss: 0.5448 - val_y_reg_z_loss: 0.2444 - val_y_up_loss: 0.6630 - learning_rate: 2.5000e-04
# Epoch 19/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.2985 - y_reg_z_loss: 0.1488 - y_up_loss: 0.2990 - val_loss: 0.5001 - val_y_reg_z_loss: 0.1989 - val_y_up_loss: 0.6437 - learning_rate: 2.5000e-04
#
# ===== Training Transformer (Improved) for CTG.VN | UpRatio=0.517 =====
# Epoch 1/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 18s 115ms/step - loss: 1.1199 - y_reg_z_loss: 0.7516 - y_up_loss: 0.7360 - val_loss: 0.7563 - val_y_reg_z_loss: 0.3038 - val_y_up_loss: 0.9833 - learning_rate: 0.0010
# Epoch 2/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.8801 - y_reg_z_loss: 0.5180 - y_up_loss: 0.7247 - val_loss: 0.8286 - val_y_reg_z_loss: 0.3926 - val_y_up_loss: 0.9872 - learning_rate: 0.0010
# Epoch 3/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 0.7326 - y_reg_z_loss: 0.4091 - y_up_loss: 0.6472 - val_loss: 0.8155 - val_y_reg_z_loss: 0.3460 - val_y_up_loss: 1.0545 - learning_rate: 0.0010
# Epoch 4/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - loss: 0.7370 - y_reg_z_loss: 0.4076 - y_up_loss: 0.6589 - val_loss: 0.8846 - val_y_reg_z_loss: 0.3929 - val_y_up_loss: 1.1213 - learning_rate: 0.0010
# Epoch 5/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.7185 - y_reg_z_loss: 0.3843 - y_up_loss: 0.6683 - val_loss: 0.8129 - val_y_reg_z_loss: 0.3046 - val_y_up_loss: 1.1429 - learning_rate: 0.0010
# Epoch 6/120
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.6437 - y_reg_z_loss: 0.3443 - y_up_loss: 0.5989
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.6423 - y_reg_z_loss: 0.3435 - y_up_loss: 0.5976 - val_loss: 1.0630 - val_y_reg_z_loss: 0.5087 - val_y_up_loss: 1.2585 - learning_rate: 0.0010
# Epoch 7/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.5403 - y_reg_z_loss: 0.2823 - y_up_loss: 0.5164 - val_loss: 0.8756 - val_y_reg_z_loss: 0.3431 - val_y_up_loss: 1.1812 - learning_rate: 5.0000e-04
# Epoch 8/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.5068 - y_reg_z_loss: 0.2552 - y_up_loss: 0.5030 - val_loss: 0.8351 - val_y_reg_z_loss: 0.2943 - val_y_up_loss: 1.1712 - learning_rate: 5.0000e-04
# Epoch 9/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 0.4756 - y_reg_z_loss: 0.2522 - y_up_loss: 0.4472 - val_loss: 0.7376 - val_y_reg_z_loss: 0.2692 - val_y_up_loss: 1.0181 - learning_rate: 5.0000e-04
# Epoch 10/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 0.4632 - y_reg_z_loss: 0.2447 - y_up_loss: 0.4373 - val_loss: 0.9583 - val_y_reg_z_loss: 0.4221 - val_y_up_loss: 1.1969 - learning_rate: 5.0000e-04
# Epoch 11/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.4211 - y_reg_z_loss: 0.2104 - y_up_loss: 0.4214 - val_loss: 0.9624 - val_y_reg_z_loss: 0.3869 - val_y_up_loss: 1.2860 - learning_rate: 5.0000e-04
# Epoch 12/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.3987 - y_reg_z_loss: 0.2004 - y_up_loss: 0.3966 - val_loss: 0.8682 - val_y_reg_z_loss: 0.3286 - val_y_up_loss: 1.2035 - learning_rate: 5.0000e-04
# Epoch 13/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.3928 - y_reg_z_loss: 0.2004 - y_up_loss: 0.3849 - val_loss: 0.9219 - val_y_reg_z_loss: 0.3835 - val_y_up_loss: 1.2126 - learning_rate: 5.0000e-04
# Epoch 14/120
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.3552 - y_reg_z_loss: 0.1776 - y_up_loss: 0.3552
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.3559 - y_reg_z_loss: 0.1782 - y_up_loss: 0.3550 - val_loss: 0.9120 - val_y_reg_z_loss: 0.3578 - val_y_up_loss: 1.2505 - learning_rate: 5.0000e-04
# Epoch 15/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.3561 - y_reg_z_loss: 0.1811 - y_up_loss: 0.3494 - val_loss: 0.8685 - val_y_reg_z_loss: 0.2744 - val_y_up_loss: 1.3371 - learning_rate: 2.5000e-04
# Epoch 16/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 0.3326 - y_reg_z_loss: 0.1626 - y_up_loss: 0.3398 - val_loss: 0.8718 - val_y_reg_z_loss: 0.2766 - val_y_up_loss: 1.3383 - learning_rate: 2.5000e-04
# Epoch 17/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - loss: 0.3167 - y_reg_z_loss: 0.1544 - y_up_loss: 0.3241 - val_loss: 0.9118 - val_y_reg_z_loss: 0.2865 - val_y_up_loss: 1.4141 - learning_rate: 2.5000e-04
# Epoch 18/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.3059 - y_reg_z_loss: 0.1528 - y_up_loss: 0.3056 - val_loss: 0.8567 - val_y_reg_z_loss: 0.2413 - val_y_up_loss: 1.3874 - learning_rate: 2.5000e-04
# Epoch 19/120
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.2864 - y_reg_z_loss: 0.1402 - y_up_loss: 0.2923
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.2877 - y_reg_z_loss: 0.1413 - y_up_loss: 0.2928 - val_loss: 0.9657 - val_y_reg_z_loss: 0.2818 - val_y_up_loss: 1.5366 - learning_rate: 2.5000e-04
# Epoch 20/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.3019 - y_reg_z_loss: 0.1528 - y_up_loss: 0.2978 - val_loss: 0.9790 - val_y_reg_z_loss: 0.2908 - val_y_up_loss: 1.5470 - learning_rate: 1.2500e-04
# Epoch 21/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.2903 - y_reg_z_loss: 0.1420 - y_up_loss: 0.2964 - val_loss: 0.9123 - val_y_reg_z_loss: 0.2805 - val_y_up_loss: 1.4240 - learning_rate: 1.2500e-04
#
# ===== Training Transformer (Improved) for TCB.VN | UpRatio=0.555 =====
# Epoch 1/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 18s 146ms/step - loss: 1.0704 - y_reg_z_loss: 0.6782 - y_up_loss: 0.7842 - val_loss: 0.5512 - val_y_reg_z_loss: 0.1747 - val_y_up_loss: 0.7380 - learning_rate: 0.0010
# Epoch 2/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.7720 - y_reg_z_loss: 0.4270 - y_up_loss: 0.6895 - val_loss: 0.5189 - val_y_reg_z_loss: 0.1416 - val_y_up_loss: 0.7157 - learning_rate: 0.0010
# Epoch 3/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.7524 - y_reg_z_loss: 0.4074 - y_up_loss: 0.6894 - val_loss: 0.5292 - val_y_reg_z_loss: 0.1452 - val_y_up_loss: 0.7251 - learning_rate: 0.0010
# Epoch 4/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.6824 - y_reg_z_loss: 0.3508 - y_up_loss: 0.6627 - val_loss: 0.5479 - val_y_reg_z_loss: 0.1529 - val_y_up_loss: 0.7402 - learning_rate: 0.0010
# Epoch 5/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.6680 - y_reg_z_loss: 0.3523 - y_up_loss: 0.6309 - val_loss: 0.5788 - val_y_reg_z_loss: 0.1842 - val_y_up_loss: 0.7663 - learning_rate: 0.0010
# Epoch 6/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.6084 - y_reg_z_loss: 0.3083 - y_up_loss: 0.5998 - val_loss: 0.5675 - val_y_reg_z_loss: 0.1680 - val_y_up_loss: 0.7637 - learning_rate: 0.0010
# Epoch 7/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.5871 - y_reg_z_loss: 0.2962 - y_up_loss: 0.5816
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - loss: 0.5874 - y_reg_z_loss: 0.2966 - y_up_loss: 0.5814 - val_loss: 0.5758 - val_y_reg_z_loss: 0.1649 - val_y_up_loss: 0.8013 - learning_rate: 0.0010
# Epoch 8/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.5627 - y_reg_z_loss: 0.2933 - y_up_loss: 0.5385 - val_loss: 0.6455 - val_y_reg_z_loss: 0.2043 - val_y_up_loss: 0.8294 - learning_rate: 5.0000e-04
# Epoch 9/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.5183 - y_reg_z_loss: 0.2622 - y_up_loss: 0.5118 - val_loss: 0.6088 - val_y_reg_z_loss: 0.1856 - val_y_up_loss: 0.8121 - learning_rate: 5.0000e-04
# Epoch 10/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.5073 - y_reg_z_loss: 0.2502 - y_up_loss: 0.5138 - val_loss: 0.6347 - val_y_reg_z_loss: 0.2029 - val_y_up_loss: 0.8244 - learning_rate: 5.0000e-04
# Epoch 11/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.4815 - y_reg_z_loss: 0.2390 - y_up_loss: 0.4846 - val_loss: 0.6168 - val_y_reg_z_loss: 0.1873 - val_y_up_loss: 0.7975 - learning_rate: 5.0000e-04
# Epoch 12/120
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.4718 - y_reg_z_loss: 0.2308 - y_up_loss: 0.4821
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.4704 - y_reg_z_loss: 0.2297 - y_up_loss: 0.4812 - val_loss: 0.5333 - val_y_reg_z_loss: 0.1458 - val_y_up_loss: 0.7537 - learning_rate: 5.0000e-04
# Epoch 13/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.4274 - y_reg_z_loss: 0.2071 - y_up_loss: 0.4405 - val_loss: 0.5531 - val_y_reg_z_loss: 0.1581 - val_y_up_loss: 0.7645 - learning_rate: 2.5000e-04
# Epoch 14/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.4005 - y_reg_z_loss: 0.1933 - y_up_loss: 0.4144 - val_loss: 0.5455 - val_y_reg_z_loss: 0.1532 - val_y_up_loss: 0.7628 - learning_rate: 2.5000e-04
#
# ===== Training Transformer (Improved) for VCB.VN | UpRatio=0.532 =====
# Epoch 1/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 20s 117ms/step - loss: 1.0952 - y_reg_z_loss: 0.7057 - y_up_loss: 0.7784 - val_loss: 0.6193 - val_y_reg_z_loss: 0.2165 - val_y_up_loss: 0.8102 - learning_rate: 0.0010
# Epoch 2/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.7707 - y_reg_z_loss: 0.4186 - y_up_loss: 0.7041 - val_loss: 0.6234 - val_y_reg_z_loss: 0.2321 - val_y_up_loss: 0.8071 - learning_rate: 0.0010
# Epoch 3/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - loss: 0.7522 - y_reg_z_loss: 0.4030 - y_up_loss: 0.6990 - val_loss: 0.6440 - val_y_reg_z_loss: 0.2210 - val_y_up_loss: 0.8756 - learning_rate: 0.0010
# Epoch 4/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 0.7310 - y_reg_z_loss: 0.3899 - y_up_loss: 0.6822 - val_loss: 0.7770 - val_y_reg_z_loss: 0.3038 - val_y_up_loss: 0.9976 - learning_rate: 0.0010
# Epoch 5/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.7341 - y_reg_z_loss: 0.3973 - y_up_loss: 0.6745 - val_loss: 0.9272 - val_y_reg_z_loss: 0.4653 - val_y_up_loss: 0.9845 - learning_rate: 0.0010
# Epoch 6/120
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.6786 - y_reg_z_loss: 0.3512 - y_up_loss: 0.6549
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.6802 - y_reg_z_loss: 0.3526 - y_up_loss: 0.6551 - val_loss: 0.7983 - val_y_reg_z_loss: 0.3968 - val_y_up_loss: 0.8556 - learning_rate: 0.0010
# Epoch 7/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 0.6283 - y_reg_z_loss: 0.3215 - y_up_loss: 0.6137 - val_loss: 1.0266 - val_y_reg_z_loss: 0.5695 - val_y_up_loss: 0.9392 - learning_rate: 5.0000e-04
# Epoch 8/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.5116 - y_reg_z_loss: 0.2331 - y_up_loss: 0.5571 - val_loss: 0.6305 - val_y_reg_z_loss: 0.2892 - val_y_up_loss: 0.6768 - learning_rate: 5.0000e-04
# Epoch 9/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - loss: 0.4546 - y_reg_z_loss: 0.2256 - y_up_loss: 0.4577 - val_loss: 0.6422 - val_y_reg_z_loss: 0.2725 - val_y_up_loss: 0.7297 - learning_rate: 5.0000e-04
# Epoch 10/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - loss: 0.4084 - y_reg_z_loss: 0.1991 - y_up_loss: 0.4188 - val_loss: 0.6289 - val_y_reg_z_loss: 0.2741 - val_y_up_loss: 0.7086 - learning_rate: 5.0000e-04
# Epoch 11/120
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.4066 - y_reg_z_loss: 0.2060 - y_up_loss: 0.4010
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.4083 - y_reg_z_loss: 0.2073 - y_up_loss: 0.4029 - val_loss: 0.9066 - val_y_reg_z_loss: 0.4595 - val_y_up_loss: 0.8742 - learning_rate: 5.0000e-04
# Epoch 12/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.3537 - y_reg_z_loss: 0.1753 - y_up_loss: 0.3567 - val_loss: 0.7625 - val_y_reg_z_loss: 0.3673 - val_y_up_loss: 0.7580 - learning_rate: 2.5000e-04
# Epoch 13/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.3703 - y_reg_z_loss: 0.1841 - y_up_loss: 0.3725 - val_loss: 0.5561 - val_y_reg_z_loss: 0.2399 - val_y_up_loss: 0.6096 - learning_rate: 2.5000e-04
# Epoch 14/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.3311 - y_reg_z_loss: 0.1596 - y_up_loss: 0.3433 - val_loss: 0.7483 - val_y_reg_z_loss: 0.3677 - val_y_up_loss: 0.7279 - learning_rate: 2.5000e-04
# Epoch 15/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.3593 - y_reg_z_loss: 0.1733 - y_up_loss: 0.3719 - val_loss: 0.6599 - val_y_reg_z_loss: 0.2923 - val_y_up_loss: 0.7074 - learning_rate: 2.5000e-04
# Epoch 16/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step - loss: 0.3219 - y_reg_z_loss: 0.1563 - y_up_loss: 0.3309 - val_loss: 0.6278 - val_y_reg_z_loss: 0.2733 - val_y_up_loss: 0.6815 - learning_rate: 2.5000e-04
# Epoch 17/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.3410 - y_reg_z_loss: 0.1586 - y_up_loss: 0.3647 - val_loss: 0.6150 - val_y_reg_z_loss: 0.2588 - val_y_up_loss: 0.6862 - learning_rate: 2.5000e-04
# Epoch 18/120
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.3009 - y_reg_z_loss: 0.1514 - y_up_loss: 0.2989
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.3026 - y_reg_z_loss: 0.1525 - y_up_loss: 0.3006 - val_loss: 0.6514 - val_y_reg_z_loss: 0.2844 - val_y_up_loss: 0.7097 - learning_rate: 2.5000e-04
# Epoch 19/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.3029 - y_reg_z_loss: 0.1491 - y_up_loss: 0.3077 - val_loss: 0.6916 - val_y_reg_z_loss: 0.3192 - val_y_up_loss: 0.7167 - learning_rate: 1.2500e-04
# Epoch 20/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.3095 - y_reg_z_loss: 0.1558 - y_up_loss: 0.3074 - val_loss: 0.5975 - val_y_reg_z_loss: 0.2467 - val_y_up_loss: 0.6789 - learning_rate: 1.2500e-04
# Epoch 21/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - loss: 0.2815 - y_reg_z_loss: 0.1425 - y_up_loss: 0.2779 - val_loss: 0.6415 - val_y_reg_z_loss: 0.2874 - val_y_up_loss: 0.6839 - learning_rate: 1.2500e-04
# Epoch 22/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.2993 - y_reg_z_loss: 0.1519 - y_up_loss: 0.2947 - val_loss: 0.6470 - val_y_reg_z_loss: 0.2719 - val_y_up_loss: 0.7233 - learning_rate: 1.2500e-04
# Epoch 23/120
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.2947 - y_reg_z_loss: 0.1515 - y_up_loss: 0.2865
# Epoch 23: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.2959 - y_reg_z_loss: 0.1520 - y_up_loss: 0.2879 - val_loss: 0.5731 - val_y_reg_z_loss: 0.2301 - val_y_up_loss: 0.6662 - learning_rate: 1.2500e-04
# Epoch 24/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 0.2861 - y_reg_z_loss: 0.1326 - y_up_loss: 0.3071 - val_loss: 0.6168 - val_y_reg_z_loss: 0.2628 - val_y_up_loss: 0.6842 - learning_rate: 6.2500e-05
# Epoch 25/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.2980 - y_reg_z_loss: 0.1533 - y_up_loss: 0.2897 - val_loss: 0.5597 - val_y_reg_z_loss: 0.2240 - val_y_up_loss: 0.6517 - learning_rate: 6.2500e-05
#
# Done. Models trained for: ['BID.VN', 'CTG.VN', 'TCB.VN', 'VCB.VN']

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import (
    mean_squared_error, mean_absolute_error,
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, confusion_matrix
)

def safe_auc(y_true_bin, y_prob):
    if len(np.unique(y_true_bin)) < 2:
        return np.nan
    return roc_auc_score(y_true_bin, y_prob)

summary_rows = []

for tk in models.keys():
    X_train_seq, X_test_seq, y_train_seq, y_test_seq = splits[tk]
    model = models[tk]
    y_mu, y_sd = meta[tk]["y_mu"], meta[tk]["y_sd"]

    # ---- predict both heads ----
    y_reg_z_pred, y_up_prob = model.predict(X_test_seq, verbose=0)
    y_reg_z_pred = y_reg_z_pred.reshape(-1)
    y_up_prob    = y_up_prob.reshape(-1)

    # inverse transform regression
    y_pred = y_reg_z_pred * y_sd + y_mu

    # regression metrics
    mse  = mean_squared_error(y_test_seq, y_pred)
    rmse = np.sqrt(mse)
    mae  = mean_absolute_error(y_test_seq, y_pred)

    # direction metrics use y_up_prob with tuned threshold (use LAST 20% of train as val proxy)
    # We'll tune threshold on the *train tail* stored in the same run:
    # (simple approach: reuse your existing X_val,y_val by re-deriving from train)
    val_size = max(1, int(0.2 * len(X_train_seq)))
    X_val = X_train_seq[-val_size:]
    y_val = y_train_seq[-val_size:]
    y_val_true = (y_val > 0).astype(int)

    _, y_val_prob = model.predict(X_val, verbose=0)
    y_val_prob = y_val_prob.reshape(-1)

    best_t, best_f1 = tune_threshold(y_val_true, y_val_prob, lo=0.3, hi=0.7, n=81)

    y_true_bin = (y_test_seq > 0).astype(int)
    y_pred_bin = (y_up_prob > best_t).astype(int)

    directional_acc = accuracy_score(y_true_bin, y_pred_bin)
    precision = precision_score(y_true_bin, y_pred_bin, zero_division=0)
    recall    = recall_score(y_true_bin, y_pred_bin, zero_division=0)
    f1        = f1_score(y_true_bin, y_pred_bin, zero_division=0)
    auc       = safe_auc(y_true_bin, y_up_prob)

    cm = confusion_matrix(y_true_bin, y_pred_bin, labels=[0,1])
    tn, fp, fn, tp = cm.ravel()

    summary_rows.append({
        "Ticker": tk,
        "N_test_seq": len(y_test_seq),
        "RMSE": rmse,
        "MAE": mae,
        "MSE": mse,
        "Directional_Acc": directional_acc,
        "Precision_Up": precision,
        "Recall_Up": recall,
        "F1_Up": f1,
        "AUC": auc,
        "Best_Threshold": best_t,
        "Val_F1_at_bestT": best_f1,
        "TN": tn, "FP": fp, "FN": fn, "TP": tp
    })

summary_df = pd.DataFrame(summary_rows).sort_values("RMSE").reset_index(drop=True)
display_cols = ["Ticker","N_test_seq","RMSE","MAE","Directional_Acc","Precision_Up","Recall_Up","F1_Up","AUC","Best_Threshold","Val_F1_at_bestT","TN","FP","FN","TP"]
print(summary_df[display_cols].to_string(index=False))

import matplotlib.pyplot as plt
import numpy as np

def plot_actual_vs_pred_all(
    tickers,
    splits,
    models,
    meta,
    df,
    n_last=200,
    figsize=(16, 8)
):
    """
    Vẽ Actual vs Predicted return cho nhiều mã (multi-panel)
    tickers: list ticker, ví dụ ["VCB.VN","BID.VN","TCB.VN","CTG.VN"]
    """

    n = len(tickers)
    nrows = int(np.ceil(n / 2))
    ncols = 2

    fig, axes = plt.subplots(nrows, ncols, figsize=figsize, sharex=False)
    axes = axes.flatten()

    for i, tk in enumerate(tickers):
        ax = axes[i]

        X_train_seq, X_test_seq, y_train_seq, y_test_seq = splits[tk]
        model = models[tk]
        y_mu, y_sd = meta[tk]["y_mu"], meta[tk]["y_sd"]

        # Predict (regression head)
        y_reg_z_pred, _ = model.predict(X_test_seq, verbose=0)
        y_pred = y_reg_z_pred.reshape(-1) * y_sd + y_mu

        # Dates corresponding to test
        dft = df[df["ticker"] == tk].sort_values("date").reset_index(drop=True)
        test_dates = dft["date"].iloc[-len(y_test_seq):].values

        # Take last N points
        if n_last is not None:
            y_test_plot = y_test_seq[-n_last:]
            y_pred_plot = y_pred[-n_last:]
            date_plot   = test_dates[-n_last:]
        else:
            y_test_plot = y_test_seq
            y_pred_plot = y_pred
            date_plot   = test_dates

        ax.plot(date_plot, y_test_plot, label="Actual", linewidth=2)
        ax.plot(date_plot, y_pred_plot, label="Predicted", linewidth=2, alpha=0.85)
        ax.axhline(0, linestyle="--", linewidth=1, alpha=0.7)

        ax.set_title(
            f"{tk} | RMSE={np.sqrt(np.mean((y_test_plot - y_pred_plot)**2)):.4f}",
            fontsize=11
        )
        ax.grid(alpha=0.3)

        if i % 2 == 0:
            ax.set_ylabel("Return")

        if i >= (nrows - 1) * ncols:
            ax.set_xlabel("Date")

        ax.legend(fontsize=9)

    # Remove empty subplots if any
    for j in range(i + 1, len(axes)):
        fig.delaxes(axes[j])

    fig.suptitle(
        "Actual vs Transformer Predicted Return (Test Set)",
        fontsize=14,
        y=1.02
    )

    plt.tight_layout()
    plt.show()

print("📊 ACTUAL vs TRANSFORMER PREDICTED RETURN")
plot_actual_vs_pred_all(
    tickers=["VCB.VN", "BID.VN", "TCB.VN", "CTG.VN"],
    splits=splits,
    models=models,
    meta=meta,
    df=df,
    n_last=200
)
# Out:
# Ticker  N_test_seq     RMSE      MAE  Directional_Acc  Precision_Up  Recall_Up    F1_Up      AUC  Best_Threshold  Val_F1_at_bestT  TN  FP  FN  TP
# BID.VN         202 0.004606 0.003459         0.722772      0.649123   0.822222 0.725490 0.797421           0.355         0.816901  72  40  16  74
# VCB.VN         202 0.005361 0.004496         0.732673      0.696203   0.647059 0.670732 0.799095           0.300         0.784946  93  24  30  55
# TCB.VN         184 0.007787 0.006007         0.586957      0.635762   0.820513 0.716418 0.545733           0.300         0.730769  12  55  21  96
# CTG.VN         202 0.012058 0.010518         0.559406      0.947368   0.169811 0.288000 0.750295           0.310         0.513514  95   1  88  18
# 📊 ACTUAL vs TRANSFORMER PREDICTED RETURN

# %% [markdown]
# # Hybrid Transformer

# %%
# =========================
# HYBRID: FFT + Wavelet + Transformer (Multi-input, multitask)
# =========================

import numpy as np
import pandas as pd
import pywt
import tensorflow as tf
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import (
    mean_squared_error, mean_absolute_error,
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, confusion_matrix
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# -------------------------
# 1) Wavelet features (from your snippet)
# -------------------------
def rolling_wavelet_features(x_window, wavelet="db4", level=3):
    """
    DWT trên cửa sổ returns:
      - năng lượng approx (A) và detail (D1..Dlevel)
      - tỷ lệ năng lượng detail/total
      - denoised_last: giá trị denoised ở điểm cuối (proxy)
    """
    x = np.asarray(x_window, dtype=np.float32)
    x = x[np.isfinite(x)] # Remove NaNs from window

    L = len(x)
    if L < 16 or np.allclose(x, 0): # Ensure sufficient data after NaN removal
        return {
            "wav_EA": 0.0,
            **{f"wav_ED{i}": 0.0 for i in range(1, level+1)},
            "wav_detail_ratio": 0.0,
            "wav_denoised_last": 0.0
        }

    x = x - np.mean(x) # Demean after NaN removal

    coeffs = pywt.wavedec(x, wavelet=wavelet, level=level, mode="symmetric")
    cA = coeffs[0]
    cDs = coeffs[1:]  # [cD_level, ..., cD1]

    EA = float(np.sum(cA**2))
    ED = [float(np.sum(cd**2)) for cd in cDs]
    total = EA + sum(ED) + 1e-12
    detail_ratio = float(sum(ED) / total)

    # denoise: soft-threshold detail coeffs (universal threshold)
    cD1 = cDs[-1]
    # Check for NaN in cD1 before median calculation
    if np.all(np.isnan(cD1)) or len(cD1) == 0:
        sigma = 1e-12
    else:
        sigma = np.median(np.abs(cD1 - np.median(cD1[np.isfinite(cD1)]))) / 0.6745 + 1e-12 # Calculate median only on finite values

    uthresh = sigma * np.sqrt(2*np.log(L))

    coeffs_dn = [cA]
    for cd in cDs:
        coeffs_dn.append(pywt.threshold(cd, value=uthresh, mode="soft"))

    x_dn = pywt.waverec(coeffs_dn, wavelet=wavelet, mode="symmetric")
    denoised_last = float(x_dn[-1]) if len(x_dn) > 0 and np.isfinite(x_dn[-1]) else 0.0 # Check for finite

    out = {"wav_EA": EA if np.isfinite(EA) else 0.0}
    ED_reversed = list(reversed(ED))
    for i in range(1, level+1):
        out[f"wav_ED{i}"] = ED_reversed[i-1] if np.isfinite(ED_reversed[i-1]) else 0.0 # Check for finite
    out["wav_detail_ratio"] = detail_ratio if np.isfinite(detail_ratio) else 0.0
    out["wav_denoised_last"] = denoised_last
    return out

# -------------------------
# 2) FFT features
# -------------------------
def rolling_fft_features(x_window, n_top=3):
    """
    FFT trên cửa sổ returns (demean):
      - spectral_energy: tổng năng lượng phổ
      - low_band_ratio: tỷ lệ năng lượng tần số thấp (proxy trend/slow cycles)
      - spectral_centroid: trọng tâm phổ
      - topk_mag_mean: trung bình biên độ top-k tần số trội (bỏ DC)
    """
    x = np.asarray(x_window, dtype=np.float32)
    x = x[np.isfinite(x)] # Remove NaNs from window

    L = len(x)
    if L < 16 or np.allclose(x, 0): # Ensure sufficient data after NaN removal
        return {
            "fft_energy": 0.0,
            "fft_low_ratio": 0.0,
            "fft_centroid": 0.0,
            "fft_topk_mag": 0.0
        }

    x = x - np.mean(x) # Demean after NaN removal

    # rfft -> non-negative frequencies
    X = np.fft.rfft(x)
    mag = np.abs(X).astype(np.float32)
    # zero out DC component for top-k
    mag_nodc = mag.copy()
    if len(mag_nodc) > 0:
        mag_nodc[0] = 0.0

    power = mag**2
    total_energy = float(np.sum(power) + 1e-12)

    # define "low band": first ~10% bins (excluding DC) as proxy
    n_bins = len(mag)
    low_end = max(2, int(0.10 * n_bins))
    low_energy = float(np.sum(power[1:low_end]) + 1e-12)
    low_ratio = float(low_energy / total_energy)

    # spectral centroid (frequency-weighted magnitude)
    # Check for zero sum of mag to avoid division by zero
    sum_mag = np.sum(mag)
    if sum_mag == 0:
        centroid = 0.0
    else:
        freqs = np.arange(n_bins, dtype=np.float32)
        centroid = float(np.sum(freqs * mag) / (sum_mag + 1e-12))

    # top-k magnitude mean
    k = min(n_top, max(1, n_bins-1))

    # Filter out NaNs from mag_nodc before partitioning/mean
    finite_mag_nodc = mag_nodc[np.isfinite(mag_nodc)]

    if len(finite_mag_nodc) == 0:
        topk_mag = 0.0
    else:
        k_actual = min(k, len(finite_mag_nodc))
        topk = np.partition(finite_mag_nodc, -k_actual)[-k_actual:]
        topk_mag = float(np.mean(topk)) if len(topk) else 0.0

    return {
        "fft_energy": total_energy if np.isfinite(total_energy) else 0.0,
        "fft_low_ratio": low_ratio if np.isfinite(low_ratio) else 0.0,
        "fft_centroid": centroid if np.isfinite(centroid) else 0.0,
        "fft_topk_mag": topk_mag if np.isfinite(topk_mag) else 0.0
    }

# -------------------------
# 3) Build rolling FFT+Wavelet aux features (past-only)
# -------------------------
def add_fft_wavelet_aux_features(df_one_ticker, ret_col="return", aux_window=64, wavelet="db4", level=3):
    """
    Tạo aux features tại thời điểm t bằng cửa sổ returns quá khứ [t-aux_window .. t-1].
    -> tránh leakage: dùng shift(1).
    """
    d = df_one_ticker.sort_values("date").reset_index(drop=True).copy()
    r = d[ret_col].astype(np.float32)

    # past-only series for rolling window
    r_past = r.shift(1)

    aux_rows = []
    for i in range(len(d)):
        if i < aux_window:
            aux_rows.append({**rolling_fft_features(np.zeros(aux_window)), **rolling_wavelet_features(np.zeros(aux_window), wavelet, level)})
        else:
            win = r_past.iloc[i-aux_window:i].values
            aux_rows.append({**rolling_fft_features(win), **rolling_wavelet_features(win, wavelet, level)})

    aux_df = pd.DataFrame(aux_rows)
    return pd.concat([d, aux_df], axis=1)

# -------------------------
# 4) Sequence builder: X_seq + X_aux align
# -------------------------
def create_sequences_with_aux(X_seq_features, X_aux_features, y, seq_len):
    """
    X_seq_features: (T, n_seq_feat)
    X_aux_features: (T, n_aux_feat) -- aux at time t
    y: (T,)
    Create samples at index i where input sequence is [i-seq_len..i-1], target is y[i], aux is aux[i]
    """
    Xs, Xa, ys = [], [], []
    for i in range(seq_len, len(y)):
        Xs.append(X_seq_features[i-seq_len:i])
        Xa.append(X_aux_features[i])
        ys.append(y[i])
    return np.array(Xs), np.array(Xa), np.array(ys)

# -------------------------
# 5) Transformer blocks (as yours)
# -------------------------
class PositionalEncoding(tf.keras.layers.Layer):
    def __init__(self, position: int, d_model: int):
        super().__init__()
        pos = np.arange(position)[:, np.newaxis]
        i   = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        angle_rads  = pos * angle_rates
        angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
        angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.pos_encoding = tf.constant(angle_rads[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        return x + self.pos_encoding[:, :tf.shape(x)[1], :]

def transformer_encoder(x, num_heads, key_dim, ff_dim, dropout=0.2):
    attn_out = tf.keras.layers.MultiHeadAttention(num_heads=num_heads, key_dim=key_dim, dropout=dropout)(x, x)
    attn_out = tf.keras.layers.Dropout(dropout)(attn_out)
    x = tf.keras.layers.Add()([x, attn_out])
    x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(x)

    ff = tf.keras.layers.Dense(ff_dim, activation="relu")(x)
    ff = tf.keras.layers.Dropout(dropout)(ff)
    ff = tf.keras.layers.Dense(x.shape[-1])(ff)
    x = tf.keras.layers.Add()([x, ff])
    x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(x)
    return x

# -------------------------
# 6) Hybrid model: Transformer(seq) + MLP(aux FFT/Wavelet) -> concat -> multitask heads
# -------------------------
def build_hybrid_fft_wav_transformer(
    seq_input_shape,     # (LOOKBACK, n_seq_feat)
    aux_input_dim,       # n_aux_feat
    d_model=64,
    num_heads=4,
    ff_dim=128,
    num_blocks=3,
    dropout=0.2,
    use_conv_frontend=True,
    aux_mlp_units=(64, 32)
):
    seq_in = tf.keras.Input(shape=seq_input_shape, name="seq_in")
    aux_in = tf.keras.Input(shape=(aux_input_dim,), name="aux_in")

    # --- Transformer branch ---
    x = tf.keras.layers.Dense(d_model)(seq_in)
    if use_conv_frontend:
        x = tf.keras.layers.Conv1D(filters=d_model, kernel_size=3, padding="causal", activation="relu")(x)
        x = tf.keras.layers.Dropout(dropout)(x)

    x = PositionalEncoding(position=seq_input_shape[0], d_model=d_model)(x)

    key_dim = max(8, d_model // num_heads)
    for _ in range(num_blocks):
        x = transformer_encoder(x, num_heads=num_heads, key_dim=key_dim, ff_dim=ff_dim, dropout=dropout)

    x = tf.keras.layers.GlobalAveragePooling1D()(x)
    x = tf.keras.layers.Dropout(dropout)(x)

    # --- Aux branch (FFT+Wavelet) ---
    a = aux_in
    a = tf.keras.layers.LayerNormalization()(a)
    for u in aux_mlp_units:
        a = tf.keras.layers.Dense(u, activation="relu")(a)
        a = tf.keras.layers.Dropout(dropout)(a)

    # --- Fusion ---
    h = tf.keras.layers.Concatenate()([x, a])
    h = tf.keras.layers.Dense(64, activation="relu")(h)
    h = tf.keras.layers.Dropout(dropout)(h)

    # Head 1: regression (standardized)
    y_reg_z = tf.keras.layers.Dense(1, name="y_reg_z")(h)
    # Head 2: direction
    y_up = tf.keras.layers.Dense(1, activation="sigmoid", name="y_up")(h)

    return tf.keras.Model([seq_in, aux_in], [y_reg_z, y_up])

# -------------------------
# 7) Weighted BCE + threshold tuning (reuse)
# -------------------------
def make_weighted_bce(w_pos, w_neg):
    def weighted_bce(y_true, y_pred):
        bce = tf.keras.backend.binary_crossentropy(y_true, y_pred)
        w = y_true * w_pos + (1.0 - y_true) * w_neg
        return tf.reduce_mean(bce * w)
    return weighted_bce

from sklearn.metrics import f1_score

def tune_threshold(y_true_bin, y_prob, lo=0.2, hi=0.8, n=121):
    ths = np.linspace(lo, hi, n)
    best_t, best_f1 = 0.5, -1
    for t in ths:
        f1 = f1_score(y_true_bin, (y_prob > t).astype(int), zero_division=0)
        if f1 > best_f1:
            best_f1, best_t = f1, t
    return best_t, best_f1

def safe_auc(y_true_bin, y_prob):
    if len(np.unique(y_true_bin)) < 2:
        return np.nan
    return roc_auc_score(y_true_bin, y_prob)

# =========================
# 8) TRAIN + EVALUATE per ticker
# =========================
LOOKBACK = 30
AUX_WINDOW = 64          # cửa sổ FFT/Wavelet (thường 64/96/128)
WAVELET = "db4"
WAV_LEVEL = 3

# df: your final features table must already exist, same as your pipeline:
# required columns: ["date","ticker","target"] + your feature columns including "return"
df = df.copy()
df["date"] = pd.to_datetime(df["date"])

non_feature = ['date', 'ticker', 'target']
base_feature_cols = [c for c in df.columns if c not in non_feature]  # includes return + TA features

models, scalers, splits, meta = {}, {}, {}, {}

summary_rows = []

for tk, dft in df.groupby("ticker"):
    dft = dft.sort_values("date").reset_index(drop=True)

    # add aux FFT+Wavelet features (past-only)
    dft = add_fft_wavelet_aux_features(
        dft, ret_col="return",
        aux_window=AUX_WINDOW,
        wavelet=WAVELET, level=WAV_LEVEL
    )

    aux_cols = [c for c in dft.columns if c.startswith("fft_") or c.startswith("wav_")]
    if len(aux_cols) == 0:
        raise ValueError("No aux cols found. Check prefix names.")

    # build matrices
    X_seq_raw = dft[base_feature_cols].values.astype(np.float32)
    X_aux_raw = dft[aux_cols].values.astype(np.float32)
    y_raw     = dft["target"].values.astype(np.float32)

    if len(dft) < (LOOKBACK + 80):
        print(f"⚠️ {tk}: dữ liệu quá ít ({len(dft)} dòng) -> bỏ qua")
        continue

    split_index = int(len(dft) * 0.8)
    X_seq_train_raw, X_seq_test_raw = X_seq_raw[:split_index], X_seq_raw[split_index:]
    X_aux_train_raw, X_aux_test_raw = X_aux_raw[:split_index], X_aux_raw[split_index:]
    y_train_raw, y_test_raw         = y_raw[:split_index], y_raw[split_index:]

    # scale seq + aux separately (robust scaling is good for finance)
    seq_scaler = RobustScaler()
    aux_scaler = RobustScaler()

    X_seq_train = seq_scaler.fit_transform(X_seq_train_raw)
    X_seq_test  = seq_scaler.transform(X_seq_test_raw)

    X_aux_train = aux_scaler.fit_transform(X_aux_train_raw)
    X_aux_test  = aux_scaler.transform(X_aux_test_raw)

    # create aligned sequences
    Xtr_seq, Xtr_aux, ytr = create_sequences_with_aux(X_seq_train, X_aux_train, y_train_raw, LOOKBACK)
    Xte_seq, Xte_aux, yte = create_sequences_with_aux(X_seq_test,  X_aux_test,  y_test_raw,  LOOKBACK)

    # validation tail from train
    val_size = max(1, int(0.2 * len(Xtr_seq)))
    X_tr_seq, X_val_seq = Xtr_seq[:-val_size], Xtr_seq[-val_size:]
    X_tr_aux, X_val_aux = Xtr_aux[:-val_size], Xtr_aux[-val_size:]
    y_tr, y_val         = ytr[:-val_size], ytr[-val_size:]

    # standardize regression target on train only
    y_mu = float(np.mean(y_tr))
    y_sd = float(np.std(y_tr) + 1e-8)
    y_tr_z  = ((y_tr  - y_mu) / y_sd).astype(np.float32)
    y_val_z = ((y_val - y_mu) / y_sd).astype(np.float32)

    # direction labels
    y_tr_up  = (y_tr > 0).astype(np.float32)
    y_val_up = (y_val > 0).astype(np.float32)

    # weighted BCE
    pos = float(y_tr_up.mean())
    w_pos = 0.5 / (pos + 1e-8)
    w_neg = 0.5 / (1.0 - pos + 1e-8)
    w_bce = make_weighted_bce(w_pos=w_pos, w_neg=w_neg)

    # build hybrid model
    model = build_hybrid_fft_wav_transformer(
        seq_input_shape=(LOOKBACK, Xtr_seq.shape[2]),
        aux_input_dim=Xtr_aux.shape[1],
        d_model=64, num_heads=4, ff_dim=128, num_blocks=3,
        dropout=0.2, use_conv_frontend=True,
        aux_mlp_units=(64, 32)
    )

    opt = Adam(learning_rate=1e-3, clipnorm=1.0)
    model.compile(
        optimizer=opt,
        loss={"y_reg_z": tf.keras.losses.Huber(delta=1.0), "y_up": w_bce},
        loss_weights={"y_reg_z": 1.0, "y_up": 0.5}
    )

    early_stop = EarlyStopping(monitor="val_loss", patience=12, restore_best_weights=True)
    rlr = ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=5, min_lr=1e-5, verbose=1)

    print(f"\n===== Training HYBRID FFT+WAV+Transformer for {tk} | UpRatio={pos:.3f} =====")
    model.fit(
        [X_tr_seq, X_tr_aux], {"y_reg_z": y_tr_z, "y_up": y_tr_up},
        validation_data=([X_val_seq, X_val_aux], {"y_reg_z": y_val_z, "y_up": y_val_up}),
        epochs=120, batch_size=32,
        callbacks=[early_stop, rlr],
        verbose=1
    )

    # store
    models[tk] = model
    scalers[tk] = {"seq": seq_scaler, "aux": aux_scaler}
    splits[tk] = (Xtr_seq, Xtr_aux, Xte_seq, Xte_aux, ytr, yte)
    meta[tk] = {"y_mu": y_mu, "y_sd": y_sd, "up_ratio": pos, "w_pos": w_pos, "w_neg": w_neg}

    # =========================
    # Evaluate
    # =========================
    y_reg_z_pred, y_up_prob = model.predict([Xte_seq, Xte_aux], verbose=0)
    y_reg_z_pred = y_reg_z_pred.reshape(-1)
    y_up_prob    = y_up_prob.reshape(-1)

    y_pred = y_reg_z_pred * y_sd + y_mu

    rmse = float(np.sqrt(mean_squared_error(yte, y_pred)))
    mae  = float(mean_absolute_error(yte, y_pred))

    # tune threshold on train tail (val proxy)
    _, y_val_prob = model.predict([X_val_seq, X_val_aux], verbose=0)
    y_val_prob = y_val_prob.reshape(-1)
    y_val_true = (y_val > 0).astype(int)

    best_t, best_f1 = tune_threshold(y_val_true, y_val_prob, lo=0.2, hi=0.8, n=121)

    y_true_bin = (yte > 0).astype(int)
    y_pred_bin = (y_up_prob > best_t).astype(int)

    directional_acc = float(accuracy_score(y_true_bin, y_pred_bin))
    precision = float(precision_score(y_true_bin, y_pred_bin, zero_division=0))
    recall    = float(recall_score(y_true_bin, y_pred_bin, zero_division=0))
    f1        = float(f1_score(y_true_bin, y_pred_bin, zero_division=0))
    auc       = float(safe_auc(y_true_bin, y_up_prob))

    tn, fp, fn, tp = confusion_matrix(y_true_bin, y_pred_bin, labels=[0,1]).ravel()

    summary_rows.append({
        "Ticker": tk,
        "N_test_seq": len(yte),
        "RMSE": rmse,
        "MAE": mae,
        "Directional_Acc": directional_acc,
        "Precision_Up": precision,
        "Recall_Up": recall,
        "F1_Up": f1,
        "AUC": auc,
        "Best_Threshold": float(best_t),
        "Val_F1_at_bestT": float(best_f1),
        "TN": int(tn), "FP": int(fp), "FN": int(fn), "TP": int(tp)
    })

summary_df = pd.DataFrame(summary_rows).sort_values("RMSE").reset_index(drop=True)
print(summary_df.to_string(index=False))

print("📊 ACTUAL vs HYBRID TRANSFORMER PREDICTED RETURN (4 STOCKS)")

import matplotlib.pyplot as plt

# store predictions for later use (global)
pred_store = {}

# ✅ ưu tiên đúng 4 mã bạn dùng trong báo cáo
preferred = ["VCB.VN", "BID.VN", "CTG.VN", "TCB.VN"]

# lấy những mã thực sự tồn tại trong splits
tickers = [t for t in preferred if t in splits]

# nếu thiếu (ví dụ bạn train ít mã), bổ sung bằng các mã còn lại trong splits
if len(tickers) < 4:
    for t in splits.keys():
        if t not in tickers:
            tickers.append(t)
        if len(tickers) == 4:
            break

# nếu vẫn <4 thì vẽ theo số lượng thực tế
n = len(tickers)
if n == 0:
    raise ValueError("splits is empty. Bạn cần train xong và có dữ liệu trong splits trước khi plot.")

rows = 2
cols = 2
fig, axes = plt.subplots(rows, cols, figsize=(16, 8))
axes = axes.flatten()

for i in range(rows * cols):
    ax = axes[i]
    if i >= n:
        ax.axis("off")
        continue

    tk = tickers[i]
    (Xtr_seq, Xtr_aux, Xte_seq, Xte_aux, ytr, yte) = splits[tk]
    model = models[tk]
    y_mu  = meta[tk]["y_mu"]
    y_sd  = meta[tk]["y_sd"]

    # predict
    y_reg_z_pred, y_up_prob = model.predict([Xte_seq, Xte_aux], verbose=0)
    y_reg_z_pred = y_reg_z_pred.reshape(-1)
    y_up_prob    = y_up_prob.reshape(-1)

    # denormalize
    y_pred = y_reg_z_pred * y_sd + y_mu

    # save
    pred_store[tk] = {"y_true": yte, "y_pred": y_pred, "y_up_prob": y_up_prob}

    # plot
    ax.plot(yte, label="Actual Return", linewidth=1.4)
    ax.plot(y_pred, label="Predicted Return (Hybrid)", linewidth=1.4)
    ax.set_title(f"{tk} | Actual vs Hybrid Predicted Return")
    ax.set_xlabel("Test Time Index")
    ax.set_ylabel("Return")
    ax.grid(True, alpha=0.3)
    ax.legend()

plt.tight_layout()
plt.show()
# Out:
# ===== Training HYBRID FFT+WAV+Transformer for BID.VN | UpRatio=0.524 =====
# Epoch 1/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 27s 122ms/step - loss: 0.9601 - y_reg_z_loss: 0.5934 - y_up_loss: 0.7324 - val_loss: 0.5122 - val_y_reg_z_loss: 0.1878 - val_y_up_loss: 0.6741 - learning_rate: 0.0010
# Epoch 2/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step - loss: 0.7390 - y_reg_z_loss: 0.3898 - y_up_loss: 0.6986 - val_loss: 0.5300 - val_y_reg_z_loss: 0.2279 - val_y_up_loss: 0.6641 - learning_rate: 0.0010
# Epoch 3/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.6991 - y_reg_z_loss: 0.3623 - y_up_loss: 0.6730 - val_loss: 0.5321 - val_y_reg_z_loss: 0.2363 - val_y_up_loss: 0.6659 - learning_rate: 0.0010
# Epoch 4/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.6841 - y_reg_z_loss: 0.3555 - y_up_loss: 0.6568 - val_loss: 0.4847 - val_y_reg_z_loss: 0.1914 - val_y_up_loss: 0.6324 - learning_rate: 0.0010
# Epoch 5/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.6486 - y_reg_z_loss: 0.3439 - y_up_loss: 0.6091 - val_loss: 0.5392 - val_y_reg_z_loss: 0.2481 - val_y_up_loss: 0.6600 - learning_rate: 0.0010
# Epoch 6/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - loss: 0.6545 - y_reg_z_loss: 0.3469 - y_up_loss: 0.6150 - val_loss: 0.5522 - val_y_reg_z_loss: 0.2606 - val_y_up_loss: 0.6769 - learning_rate: 0.0010
# Epoch 7/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.5844 - y_reg_z_loss: 0.3017 - y_up_loss: 0.5651 - val_loss: 0.5737 - val_y_reg_z_loss: 0.2692 - val_y_up_loss: 0.7073 - learning_rate: 0.0010
# Epoch 8/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step - loss: 0.5476 - y_reg_z_loss: 0.2809 - y_up_loss: 0.5332 - val_loss: 0.4774 - val_y_reg_z_loss: 0.2003 - val_y_up_loss: 0.6308 - learning_rate: 0.0010
# Epoch 9/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - loss: 0.5214 - y_reg_z_loss: 0.2550 - y_up_loss: 0.5325 - val_loss: 0.5117 - val_y_reg_z_loss: 0.2296 - val_y_up_loss: 0.6542 - learning_rate: 0.0010
# Epoch 10/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.5109 - y_reg_z_loss: 0.2619 - y_up_loss: 0.4976 - val_loss: 0.5476 - val_y_reg_z_loss: 0.2544 - val_y_up_loss: 0.6791 - learning_rate: 0.0010
# Epoch 11/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.4444 - y_reg_z_loss: 0.2189 - y_up_loss: 0.4513 - val_loss: 0.4978 - val_y_reg_z_loss: 0.2386 - val_y_up_loss: 0.5990 - learning_rate: 0.0010
# Epoch 12/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.4772 - y_reg_z_loss: 0.2442 - y_up_loss: 0.4655 - val_loss: 0.4936 - val_y_reg_z_loss: 0.2082 - val_y_up_loss: 0.6437 - learning_rate: 0.0010
# Epoch 13/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.4614 - y_reg_z_loss: 0.2330 - y_up_loss: 0.4570
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - loss: 0.4597 - y_reg_z_loss: 0.2321 - y_up_loss: 0.4555 - val_loss: 0.5294 - val_y_reg_z_loss: 0.2210 - val_y_up_loss: 0.6590 - learning_rate: 0.0010
# Epoch 14/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - loss: 0.3991 - y_reg_z_loss: 0.2047 - y_up_loss: 0.3881 - val_loss: 0.5770 - val_y_reg_z_loss: 0.2627 - val_y_up_loss: 0.6912 - learning_rate: 5.0000e-04
# Epoch 15/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.3782 - y_reg_z_loss: 0.1908 - y_up_loss: 0.3745 - val_loss: 0.5526 - val_y_reg_z_loss: 0.2278 - val_y_up_loss: 0.6800 - learning_rate: 5.0000e-04
# Epoch 16/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.3599 - y_reg_z_loss: 0.1845 - y_up_loss: 0.3506 - val_loss: 0.6040 - val_y_reg_z_loss: 0.2469 - val_y_up_loss: 0.7633 - learning_rate: 5.0000e-04
# Epoch 17/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.3401 - y_reg_z_loss: 0.1750 - y_up_loss: 0.3301 - val_loss: 0.6580 - val_y_reg_z_loss: 0.2756 - val_y_up_loss: 0.8139 - learning_rate: 5.0000e-04
# Epoch 18/120
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.3342 - y_reg_z_loss: 0.1662 - y_up_loss: 0.3361
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.3344 - y_reg_z_loss: 0.1660 - y_up_loss: 0.3363 - val_loss: 0.5796 - val_y_reg_z_loss: 0.2385 - val_y_up_loss: 0.7291 - learning_rate: 5.0000e-04
# Epoch 19/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - loss: 0.3273 - y_reg_z_loss: 0.1701 - y_up_loss: 0.3145 - val_loss: 0.6110 - val_y_reg_z_loss: 0.2534 - val_y_up_loss: 0.7772 - learning_rate: 2.5000e-04
# Epoch 20/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 0.3150 - y_reg_z_loss: 0.1608 - y_up_loss: 0.3080 - val_loss: 0.6219 - val_y_reg_z_loss: 0.2584 - val_y_up_loss: 0.7836 - learning_rate: 2.5000e-04
#
# ===== Training HYBRID FFT+WAV+Transformer for CTG.VN | UpRatio=0.517 =====
# Epoch 1/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 25s 118ms/step - loss: 0.8262 - y_reg_z_loss: 0.4677 - y_up_loss: 0.7161 - val_loss: 0.5389 - val_y_reg_z_loss: 0.2079 - val_y_up_loss: 0.7072 - learning_rate: 0.0010
# Epoch 2/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.7056 - y_reg_z_loss: 0.3718 - y_up_loss: 0.6669 - val_loss: 0.6254 - val_y_reg_z_loss: 0.2725 - val_y_up_loss: 0.8067 - learning_rate: 0.0010
# Epoch 3/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.6637 - y_reg_z_loss: 0.3477 - y_up_loss: 0.6322 - val_loss: 0.6950 - val_y_reg_z_loss: 0.3164 - val_y_up_loss: 0.8683 - learning_rate: 0.0010
# Epoch 4/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.6216 - y_reg_z_loss: 0.3191 - y_up_loss: 0.6047 - val_loss: 0.6388 - val_y_reg_z_loss: 0.2787 - val_y_up_loss: 0.8101 - learning_rate: 0.0010
# Epoch 5/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.6050 - y_reg_z_loss: 0.3088 - y_up_loss: 0.5922 - val_loss: 0.7027 - val_y_reg_z_loss: 0.3355 - val_y_up_loss: 0.8382 - learning_rate: 0.0010
# Epoch 6/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.5690 - y_reg_z_loss: 0.2843 - y_up_loss: 0.5693
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - loss: 0.5696 - y_reg_z_loss: 0.2848 - y_up_loss: 0.5693 - val_loss: 0.7662 - val_y_reg_z_loss: 0.3273 - val_y_up_loss: 0.9960 - learning_rate: 0.0010
# Epoch 7/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.5476 - y_reg_z_loss: 0.2815 - y_up_loss: 0.5324 - val_loss: 0.8812 - val_y_reg_z_loss: 0.4259 - val_y_up_loss: 1.0412 - learning_rate: 5.0000e-04
# Epoch 8/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.5395 - y_reg_z_loss: 0.2793 - y_up_loss: 0.5199 - val_loss: 0.8734 - val_y_reg_z_loss: 0.4166 - val_y_up_loss: 1.0494 - learning_rate: 5.0000e-04
# Epoch 9/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.5172 - y_reg_z_loss: 0.2628 - y_up_loss: 0.5083 - val_loss: 0.8931 - val_y_reg_z_loss: 0.3972 - val_y_up_loss: 1.1375 - learning_rate: 5.0000e-04
# Epoch 10/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.5026 - y_reg_z_loss: 0.2567 - y_up_loss: 0.4910 - val_loss: 0.8141 - val_y_reg_z_loss: 0.3423 - val_y_up_loss: 1.0825 - learning_rate: 5.0000e-04
# Epoch 11/120
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.4799 - y_reg_z_loss: 0.2428 - y_up_loss: 0.4741
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.4782 - y_reg_z_loss: 0.2419 - y_up_loss: 0.4718 - val_loss: 0.8695 - val_y_reg_z_loss: 0.3845 - val_y_up_loss: 1.1419 - learning_rate: 5.0000e-04
# Epoch 12/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 0.4615 - y_reg_z_loss: 0.2350 - y_up_loss: 0.4525 - val_loss: 0.9609 - val_y_reg_z_loss: 0.4360 - val_y_up_loss: 1.2313 - learning_rate: 2.5000e-04
# Epoch 13/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 0.4500 - y_reg_z_loss: 0.2318 - y_up_loss: 0.4359 - val_loss: 0.9083 - val_y_reg_z_loss: 0.3952 - val_y_up_loss: 1.1970 - learning_rate: 2.5000e-04
#
# ===== Training HYBRID FFT+WAV+Transformer for TCB.VN | UpRatio=0.555 =====
# Epoch 1/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 179ms/step - loss: 0.7978 - y_reg_z_loss: 0.4383 - y_up_loss: 0.7182 - val_loss: 0.4712 - val_y_reg_z_loss: 0.1162 - val_y_up_loss: 0.6901 - learning_rate: 0.0010
# Epoch 2/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.6575 - y_reg_z_loss: 0.3327 - y_up_loss: 0.6493 - val_loss: 0.4921 - val_y_reg_z_loss: 0.1443 - val_y_up_loss: 0.6850 - learning_rate: 0.0010
# Epoch 3/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.5901 - y_reg_z_loss: 0.2850 - y_up_loss: 0.6098 - val_loss: 0.4837 - val_y_reg_z_loss: 0.1316 - val_y_up_loss: 0.6930 - learning_rate: 0.0010
# Epoch 4/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.5788 - y_reg_z_loss: 0.2845 - y_up_loss: 0.5879 - val_loss: 0.4599 - val_y_reg_z_loss: 0.1106 - val_y_up_loss: 0.6843 - learning_rate: 0.0010
# Epoch 5/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.5333 - y_reg_z_loss: 0.2540 - y_up_loss: 0.5583 - val_loss: 0.4927 - val_y_reg_z_loss: 0.1306 - val_y_up_loss: 0.7030 - learning_rate: 0.0010
# Epoch 6/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.5602 - y_reg_z_loss: 0.2759 - y_up_loss: 0.5682 - val_loss: 0.4573 - val_y_reg_z_loss: 0.1096 - val_y_up_loss: 0.6902 - learning_rate: 0.0010
# Epoch 7/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - loss: 0.5375 - y_reg_z_loss: 0.2598 - y_up_loss: 0.5548 - val_loss: 0.4825 - val_y_reg_z_loss: 0.1230 - val_y_up_loss: 0.7058 - learning_rate: 0.0010
# Epoch 8/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - loss: 0.5199 - y_reg_z_loss: 0.2494 - y_up_loss: 0.5403 - val_loss: 0.4895 - val_y_reg_z_loss: 0.1286 - val_y_up_loss: 0.7010 - learning_rate: 0.0010
# Epoch 9/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.5068 - y_reg_z_loss: 0.2358 - y_up_loss: 0.5414 - val_loss: 0.4961 - val_y_reg_z_loss: 0.1316 - val_y_up_loss: 0.7189 - learning_rate: 0.0010
# Epoch 10/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.4729 - y_reg_z_loss: 0.2265 - y_up_loss: 0.4923 - val_loss: 0.4794 - val_y_reg_z_loss: 0.1278 - val_y_up_loss: 0.6858 - learning_rate: 0.0010
# Epoch 11/120
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.4606 - y_reg_z_loss: 0.2198 - y_up_loss: 0.4815
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.4640 - y_reg_z_loss: 0.2227 - y_up_loss: 0.4820 - val_loss: 0.5027 - val_y_reg_z_loss: 0.1358 - val_y_up_loss: 0.7013 - learning_rate: 0.0010
# Epoch 12/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.4114 - y_reg_z_loss: 0.1865 - y_up_loss: 0.4494 - val_loss: 0.6339 - val_y_reg_z_loss: 0.2074 - val_y_up_loss: 0.8070 - learning_rate: 5.0000e-04
# Epoch 13/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.3955 - y_reg_z_loss: 0.1841 - y_up_loss: 0.4223 - val_loss: 0.5514 - val_y_reg_z_loss: 0.1454 - val_y_up_loss: 0.7841 - learning_rate: 5.0000e-04
# Epoch 14/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - loss: 0.3678 - y_reg_z_loss: 0.1663 - y_up_loss: 0.4025 - val_loss: 0.5361 - val_y_reg_z_loss: 0.1309 - val_y_up_loss: 0.8056 - learning_rate: 5.0000e-04
# Epoch 15/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.3258 - y_reg_z_loss: 0.1476 - y_up_loss: 0.3559 - val_loss: 0.5055 - val_y_reg_z_loss: 0.1335 - val_y_up_loss: 0.8032 - learning_rate: 5.0000e-04
# Epoch 16/120
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.3393 - y_reg_z_loss: 0.1561 - y_up_loss: 0.3664
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.3408 - y_reg_z_loss: 0.1576 - y_up_loss: 0.3659 - val_loss: 0.5617 - val_y_reg_z_loss: 0.1440 - val_y_up_loss: 0.8574 - learning_rate: 5.0000e-04
# Epoch 17/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.3112 - y_reg_z_loss: 0.1417 - y_up_loss: 0.3385 - val_loss: 0.5807 - val_y_reg_z_loss: 0.1486 - val_y_up_loss: 0.8960 - learning_rate: 2.5000e-04
# Epoch 18/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.3029 - y_reg_z_loss: 0.1442 - y_up_loss: 0.3170 - val_loss: 0.6176 - val_y_reg_z_loss: 0.1497 - val_y_up_loss: 0.9448 - learning_rate: 2.5000e-04
#
# ===== Training HYBRID FFT+WAV+Transformer for VCB.VN | UpRatio=0.532 =====
# Epoch 1/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 20s 116ms/step - loss: 0.8137 - y_reg_z_loss: 0.4492 - y_up_loss: 0.7285 - val_loss: 0.5557 - val_y_reg_z_loss: 0.2130 - val_y_up_loss: 0.6894 - learning_rate: 0.0010
# Epoch 2/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.7644 - y_reg_z_loss: 0.4229 - y_up_loss: 0.6833 - val_loss: 0.5252 - val_y_reg_z_loss: 0.1942 - val_y_up_loss: 0.6672 - learning_rate: 0.0010
# Epoch 3/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.7314 - y_reg_z_loss: 0.3916 - y_up_loss: 0.6794 - val_loss: 0.5114 - val_y_reg_z_loss: 0.1851 - val_y_up_loss: 0.6477 - learning_rate: 0.0010
# Epoch 4/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 0.7074 - y_reg_z_loss: 0.3782 - y_up_loss: 0.6582 - val_loss: 0.5051 - val_y_reg_z_loss: 0.1874 - val_y_up_loss: 0.6430 - learning_rate: 0.0010
# Epoch 5/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - loss: 0.6733 - y_reg_z_loss: 0.3583 - y_up_loss: 0.6299 - val_loss: 0.5027 - val_y_reg_z_loss: 0.1887 - val_y_up_loss: 0.6382 - learning_rate: 0.0010
# Epoch 6/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.6291 - y_reg_z_loss: 0.3262 - y_up_loss: 0.6060 - val_loss: 0.4992 - val_y_reg_z_loss: 0.1892 - val_y_up_loss: 0.6100 - learning_rate: 0.0010
# Epoch 7/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.6501 - y_reg_z_loss: 0.3522 - y_up_loss: 0.5961 - val_loss: 0.4992 - val_y_reg_z_loss: 0.1921 - val_y_up_loss: 0.6141 - learning_rate: 0.0010
# Epoch 8/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.6278 - y_reg_z_loss: 0.3341 - y_up_loss: 0.5874 - val_loss: 0.5064 - val_y_reg_z_loss: 0.2015 - val_y_up_loss: 0.5969 - learning_rate: 0.0010
# Epoch 9/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.6151 - y_reg_z_loss: 0.3299 - y_up_loss: 0.5705 - val_loss: 0.5039 - val_y_reg_z_loss: 0.1927 - val_y_up_loss: 0.6181 - learning_rate: 0.0010
# Epoch 10/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.6001 - y_reg_z_loss: 0.3241 - y_up_loss: 0.5522 - val_loss: 0.4744 - val_y_reg_z_loss: 0.1793 - val_y_up_loss: 0.5869 - learning_rate: 0.0010
# Epoch 11/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step - loss: 0.5634 - y_reg_z_loss: 0.3018 - y_up_loss: 0.5233 - val_loss: 0.5550 - val_y_reg_z_loss: 0.2178 - val_y_up_loss: 0.6742 - learning_rate: 0.0010
# Epoch 12/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - loss: 0.5141 - y_reg_z_loss: 0.2774 - y_up_loss: 0.4735 - val_loss: 0.3980 - val_y_reg_z_loss: 0.1478 - val_y_up_loss: 0.4932 - learning_rate: 0.0010
# Epoch 13/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.4966 - y_reg_z_loss: 0.2576 - y_up_loss: 0.4782 - val_loss: 0.3977 - val_y_reg_z_loss: 0.1332 - val_y_up_loss: 0.5255 - learning_rate: 0.0010
# Epoch 14/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - loss: 0.4374 - y_reg_z_loss: 0.2265 - y_up_loss: 0.4224 - val_loss: 0.4105 - val_y_reg_z_loss: 0.1310 - val_y_up_loss: 0.5614 - learning_rate: 0.0010
# Epoch 15/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.4243 - y_reg_z_loss: 0.2271 - y_up_loss: 0.3942 - val_loss: 0.4284 - val_y_reg_z_loss: 0.1483 - val_y_up_loss: 0.5561 - learning_rate: 0.0010
# Epoch 16/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.3906 - y_reg_z_loss: 0.2067 - y_up_loss: 0.3679 - val_loss: 0.4022 - val_y_reg_z_loss: 0.1376 - val_y_up_loss: 0.5174 - learning_rate: 0.0010
# Epoch 17/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 0.4116 - y_reg_z_loss: 0.2140 - y_up_loss: 0.3954 - val_loss: 0.4231 - val_y_reg_z_loss: 0.1413 - val_y_up_loss: 0.5606 - learning_rate: 0.0010
# Epoch 18/120
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.3932 - y_reg_z_loss: 0.2148 - y_up_loss: 0.3568
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.3908 - y_reg_z_loss: 0.2133 - y_up_loss: 0.3548 - val_loss: 0.3985 - val_y_reg_z_loss: 0.1325 - val_y_up_loss: 0.5240 - learning_rate: 0.0010
# Epoch 19/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.3590 - y_reg_z_loss: 0.1890 - y_up_loss: 0.3401 - val_loss: 0.4201 - val_y_reg_z_loss: 0.1386 - val_y_up_loss: 0.5552 - learning_rate: 5.0000e-04
# Epoch 20/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.3131 - y_reg_z_loss: 0.1619 - y_up_loss: 0.3025 - val_loss: 0.4791 - val_y_reg_z_loss: 0.1609 - val_y_up_loss: 0.6344 - learning_rate: 5.0000e-04
# Epoch 21/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.2875 - y_reg_z_loss: 0.1582 - y_up_loss: 0.2584 - val_loss: 0.4010 - val_y_reg_z_loss: 0.1238 - val_y_up_loss: 0.5468 - learning_rate: 5.0000e-04
# Epoch 22/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.3041 - y_reg_z_loss: 0.1560 - y_up_loss: 0.2957 - val_loss: 0.5002 - val_y_reg_z_loss: 0.1606 - val_y_up_loss: 0.6922 - learning_rate: 5.0000e-04
# Epoch 23/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.2903 - y_reg_z_loss: 0.1678 - y_up_loss: 0.2446
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - loss: 0.2889 - y_reg_z_loss: 0.1668 - y_up_loss: 0.2440 - val_loss: 0.5023 - val_y_reg_z_loss: 0.1659 - val_y_up_loss: 0.6820 - learning_rate: 5.0000e-04
# Epoch 24/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.3038 - y_reg_z_loss: 0.1688 - y_up_loss: 0.2701 - val_loss: 0.5017 - val_y_reg_z_loss: 0.1563 - val_y_up_loss: 0.6998 - learning_rate: 2.5000e-04
# Epoch 25/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step - loss: 0.2557 - y_reg_z_loss: 0.1490 - y_up_loss: 0.2134 - val_loss: 0.5450 - val_y_reg_z_loss: 0.1687 - val_y_up_loss: 0.7603 - learning_rate: 2.5000e-04
# Ticker  N_test_seq     RMSE      MAE  Directional_Acc  Precision_Up  Recall_Up    F1_Up      AUC  Best_Threshold  Val_F1_at_bestT  TN  FP  FN  TP
# VCB.VN         202 0.002820 0.002090         0.693069      0.623656   0.682353 0.651685 0.757164           0.300         0.814815  82  35  27  58
# BID.VN         202 0.004783 0.003670         0.628713      0.549669   0.922222 0.688797 0.767361           0.230         0.743802  44  68   7  83
# CTG.VN         202 0.006304 0.005040         0.524752      0.524752   1.000000 0.688312 0.580287           0.200         0.739437   0  96   0 106
# TCB.VN         184 0.007099 0.005514         0.706522      0.752000   0.803419 0.776860 0.704682           0.255         0.735849  36  31  23  94
# 📊 ACTUAL vs HYBRID TRANSFORMER PREDICTED RETURN (4 STOCKS)
