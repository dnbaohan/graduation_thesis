# %% [markdown]
# <a href="https://colab.research.google.com/github/dnbaohan/graduation_thesis/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Library

# %%
# Install required libraries
# !pip install yfinance --quiet
# !pip install scikit-learn --quiet
# !pip install scikeras --quiet
# !pip install tensorflow pandas numpy matplotlib --quiet
# !pip install TA-Lib --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 40.6 MB/s eta 0:00:00

# %%
# =========================
# Standard Libraries
# =========================
import os
import math
import warnings
from datetime import datetime, timedelta
import pywt
import tensorflow as tf
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import (
    mean_squared_error, mean_absolute_error,
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, confusion_matrix
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import f1_score


# =========================
# Numerical & Data Handling
# =========================
import numpy as np
import pandas as pd

# =========================
# Visualization
# =========================
import matplotlib.pyplot as plt

# =========================
# Signal Processing & Statistics
# =========================
import pywt
from scipy.fft import fft, ifft
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller

# =========================
# Financial Data & Indicators
# =========================
import yfinance as yf
import talib  # Technical Analysis Library

# =========================
# Machine Learning & Preprocessing
# =========================
from sklearn.model_selection import train_test_split,TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
from sklearn.metrics import (
    mean_squared_error, mean_absolute_error, r2_score,
    precision_score, recall_score, f1_score,
    roc_auc_score, average_precision_score,
    confusion_matrix, classification_report,
    balanced_accuracy_score
)
from sklearn.utils.class_weight import compute_class_weight

# =========================
# Imbalanced Learning
# =========================
from imblearn.over_sampling import SMOTE

# =========================
# Deep Learning (TensorFlow / Keras)
# =========================
import tensorflow as tf
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from tensorflow.keras.callbacks import (
    EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
)
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import (
    Input, Dense, Dropout, BatchNormalization, LayerNormalization,
    LSTM, GRU, Bidirectional,
    Conv1D, GlobalAveragePooling1D, GlobalMaxPooling1D,
    Attention, MultiHeadAttention, Concatenate
)

# =========================
# Configuration
# =========================
plt.rcParams["figure.figsize"] = (15, 8)
warnings.filterwarnings("ignore")
np.random.seed(0)
tf.random.set_seed(0)

# =========================
# Directory Setup
# =========================
os.makedirs("results/models", exist_ok=True)
os.makedirs("results/plots", exist_ok=True)

# %% [markdown]
# # Data

# %%
start_date = "2020-01-01"
end_date   = "2025-01-01"

tickers = {
    "VCB": "VCB.VN",
    "CTG": "CTG.VN",
    "BID": "BID.VN",
    "TCB": "TCB.VN",
}

# Download dữ liệu
stocks_data = {}
for ticker, symbol in tickers.items():
    df = yf.download(symbol, start=start_date, end=end_date)
    df = df[['Open', 'High', 'Low', 'Close', 'Volume']]
    stocks_data[symbol] = df
# Hiển thị dữ liệu của tất cả mã
for symbol, df in stocks_data.items():
    print(f"Dữ liệu cổ phiếu: {symbol}")
    print(df.head(10))



# Tạo DataFrame với giá đóng cửa cho từng cổ phiếu
df_close = pd.concat({tk: d['Close'] for tk, d in stocks_data.items()}, axis=1)
df_close.columns = df_close.columns.droplevel(0)  # Đổi tên cột sau khi concat

# Tính toán tỷ lệ log return hàng ngày
daily_log_returns = np.log(df_close / df_close.shift(1))

rows = []

for ticker in daily_log_returns.columns:

    # =========================
    # Base series
    # =========================
    close  = df_close[ticker]
    ret    = daily_log_returns[ticker]
    # Ensure volume, high, and low are Series by using .squeeze() and reindexing
    volume = stocks_data[ticker]["Volume"].squeeze().reindex(close.index)
    high   = stocks_data[ticker]["High"].squeeze().reindex(close.index)
    low    = stocks_data[ticker]["Low"].squeeze().reindex(close.index)

    df_feat = pd.DataFrame({
        "date": ret.index,
        "ticker": ticker,
        "return": ret,
        "return_lag1": ret.shift(1),
        "return_lag5": ret.shift(5),
        "return_lag10": ret.shift(10)
    })

    # =========================
    # 1. Volatility
    # =========================
    df_feat["volatility_21"] = ret.rolling(21).std() * np.sqrt(252)
    df_feat["Vol_5"]  = ret.rolling(5).std()
    df_feat["Vol_10"] = ret.rolling(10).std()
    df_feat["Vol_20"] = ret.rolling(20).std()
    # # sigma proxy (shift 1 để chỉ dùng thông tin quá khứ)
    # dft["sigma"] = dft["Vol_20"].shift(1).clip(lower=1e-6).astype(np.float32)
    # # target scaled
    # dft["y_scaled"] = (dft["target"] / dft["sigma"]).astype(np.float32)



    # =========================
    # 2. RSI
    # =========================
    df_feat["RSI_14"] = talib.RSI(close, timeperiod=14)

    # =========================
    # 3. MACD
    # =========================
    macd, macd_sig, _ = talib.MACD(close, 12, 26, 9)
    df_feat["MACD"] = macd
    df_feat["MACD_signal"] = macd_sig

    # =========================
    # 4. Bollinger Bands
    # =========================
    bb_up, bb_mid, bb_low = talib.BBANDS(close, timeperiod=20)
    df_feat["BB_upper"] = bb_up
    df_feat["BB_middle"] = bb_mid
    df_feat["BB_lower"] = bb_low
    df_feat["Boll_width"] = (bb_up - bb_low) / bb_mid
    df_feat["Boll_percB"] = (close - bb_low) / (bb_up - bb_low)

    # =========================
    # 5. Moving Averages
    # =========================
    df_feat["MA_5"]  = ret.rolling(5).mean()
    df_feat["EMA_12"] = ret.ewm(span=12, adjust=False).mean()
    df_feat["EMA_26"] = ret.ewm(span=26, adjust=False).mean()
    df_feat["Trend_20"] = ret.rolling(20).mean()

    # =========================
    # 6. Regime (High/Low vol)
    # =========================
    df_feat["Regime"] = (
        df_feat["Vol_20"] > df_feat["Vol_20"].rolling(60).mean()
    ).astype(int)

    # =========================
    # 7. OBV
    # =========================
    df_feat["OBV"] = talib.OBV(close, volume)

    # =========================
    # 8. Forward returns
    # =========================
    for k in [5, 10, 21]:
        df_feat[f"ret_{k}"] = np.log(close / close.shift(k))

    # =========================
    # 9. Momentum
    # =========================
    short_mom = close / close.shift(5) - 1
    long_mom  = close / close.shift(21) - 1

    df_feat["momentum_diff"] = short_mom - long_mom
    df_feat["momentum_90"] = close / close.shift(90) - 1


    # =========================
    # 10. MA / EMA ratios
    # =========================
    df_feat["SMA20_ratio"] = close / close.rolling(20).mean() - 1
    df_feat["SMA50_ratio"] = close / close.rolling(50).mean() - 1
    df_feat["EMA12_ratio"] = close / close.ewm(span=12).mean() - 1
    df_feat["EMA26_ratio"] = close / close.ewm(span=26).mean() - 1

    # =========================
    # 11. ATR (normalized)
    # =========================
    tr = np.maximum(
        high - low,
        np.maximum(
            (high - close.shift()).abs(),
            (low - close.shift()).abs()
        )
    )
    df_feat["ATR_14"] = tr.rolling(14).mean() / close

    # =========================
    # 12. Volume
    # =========================
    log_vol = np.log(volume.replace(0, np.nan))
    df_feat["Volume_diff"] = log_vol.diff()

    rows.append(df_feat)

# =========================
# Final feature table
# =========================
features = (
    pd.concat(rows)
    .sort_values(["ticker", "date"])
    .reset_index(drop=True)
)

# 7) Target = return ngày kế tiếp
features = features.sort_values(["ticker", "date"])
features["target"] = (
    features.groupby("ticker")["return"]
            .transform(lambda s: s.shift(-1).rolling(5).mean())
)


# 8) Làm sạch dữ liệu (bỏ tất cả NaN phát sinh)
df = features.dropna().reset_index(drop=True)

# Kiểm tra kết quả cuối cùng
print("Dataset cuối cùng:", df.shape)
print(df.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Dữ liệu cổ phiếu: VCB.VN
# Price               Open          High           Low         Close   Volume
# Ticker            VCB.VN        VCB.VN        VCB.VN        VCB.VN   VCB.VN
# Date
# 2020-01-02  39747.175948  40275.960743  39526.846687  40011.566406   870270
# 2020-01-03  40320.025537  40452.224643  39614.976562  39614.976562  1207844
# 2020-01-06  39306.516379  39438.715483  38557.402344  38557.402344  1982797
# 2020-01-07  38337.073175  38733.662732  37632.024213  38689.597656  2529103
# 2020-01-08  38293.009142  38733.663786  37984.549728  38337.074219  1897570
# 2020-01-09  38645.532893  39174.321558  38645.532893  39086.191406  2040337
# 2020-01-10  39086.190369  39835.304393  38733.662017  39438.714844  3596527
# 2020-01-13  39218.388128  39570.912625  39218.388128  39394.648438  3880278
# 2020-01-14  39438.717393  39659.042780  39262.453205  39394.648438  2255442
# 2020-01-15  39482.781137  39482.781137  39130.256652  39350.582031  3379031
# Dữ liệu cổ phiếu: CTG.VN
# Price               Open          High           Low         Close     Volume
# Ticker            CTG.VN        CTG.VN        CTG.VN        CTG.VN     CTG.VN
# Date
# 2020-01-02   9902.445536  10305.176411   9878.755371  10186.725586    9069367
# 2020-01-03  10305.176339  10352.556668  10068.275655  10091.965820    7565383
# 2020-01-06  10044.585754  10281.486443   9997.205423  10115.656250    6620064
# 2020-01-07  10234.105998  10352.556824  10163.035502  10281.486328    8879516
# 2020-01-08  10210.415569  10494.696579  10091.965712  10257.795898  136795825
# 2020-01-09  10352.556861  10707.907410  10352.556861  10636.836914   19592888
# 2020-01-10  10660.527017  11371.229076  10660.527017  11158.018555   31801609
# 2020-01-13  11039.567842  11371.229192  10992.188477  10992.188477   11155134
# 2020-01-14  11015.878267  11276.468147  10992.188103  11134.328125   44334358
# 2020-01-15  11134.328653  11229.089316  11015.878790  11181.708984    9147052
# Dữ liệu cổ phiếu: BID.VN
# Price               Open          High           Low         Close   Volume
# Ticker            BID.VN        BID.VN        BID.VN        BID.VN   BID.VN
# Date
# 2020-01-02  26527.793560  27219.823378  26470.124570  27046.816406  1496500
# 2020-01-03  27306.327921  27392.830441  26931.478516  26931.478516  1035726
# 2020-01-06  26931.477914  26931.477914  26412.455078  26412.455078  1362510
# 2020-01-07  26412.455668  26931.478516  26066.441724  26931.478516   903589
# 2020-01-08  26527.793472  27623.506219  26412.455492  27162.154297  2110812
# 2020-01-09  27537.004037  28776.890240  27450.499584  28632.716797  2697943
# 2020-01-10  28632.716571  29987.940746  28603.883042  29584.257812  2583418
# 2020-01-13  28776.890533  29699.596329  28546.214566  28892.228516   934201
# 2020-01-14  28892.228516  29699.596329  28776.890533  28892.228516  1461481
# 2020-01-15  28776.889191  29584.256967  28776.889191  29411.250000  1192387
# Dữ liệu cổ phiếu: TCB.VN
# Price               Open          High           Low         Close    Volume
# Ticker            TCB.VN        TCB.VN        TCB.VN        TCB.VN    TCB.VN
# Date
# 2020-01-02  10778.707216  10916.015588  10755.822487  10893.130859   2820080
# 2020-01-03  10938.900205  10961.784933  10824.476562  10824.476562   1513400
# 2020-01-06  10710.053459  10710.053459  10549.860352  10549.860352   2325980
# 2020-01-07  10549.859489  10618.513672  10526.974761  10618.513672   4920200
# 2020-01-08  10435.436487  10549.860133  10343.897570  10412.551758   3420780
# 2020-01-09  10526.975622  10572.745081  10458.321433  10549.860352   4019680
# 2020-01-10  10526.974723  10755.822000  10526.974723  10595.628906   7358220
# 2020-01-13  10526.974571  10595.628753  10412.550934  10504.089844   1784720
# 2020-01-14  10504.090784  10549.860243  10481.206055  10481.206055   4561960
# 2020-01-15  10481.206055  10526.975513  10435.436596  10481.206055  11830560
# Dataset cuối cùng: (4547, 36)
#         date  ticker    return  return_lag1  return_lag5  return_lag10  \
# 0 2020-05-19  BID.VN  0.005128     0.007742     0.001298      0.000000
# 1 2020-05-20  BID.VN  0.001278     0.005128     0.026873      0.019636
# 2 2020-05-21  BID.VN  0.013951     0.001278     0.002522      0.042154
# 3 2020-05-22  BID.VN -0.010127     0.013951    -0.028099      0.011913
# 4 2020-05-25  BID.VN  0.008866    -0.010127     0.007742      0.013072
#
#    volatility_21     Vol_5    Vol_10    Vol_20  ...    ret_21  momentum_diff  \
# 0       0.375966  0.019775  0.018367  0.024299  ...  0.047129      -0.033990
# 1       0.375977  0.014643  0.018239  0.024180  ...  0.045730      -0.058155
# 2       0.376159  0.016371  0.014162  0.017873  ...  0.067734      -0.070081
# 3       0.282645  0.008950  0.014767  0.016140  ...  0.124485      -0.114430
# 4       0.250277  0.009094  0.014517  0.016143  ...  0.091032      -0.076024
#
#    momentum_90  SMA20_ratio  SMA50_ratio  EMA12_ratio  EMA26_ratio    ATR_14  \
# 0    -0.166311     0.055117     0.077283     0.023980     0.041833  0.031056
# 1    -0.161670     0.053552     0.083257     0.021316     0.039838  0.030104
# 2    -0.133188     0.061214     0.100851     0.030013     0.050207  0.029867
# 3    -0.158458     0.046187     0.091636     0.016564     0.036581  0.029080
# 4    -0.158174     0.050679     0.101236     0.021591     0.042273  0.029184
#
#    Volume_diff        target
# 0    -0.100422 -2.285745e-03
# 1    -0.627118  6.938894e-18
# 2     1.010765  3.594464e-03
# 3    -0.774392  3.819332e-03
# 4    -0.250203  1.430943e-02
#
# [5 rows x 36 columns]

# %%
def adf_summary_full(df):
    results = []
    numeric_cols = df.select_dtypes(include=[np.number]).columns  # chỉ lấy cột số

    for col in numeric_cols:
        series = df[col].dropna()
        if len(series) < 20:  # bỏ qua cột có quá ít quan sát
            continue
        adf_result = adfuller(series, autolag='AIC')
        pval = adf_result[1]
        stat = adf_result[0]
        crit = adf_result[4]['5%']
        results.append({
            'Variable': col,
            'ADF Statistic': round(stat, 4),
            'p-value': round(pval, 4),
            '5% Critical Value': round(crit, 4),
            'Stationary': 'Yes' if pval < 0.05 else 'No'
        })

    return pd.DataFrame(results)

# Gọi hàm trên toàn bộ dataframe của bạn
adf_table_full = adf_summary_full(df)
print(adf_table_full)

df.columns
# Out:
#          Variable  ADF Statistic  p-value  5% Critical Value Stationary
# 0          return       -11.8925   0.0000            -2.8622        Yes
# 1     return_lag1       -11.9094   0.0000            -2.8622        Yes
# 2     return_lag5       -11.9292   0.0000            -2.8622        Yes
# 3    return_lag10       -12.0856   0.0000            -2.8622        Yes
# 4   volatility_21        -7.7038   0.0000            -2.8622        Yes
# 5           Vol_5        -7.0304   0.0000            -2.8622        Yes
# 6          Vol_10        -7.1426   0.0000            -2.8622        Yes
# 7          Vol_20        -7.8243   0.0000            -2.8622        Yes
# 8          RSI_14       -13.1756   0.0000            -2.8622        Yes
# 9            MACD       -10.8881   0.0000            -2.8622        Yes
# 10    MACD_signal       -10.1030   0.0000            -2.8622        Yes
# 11       BB_upper        -0.9483   0.7716            -2.8622         No
# 12      BB_middle        -0.6742   0.8533            -2.8622         No
# 13       BB_lower        -0.9027   0.7871            -2.8622         No
# 14     Boll_width        -9.9387   0.0000            -2.8622        Yes
# 15     Boll_percB       -16.6423   0.0000            -2.8622        Yes
# 16           MA_5       -10.5486   0.0000            -2.8622        Yes
# 17         EMA_12       -10.2036   0.0000            -2.8622        Yes
# 18         EMA_26        -9.4078   0.0000            -2.8622        Yes
# 19       Trend_20       -10.9190   0.0000            -2.8622        Yes
# 20         Regime       -11.1358   0.0000            -2.8622        Yes
# 21            OBV        -2.2195   0.1992            -2.8622         No
# 22          ret_5       -10.5486   0.0000            -2.8622        Yes
# 23         ret_10        -9.9360   0.0000            -2.8622        Yes
# 24         ret_21       -10.5904   0.0000            -2.8622        Yes
# 25  momentum_diff        -9.0520   0.0000            -2.8622        Yes
# 26    momentum_90        -6.4862   0.0000            -2.8622        Yes
# 27    SMA20_ratio       -10.5529   0.0000            -2.8622        Yes
# 28    SMA50_ratio        -9.7066   0.0000            -2.8622        Yes
# 29    EMA12_ratio       -10.1994   0.0000            -2.8622        Yes
# 30    EMA26_ratio        -9.3775   0.0000            -2.8622        Yes
# 31         ATR_14        -7.5531   0.0000            -2.8622        Yes
# 32    Volume_diff       -21.2388   0.0000            -2.8622        Yes
# 33         target       -10.5445   0.0000            -2.8622        Yes
# Index(['date', 'ticker', 'return', 'return_lag1', 'return_lag5',
#        'return_lag10', 'volatility_21', 'Vol_5', 'Vol_10', 'Vol_20', 'RSI_14',
#        'MACD', 'MACD_signal', 'BB_upper', 'BB_middle', 'BB_lower',
#        'Boll_width', 'Boll_percB', 'MA_5', 'EMA_12', 'EMA_26', 'Trend_20',
#        'Regime', 'OBV', 'ret_5', 'ret_10', 'ret_21', 'momentum_diff',
#        'momentum_90', 'SMA20_ratio', 'SMA50_ratio', 'EMA12_ratio',
#        'EMA26_ratio', 'ATR_14', 'Volume_diff', 'target'],
#       dtype='object')

# %% [markdown]
# # LSTM

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import (
    mean_squared_error, mean_absolute_error,
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, confusion_matrix, balanced_accuracy_score
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# ============================================================
# 0) Utils
# ============================================================
def create_sequences(X, y, seq_len):
    """
    X: (T, n_features)
    y: (T,)
    returns:
      X_seq: (T-seq_len, seq_len, n_features)
      y_seq: (T-seq_len,)
    y at time t corresponds to the step immediately after the sequence end:
      seq uses X[t-seq_len : t], target is y[t]
    """
    Xs, ys = [], []
    for t in range(seq_len, len(X)):
        Xs.append(X[t-seq_len:t])
        ys.append(y[t])
    return np.asarray(Xs, dtype=np.float32), np.asarray(ys, dtype=np.float32)

def safe_auc(y_true_bin, y_prob):
    y_true_bin = np.asarray(y_true_bin).astype(int)
    y_prob = np.asarray(y_prob).astype(float)
    if len(np.unique(y_true_bin)) < 2:
        return np.nan
    return roc_auc_score(y_true_bin, y_prob)

def tune_threshold_balacc(y_true, y_prob, lo=0.05, hi=0.95, n=181):
    """
    Tune threshold to maximize Balanced Accuracy on validation.
    Prevents all-positive collapse.
    """
    y_true = np.asarray(y_true).astype(int)
    y_prob = np.asarray(y_prob).astype(float)
    ts = np.linspace(lo, hi, n)

    best_t, best_s = 0.5, -1.0
    for t in ts:
        y_pred = (y_prob >= t).astype(int)
        s = balanced_accuracy_score(y_true, y_pred)
        if s > best_s:
            best_s, best_t = s, t
    return float(best_t), float(best_s)

def binary_focal_loss(gamma=2.0, alpha=0.25):
    """
    Focal loss for binary classification.
    alpha: weight for positive class
    gamma: focusing parameter
    """
    def loss(y_true, y_prob):
        y_true = tf.cast(y_true, tf.float32)
        eps = tf.keras.backend.epsilon()
        y_prob = tf.clip_by_value(y_prob, eps, 1.0 - eps)

        pt = tf.where(tf.equal(y_true, 1.0), y_prob, 1.0 - y_prob)
        w  = tf.where(tf.equal(y_true, 1.0), alpha, 1.0 - alpha)
        return -tf.reduce_mean(w * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# ============================================================
# 1) Model (improved LSTM baseline)
# ============================================================
def build_lstm_multitask_v2(
    input_shape,
    units=64,
    dropout=0.2,
    l2=1e-6,
    dense_units=32
):
    """
    input_shape: (LOOKBACK, n_features)
    outputs:
      - y_reg_z: standardized regression output
      - y_up: direction sigmoid
    """
    inp = tf.keras.Input(shape=input_shape)

    x = tf.keras.layers.SpatialDropout1D(dropout)(inp)

    x = tf.keras.layers.LSTM(
        units, return_sequences=True,
        kernel_regularizer=tf.keras.regularizers.l2(l2)
    )(x)
    x = tf.keras.layers.LayerNormalization()(x)

    x = tf.keras.layers.LSTM(
        max(16, units // 2), return_sequences=False,
        kernel_regularizer=tf.keras.regularizers.l2(l2)
    )(x)
    x = tf.keras.layers.LayerNormalization()(x)

    x = tf.keras.layers.Dropout(dropout)(x)
    x = tf.keras.layers.Dense(dense_units, activation="relu")(x)
    x = tf.keras.layers.Dropout(dropout)(x)

    y_reg_z = tf.keras.layers.Dense(1, name="y_reg_z")(x)
    y_up    = tf.keras.layers.Dense(1, activation="sigmoid", name="y_up")(x)

    return tf.keras.Model(inp, [y_reg_z, y_up])

# ============================================================
# 2) Train + Eval loop (per ticker)
# ============================================================
LOOKBACK = 30
non_feature = ["date", "ticker", "target"]
feature_cols = [c for c in df.columns if c not in non_feature]

df = df.copy()
df["date"] = pd.to_datetime(df["date"])

lstm_models, lstm_scalers, lstm_histories, lstm_splits, lstm_meta = {}, {}, {}, {}, {}
summary_rows = []

for tk, dft in df.groupby("ticker"):
    dft = dft.sort_values("date").reset_index(drop=True)

    X = dft[feature_cols].values.astype(np.float32)
    y = dft["target"].values.astype(np.float32)

    if len(dft) < (LOOKBACK + 80):
        print(f"⚠️ {tk}: dữ liệu quá ít ({len(dft)} dòng) -> bỏ qua")
        continue

    split_index = int(len(dft) * 0.8)
    X_train_raw, X_test_raw = X[:split_index], X[split_index:]
    y_train_raw, y_test_raw = y[:split_index], y[split_index:]

    # scale X (train only)
    scaler = RobustScaler()
    X_train_scaled = scaler.fit_transform(X_train_raw)
    X_test_scaled  = scaler.transform(X_test_raw)

    # sequences
    X_train_seq, y_train_seq = create_sequences(X_train_scaled, y_train_raw, LOOKBACK)
    X_test_seq,  y_test_seq  = create_sequences(X_test_scaled,  y_test_raw,  LOOKBACK)

    if len(X_train_seq) < 50 or len(X_test_seq) < 30:
        print(f"⚠️ {tk}: số sequence quá ít -> bỏ qua")
        continue

    # validation tail (20% of train sequences) + purge gap to reduce overlap leakage
    val_size = max(1, int(0.2 * len(X_train_seq)))
    gap = LOOKBACK

    if len(X_train_seq) <= (val_size + gap + 5):
        # fallback if too short
        gap = 0

    X_tr, y_tr = X_train_seq[:-val_size-gap], y_train_seq[:-val_size-gap]
    X_val, y_val = X_train_seq[-val_size:], y_train_seq[-val_size:]

    # standardize regression target on train only
    y_mu = float(np.mean(y_tr))
    y_sd = float(np.std(y_tr) + 1e-8)

    y_tr_z  = ((y_tr  - y_mu) / y_sd).astype(np.float32)
    y_val_z = ((y_val - y_mu) / y_sd).astype(np.float32)

    # direction labels
    y_tr_up  = (y_tr > 0).astype(np.float32)
    y_val_up = (y_val > 0).astype(np.float32)

    # focal loss (alpha based on class balance is optional; keep stable default)
    focal = binary_focal_loss(gamma=2.0, alpha=0.25)

    # build model
    model = build_lstm_multitask_v2(
        input_shape=(LOOKBACK, X_train_seq.shape[2]),
        units=64,
        dropout=0.2,
        l2=1e-6,
        dense_units=32
    )

    opt = Adam(learning_rate=1e-3, clipnorm=1.0)
    model.compile(
        optimizer=opt,
        loss={
            "y_reg_z": tf.keras.losses.Huber(delta=1.0),
            "y_up": focal
        },
        loss_weights={"y_reg_z": 1.0, "y_up": 0.2},
        metrics={"y_up": [tf.keras.metrics.AUC(name="auc")]}
    )

    early_stop = EarlyStopping(
        monitor="val_y_up_auc",
        mode="max",
        patience=10,
        restore_best_weights=True
    )
    rlr = ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,
        patience=5,
        min_lr=1e-5,
        verbose=1
    )

    print(f"\n===== Training IMPROVED LSTM for {tk} | TrainSeq={len(X_tr)} ValSeq={len(X_val)} =====")
    history = model.fit(
        X_tr, {"y_reg_z": y_tr_z, "y_up": y_tr_up},
        validation_data=(X_val, {"y_reg_z": y_val_z, "y_up": y_val_up}),
        epochs=150,
        batch_size=32,
        callbacks=[early_stop, rlr],
        verbose=1
    )

    # store
    lstm_models[tk] = model
    lstm_scalers[tk] = scaler
    lstm_histories[tk] = history
    lstm_splits[tk] = (X_train_seq, X_test_seq, y_train_seq, y_test_seq, X_val, y_val)
    lstm_meta[tk] = {"y_mu": y_mu, "y_sd": y_sd}

    # ============================================================
    # 3) Evaluate
    # ============================================================
    y_reg_z_pred, y_up_prob = model.predict(X_test_seq, verbose=0)
    y_reg_z_pred = y_reg_z_pred.reshape(-1)
    y_up_prob    = y_up_prob.reshape(-1)

    # inverse regression
    y_pred = y_reg_z_pred * y_sd + y_mu

    mse  = float(mean_squared_error(y_test_seq, y_pred))
    rmse = float(np.sqrt(mse))
    mae  = float(mean_absolute_error(y_test_seq, y_pred))

    # tune threshold on val via balanced accuracy
    _, y_val_prob = model.predict(X_val, verbose=0)
    y_val_prob = y_val_prob.reshape(-1)
    y_val_true = (y_val > 0).astype(int)

    best_t, best_balacc = tune_threshold_balacc(y_val_true, y_val_prob, lo=0.05, hi=0.95, n=181)

    y_true_bin = (y_test_seq > 0).astype(int)
    y_pred_bin = (y_up_prob >= best_t).astype(int)

    directional_acc = float(accuracy_score(y_true_bin, y_pred_bin))
    precision = float(precision_score(y_true_bin, y_pred_bin, zero_division=0))
    recall    = float(recall_score(y_true_bin, y_pred_bin, zero_division=0))
    f1        = float(f1_score(y_true_bin, y_pred_bin, zero_division=0))
    auc       = float(safe_auc(y_true_bin, y_up_prob))

    tn, fp, fn, tp = confusion_matrix(y_true_bin, y_pred_bin, labels=[0, 1]).ravel()

    summary_rows.append({
        "Ticker": tk,
        "N_test_seq": int(len(y_test_seq)),
        "RMSE": rmse,
        "MAE": mae,
        "Directional_Acc": directional_acc,
        "Precision_Up": precision,
        "Recall_Up": recall,
        "F1_Up": f1,
        "AUC": auc,
        "Best_Threshold": float(best_t),
        "Val_BalAcc_at_bestT": float(best_balacc),
        "TN": int(tn), "FP": int(fp), "FN": int(fn), "TP": int(tp)
    })

# ============================================================
# 4) Summary table
# ============================================================
summary_lstm_df = pd.DataFrame(summary_rows).sort_values("RMSE").reset_index(drop=True)
display_cols = [
    "Ticker","N_test_seq","RMSE","MAE",
    "Directional_Acc","Precision_Up","Recall_Up","F1_Up","AUC",
    "Best_Threshold","Val_BalAcc_at_bestT","TN","FP","FN","TP"
]
print("\n===== IMPROVED LSTM SUMMARY =====")
print(summary_lstm_df[display_cols].to_string(index=False))
# Out:
# ===== Training IMPROVED LSTM for BID.VN | TrainSeq=688 ValSeq=179 =====
# Epoch 1/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 18s 214ms/step - loss: 0.6398 - y_reg_z_loss: 0.5944 - y_up_auc: 0.5406 - y_up_loss: 0.2255 - val_loss: 0.2334 - val_y_reg_z_loss: 0.2090 - val_y_up_auc: 0.3857 - val_y_up_loss: 0.1099 - learning_rate: 0.0010
# Epoch 2/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 0.4564 - y_reg_z_loss: 0.4313 - y_up_auc: 0.5616 - y_up_loss: 0.1251 - val_loss: 0.1990 - val_y_reg_z_loss: 0.1929 - val_y_up_auc: 0.4239 - val_y_up_loss: 0.1030 - learning_rate: 0.0010
# Epoch 3/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.4059 - y_reg_z_loss: 0.3837 - y_up_auc: 0.5543 - y_up_loss: 0.1113 - val_loss: 0.1944 - val_y_reg_z_loss: 0.1819 - val_y_up_auc: 0.4408 - val_y_up_loss: 0.1035 - learning_rate: 0.0010
# Epoch 4/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.3391 - y_reg_z_loss: 0.3195 - y_up_auc: 0.5672 - y_up_loss: 0.0975 - val_loss: 0.1994 - val_y_reg_z_loss: 0.1878 - val_y_up_auc: 0.5793 - val_y_up_loss: 0.0936 - learning_rate: 0.0010
# Epoch 5/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.3338 - y_reg_z_loss: 0.3160 - y_up_auc: 0.6042 - y_up_loss: 0.0876 - val_loss: 0.2144 - val_y_reg_z_loss: 0.2034 - val_y_up_auc: 0.5554 - val_y_up_loss: 0.0936 - learning_rate: 0.0010
# Epoch 6/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3369 - y_reg_z_loss: 0.3200 - y_up_auc: 0.6252 - y_up_loss: 0.0833 - val_loss: 0.2106 - val_y_reg_z_loss: 0.2066 - val_y_up_auc: 0.5636 - val_y_up_loss: 0.0866 - learning_rate: 0.0010
# Epoch 7/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.3060 - y_reg_z_loss: 0.2879 - y_up_auc: 0.6357 - y_up_loss: 0.0909 - val_loss: 0.2117 - val_y_reg_z_loss: 0.2051 - val_y_up_auc: 0.5913 - val_y_up_loss: 0.0810 - learning_rate: 0.0010
# Epoch 8/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.3136 - y_reg_z_loss: 0.2958 - y_up_auc: 0.6119 - y_up_loss: 0.0880 - val_loss: 0.1848 - val_y_reg_z_loss: 0.1749 - val_y_up_auc: 0.5777 - val_y_up_loss: 0.0804 - learning_rate: 0.0010
# Epoch 9/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.3043 - y_reg_z_loss: 0.2883 - y_up_auc: 0.6278 - y_up_loss: 0.0795 - val_loss: 0.1714 - val_y_reg_z_loss: 0.1619 - val_y_up_auc: 0.6138 - val_y_up_loss: 0.0757 - learning_rate: 0.0010
# Epoch 10/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.2741 - y_reg_z_loss: 0.2600 - y_up_auc: 0.6981 - y_up_loss: 0.0700 - val_loss: 0.1855 - val_y_reg_z_loss: 0.1740 - val_y_up_auc: 0.4919 - val_y_up_loss: 0.0910 - learning_rate: 0.0010
# Epoch 11/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.2738 - y_reg_z_loss: 0.2589 - y_up_auc: 0.6878 - y_up_loss: 0.0748 - val_loss: 0.2543 - val_y_reg_z_loss: 0.2468 - val_y_up_auc: 0.5474 - val_y_up_loss: 0.0933 - learning_rate: 0.0010
# Epoch 12/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.2681 - y_reg_z_loss: 0.2529 - y_up_auc: 0.6858 - y_up_loss: 0.0755 - val_loss: 0.2013 - val_y_reg_z_loss: 0.1881 - val_y_up_auc: 0.6017 - val_y_up_loss: 0.0827 - learning_rate: 0.0010
# Epoch 13/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2839 - y_reg_z_loss: 0.2685 - y_up_auc: 0.6923 - y_up_loss: 0.0766 - val_loss: 0.1998 - val_y_reg_z_loss: 0.1931 - val_y_up_auc: 0.6106 - val_y_up_loss: 0.0987 - learning_rate: 0.0010
# Epoch 14/150
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.2577 - y_reg_z_loss: 0.2436 - y_up_auc: 0.6961 - y_up_loss: 0.0699
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.2583 - y_reg_z_loss: 0.2443 - y_up_auc: 0.6981 - y_up_loss: 0.0699 - val_loss: 0.2306 - val_y_reg_z_loss: 0.2284 - val_y_up_auc: 0.5021 - val_y_up_loss: 0.1044 - learning_rate: 0.0010
# Epoch 15/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.2552 - y_reg_z_loss: 0.2423 - y_up_auc: 0.7553 - y_up_loss: 0.0644 - val_loss: 0.2159 - val_y_reg_z_loss: 0.2120 - val_y_up_auc: 0.5256 - val_y_up_loss: 0.0917 - learning_rate: 5.0000e-04
# Epoch 16/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.2417 - y_reg_z_loss: 0.2295 - y_up_auc: 0.7857 - y_up_loss: 0.0603 - val_loss: 0.2280 - val_y_reg_z_loss: 0.2256 - val_y_up_auc: 0.5189 - val_y_up_loss: 0.0961 - learning_rate: 5.0000e-04
# Epoch 17/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2655 - y_reg_z_loss: 0.2513 - y_up_auc: 0.7241 - y_up_loss: 0.0714 - val_loss: 0.2258 - val_y_reg_z_loss: 0.2272 - val_y_up_auc: 0.4977 - val_y_up_loss: 0.0975 - learning_rate: 5.0000e-04
# Epoch 18/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2584 - y_reg_z_loss: 0.2444 - y_up_auc: 0.7565 - y_up_loss: 0.0695 - val_loss: 0.2013 - val_y_reg_z_loss: 0.2022 - val_y_up_auc: 0.5179 - val_y_up_loss: 0.0938 - learning_rate: 5.0000e-04
# Epoch 19/150
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2281 - y_reg_z_loss: 0.2143 - y_up_auc: 0.7406 - y_up_loss: 0.0684
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2286 - y_reg_z_loss: 0.2149 - y_up_auc: 0.7431 - y_up_loss: 0.0680 - val_loss: 0.2267 - val_y_reg_z_loss: 0.2308 - val_y_up_auc: 0.4643 - val_y_up_loss: 0.1071 - learning_rate: 5.0000e-04
#
# ===== Training IMPROVED LSTM for CTG.VN | TrainSeq=688 ValSeq=179 =====
# Epoch 1/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 10s 71ms/step - loss: 0.7535 - y_reg_z_loss: 0.7243 - y_up_auc: 0.5009 - y_up_loss: 0.1450 - val_loss: 0.4279 - val_y_reg_z_loss: 0.4420 - val_y_up_auc: 0.4838 - val_y_up_loss: 0.1194 - learning_rate: 0.0010
# Epoch 2/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.5044 - y_reg_z_loss: 0.4859 - y_up_auc: 0.5887 - y_up_loss: 0.0912 - val_loss: 0.3376 - val_y_reg_z_loss: 0.3500 - val_y_up_auc: 0.4844 - val_y_up_loss: 0.0964 - learning_rate: 0.0010
# Epoch 3/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.4178 - y_reg_z_loss: 0.3987 - y_up_auc: 0.5646 - y_up_loss: 0.0950 - val_loss: 0.3330 - val_y_reg_z_loss: 0.3454 - val_y_up_auc: 0.5033 - val_y_up_loss: 0.1070 - learning_rate: 0.0010
# Epoch 4/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.3694 - y_reg_z_loss: 0.3517 - y_up_auc: 0.5860 - y_up_loss: 0.0877 - val_loss: 0.3022 - val_y_reg_z_loss: 0.3143 - val_y_up_auc: 0.4829 - val_y_up_loss: 0.1029 - learning_rate: 0.0010
# Epoch 5/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.3808 - y_reg_z_loss: 0.3640 - y_up_auc: 0.5743 - y_up_loss: 0.0832 - val_loss: 0.2929 - val_y_reg_z_loss: 0.3030 - val_y_up_auc: 0.4657 - val_y_up_loss: 0.1112 - learning_rate: 0.0010
# Epoch 6/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3923 - y_reg_z_loss: 0.3754 - y_up_auc: 0.5621 - y_up_loss: 0.0829 - val_loss: 0.2961 - val_y_reg_z_loss: 0.3128 - val_y_up_auc: 0.4881 - val_y_up_loss: 0.1031 - learning_rate: 0.0010
# Epoch 7/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3705 - y_reg_z_loss: 0.3548 - y_up_auc: 0.5928 - y_up_loss: 0.0778 - val_loss: 0.4542 - val_y_reg_z_loss: 0.4675 - val_y_up_auc: 0.4738 - val_y_up_loss: 0.1051 - learning_rate: 0.0010
# Epoch 8/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3255 - y_reg_z_loss: 0.3095 - y_up_auc: 0.5782 - y_up_loss: 0.0786 - val_loss: 0.4208 - val_y_reg_z_loss: 0.4398 - val_y_up_auc: 0.5094 - val_y_up_loss: 0.0982 - learning_rate: 0.0010
# Epoch 9/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3299 - y_reg_z_loss: 0.3144 - y_up_auc: 0.5948 - y_up_loss: 0.0771 - val_loss: 0.4431 - val_y_reg_z_loss: 0.4582 - val_y_up_auc: 0.5122 - val_y_up_loss: 0.1028 - learning_rate: 0.0010
# Epoch 10/150
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.3077 - y_reg_z_loss: 0.2938 - y_up_auc: 0.6836 - y_up_loss: 0.0684
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3065 - y_reg_z_loss: 0.2927 - y_up_auc: 0.6824 - y_up_loss: 0.0685 - val_loss: 0.5103 - val_y_reg_z_loss: 0.5271 - val_y_up_auc: 0.5072 - val_y_up_loss: 0.1180 - learning_rate: 0.0010
# Epoch 11/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3099 - y_reg_z_loss: 0.2943 - y_up_auc: 0.5955 - y_up_loss: 0.0769 - val_loss: 0.4944 - val_y_reg_z_loss: 0.5131 - val_y_up_auc: 0.5065 - val_y_up_loss: 0.1149 - learning_rate: 5.0000e-04
# Epoch 12/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.2935 - y_reg_z_loss: 0.2789 - y_up_auc: 0.6455 - y_up_loss: 0.0718 - val_loss: 0.4828 - val_y_reg_z_loss: 0.5023 - val_y_up_auc: 0.5242 - val_y_up_loss: 0.1100 - learning_rate: 5.0000e-04
# Epoch 13/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.2708 - y_reg_z_loss: 0.2566 - y_up_auc: 0.6967 - y_up_loss: 0.0698 - val_loss: 0.4442 - val_y_reg_z_loss: 0.4615 - val_y_up_auc: 0.5275 - val_y_up_loss: 0.1096 - learning_rate: 5.0000e-04
# Epoch 14/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.2605 - y_reg_z_loss: 0.2470 - y_up_auc: 0.6936 - y_up_loss: 0.0674 - val_loss: 0.4307 - val_y_reg_z_loss: 0.4493 - val_y_up_auc: 0.5379 - val_y_up_loss: 0.1107 - learning_rate: 5.0000e-04
# Epoch 15/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.2821 - y_reg_z_loss: 0.2675 - y_up_auc: 0.6552 - y_up_loss: 0.0724
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.2811 - y_reg_z_loss: 0.2666 - y_up_auc: 0.6565 - y_up_loss: 0.0723 - val_loss: 0.4687 - val_y_reg_z_loss: 0.4836 - val_y_up_auc: 0.5263 - val_y_up_loss: 0.1158 - learning_rate: 5.0000e-04
# Epoch 16/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.2768 - y_reg_z_loss: 0.2630 - y_up_auc: 0.6846 - y_up_loss: 0.0682 - val_loss: 0.4687 - val_y_reg_z_loss: 0.4847 - val_y_up_auc: 0.5185 - val_y_up_loss: 0.1144 - learning_rate: 2.5000e-04
# Epoch 17/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.2589 - y_reg_z_loss: 0.2449 - y_up_auc: 0.6867 - y_up_loss: 0.0701 - val_loss: 0.4550 - val_y_reg_z_loss: 0.4701 - val_y_up_auc: 0.5229 - val_y_up_loss: 0.1131 - learning_rate: 2.5000e-04
# Epoch 18/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.2553 - y_reg_z_loss: 0.2417 - y_up_auc: 0.6976 - y_up_loss: 0.0672 - val_loss: 0.4457 - val_y_reg_z_loss: 0.4608 - val_y_up_auc: 0.5153 - val_y_up_loss: 0.1153 - learning_rate: 2.5000e-04
# Epoch 19/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.2389 - y_reg_z_loss: 0.2256 - y_up_auc: 0.7165 - y_up_loss: 0.0661 - val_loss: 0.4739 - val_y_reg_z_loss: 0.4899 - val_y_up_auc: 0.5117 - val_y_up_loss: 0.1186 - learning_rate: 2.5000e-04
# Epoch 20/150
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2446 - y_reg_z_loss: 0.2313 - y_up_auc: 0.7213 - y_up_loss: 0.0658
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.2430 - y_reg_z_loss: 0.2299 - y_up_auc: 0.7219 - y_up_loss: 0.0656 - val_loss: 0.5084 - val_y_reg_z_loss: 0.5211 - val_y_up_auc: 0.5198 - val_y_up_loss: 0.1234 - learning_rate: 2.5000e-04
# Epoch 21/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.2873 - y_reg_z_loss: 0.2733 - y_up_auc: 0.6843 - y_up_loss: 0.0688 - val_loss: 0.4835 - val_y_reg_z_loss: 0.4952 - val_y_up_auc: 0.5272 - val_y_up_loss: 0.1223 - learning_rate: 1.2500e-04
# Epoch 22/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2807 - y_reg_z_loss: 0.2671 - y_up_auc: 0.6964 - y_up_loss: 0.0664 - val_loss: 0.4446 - val_y_reg_z_loss: 0.4572 - val_y_up_auc: 0.5171 - val_y_up_loss: 0.1195 - learning_rate: 1.2500e-04
# Epoch 23/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.2523 - y_reg_z_loss: 0.2393 - y_up_auc: 0.7201 - y_up_loss: 0.0644 - val_loss: 0.4479 - val_y_reg_z_loss: 0.4598 - val_y_up_auc: 0.5108 - val_y_up_loss: 0.1237 - learning_rate: 1.2500e-04
# Epoch 24/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2399 - y_reg_z_loss: 0.2261 - y_up_auc: 0.6811 - y_up_loss: 0.0680 - val_loss: 0.4451 - val_y_reg_z_loss: 0.4574 - val_y_up_auc: 0.5119 - val_y_up_loss: 0.1239 - learning_rate: 1.2500e-04
#
# ===== Training IMPROVED LSTM for TCB.VN | TrainSeq=631 ValSeq=165 =====
# Epoch 1/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - loss: 0.6374 - y_reg_z_loss: 0.6100 - y_up_auc: 0.5345 - y_up_loss: 0.1374 - val_loss: 0.2663 - val_y_reg_z_loss: 0.2318 - val_y_up_auc: 0.6324 - val_y_up_loss: 0.0930 - learning_rate: 0.0010
# Epoch 2/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.4839 - y_reg_z_loss: 0.4590 - y_up_auc: 0.4827 - y_up_loss: 0.1237 - val_loss: 0.2124 - val_y_reg_z_loss: 0.2082 - val_y_up_auc: 0.6051 - val_y_up_loss: 0.0904 - learning_rate: 0.0010
# Epoch 3/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.4183 - y_reg_z_loss: 0.3954 - y_up_auc: 0.4142 - y_up_loss: 0.1142 - val_loss: 0.2231 - val_y_reg_z_loss: 0.2098 - val_y_up_auc: 0.5944 - val_y_up_loss: 0.0861 - learning_rate: 0.0010
# Epoch 4/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.4105 - y_reg_z_loss: 0.3903 - y_up_auc: 0.4858 - y_up_loss: 0.1002 - val_loss: 0.1633 - val_y_reg_z_loss: 0.1333 - val_y_up_auc: 0.5200 - val_y_up_loss: 0.0855 - learning_rate: 0.0010
# Epoch 5/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3674 - y_reg_z_loss: 0.3498 - y_up_auc: 0.5007 - y_up_loss: 0.0881 - val_loss: 0.1776 - val_y_reg_z_loss: 0.1467 - val_y_up_auc: 0.4384 - val_y_up_loss: 0.0857 - learning_rate: 0.0010
# Epoch 6/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3298 - y_reg_z_loss: 0.3117 - y_up_auc: 0.4515 - y_up_loss: 0.0911 - val_loss: 0.1937 - val_y_reg_z_loss: 0.2005 - val_y_up_auc: 0.3751 - val_y_up_loss: 0.0824 - learning_rate: 0.0010
# Epoch 7/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3344 - y_reg_z_loss: 0.3168 - y_up_auc: 0.4574 - y_up_loss: 0.0883 - val_loss: 0.1625 - val_y_reg_z_loss: 0.1335 - val_y_up_auc: 0.4302 - val_y_up_loss: 0.0820 - learning_rate: 0.0010
# Epoch 8/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3241 - y_reg_z_loss: 0.3073 - y_up_auc: 0.5028 - y_up_loss: 0.0838 - val_loss: 0.1610 - val_y_reg_z_loss: 0.1336 - val_y_up_auc: 0.4400 - val_y_up_loss: 0.0813 - learning_rate: 0.0010
# Epoch 9/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3016 - y_reg_z_loss: 0.2846 - y_up_auc: 0.5023 - y_up_loss: 0.0845 - val_loss: 0.1584 - val_y_reg_z_loss: 0.1331 - val_y_up_auc: 0.3926 - val_y_up_loss: 0.0817 - learning_rate: 0.0010
# Epoch 10/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.2981 - y_reg_z_loss: 0.2817 - y_up_auc: 0.5809 - y_up_loss: 0.0823 - val_loss: 0.1656 - val_y_reg_z_loss: 0.1381 - val_y_up_auc: 0.4216 - val_y_up_loss: 0.0782 - learning_rate: 0.0010
# Epoch 11/150
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.2801 - y_reg_z_loss: 0.2658 - y_up_auc: 0.6521 - y_up_loss: 0.0720 - val_loss: 0.1685 - val_y_reg_z_loss: 0.1396 - val_y_up_auc: 0.4344 - val_y_up_loss: 0.0779 - learning_rate: 0.0010
#
# ===== Training IMPROVED LSTM for VCB.VN | TrainSeq=688 ValSeq=179 =====
# Epoch 1/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - loss: 0.6604 - y_reg_z_loss: 0.6329 - y_up_auc: 0.5265 - y_up_loss: 0.1345 - val_loss: 0.4239 - val_y_reg_z_loss: 0.4351 - val_y_up_auc: 0.5299 - val_y_up_loss: 0.1188 - learning_rate: 0.0010
# Epoch 2/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.4904 - y_reg_z_loss: 0.4647 - y_up_auc: 0.5298 - y_up_loss: 0.1292 - val_loss: 0.4227 - val_y_reg_z_loss: 0.4199 - val_y_up_auc: 0.4754 - val_y_up_loss: 0.1439 - learning_rate: 0.0010
# Epoch 3/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.4237 - y_reg_z_loss: 0.4015 - y_up_auc: 0.5545 - y_up_loss: 0.1112 - val_loss: 0.3943 - val_y_reg_z_loss: 0.3968 - val_y_up_auc: 0.4762 - val_y_up_loss: 0.1103 - learning_rate: 0.0010
# Epoch 4/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.3980 - y_reg_z_loss: 0.3803 - y_up_auc: 0.6096 - y_up_loss: 0.0884 - val_loss: 0.4271 - val_y_reg_z_loss: 0.4302 - val_y_up_auc: 0.4774 - val_y_up_loss: 0.0999 - learning_rate: 0.0010
# Epoch 5/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3670 - y_reg_z_loss: 0.3496 - y_up_auc: 0.5756 - y_up_loss: 0.0857 - val_loss: 0.3761 - val_y_reg_z_loss: 0.3848 - val_y_up_auc: 0.5071 - val_y_up_loss: 0.0893 - learning_rate: 0.0010
# Epoch 6/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.3628 - y_reg_z_loss: 0.3455 - y_up_auc: 0.6021 - y_up_loss: 0.0855 - val_loss: 0.3304 - val_y_reg_z_loss: 0.3373 - val_y_up_auc: 0.4828 - val_y_up_loss: 0.1027 - learning_rate: 0.0010
# Epoch 7/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3433 - y_reg_z_loss: 0.3265 - y_up_auc: 0.5965 - y_up_loss: 0.0841 - val_loss: 0.3506 - val_y_reg_z_loss: 0.3481 - val_y_up_auc: 0.4395 - val_y_up_loss: 0.1094 - learning_rate: 0.0010
# Epoch 8/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3435 - y_reg_z_loss: 0.3262 - y_up_auc: 0.5804 - y_up_loss: 0.0856 - val_loss: 0.3265 - val_y_reg_z_loss: 0.3223 - val_y_up_auc: 0.4915 - val_y_up_loss: 0.1078 - learning_rate: 0.0010
# Epoch 9/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.3228 - y_reg_z_loss: 0.3063 - y_up_auc: 0.6115 - y_up_loss: 0.0810 - val_loss: 0.2907 - val_y_reg_z_loss: 0.2794 - val_y_up_auc: 0.5832 - val_y_up_loss: 0.1081 - learning_rate: 0.0010
# Epoch 10/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3320 - y_reg_z_loss: 0.3168 - y_up_auc: 0.6339 - y_up_loss: 0.0757 - val_loss: 0.2586 - val_y_reg_z_loss: 0.2579 - val_y_up_auc: 0.5814 - val_y_up_loss: 0.1044 - learning_rate: 0.0010
# Epoch 11/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.2937 - y_reg_z_loss: 0.2802 - y_up_auc: 0.7117 - y_up_loss: 0.0667 - val_loss: 0.3526 - val_y_reg_z_loss: 0.3565 - val_y_up_auc: 0.4715 - val_y_up_loss: 0.1039 - learning_rate: 0.0010
# Epoch 12/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.2912 - y_reg_z_loss: 0.2756 - y_up_auc: 0.6380 - y_up_loss: 0.0772 - val_loss: 0.3519 - val_y_reg_z_loss: 0.3438 - val_y_up_auc: 0.5831 - val_y_up_loss: 0.0948 - learning_rate: 0.0010
# Epoch 13/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3094 - y_reg_z_loss: 0.2942 - y_up_auc: 0.6502 - y_up_loss: 0.0761 - val_loss: 0.3072 - val_y_reg_z_loss: 0.2969 - val_y_up_auc: 0.5714 - val_y_up_loss: 0.0980 - learning_rate: 0.0010
# Epoch 14/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2755 - y_reg_z_loss: 0.2612 - y_up_auc: 0.6778 - y_up_loss: 0.0712 - val_loss: 0.4474 - val_y_reg_z_loss: 0.4602 - val_y_up_auc: 0.5688 - val_y_up_loss: 0.1062 - learning_rate: 0.0010
# Epoch 15/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.2619 - y_reg_z_loss: 0.2486 - y_up_auc: 0.7305 - y_up_loss: 0.0656
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.2619 - y_reg_z_loss: 0.2487 - y_up_auc: 0.7301 - y_up_loss: 0.0656 - val_loss: 0.3815 - val_y_reg_z_loss: 0.3816 - val_y_up_auc: 0.5454 - val_y_up_loss: 0.1032 - learning_rate: 0.0010
# Epoch 16/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.2533 - y_reg_z_loss: 0.2406 - y_up_auc: 0.7379 - y_up_loss: 0.0629 - val_loss: 0.4039 - val_y_reg_z_loss: 0.4118 - val_y_up_auc: 0.5707 - val_y_up_loss: 0.1020 - learning_rate: 5.0000e-04
# Epoch 17/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.2391 - y_reg_z_loss: 0.2261 - y_up_auc: 0.7399 - y_up_loss: 0.0646 - val_loss: 0.4195 - val_y_reg_z_loss: 0.4266 - val_y_up_auc: 0.6202 - val_y_up_loss: 0.1032 - learning_rate: 5.0000e-04
# Epoch 18/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.2749 - y_reg_z_loss: 0.2604 - y_up_auc: 0.6839 - y_up_loss: 0.0714 - val_loss: 0.4049 - val_y_reg_z_loss: 0.4120 - val_y_up_auc: 0.6323 - val_y_up_loss: 0.1040 - learning_rate: 5.0000e-04
# Epoch 19/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.2433 - y_reg_z_loss: 0.2302 - y_up_auc: 0.7268 - y_up_loss: 0.0646 - val_loss: 0.3880 - val_y_reg_z_loss: 0.3931 - val_y_up_auc: 0.6665 - val_y_up_loss: 0.1017 - learning_rate: 5.0000e-04
# Epoch 20/150
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2293 - y_reg_z_loss: 0.2163 - y_up_auc: 0.7337 - y_up_loss: 0.0642
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.2288 - y_reg_z_loss: 0.2157 - y_up_auc: 0.7348 - y_up_loss: 0.0642 - val_loss: 0.4029 - val_y_reg_z_loss: 0.4045 - val_y_up_auc: 0.7000 - val_y_up_loss: 0.0981 - learning_rate: 5.0000e-04
# Epoch 21/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.2453 - y_reg_z_loss: 0.2323 - y_up_auc: 0.7079 - y_up_loss: 0.0656 - val_loss: 0.3941 - val_y_reg_z_loss: 0.3957 - val_y_up_auc: 0.7066 - val_y_up_loss: 0.0970 - learning_rate: 2.5000e-04
# Epoch 22/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.2259 - y_reg_z_loss: 0.2132 - y_up_auc: 0.7506 - y_up_loss: 0.0627 - val_loss: 0.3875 - val_y_reg_z_loss: 0.3888 - val_y_up_auc: 0.6979 - val_y_up_loss: 0.0966 - learning_rate: 2.5000e-04
# Epoch 23/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.2274 - y_reg_z_loss: 0.2142 - y_up_auc: 0.7210 - y_up_loss: 0.0654 - val_loss: 0.3931 - val_y_reg_z_loss: 0.3952 - val_y_up_auc: 0.6890 - val_y_up_loss: 0.0992 - learning_rate: 2.5000e-04
# Epoch 24/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.2391 - y_reg_z_loss: 0.2262 - y_up_auc: 0.7188 - y_up_loss: 0.0645 - val_loss: 0.4177 - val_y_reg_z_loss: 0.4219 - val_y_up_auc: 0.6902 - val_y_up_loss: 0.1047 - learning_rate: 2.5000e-04
# Epoch 25/150
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.2393 - y_reg_z_loss: 0.2266 - y_up_auc: 0.7478 - y_up_loss: 0.0627
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.2387 - y_reg_z_loss: 0.2260 - y_up_auc: 0.7498 - y_up_loss: 0.0625 - val_loss: 0.4160 - val_y_reg_z_loss: 0.4235 - val_y_up_auc: 0.7020 - val_y_up_loss: 0.1055 - learning_rate: 2.5000e-04
# Epoch 26/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.2294 - y_reg_z_loss: 0.2165 - y_up_auc: 0.7433 - y_up_loss: 0.0642 - val_loss: 0.4128 - val_y_reg_z_loss: 0.4212 - val_y_up_auc: 0.6961 - val_y_up_loss: 0.1050 - learning_rate: 1.2500e-04
# Epoch 27/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.2285 - y_reg_z_loss: 0.2161 - y_up_auc: 0.7579 - y_up_loss: 0.0618 - val_loss: 0.3988 - val_y_reg_z_loss: 0.4071 - val_y_up_auc: 0.6977 - val_y_up_loss: 0.1034 - learning_rate: 1.2500e-04
# Epoch 28/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.2256 - y_reg_z_loss: 0.2131 - y_up_auc: 0.7656 - y_up_loss: 0.0620 - val_loss: 0.4002 - val_y_reg_z_loss: 0.4100 - val_y_up_auc: 0.6916 - val_y_up_loss: 0.1037 - learning_rate: 1.2500e-04
# Epoch 29/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.2474 - y_reg_z_loss: 0.2347 - y_up_auc: 0.7440 - y_up_loss: 0.0632 - val_loss: 0.4183 - val_y_reg_z_loss: 0.4301 - val_y_up_auc: 0.6900 - val_y_up_loss: 0.1046 - learning_rate: 1.2500e-04
# Epoch 30/150
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.2255 - y_reg_z_loss: 0.2128 - y_up_auc: 0.7454 - y_up_loss: 0.0630
# Epoch 30: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.2245 - y_reg_z_loss: 0.2118 - y_up_auc: 0.7486 - y_up_loss: 0.0627 - val_loss: 0.4195 - val_y_reg_z_loss: 0.4307 - val_y_up_auc: 0.6878 - val_y_up_loss: 0.1055 - learning_rate: 1.2500e-04
# Epoch 31/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.2230 - y_reg_z_loss: 0.2104 - y_up_auc: 0.7548 - y_up_loss: 0.0620 - val_loss: 0.4176 - val_y_reg_z_loss: 0.4290 - val_y_up_auc: 0.6870 - val_y_up_loss: 0.1060 - learning_rate: 6.2500e-05
#
# ===== IMPROVED LSTM SUMMARY =====
# Ticker  N_test_seq     RMSE      MAE  Directional_Acc  Precision_Up  Recall_Up    F1_Up      AUC  Best_Threshold  Val_BalAcc_at_bestT  TN  FP  FN  TP
# VCB.VN         202 0.005503 0.004447         0.514851      0.429825   0.597561 0.500000 0.543089            0.31             0.675821  55  65  33  49
# BID.VN         202 0.006313 0.004837         0.544554      0.464286   0.144444 0.220339 0.513690            0.42             0.639520  97  15  77  13
# CTG.VN         202 0.007326 0.005842         0.490099      1.000000   0.019048 0.037383 0.674423            0.44             0.564679  97   0 103   2
# TCB.VN         184 0.010005 0.007942         0.434783      0.642857   0.232759 0.341772 0.490112            0.50             0.645101  53  15  89  27

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import mean_squared_error

def plot_4stocks_actual_vs_lstm(
    stock_data,   # dict: {ticker: (dates, y_true, y_pred)}
    max_points=250
):
    fig, axes = plt.subplots(2, 2, figsize=(14, 8), sharey=True)
    axes = axes.flatten()

    for ax, (ticker, (y_true, y_pred)) in zip(axes, stock_data.items()):

        if len(y_true) > max_points:
            # dates  = dates[-max_points:]
            y_true = y_true[-max_points:]
            y_pred = y_pred[-max_points:]

        # RMSE
        rmse = np.sqrt(mean_squared_error(y_true, y_pred))
        ax.set_xlabel("Test Time Index")
        ax.plot(y_true, label="Actual", linewidth=1.8)
        ax.plot(y_pred, label="LSTM Predicted")

        ax.set_title(
            f"{ticker} | Actual vs LSTM Predicted Returns\nRMSE = {rmse:.4f}",
            fontsize=11
        )
        ax.grid(alpha=0.3)

    axes[0].legend(loc="upper left")
    fig.suptitle("Actual vs LSTM Predicted Returns", fontsize=14)
    fig.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.show()
stock_data = {}

for tk in ["VCB.VN", "TCB.VN", "BID.VN", "CTG.VN"]:
    model = lstm_models[tk]
    y_mu = lstm_meta[tk]["y_mu"]
    y_sd = lstm_meta[tk]["y_sd"]

    X_train_seq, X_test_seq, y_train_seq, y_test_seq, X_val, y_val = lstm_splits[tk]

    y_reg_z_pred, _ = model.predict(X_test_seq, verbose=0)
    y_pred = y_reg_z_pred.reshape(-1) * y_sd + y_mu

    dft = df[df["ticker"] == tk].sort_values("date")
    split_index = int(len(dft) * 0.8)
    # dates = dft["date"].iloc[split_index + LOOKBACK:].values

    stock_data[tk] = (y_test_seq, y_pred)

plot_4stocks_actual_vs_lstm(stock_data)

# %% [markdown]
# # Transformer

# %%
# ---------- Positional Encoding ----------
class PositionalEncoding(tf.keras.layers.Layer):
    def __init__(self, position: int, d_model: int):
        super().__init__()
        pos = np.arange(position)[:, np.newaxis]
        i   = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        angle_rads  = pos * angle_rates
        angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
        angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.pos_encoding = tf.constant(angle_rads[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        return x + self.pos_encoding[:, :tf.shape(x)[1], :]

def transformer_encoder(x, num_heads, key_dim, ff_dim, dropout=0.2):
    attn_out = tf.keras.layers.MultiHeadAttention(
        num_heads=num_heads, key_dim=key_dim, dropout=dropout
    )(x, x)
    attn_out = tf.keras.layers.Dropout(dropout)(attn_out)
    x = tf.keras.layers.Add()([x, attn_out])
    x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(x)

    ff = tf.keras.layers.Dense(ff_dim, activation="relu")(x)
    ff = tf.keras.layers.Dropout(dropout)(ff)
    ff = tf.keras.layers.Dense(x.shape[-1])(ff)
    x = tf.keras.layers.Add()([x, ff])
    x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(x)
    return x

# %%
def build_transformer_multitask(
    input_shape,
    d_model=64,
    num_heads=4,
    ff_dim=128,
    num_blocks=3,
    dropout=0.2,
    use_conv_frontend=True
):
    """
    input_shape: (LOOKBACK, n_features)
    outputs:
      - y_reg_z: standardized return (regression)
      - y_up: probability of Up (classification)
    """
    inputs = tf.keras.Input(shape=input_shape)

    # Project features -> d_model
    x = tf.keras.layers.Dense(d_model)(inputs)

    # Optional local-pattern front-end (often helps for financial series)
    if use_conv_frontend:
        x = tf.keras.layers.Conv1D(filters=d_model, kernel_size=3, padding="causal", activation="relu")(x)
        x = tf.keras.layers.Dropout(dropout)(x)

    x = PositionalEncoding(position=input_shape[0], d_model=d_model)(x)

    key_dim = max(8, d_model // num_heads)
    for _ in range(num_blocks):
        x = transformer_encoder(x, num_heads=num_heads, key_dim=key_dim, ff_dim=ff_dim, dropout=dropout)

    x = tf.keras.layers.GlobalAveragePooling1D()(x)
    x = tf.keras.layers.Dropout(dropout)(x)

    # Head 1: regression on standardized target
    y_reg_z = tf.keras.layers.Dense(1, name="y_reg_z")(x)

    # Head 2: direction probability
    y_up = tf.keras.layers.Dense(1, activation="sigmoid", name="y_up")(x)

    return tf.keras.Model(inputs, [y_reg_z, y_up])

# %%
def make_weighted_bce(w_pos, w_neg):
    # w_pos applies to y_true==1, w_neg applies to y_true==0
    def weighted_bce(y_true, y_pred):
        bce = tf.keras.backend.binary_crossentropy(y_true, y_pred)
        w = y_true * w_pos + (1.0 - y_true) * w_neg
        return tf.reduce_mean(bce * w)
    return weighted_bce

# %%
import numpy as np
from sklearn.metrics import f1_score

def tune_threshold(y_true_bin, y_prob, lo=0.3, hi=0.7, n=81):
    ths = np.linspace(lo, hi, n)
    best_t, best_f1 = 0.5, -1
    for t in ths:
        f1 = f1_score(y_true_bin, (y_prob > t).astype(int), zero_division=0)
        if f1 > best_f1:
            best_f1, best_t = f1, t
    return best_t, best_f1

# %%
def create_sequences(X, y, seq_len):
    X_seq, y_seq = [], []
    for i in range(seq_len, len(X)):
        X_seq.append(X[i-seq_len:i])
        y_seq.append(y[i])
    return np.array(X_seq), np.array(y_seq)

LOOKBACK = 30
non_feature = ['date', 'ticker', 'target']
feature_cols = [c for c in df.columns if c not in non_feature]

df = df.copy()
df["date"] = pd.to_datetime(df["date"])

models, scalers, histories, splits, meta = {}, {}, {}, {}, {}


# -------------------
import tensorflow as tf
import numpy as np

def focal_loss(alpha=0.5, gamma=2.0):
    """Binary focal loss for collapse-prone classification."""
    def fl(y_true, y_pred):
        eps = tf.keras.backend.epsilon()
        y_pred = tf.clip_by_value(y_pred, eps, 1.0 - eps)
        ce = -(y_true * tf.math.log(y_pred) + (1.0 - y_true) * tf.math.log(1.0 - y_pred))
        p_t = y_true * y_pred + (1.0 - y_true) * (1.0 - y_pred)
        w = alpha * y_true + (1.0 - alpha) * (1.0 - y_true)
        return tf.reduce_mean(w * tf.pow((1.0 - p_t), gamma) * ce)
    return fl

def make_direction_labels_with_mask(y, vol_proxy, k=0.3):
    """
    y: target series (float)
    vol_proxy: volatility proxy at time t (must be past-only; shift outside if needed)
    k: noise filter strength; CTG thường hợp 0.25–0.40
    Returns:
      y_up (0/1), mask (0/1) -> mask=0 means ignore this sample for classification loss
    """
    vol_proxy = np.asarray(vol_proxy, dtype=np.float32)
    y = np.asarray(y, dtype=np.float32)

    thr = k * vol_proxy
    mask = np.isfinite(y) & np.isfinite(vol_proxy) & (np.abs(y) >= thr)
    y_up = (y > 0).astype(np.float32)

    return y_up, mask.astype(np.float32)
# --------------

for tk, dft in df.groupby("ticker"):
    dft = dft.sort_values("date").reset_index(drop=True)

    X = dft[feature_cols].values.astype(np.float32)
    y = dft["target"].values.astype(np.float32)

    if len(dft) < (LOOKBACK + 80):
        print(f"⚠️ {tk}: dữ liệu quá ít ({len(dft)} dòng) -> bỏ qua")
        continue

    split_index = int(len(dft) * 0.8)
    X_train_raw, X_test_raw = X[:split_index], X[split_index:]
    y_train_raw, y_test_raw = y[:split_index], y[split_index:]

    scaler = RobustScaler()
    X_train_scaled = scaler.fit_transform(X_train_raw)
    X_test_scaled  = scaler.transform(X_test_raw)

    X_train_seq, y_train_seq = create_sequences(X_train_scaled, y_train_raw, LOOKBACK)
    X_test_seq,  y_test_seq  = create_sequences(X_test_scaled,  y_test_raw,  LOOKBACK)

    # validation from tail of train
    val_size = max(1, int(0.2 * len(X_train_seq)))
    X_tr, y_tr = X_train_seq[:-val_size], y_train_seq[:-val_size]
    X_val, y_val = X_train_seq[-val_size:], y_train_seq[-val_size:]

    # ===== 1) Standardize y on train ONLY =====
    y_mu = float(np.mean(y_tr))
    y_sd = float(np.std(y_tr) + 1e-8)
    y_tr_z  = ((y_tr  - y_mu) / y_sd).astype(np.float32)
    y_val_z = ((y_val - y_mu) / y_sd).astype(np.float32)

    # direction labels
    y_tr_up  = (y_tr > 0).astype(np.float32)
    y_val_up = (y_val > 0).astype(np.float32)

    # ===== 2) Weighted BCE to reduce collapse/bias =====
    pos = float(y_tr_up.mean())          # P(Up)
    w_pos = 0.5 / (pos + 1e-8)
    w_neg = 0.5 / (1.0 - pos + 1e-8)
    w_bce = make_weighted_bce(w_pos=w_pos, w_neg=w_neg)

    # ===== 3) Build model =====
    model = build_transformer_multitask(
        input_shape=(LOOKBACK, X_train_seq.shape[2]),
        d_model=64,
        num_heads=4,
        ff_dim=128,
        num_blocks=3,
        dropout=0.2,
        use_conv_frontend=True
    )

    # optimizer: clipnorm improves stability a lot on noisy targets
    opt = Adam(learning_rate=1e-3, clipnorm=1.0)

    model.compile(
        optimizer=opt,
        loss={
            "y_reg_z": tf.keras.losses.Huber(delta=1.0),
            "y_up": w_bce
        },
        loss_weights={"y_reg_z": 1.0, "y_up": 0.5}  # you can try 0.3–0.8
    )

    early_stop = EarlyStopping(monitor="val_loss", patience=12, restore_best_weights=True)
    rlr = ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=5, min_lr=1e-5, verbose=1)

    print(f"\n===== Training Transformer (Improved) for {tk} | UpRatio={pos:.3f} =====")
    history = model.fit(
        X_tr, {"y_reg_z": y_tr_z, "y_up": y_tr_up},
        validation_data=(X_val, {"y_reg_z": y_val_z, "y_up": y_val_up}),
        epochs=120,
        batch_size=32,   # often better than 64 for financial series
        callbacks=[early_stop, rlr],
        verbose=1
    )

    models[tk] = model
    scalers[tk] = scaler
    histories[tk] = history
    splits[tk] = (X_train_seq, X_test_seq, y_train_seq, y_test_seq)
    meta[tk] = {"y_mu": y_mu, "y_sd": y_sd, "up_ratio": pos, "w_pos": w_pos, "w_neg": w_neg}

print("\nDone. Models trained for:", list(models.keys()))
# Out:
# ===== Training Transformer (Improved) for BID.VN | UpRatio=0.524 =====
# Epoch 1/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 16s 107ms/step - loss: 1.0396 - y_reg_z_loss: 0.6218 - y_up_loss: 0.8348 - val_loss: 0.6601 - val_y_reg_z_loss: 0.3688 - val_y_up_loss: 0.7028 - learning_rate: 0.0010
# Epoch 2/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 0.8472 - y_reg_z_loss: 0.4854 - y_up_loss: 0.7232 - val_loss: 0.6041 - val_y_reg_z_loss: 0.2937 - val_y_up_loss: 0.7335 - learning_rate: 0.0010
# Epoch 3/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 0.7615 - y_reg_z_loss: 0.4199 - y_up_loss: 0.6833 - val_loss: 0.6154 - val_y_reg_z_loss: 0.3004 - val_y_up_loss: 0.7492 - learning_rate: 0.0010
# Epoch 4/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 0.7752 - y_reg_z_loss: 0.4219 - y_up_loss: 0.7065 - val_loss: 0.6138 - val_y_reg_z_loss: 0.2665 - val_y_up_loss: 0.8061 - learning_rate: 0.0010
# Epoch 5/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step - loss: 0.7434 - y_reg_z_loss: 0.4076 - y_up_loss: 0.6710 - val_loss: 0.6601 - val_y_reg_z_loss: 0.3265 - val_y_up_loss: 0.8411 - learning_rate: 0.0010
# Epoch 6/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - loss: 0.6493 - y_reg_z_loss: 0.3437 - y_up_loss: 0.6104 - val_loss: 0.7603 - val_y_reg_z_loss: 0.3969 - val_y_up_loss: 0.8749 - learning_rate: 0.0010
# Epoch 7/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - loss: 0.5862 - y_reg_z_loss: 0.3119 - y_up_loss: 0.5482 - val_loss: 0.4150 - val_y_reg_z_loss: 0.1615 - val_y_up_loss: 0.5409 - learning_rate: 0.0010
# Epoch 8/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 0.4624 - y_reg_z_loss: 0.2327 - y_up_loss: 0.4592 - val_loss: 0.5168 - val_y_reg_z_loss: 0.2015 - val_y_up_loss: 0.7051 - learning_rate: 0.0010
# Epoch 9/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.4481 - y_reg_z_loss: 0.2294 - y_up_loss: 0.4375 - val_loss: 0.4836 - val_y_reg_z_loss: 0.1656 - val_y_up_loss: 0.6985 - learning_rate: 0.0010
# Epoch 10/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - loss: 0.4338 - y_reg_z_loss: 0.2226 - y_up_loss: 0.4219 - val_loss: 0.4333 - val_y_reg_z_loss: 0.1694 - val_y_up_loss: 0.5643 - learning_rate: 0.0010
# Epoch 11/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - loss: 0.4160 - y_reg_z_loss: 0.2166 - y_up_loss: 0.3987 - val_loss: 0.6058 - val_y_reg_z_loss: 0.2470 - val_y_up_loss: 0.7852 - learning_rate: 0.0010
# Epoch 12/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.3989 - y_reg_z_loss: 0.2045 - y_up_loss: 0.3885 - val_loss: 0.3752 - val_y_reg_z_loss: 0.1306 - val_y_up_loss: 0.5063 - learning_rate: 0.0010
# Epoch 13/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 0.4100 - y_reg_z_loss: 0.2194 - y_up_loss: 0.3808 - val_loss: 0.4537 - val_y_reg_z_loss: 0.1723 - val_y_up_loss: 0.5743 - learning_rate: 0.0010
# Epoch 14/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 0.3497 - y_reg_z_loss: 0.1794 - y_up_loss: 0.3404 - val_loss: 0.4390 - val_y_reg_z_loss: 0.1667 - val_y_up_loss: 0.5488 - learning_rate: 0.0010
# Epoch 15/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - loss: 0.3709 - y_reg_z_loss: 0.1904 - y_up_loss: 0.3604 - val_loss: 0.4295 - val_y_reg_z_loss: 0.1690 - val_y_up_loss: 0.5516 - learning_rate: 0.0010
# Epoch 16/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - loss: 0.3207 - y_reg_z_loss: 0.1592 - y_up_loss: 0.3226 - val_loss: 0.5631 - val_y_reg_z_loss: 0.2105 - val_y_up_loss: 0.7576 - learning_rate: 0.0010
# Epoch 17/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - loss: 0.3348 - y_reg_z_loss: 0.1763 - y_up_loss: 0.3166
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 201ms/step - loss: 0.3346 - y_reg_z_loss: 0.1759 - y_up_loss: 0.3167 - val_loss: 0.5074 - val_y_reg_z_loss: 0.1902 - val_y_up_loss: 0.6719 - learning_rate: 0.0010
# Epoch 18/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - loss: 0.3051 - y_reg_z_loss: 0.1530 - y_up_loss: 0.3037 - val_loss: 0.4860 - val_y_reg_z_loss: 0.1771 - val_y_up_loss: 0.6583 - learning_rate: 5.0000e-04
# Epoch 19/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.3215 - y_reg_z_loss: 0.1687 - y_up_loss: 0.3047 - val_loss: 0.5231 - val_y_reg_z_loss: 0.1981 - val_y_up_loss: 0.6821 - learning_rate: 5.0000e-04
# Epoch 20/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 0.2764 - y_reg_z_loss: 0.1398 - y_up_loss: 0.2729 - val_loss: 0.5623 - val_y_reg_z_loss: 0.2156 - val_y_up_loss: 0.7517 - learning_rate: 5.0000e-04
# Epoch 21/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - loss: 0.2768 - y_reg_z_loss: 0.1430 - y_up_loss: 0.2668 - val_loss: 0.5219 - val_y_reg_z_loss: 0.1905 - val_y_up_loss: 0.7024 - learning_rate: 5.0000e-04
# Epoch 22/120
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2848 - y_reg_z_loss: 0.1442 - y_up_loss: 0.2811
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 0.2837 - y_reg_z_loss: 0.1435 - y_up_loss: 0.2800 - val_loss: 0.6532 - val_y_reg_z_loss: 0.2694 - val_y_up_loss: 0.8437 - learning_rate: 5.0000e-04
# Epoch 23/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - loss: 0.2544 - y_reg_z_loss: 0.1335 - y_up_loss: 0.2411 - val_loss: 0.5928 - val_y_reg_z_loss: 0.2128 - val_y_up_loss: 0.8315 - learning_rate: 2.5000e-04
# Epoch 24/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 0.2599 - y_reg_z_loss: 0.1335 - y_up_loss: 0.2523 - val_loss: 0.6375 - val_y_reg_z_loss: 0.2265 - val_y_up_loss: 0.8880 - learning_rate: 2.5000e-04
#
# ===== Training Transformer (Improved) for CTG.VN | UpRatio=0.511 =====
# Epoch 1/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 16s 108ms/step - loss: 1.0480 - y_reg_z_loss: 0.6538 - y_up_loss: 0.7873 - val_loss: 0.6181 - val_y_reg_z_loss: 0.2326 - val_y_up_loss: 0.8553 - learning_rate: 0.0010
# Epoch 2/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - loss: 0.8069 - y_reg_z_loss: 0.4696 - y_up_loss: 0.6738 - val_loss: 0.7720 - val_y_reg_z_loss: 0.3453 - val_y_up_loss: 0.9858 - learning_rate: 0.0010
# Epoch 3/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 0.7511 - y_reg_z_loss: 0.4099 - y_up_loss: 0.6818 - val_loss: 0.8185 - val_y_reg_z_loss: 0.3753 - val_y_up_loss: 1.0443 - learning_rate: 0.0010
# Epoch 4/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.7311 - y_reg_z_loss: 0.3898 - y_up_loss: 0.6817 - val_loss: 1.1204 - val_y_reg_z_loss: 0.6106 - val_y_up_loss: 1.2496 - learning_rate: 0.0010
# Epoch 5/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - loss: 0.6931 - y_reg_z_loss: 0.3660 - y_up_loss: 0.6537 - val_loss: 1.3324 - val_y_reg_z_loss: 0.8190 - val_y_up_loss: 1.2751 - learning_rate: 0.0010
# Epoch 6/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 0.6703 - y_reg_z_loss: 0.3529 - y_up_loss: 0.6342
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 199ms/step - loss: 0.6699 - y_reg_z_loss: 0.3527 - y_up_loss: 0.6333 - val_loss: 1.3596 - val_y_reg_z_loss: 0.7853 - val_y_up_loss: 1.3964 - learning_rate: 0.0010
# Epoch 7/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - loss: 0.5711 - y_reg_z_loss: 0.2864 - y_up_loss: 0.5687 - val_loss: 1.1198 - val_y_reg_z_loss: 0.5537 - val_y_up_loss: 1.3810 - learning_rate: 5.0000e-04
# Epoch 8/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - loss: 0.5411 - y_reg_z_loss: 0.2678 - y_up_loss: 0.5458 - val_loss: 1.1366 - val_y_reg_z_loss: 0.5415 - val_y_up_loss: 1.4558 - learning_rate: 5.0000e-04
# Epoch 9/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - loss: 0.4843 - y_reg_z_loss: 0.2378 - y_up_loss: 0.4923 - val_loss: 1.0252 - val_y_reg_z_loss: 0.4391 - val_y_up_loss: 1.4475 - learning_rate: 5.0000e-04
# Epoch 10/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 0.4413 - y_reg_z_loss: 0.2233 - y_up_loss: 0.4359 - val_loss: 1.1531 - val_y_reg_z_loss: 0.5212 - val_y_up_loss: 1.5435 - learning_rate: 5.0000e-04
# Epoch 11/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.4227 - y_reg_z_loss: 0.2171 - y_up_loss: 0.4111
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.4230 - y_reg_z_loss: 0.2172 - y_up_loss: 0.4111 - val_loss: 1.0451 - val_y_reg_z_loss: 0.4223 - val_y_up_loss: 1.5222 - learning_rate: 5.0000e-04
# Epoch 12/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.4112 - y_reg_z_loss: 0.2153 - y_up_loss: 0.3912 - val_loss: 1.3692 - val_y_reg_z_loss: 0.6349 - val_y_up_loss: 1.7917 - learning_rate: 2.5000e-04
# Epoch 13/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 0.3865 - y_reg_z_loss: 0.1938 - y_up_loss: 0.3849 - val_loss: 1.1647 - val_y_reg_z_loss: 0.4830 - val_y_up_loss: 1.6713 - learning_rate: 2.5000e-04
#
# ===== Training Transformer (Improved) for TCB.VN | UpRatio=0.555 =====
# Epoch 1/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 149ms/step - loss: 1.0958 - y_reg_z_loss: 0.7395 - y_up_loss: 0.7118 - val_loss: 0.5538 - val_y_reg_z_loss: 0.1400 - val_y_up_loss: 0.8078 - learning_rate: 0.0010
# Epoch 2/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - loss: 0.7379 - y_reg_z_loss: 0.3898 - y_up_loss: 0.6955 - val_loss: 0.5282 - val_y_reg_z_loss: 0.1420 - val_y_up_loss: 0.7425 - learning_rate: 0.0010
# Epoch 3/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.6998 - y_reg_z_loss: 0.3641 - y_up_loss: 0.6713 - val_loss: 0.5340 - val_y_reg_z_loss: 0.1456 - val_y_up_loss: 0.7445 - learning_rate: 0.0010
# Epoch 4/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 0.6583 - y_reg_z_loss: 0.3286 - y_up_loss: 0.6591 - val_loss: 0.5320 - val_y_reg_z_loss: 0.1476 - val_y_up_loss: 0.7276 - learning_rate: 0.0010
# Epoch 5/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.6355 - y_reg_z_loss: 0.3181 - y_up_loss: 0.6343 - val_loss: 0.5566 - val_y_reg_z_loss: 0.1591 - val_y_up_loss: 0.7490 - learning_rate: 0.0010
# Epoch 6/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.5838 - y_reg_z_loss: 0.2900 - y_up_loss: 0.5870 - val_loss: 0.5828 - val_y_reg_z_loss: 0.1738 - val_y_up_loss: 0.7675 - learning_rate: 0.0010
# Epoch 7/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.5445 - y_reg_z_loss: 0.2621 - y_up_loss: 0.5646
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - loss: 0.5452 - y_reg_z_loss: 0.2630 - y_up_loss: 0.5636 - val_loss: 0.5749 - val_y_reg_z_loss: 0.1853 - val_y_up_loss: 0.7285 - learning_rate: 0.0010
# Epoch 8/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - loss: 0.4396 - y_reg_z_loss: 0.2007 - y_up_loss: 0.4772 - val_loss: 0.5546 - val_y_reg_z_loss: 0.2077 - val_y_up_loss: 0.6656 - learning_rate: 5.0000e-04
# Epoch 9/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.3983 - y_reg_z_loss: 0.1951 - y_up_loss: 0.4060 - val_loss: 0.5226 - val_y_reg_z_loss: 0.1780 - val_y_up_loss: 0.6357 - learning_rate: 5.0000e-04
# Epoch 10/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.3724 - y_reg_z_loss: 0.1886 - y_up_loss: 0.3671 - val_loss: 0.5091 - val_y_reg_z_loss: 0.1638 - val_y_up_loss: 0.6393 - learning_rate: 5.0000e-04
# Epoch 11/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.3794 - y_reg_z_loss: 0.1879 - y_up_loss: 0.3827 - val_loss: 0.5081 - val_y_reg_z_loss: 0.1585 - val_y_up_loss: 0.6525 - learning_rate: 5.0000e-04
# Epoch 12/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.3299 - y_reg_z_loss: 0.1740 - y_up_loss: 0.3113 - val_loss: 0.5076 - val_y_reg_z_loss: 0.1593 - val_y_up_loss: 0.6522 - learning_rate: 5.0000e-04
# Epoch 13/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.3538 - y_reg_z_loss: 0.1893 - y_up_loss: 0.3285 - val_loss: 0.4837 - val_y_reg_z_loss: 0.1445 - val_y_up_loss: 0.6367 - learning_rate: 5.0000e-04
# Epoch 14/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.3371 - y_reg_z_loss: 0.1750 - y_up_loss: 0.3240 - val_loss: 0.5245 - val_y_reg_z_loss: 0.1667 - val_y_up_loss: 0.6566 - learning_rate: 5.0000e-04
# Epoch 15/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - loss: 0.3270 - y_reg_z_loss: 0.1597 - y_up_loss: 0.3341 - val_loss: 0.5058 - val_y_reg_z_loss: 0.1722 - val_y_up_loss: 0.6458 - learning_rate: 5.0000e-04
# Epoch 16/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.3132 - y_reg_z_loss: 0.1650 - y_up_loss: 0.2960 - val_loss: 0.5145 - val_y_reg_z_loss: 0.1464 - val_y_up_loss: 0.7013 - learning_rate: 5.0000e-04
# Epoch 17/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.2758 - y_reg_z_loss: 0.1389 - y_up_loss: 0.2734 - val_loss: 0.5039 - val_y_reg_z_loss: 0.1320 - val_y_up_loss: 0.7102 - learning_rate: 5.0000e-04
# Epoch 18/120
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.2902 - y_reg_z_loss: 0.1413 - y_up_loss: 0.2977
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.2903 - y_reg_z_loss: 0.1419 - y_up_loss: 0.2964 - val_loss: 0.5283 - val_y_reg_z_loss: 0.1441 - val_y_up_loss: 0.7231 - learning_rate: 5.0000e-04
# Epoch 19/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.2558 - y_reg_z_loss: 0.1251 - y_up_loss: 0.2612 - val_loss: 0.5422 - val_y_reg_z_loss: 0.1484 - val_y_up_loss: 0.7401 - learning_rate: 2.5000e-04
# Epoch 20/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.2706 - y_reg_z_loss: 0.1296 - y_up_loss: 0.2817 - val_loss: 0.5672 - val_y_reg_z_loss: 0.1469 - val_y_up_loss: 0.7856 - learning_rate: 2.5000e-04
# Epoch 21/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.2530 - y_reg_z_loss: 0.1159 - y_up_loss: 0.2740 - val_loss: 0.5566 - val_y_reg_z_loss: 0.1512 - val_y_up_loss: 0.8155 - learning_rate: 2.5000e-04
# Epoch 22/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.2546 - y_reg_z_loss: 0.1237 - y_up_loss: 0.2618 - val_loss: 0.6003 - val_y_reg_z_loss: 0.1717 - val_y_up_loss: 0.8042 - learning_rate: 2.5000e-04
# Epoch 23/120
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.2404 - y_reg_z_loss: 0.1164 - y_up_loss: 0.2481
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - loss: 0.2408 - y_reg_z_loss: 0.1173 - y_up_loss: 0.2468 - val_loss: 0.5729 - val_y_reg_z_loss: 0.1484 - val_y_up_loss: 0.8272 - learning_rate: 2.5000e-04
# Epoch 24/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.2241 - y_reg_z_loss: 0.1073 - y_up_loss: 0.2335 - val_loss: 0.5897 - val_y_reg_z_loss: 0.1573 - val_y_up_loss: 0.8448 - learning_rate: 1.2500e-04
# Epoch 25/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.2085 - y_reg_z_loss: 0.0973 - y_up_loss: 0.2222 - val_loss: 0.5870 - val_y_reg_z_loss: 0.1533 - val_y_up_loss: 0.8628 - learning_rate: 1.2500e-04
#
# ===== Training Transformer (Improved) for VCB.VN | UpRatio=0.526 =====
# Epoch 1/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 16s 112ms/step - loss: 1.2071 - y_reg_z_loss: 0.7952 - y_up_loss: 0.8234 - val_loss: 0.5757 - val_y_reg_z_loss: 0.2353 - val_y_up_loss: 0.6985 - learning_rate: 0.0010
# Epoch 2/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - loss: 0.8902 - y_reg_z_loss: 0.5345 - y_up_loss: 0.7118 - val_loss: 0.5687 - val_y_reg_z_loss: 0.2067 - val_y_up_loss: 0.7438 - learning_rate: 0.0010
# Epoch 3/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - loss: 0.8358 - y_reg_z_loss: 0.4835 - y_up_loss: 0.7043 - val_loss: 0.6174 - val_y_reg_z_loss: 0.2191 - val_y_up_loss: 0.8243 - learning_rate: 0.0010
# Epoch 4/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - loss: 0.7791 - y_reg_z_loss: 0.4347 - y_up_loss: 0.6888 - val_loss: 0.6427 - val_y_reg_z_loss: 0.2340 - val_y_up_loss: 0.8436 - learning_rate: 0.0010
# Epoch 5/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.7444 - y_reg_z_loss: 0.4095 - y_up_loss: 0.6705 - val_loss: 0.6376 - val_y_reg_z_loss: 0.2399 - val_y_up_loss: 0.8309 - learning_rate: 0.0010
# Epoch 6/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.6762 - y_reg_z_loss: 0.3697 - y_up_loss: 0.6127 - val_loss: 0.8513 - val_y_reg_z_loss: 0.4527 - val_y_up_loss: 0.8329 - learning_rate: 0.0010
# Epoch 7/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.5433 - y_reg_z_loss: 0.2837 - y_up_loss: 0.5193 - val_loss: 0.4152 - val_y_reg_z_loss: 0.1349 - val_y_up_loss: 0.5695 - learning_rate: 0.0010
# Epoch 8/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - loss: 0.5033 - y_reg_z_loss: 0.2720 - y_up_loss: 0.4628 - val_loss: 0.4400 - val_y_reg_z_loss: 0.1437 - val_y_up_loss: 0.5842 - learning_rate: 0.0010
# Epoch 9/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.4359 - y_reg_z_loss: 0.2292 - y_up_loss: 0.4138 - val_loss: 0.5651 - val_y_reg_z_loss: 0.2146 - val_y_up_loss: 0.7230 - learning_rate: 0.0010
# Epoch 10/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.4283 - y_reg_z_loss: 0.2320 - y_up_loss: 0.3930 - val_loss: 0.4308 - val_y_reg_z_loss: 0.1364 - val_y_up_loss: 0.5678 - learning_rate: 0.0010
# Epoch 11/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.4025 - y_reg_z_loss: 0.2079 - y_up_loss: 0.3897 - val_loss: 0.4484 - val_y_reg_z_loss: 0.1565 - val_y_up_loss: 0.5732 - learning_rate: 0.0010
# Epoch 12/120
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.3820 - y_reg_z_loss: 0.1942 - y_up_loss: 0.3757
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.3811 - y_reg_z_loss: 0.1941 - y_up_loss: 0.3743 - val_loss: 0.5310 - val_y_reg_z_loss: 0.1967 - val_y_up_loss: 0.6476 - learning_rate: 0.0010
# Epoch 13/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.3501 - y_reg_z_loss: 0.1857 - y_up_loss: 0.3296 - val_loss: 0.5017 - val_y_reg_z_loss: 0.1732 - val_y_up_loss: 0.6381 - learning_rate: 5.0000e-04
# Epoch 14/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.3501 - y_reg_z_loss: 0.1954 - y_up_loss: 0.3095 - val_loss: 0.5230 - val_y_reg_z_loss: 0.1906 - val_y_up_loss: 0.6539 - learning_rate: 5.0000e-04
# Epoch 15/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 0.3661 - y_reg_z_loss: 0.1957 - y_up_loss: 0.3405 - val_loss: 0.5158 - val_y_reg_z_loss: 0.1671 - val_y_up_loss: 0.6815 - learning_rate: 5.0000e-04
# Epoch 16/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - loss: 0.3379 - y_reg_z_loss: 0.1737 - y_up_loss: 0.3282 - val_loss: 0.5099 - val_y_reg_z_loss: 0.1679 - val_y_up_loss: 0.6656 - learning_rate: 5.0000e-04
# Epoch 17/120
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.3221 - y_reg_z_loss: 0.1717 - y_up_loss: 0.3008
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.3207 - y_reg_z_loss: 0.1711 - y_up_loss: 0.2991 - val_loss: 0.5274 - val_y_reg_z_loss: 0.1776 - val_y_up_loss: 0.6817 - learning_rate: 5.0000e-04
# Epoch 18/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.3193 - y_reg_z_loss: 0.1750 - y_up_loss: 0.2883 - val_loss: 0.5617 - val_y_reg_z_loss: 0.2040 - val_y_up_loss: 0.7035 - learning_rate: 2.5000e-04
# Epoch 19/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.2838 - y_reg_z_loss: 0.1533 - y_up_loss: 0.2610 - val_loss: 0.5959 - val_y_reg_z_loss: 0.2217 - val_y_up_loss: 0.7383 - learning_rate: 2.5000e-04
#
# Done. Models trained for: ['BID.VN', 'CTG.VN', 'TCB.VN', 'VCB.VN']

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import (
    mean_squared_error, mean_absolute_error,
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, confusion_matrix
)

def safe_auc(y_true_bin, y_prob):
    if len(np.unique(y_true_bin)) < 2:
        return np.nan
    return roc_auc_score(y_true_bin, y_prob)

summary_rows = []

for tk in models.keys():
    X_train_seq, X_test_seq, y_train_seq, y_test_seq = splits[tk]
    model = models[tk]
    y_mu, y_sd = meta[tk]["y_mu"], meta[tk]["y_sd"]

    # ---- predict both heads ----
    y_reg_z_pred, y_up_prob = model.predict(X_test_seq, verbose=0)
    y_reg_z_pred = y_reg_z_pred.reshape(-1)
    y_up_prob    = y_up_prob.reshape(-1)

    # inverse transform regression
    y_pred = y_reg_z_pred * y_sd + y_mu

    # regression metrics
    mse  = mean_squared_error(y_test_seq, y_pred)
    rmse = np.sqrt(mse)
    mae  = mean_absolute_error(y_test_seq, y_pred)

    # direction metrics use y_up_prob with tuned threshold (use LAST 20% of train as val proxy)
    # We'll tune threshold on the *train tail* stored in the same run:
    # (simple approach: reuse your existing X_val,y_val by re-deriving from train)
    val_size = max(1, int(0.2 * len(X_train_seq)))
    X_val = X_train_seq[-val_size:]
    y_val = y_train_seq[-val_size:]
    y_val_true = (y_val > 0).astype(int)

    _, y_val_prob = model.predict(X_val, verbose=0)
    y_val_prob = y_val_prob.reshape(-1)

    best_t, best_f1 = tune_threshold(y_val_true, y_val_prob, lo=0.3, hi=0.7, n=81)

    y_true_bin = (y_test_seq > 0).astype(int)
    y_pred_bin = (y_up_prob > best_t).astype(int)

    directional_acc = accuracy_score(y_true_bin, y_pred_bin)
    precision = precision_score(y_true_bin, y_pred_bin, zero_division=0)
    recall    = recall_score(y_true_bin, y_pred_bin, zero_division=0)
    f1        = f1_score(y_true_bin, y_pred_bin, zero_division=0)
    auc       = safe_auc(y_true_bin, y_up_prob)

    cm = confusion_matrix(y_true_bin, y_pred_bin, labels=[0,1])
    tn, fp, fn, tp = cm.ravel()

    summary_rows.append({
        "Ticker": tk,
        "N_test_seq": len(y_test_seq),
        "RMSE": rmse,
        "MAE": mae,
        "MSE": mse,
        "Directional_Acc": directional_acc,
        "Precision_Up": precision,
        "Recall_Up": recall,
        "F1_Up": f1,
        "AUC": auc,
        "Best_Threshold": best_t,
        "Val_F1_at_bestT": best_f1,
        "TN": tn, "FP": fp, "FN": fn, "TP": tp
    })

summary_df = pd.DataFrame(summary_rows).sort_values("RMSE").reset_index(drop=True)
display_cols = ["Ticker","N_test_seq","RMSE","MAE","Directional_Acc","Precision_Up","Recall_Up","F1_Up","AUC","Best_Threshold","Val_F1_at_bestT","TN","FP","FN","TP"]
print(summary_df[display_cols].to_string(index=False))

import matplotlib.pyplot as plt
import numpy as np

def plot_actual_vs_pred_all(
    tickers,
    splits,
    models,
    meta,
    df,
    n_last=200,
    figsize=(16, 8)
):
    """
    Vẽ Actual vs Predicted return cho nhiều mã (multi-panel)
    tickers: list ticker, ví dụ ["VCB.VN","BID.VN","TCB.VN","CTG.VN"]
    """

    n = len(tickers)
    nrows = int(np.ceil(n / 2))
    ncols = 2

    fig, axes = plt.subplots(nrows, ncols, figsize=figsize, sharex=False)
    axes = axes.flatten()

    for i, tk in enumerate(tickers):
        ax = axes[i]

        X_train_seq, X_test_seq, y_train_seq, y_test_seq = splits[tk]
        model = models[tk]
        y_mu, y_sd = meta[tk]["y_mu"], meta[tk]["y_sd"]

        # Predict (regression head)
        y_reg_z_pred, _ = model.predict(X_test_seq, verbose=0)
        y_pred = y_reg_z_pred.reshape(-1) * y_sd + y_mu

        # Dates corresponding to test
        dft = df[df["ticker"] == tk].sort_values("date").reset_index(drop=True)
        test_dates = dft["date"].iloc[-len(y_test_seq):].values

        # Take last N points
        if n_last is not None:
            y_test_plot = y_test_seq[-n_last:]
            y_pred_plot = y_pred[-n_last:]
            date_plot   = test_dates[-n_last:]
        else:
            y_test_plot = y_test_seq
            y_pred_plot = y_pred
            date_plot   = test_dates

        ax.plot(date_plot, y_test_plot, label="Actual", linewidth=2)
        ax.plot(date_plot, y_pred_plot, label="Predicted", linewidth=2, alpha=0.85)
        ax.axhline(0, linestyle="--", linewidth=1, alpha=0.7)

        ax.set_title(
            f"{tk} | RMSE={np.sqrt(np.mean((y_test_plot - y_pred_plot)**2)):.4f}",
            fontsize=11
        )
        ax.grid(alpha=0.3)

        if i % 2 == 0:
            ax.set_ylabel("Return")

        if i >= (nrows - 1) * ncols:
            ax.set_xlabel("Date")

        ax.legend(fontsize=9)

    # Remove empty subplots if any
    for j in range(i + 1, len(axes)):
        fig.delaxes(axes[j])

    fig.suptitle(
        "Actual vs Transformer Predicted Return (Test Set)",
        fontsize=14,
        y=1.02
    )

    plt.tight_layout()
    plt.show()

print("📊 ACTUAL vs TRANSFORMER PREDICTED RETURN")
plot_actual_vs_pred_all(
    tickers=["VCB.VN", "BID.VN", "TCB.VN", "CTG.VN"],
    splits=splits,
    models=models,
    meta=meta,
    df=df,
    n_last=200
)
# Out:
# Ticker  N_test_seq     RMSE      MAE  Directional_Acc  Precision_Up  Recall_Up    F1_Up      AUC  Best_Threshold  Val_F1_at_bestT  TN  FP  FN  TP
# VCB.VN         202 0.003530 0.002751         0.707921      0.688525   0.512195 0.587413 0.744919           0.300         0.784946 101  19  40  42
# BID.VN         202 0.004286 0.003284         0.712871      0.656863   0.744444 0.697917 0.801786           0.335         0.827907  77  35  23  67
# TCB.VN         184 0.005412 0.004283         0.728261      0.805556   0.750000 0.776786 0.825938           0.300         0.779487  47  21  29  87
# CTG.VN         202 0.008189 0.006735         0.470297      0.437500   0.066667 0.115702 0.564654           0.300         0.599156  88   9  98   7
# 📊 ACTUAL vs TRANSFORMER PREDICTED RETURN

# %% [markdown]
# # Hybrid Transformer

# %%
import numpy as np
import pandas as pd
import pywt
import tensorflow as tf
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import (
    mean_squared_error, mean_absolute_error,
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, confusion_matrix
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# =========================
# 0) Reproducibility
# =========================
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)

# =========================
# 1) Wavelet features (safe level)
# =========================
def rolling_wavelet_features(x_window, wavelet="db4", level=3):
    x = np.asarray(x_window, dtype=np.float32)
    x = x[np.isfinite(x)]
    L = len(x)

    if L < 16 or np.allclose(x, 0):
        return {
            "wav_EA": 0.0,
            **{f"wav_ED{i}": 0.0 for i in range(1, level+1)},
            "wav_detail_ratio": 0.0,
            "wav_denoised_last": 0.0
        }

    x = x - np.mean(x)

    # SAFE LEVEL
    w = pywt.Wavelet(wavelet)
    max_lvl = pywt.dwt_max_level(data_len=L, filter_len=w.dec_len)
    lvl = int(min(level, max_lvl)) if max_lvl > 0 else 1

    coeffs = pywt.wavedec(x, wavelet=wavelet, level=lvl, mode="symmetric")
    cA = coeffs[0]
    cDs = coeffs[1:]

    EA = float(np.sum(cA**2))
    ED = [float(np.sum(cd**2)) for cd in cDs]
    total = EA + sum(ED) + 1e-12
    detail_ratio = float(sum(ED) / total)

    # denoise
    cD1 = cDs[-1] if len(cDs) else np.array([0.0], dtype=np.float32)
    cD1 = cD1[np.isfinite(cD1)]
    if len(cD1) == 0:
        sigma = 1e-12
    else:
        med = np.median(cD1)
        sigma = np.median(np.abs(cD1 - med)) / 0.6745 + 1e-12

    uthresh = sigma * np.sqrt(2*np.log(L + 1e-12))

    coeffs_dn = [cA]
    for cd in cDs:
        coeffs_dn.append(pywt.threshold(cd, value=uthresh, mode="soft"))

    x_dn = pywt.waverec(coeffs_dn, wavelet=wavelet, mode="symmetric")
    denoised_last = float(x_dn[-1]) if len(x_dn) > 0 and np.isfinite(x_dn[-1]) else 0.0

    out = {"wav_EA": EA if np.isfinite(EA) else 0.0}
    ED_reversed = list(reversed(ED))  # ED1..EDlvl
    for i in range(1, level+1):
        out[f"wav_ED{i}"] = float(ED_reversed[i-1]) if i-1 < len(ED_reversed) and np.isfinite(ED_reversed[i-1]) else 0.0

    out["wav_detail_ratio"] = detail_ratio if np.isfinite(detail_ratio) else 0.0
    out["wav_denoised_last"] = denoised_last
    return out

# =========================
# 2) FFT features (add log-energy stabilization)
# =========================
def rolling_fft_features(x_window, n_top=3):
    x = np.asarray(x_window, dtype=np.float32)
    x = x[np.isfinite(x)]
    L = len(x)

    if L < 16 or np.allclose(x, 0):
        return {"fft_energy": 0.0, "fft_low_ratio": 0.0, "fft_centroid": 0.0, "fft_topk_mag": 0.0}

    x = x - np.mean(x)

    X = np.fft.rfft(x)
    mag = (np.abs(X) + 1e-12).astype(np.float32)
    power = mag**2
    total_energy = float(np.sum(power) + 1e-12)

    n_bins = len(mag)
    low_end = max(2, int(0.10 * n_bins))
    low_energy = float(np.sum(power[1:low_end]) + 1e-12)
    low_ratio = float(low_energy / total_energy)

    sum_mag = float(np.sum(mag))
    if sum_mag <= 0:
        centroid = 0.0
    else:
        freqs = np.arange(n_bins, dtype=np.float32)
        centroid = float(np.sum(freqs * mag) / (sum_mag + 1e-12))

    mag_nodc = mag.copy()
    mag_nodc[0] = 0.0
    finite_mag = mag_nodc[np.isfinite(mag_nodc)]
    k = min(n_top, max(1, n_bins-1))
    if len(finite_mag) == 0:
        topk_mag = 0.0
    else:
        k = min(k, len(finite_mag))
        topk = np.partition(finite_mag, -k)[-k:]
        topk_mag = float(np.mean(topk)) if len(topk) else 0.0

    # log energy helps stabilize scale
    return {
        "fft_energy": float(np.log(total_energy)) if np.isfinite(total_energy) else 0.0,
        "fft_low_ratio": low_ratio if np.isfinite(low_ratio) else 0.0,
        "fft_centroid": centroid if np.isfinite(centroid) else 0.0,
        "fft_topk_mag": topk_mag if np.isfinite(topk_mag) else 0.0
    }

# =========================
# 3) Aux features: avoid zero-padding -> use shorter windows early
# =========================
def add_fft_wavelet_aux_features(df_one_ticker, ret_col="return", aux_window=64, wavelet="db4", level=3):
    d = df_one_ticker.sort_values("date").reset_index(drop=True).copy()
    r = d[ret_col].astype(np.float32)
    r_past = r.shift(1)

    aux_rows = []
    for i in range(len(d)):
        # use available past length (shorter window early) instead of all-zeros
        start = max(0, i-aux_window)
        win = r_past.iloc[start:i].values
        if len(win) < 16:
            # still too short -> neutral
            aux_rows.append({**rolling_fft_features(np.zeros(16)), **rolling_wavelet_features(np.zeros(16), wavelet, level)})
        else:
            aux_rows.append({**rolling_fft_features(win), **rolling_wavelet_features(win, wavelet, level)})

    aux_df = pd.DataFrame(aux_rows)
    return pd.concat([d, aux_df], axis=1)

# =========================
# 4) Sequence builder
# =========================
def create_sequences_with_aux(X_seq_features, X_aux_features, y, seq_len):
    Xs, Xa, ys = [], [], []
    for i in range(seq_len, len(y)):
        Xs.append(X_seq_features[i-seq_len:i])
        Xa.append(X_aux_features[i])
        ys.append(y[i])
    return np.array(Xs), np.array(Xa), np.array(ys)

# =========================
# 5) Transformer (Pre-LN) + last pooling
# =========================
class PositionalEncoding(tf.keras.layers.Layer):
    def __init__(self, position: int, d_model: int):
        super().__init__()
        pos = np.arange(position)[:, np.newaxis]
        i   = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        angle_rads  = pos * angle_rates
        angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
        angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.pos_encoding = tf.constant(angle_rads[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        return x + self.pos_encoding[:, :tf.shape(x)[1], :]

def transformer_encoder_preln(x, num_heads, key_dim, ff_dim, dropout=0.2, d_model=64):
    # Pre-LN
    x_norm = tf.keras.layers.LayerNormalization(epsilon=1e-6)(x)
    attn_out = tf.keras.layers.MultiHeadAttention(num_heads=num_heads, key_dim=key_dim, dropout=dropout)(x_norm, x_norm)
    attn_out = tf.keras.layers.Dropout(dropout)(attn_out)
    x = tf.keras.layers.Add()([x, attn_out])

    x_norm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)(x)
    ff = tf.keras.layers.Dense(ff_dim, activation="relu")(x_norm2)
    ff = tf.keras.layers.Dropout(dropout)(ff)
    ff = tf.keras.layers.Dense(d_model)(ff)
    x = tf.keras.layers.Add()([x, ff])
    return x

def build_hybrid_fft_wav_transformer(
    seq_input_shape,
    aux_input_dim,
    d_model=64,
    num_heads=4,
    ff_dim=128,
    num_blocks=3,
    dropout=0.2,
    use_conv_frontend=True,
    aux_mlp_units=(64, 32)
):
    seq_in = tf.keras.Input(shape=seq_input_shape, name="seq_in")
    aux_in = tf.keras.Input(shape=(aux_input_dim,), name="aux_in")

    # Transformer branch
    x = tf.keras.layers.Dense(d_model)(seq_in)
    if use_conv_frontend:
        x = tf.keras.layers.Conv1D(filters=d_model, kernel_size=3, padding="causal", activation="relu")(x)
        x = tf.keras.layers.Dropout(dropout)(x)

    x = PositionalEncoding(position=seq_input_shape[0], d_model=d_model)(x)

    key_dim = max(8, d_model // num_heads)
    for _ in range(num_blocks):
        x = transformer_encoder_preln(x, num_heads=num_heads, key_dim=key_dim, ff_dim=ff_dim, dropout=dropout, d_model=d_model)

    # last pooling instead of GAP
    x = tf.keras.layers.Lambda(lambda t: t[:, -1, :])(x)
    x = tf.keras.layers.Dropout(dropout)(x)

    # Aux branch
    a = tf.keras.layers.LayerNormalization()(aux_in)
    for u in aux_mlp_units:
        a = tf.keras.layers.Dense(u, activation="relu")(a)
        a = tf.keras.layers.Dropout(dropout)(a)

    # Fusion
    h = tf.keras.layers.Concatenate()([x, a])
    h = tf.keras.layers.Dense(64, activation="relu")(h)
    h = tf.keras.layers.Dropout(dropout)(h)

    y_reg_z = tf.keras.layers.Dense(1, name="y_reg_z")(h)
    y_up    = tf.keras.layers.Dense(1, activation="sigmoid", name="y_up")(h)

    return tf.keras.Model([seq_in, aux_in], [y_reg_z, y_up])

# =========================
# 6) Focal loss for direction (reduces FP explosions)
# =========================
def focal_bce(gamma=2.0, alpha=0.25):
    # y_true in {0,1}
    def loss(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1.0 - 1e-7)

        bce = -(y_true * tf.math.log(y_pred) + (1.0 - y_true) * tf.math.log(1.0 - y_pred))
        p_t = y_true * y_pred + (1.0 - y_true) * (1.0 - y_pred)
        alpha_t = y_true * alpha + (1.0 - y_true) * (1.0 - alpha)
        focal = alpha_t * tf.pow((1.0 - p_t), gamma) * bce
        return tf.reduce_mean(focal)
    return loss

# =========================
# 7) Threshold tuning: optimize DA or balanced acc
# =========================
def tune_threshold_metric(y_true_bin, y_prob, lo=0.1, hi=0.9, n=161, metric="da"):
    ths = np.linspace(lo, hi, n)
    best_t, best_score = 0.5, -1

    y_true_bin = np.asarray(y_true_bin).astype(int)
    y_prob = np.asarray(y_prob).astype(float)

    for t in ths:
        y_hat = (y_prob > t).astype(int)
        if metric == "da":
            score = accuracy_score(y_true_bin, y_hat)
        elif metric == "bal_acc":
            # balanced accuracy = (TPR + TNR)/2
            tn, fp, fn, tp = confusion_matrix(y_true_bin, y_hat, labels=[0,1]).ravel()
            tpr = tp / (tp + fn + 1e-12)
            tnr = tn / (tn + fp + 1e-12)
            score = 0.5 * (tpr + tnr)
        else:  # f1
            score = f1_score(y_true_bin, y_hat, zero_division=0)

        if score > best_score:
            best_score, best_t = score, t

    return float(best_t), float(best_score)

def safe_auc(y_true_bin, y_prob):
    if len(np.unique(y_true_bin)) < 2:
        return np.nan
    return roc_auc_score(y_true_bin, y_prob)

# =========================
# 8) TRAIN + EVALUATE per ticker (with deadzone + purge gap + better early stop)
# =========================
LOOKBACK   = 30
AUX_WINDOW = 64
WAVELET    = "db4"
WAV_LEVEL  = 3

# deadzone to reduce label noise
EPS_UP = 0.0003  # bạn có thể thử 0.0002 / 0.0005

# val purge gap (avoid bleed)
VAL_GAP = 5

df = df.copy()
df["date"] = pd.to_datetime(df["date"])

non_feature = ['date', 'ticker', 'target']
base_feature_cols = [c for c in df.columns if c not in non_feature]

models, scalers, splits, meta = {}, {}, {}, {}
summary_rows = []

for tk, dft in df.groupby("ticker"):
    dft = dft.sort_values("date").reset_index(drop=True)

    dft = add_fft_wavelet_aux_features(
        dft, ret_col="return",
        aux_window=AUX_WINDOW,
        wavelet=WAVELET, level=WAV_LEVEL
    )

    aux_cols = [c for c in dft.columns if c.startswith("fft_") or c.startswith("wav_")]
    if len(aux_cols) == 0:
        raise ValueError("No aux cols found. Check prefix names.")

    X_seq_raw = dft[base_feature_cols].values.astype(np.float32)
    X_aux_raw = dft[aux_cols].values.astype(np.float32)
    y_raw     = dft["target"].values.astype(np.float32)

    if len(dft) < (LOOKBACK + 80):
        print(f"⚠️ {tk}: dữ liệu quá ít ({len(dft)} dòng) -> bỏ qua")
        continue

    split_index = int(len(dft) * 0.8)
    X_seq_train_raw, X_seq_test_raw = X_seq_raw[:split_index], X_seq_raw[split_index:]
    X_aux_train_raw, X_aux_test_raw = X_aux_raw[:split_index], X_aux_raw[split_index:]
    y_train_raw, y_test_raw         = y_raw[:split_index], y_raw[split_index:]

    seq_scaler = RobustScaler()
    aux_scaler = RobustScaler()

    X_seq_train = seq_scaler.fit_transform(X_seq_train_raw)
    X_seq_test  = seq_scaler.transform(X_seq_test_raw)

    X_aux_train = aux_scaler.fit_transform(X_aux_train_raw)
    X_aux_test  = aux_scaler.transform(X_aux_test_raw)

    Xtr_seq, Xtr_aux, ytr = create_sequences_with_aux(X_seq_train, X_aux_train, y_train_raw, LOOKBACK)
    Xte_seq, Xte_aux, yte = create_sequences_with_aux(X_seq_test,  X_aux_test,  y_test_raw,  LOOKBACK)

    # validation tail from train WITH GAP
    val_size = max(10, int(0.2 * len(Xtr_seq)))
    cut = len(Xtr_seq) - val_size
    cut2 = max(1, cut - VAL_GAP)

    X_tr_seq, X_val_seq = Xtr_seq[:cut2], Xtr_seq[cut:]
    X_tr_aux, X_val_aux = Xtr_aux[:cut2], Xtr_aux[cut:]
    y_tr, y_val         = ytr[:cut2], ytr[cut:]

    # standardize regression target on train only
    y_mu = float(np.mean(y_tr))
    y_sd = float(np.std(y_tr) + 1e-8)
    y_tr_z  = ((y_tr  - y_mu) / y_sd).astype(np.float32)
    y_val_z = ((y_val - y_mu) / y_sd).astype(np.float32)

    # direction labels with deadzone
    y_tr_up  = (y_tr > EPS_UP).astype(np.float32)
    y_val_up = (y_val > EPS_UP).astype(np.float32)

    # build model
    model = build_hybrid_fft_wav_transformer(
        seq_input_shape=(LOOKBACK, Xtr_seq.shape[2]),
        aux_input_dim=Xtr_aux.shape[1],
        d_model=64, num_heads=4, ff_dim=128, num_blocks=3,
        dropout=0.2, use_conv_frontend=True,
        aux_mlp_units=(64, 32)
    )

    # direction loss: focal
    dir_loss = focal_bce(gamma=2.0, alpha=0.35)

    opt = Adam(learning_rate=8e-4, clipnorm=1.0)
    model.compile(
        optimizer=opt,
        loss={"y_reg_z": tf.keras.losses.Huber(delta=1.0), "y_up": dir_loss},
        loss_weights={"y_reg_z": 0.8, "y_up": 1.2},
        metrics={
            "y_up": [tf.keras.metrics.AUC(name="auc"), tf.keras.metrics.Precision(name="prec"), tf.keras.metrics.Recall(name="rec")]
        }
    )

    early_stop = EarlyStopping(
        monitor="val_y_up_auc", mode="max",
        patience=10, restore_best_weights=True
    )
    rlr = ReduceLROnPlateau(
        monitor="val_y_up_auc", mode="max",
        factor=0.5, patience=4, min_lr=1e-5, verbose=1
    )

    pos = float(y_tr_up.mean())
    print(f"\n===== Training HYBRID for {tk} | UpRatio={pos:.3f} | EPS_UP={EPS_UP} =====")

    model.fit(
        [X_tr_seq, X_tr_aux], {"y_reg_z": y_tr_z, "y_up": y_tr_up},
        validation_data=([X_val_seq, X_val_aux], {"y_reg_z": y_val_z, "y_up": y_val_up}),
        epochs=120, batch_size=32,
        callbacks=[early_stop, rlr],
        verbose=1
    )

    models[tk] = model
    scalers[tk] = {"seq": seq_scaler, "aux": aux_scaler}
    splits[tk] = (Xtr_seq, Xtr_aux, Xte_seq, Xte_aux, ytr, yte)
    meta[tk] = {"y_mu": y_mu, "y_sd": y_sd, "up_ratio": pos, "eps_up": EPS_UP}

    # ===== Evaluate =====
    y_reg_z_pred, y_up_prob = model.predict([Xte_seq, Xte_aux], verbose=0)
    y_reg_z_pred = y_reg_z_pred.reshape(-1)
    y_up_prob    = y_up_prob.reshape(-1)
    y_pred = y_reg_z_pred * y_sd + y_mu

    rmse = float(np.sqrt(mean_squared_error(yte, y_pred)))
    mae  = float(mean_absolute_error(yte, y_pred))

    # tune threshold on val (optimize DA or balanced acc, not just F1)
    _, y_val_prob = model.predict([X_val_seq, X_val_aux], verbose=0)
    y_val_prob = y_val_prob.reshape(-1)
    y_val_true = (y_val > EPS_UP).astype(int)

    best_t, best_score = tune_threshold_metric(y_val_true, y_val_prob, lo=0.1, hi=0.9, n=161, metric="bal_acc")

    y_true_bin = (yte > EPS_UP).astype(int)
    y_pred_bin = (y_up_prob > best_t).astype(int)

    directional_acc = float(accuracy_score(y_true_bin, y_pred_bin))
    precision = float(precision_score(y_true_bin, y_pred_bin, zero_division=0))
    recall    = float(recall_score(y_true_bin, y_pred_bin, zero_division=0))
    f1        = float(f1_score(y_true_bin, y_pred_bin, zero_division=0))
    auc       = float(safe_auc(y_true_bin, y_up_prob))

    tn, fp, fn, tp = confusion_matrix(y_true_bin, y_pred_bin, labels=[0,1]).ravel()

    summary_rows.append({
        "Ticker": tk,
        "N_test_seq": len(yte),
        "RMSE": rmse,
        "MAE": mae,
        "Directional_Acc": directional_acc,
        "Precision_Up": precision,
        "Recall_Up": recall,
        "F1_Up": f1,
        "AUC": auc,
        "Best_Threshold": float(best_t),
        "Val_balAcc_at_bestT": float(best_score),
        "TN": int(tn), "FP": int(fp), "FN": int(fn), "TP": int(tp)
    })

summary_df = pd.DataFrame(summary_rows).sort_values("Directional_Acc", ascending=False).reset_index(drop=True)
print(summary_df.to_string(index=False))
# Out:
# ===== Training HYBRID for BID.VN | UpRatio=0.492 | EPS_UP=0.0003 =====
# Epoch 1/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 20s 128ms/step - loss: 0.9134 - y_reg_z_loss: 0.9054 - y_up_auc: 0.4834 - y_up_loss: 0.1574 - y_up_prec: 0.4762 - y_up_rec: 0.3364 - val_loss: 0.2664 - val_y_reg_z_loss: 0.2267 - val_y_up_auc: 0.6634 - val_y_up_loss: 0.0845 - val_y_up_prec: 1.0000 - val_y_up_rec: 0.0412 - learning_rate: 8.0000e-04
# Epoch 2/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.4559 - y_reg_z_loss: 0.4372 - y_up_auc: 0.6380 - y_up_loss: 0.0889 - y_up_prec: 0.6087 - y_up_rec: 0.4630 - val_loss: 0.2424 - val_y_reg_z_loss: 0.2054 - val_y_up_auc: 0.7853 - val_y_up_loss: 0.0717 - val_y_up_prec: 0.9412 - val_y_up_rec: 0.1649 - learning_rate: 8.0000e-04
# Epoch 3/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.3706 - y_reg_z_loss: 0.3363 - y_up_auc: 0.6532 - y_up_loss: 0.0851 - y_up_prec: 0.6563 - y_up_rec: 0.4262 - val_loss: 0.2130 - val_y_reg_z_loss: 0.1705 - val_y_up_auc: 0.8204 - val_y_up_loss: 0.0670 - val_y_up_prec: 1.0000 - val_y_up_rec: 0.2474 - learning_rate: 8.0000e-04
# Epoch 4/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - loss: 0.3355 - y_reg_z_loss: 0.3006 - y_up_auc: 0.6912 - y_up_loss: 0.0792 - y_up_prec: 0.6556 - y_up_rec: 0.4786 - val_loss: 0.1727 - val_y_reg_z_loss: 0.1332 - val_y_up_auc: 0.8729 - val_y_up_loss: 0.0603 - val_y_up_prec: 0.9111 - val_y_up_rec: 0.4227 - learning_rate: 8.0000e-04
# Epoch 5/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.3083 - y_reg_z_loss: 0.2740 - y_up_auc: 0.7442 - y_up_loss: 0.0745 - y_up_prec: 0.7382 - y_up_rec: 0.5389 - val_loss: 0.1975 - val_y_reg_z_loss: 0.1572 - val_y_up_auc: 0.8605 - val_y_up_loss: 0.0679 - val_y_up_prec: 1.0000 - val_y_up_rec: 0.2371 - learning_rate: 8.0000e-04
# Epoch 6/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.2824 - y_reg_z_loss: 0.2554 - y_up_auc: 0.7915 - y_up_loss: 0.0651 - y_up_prec: 0.7875 - y_up_rec: 0.5235 - val_loss: 0.1510 - val_y_reg_z_loss: 0.1122 - val_y_up_auc: 0.8897 - val_y_up_loss: 0.0544 - val_y_up_prec: 0.8594 - val_y_up_rec: 0.5670 - learning_rate: 8.0000e-04
# Epoch 7/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.2828 - y_reg_z_loss: 0.2583 - y_up_auc: 0.8175 - y_up_loss: 0.0634 - y_up_prec: 0.7974 - y_up_rec: 0.6148 - val_loss: 0.1713 - val_y_reg_z_loss: 0.1343 - val_y_up_auc: 0.8836 - val_y_up_loss: 0.0604 - val_y_up_prec: 0.9714 - val_y_up_rec: 0.3505 - learning_rate: 8.0000e-04
# Epoch 8/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 0.2933 - y_reg_z_loss: 0.2751 - y_up_auc: 0.8277 - y_up_loss: 0.0612 - y_up_prec: 0.8236 - y_up_rec: 0.5893 - val_loss: 0.1644 - val_y_reg_z_loss: 0.1247 - val_y_up_auc: 0.8783 - val_y_up_loss: 0.0594 - val_y_up_prec: 0.9762 - val_y_up_rec: 0.4227 - learning_rate: 8.0000e-04
# Epoch 9/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.2559 - y_reg_z_loss: 0.2331 - y_up_auc: 0.8397 - y_up_loss: 0.0581 - y_up_prec: 0.8329 - y_up_rec: 0.5913 - val_loss: 0.1636 - val_y_reg_z_loss: 0.1297 - val_y_up_auc: 0.8881 - val_y_up_loss: 0.0579 - val_y_up_prec: 0.9545 - val_y_up_rec: 0.4330 - learning_rate: 8.0000e-04
# Epoch 10/120
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.2581 - y_reg_z_loss: 0.2338 - y_up_auc: 0.8358 - y_up_loss: 0.0592 - y_up_prec: 0.8546 - y_up_rec: 0.5955
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00039999998989515007.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.2587 - y_reg_z_loss: 0.2346 - y_up_auc: 0.8352 - y_up_loss: 0.0593 - y_up_prec: 0.8542 - y_up_rec: 0.5940 - val_loss: 0.1592 - val_y_reg_z_loss: 0.1267 - val_y_up_auc: 0.8852 - val_y_up_loss: 0.0552 - val_y_up_prec: 0.9273 - val_y_up_rec: 0.5258 - learning_rate: 8.0000e-04
# Epoch 11/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - loss: 0.2369 - y_reg_z_loss: 0.2047 - y_up_auc: 0.8483 - y_up_loss: 0.0611 - y_up_prec: 0.8178 - y_up_rec: 0.6523 - val_loss: 0.1799 - val_y_reg_z_loss: 0.1510 - val_y_up_auc: 0.8855 - val_y_up_loss: 0.0589 - val_y_up_prec: 0.9487 - val_y_up_rec: 0.3814 - learning_rate: 4.0000e-04
# Epoch 12/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.2245 - y_reg_z_loss: 0.1956 - y_up_auc: 0.8585 - y_up_loss: 0.0569 - y_up_prec: 0.8631 - y_up_rec: 0.6288 - val_loss: 0.1743 - val_y_reg_z_loss: 0.1439 - val_y_up_auc: 0.8845 - val_y_up_loss: 0.0591 - val_y_up_prec: 0.9583 - val_y_up_rec: 0.4742 - learning_rate: 4.0000e-04
# Epoch 13/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.2369 - y_reg_z_loss: 0.2081 - y_up_auc: 0.8431 - y_up_loss: 0.0589 - y_up_prec: 0.8576 - y_up_rec: 0.6049 - val_loss: 0.1717 - val_y_reg_z_loss: 0.1413 - val_y_up_auc: 0.8838 - val_y_up_loss: 0.0577 - val_y_up_prec: 0.9400 - val_y_up_rec: 0.4845 - learning_rate: 4.0000e-04
# Epoch 14/120
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.2281 - y_reg_z_loss: 0.2062 - y_up_auc: 0.8716 - y_up_loss: 0.0526 - y_up_prec: 0.8492 - y_up_rec: 0.6237
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.00019999999494757503.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.2281 - y_reg_z_loss: 0.2062 - y_up_auc: 0.8716 - y_up_loss: 0.0526 - y_up_prec: 0.8494 - y_up_rec: 0.6237 - val_loss: 0.1640 - val_y_reg_z_loss: 0.1313 - val_y_up_auc: 0.8845 - val_y_up_loss: 0.0577 - val_y_up_prec: 0.9412 - val_y_up_rec: 0.4948 - learning_rate: 4.0000e-04
# Epoch 15/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 0.2270 - y_reg_z_loss: 0.2025 - y_up_auc: 0.8688 - y_up_loss: 0.0544 - y_up_prec: 0.8613 - y_up_rec: 0.6704 - val_loss: 0.1808 - val_y_reg_z_loss: 0.1495 - val_y_up_auc: 0.8882 - val_y_up_loss: 0.0619 - val_y_up_prec: 0.9487 - val_y_up_rec: 0.3814 - learning_rate: 2.0000e-04
# Epoch 16/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - loss: 0.2108 - y_reg_z_loss: 0.1861 - y_up_auc: 0.8764 - y_up_loss: 0.0518 - y_up_prec: 0.8884 - y_up_rec: 0.6535 - val_loss: 0.1628 - val_y_reg_z_loss: 0.1297 - val_y_up_auc: 0.8868 - val_y_up_loss: 0.0572 - val_y_up_prec: 0.9434 - val_y_up_rec: 0.5155 - learning_rate: 2.0000e-04
#
# ===== Training HYBRID for CTG.VN | UpRatio=0.502 | EPS_UP=0.0003 =====
# Epoch 1/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 18s 129ms/step - loss: 0.7464 - y_reg_z_loss: 0.6808 - y_up_auc: 0.5025 - y_up_loss: 0.1677 - y_up_prec: 0.5151 - y_up_rec: 0.3511 - val_loss: 0.2294 - val_y_reg_z_loss: 0.1873 - val_y_up_auc: 0.7383 - val_y_up_loss: 0.0802 - val_y_up_prec: 1.0000 - val_y_up_rec: 0.0288 - learning_rate: 8.0000e-04
# Epoch 2/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - loss: 0.4344 - y_reg_z_loss: 0.4059 - y_up_auc: 0.6668 - y_up_loss: 0.0919 - y_up_prec: 0.6743 - y_up_rec: 0.4727 - val_loss: 0.1982 - val_y_reg_z_loss: 0.1500 - val_y_up_auc: 0.7866 - val_y_up_loss: 0.0706 - val_y_up_prec: 0.7264 - val_y_up_rec: 0.7404 - learning_rate: 8.0000e-04
# Epoch 3/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 0.4002 - y_reg_z_loss: 0.3791 - y_up_auc: 0.6907 - y_up_loss: 0.0818 - y_up_prec: 0.6860 - y_up_rec: 0.4904 - val_loss: 0.2011 - val_y_reg_z_loss: 0.1587 - val_y_up_auc: 0.7522 - val_y_up_loss: 0.0738 - val_y_up_prec: 1.0000 - val_y_up_rec: 0.2019 - learning_rate: 8.0000e-04
# Epoch 4/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 0.3260 - y_reg_z_loss: 0.3025 - y_up_auc: 0.7760 - y_up_loss: 0.0702 - y_up_prec: 0.7944 - y_up_rec: 0.5125 - val_loss: 0.1617 - val_y_reg_z_loss: 0.1183 - val_y_up_auc: 0.8277 - val_y_up_loss: 0.0627 - val_y_up_prec: 0.8657 - val_y_up_rec: 0.5577 - learning_rate: 8.0000e-04
# Epoch 5/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.3046 - y_reg_z_loss: 0.2831 - y_up_auc: 0.8163 - y_up_loss: 0.0651 - y_up_prec: 0.7620 - y_up_rec: 0.6683 - val_loss: 0.1702 - val_y_reg_z_loss: 0.1264 - val_y_up_auc: 0.8140 - val_y_up_loss: 0.0647 - val_y_up_prec: 0.8852 - val_y_up_rec: 0.5192 - learning_rate: 8.0000e-04
# Epoch 6/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 0.2889 - y_reg_z_loss: 0.2626 - y_up_auc: 0.8004 - y_up_loss: 0.0659 - y_up_prec: 0.7881 - y_up_rec: 0.5757 - val_loss: 0.1641 - val_y_reg_z_loss: 0.1183 - val_y_up_auc: 0.8252 - val_y_up_loss: 0.0642 - val_y_up_prec: 0.8730 - val_y_up_rec: 0.5288 - learning_rate: 8.0000e-04
# Epoch 7/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 0.2669 - y_reg_z_loss: 0.2456 - y_up_auc: 0.8464 - y_up_loss: 0.0594 - y_up_prec: 0.8019 - y_up_rec: 0.7028 - val_loss: 0.1629 - val_y_reg_z_loss: 0.1177 - val_y_up_auc: 0.8187 - val_y_up_loss: 0.0640 - val_y_up_prec: 0.8750 - val_y_up_rec: 0.4712 - learning_rate: 8.0000e-04
# Epoch 8/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 0.2891 - y_reg_z_loss: 0.2674 - y_up_auc: 0.8327 - y_up_loss: 0.0633 - y_up_prec: 0.8060 - y_up_rec: 0.6784 - val_loss: 0.1601 - val_y_reg_z_loss: 0.1241 - val_y_up_auc: 0.8394 - val_y_up_loss: 0.0611 - val_y_up_prec: 0.8955 - val_y_up_rec: 0.5769 - learning_rate: 8.0000e-04
# Epoch 9/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 0.2681 - y_reg_z_loss: 0.2468 - y_up_auc: 0.8464 - y_up_loss: 0.0593 - y_up_prec: 0.7815 - y_up_rec: 0.6919 - val_loss: 0.1596 - val_y_reg_z_loss: 0.1227 - val_y_up_auc: 0.8301 - val_y_up_loss: 0.0621 - val_y_up_prec: 0.8824 - val_y_up_rec: 0.5769 - learning_rate: 8.0000e-04
# Epoch 10/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.2608 - y_reg_z_loss: 0.2437 - y_up_auc: 0.8718 - y_up_loss: 0.0554 - y_up_prec: 0.8693 - y_up_rec: 0.6934 - val_loss: 0.1800 - val_y_reg_z_loss: 0.1472 - val_y_up_auc: 0.8292 - val_y_up_loss: 0.0656 - val_y_up_prec: 0.8958 - val_y_up_rec: 0.4135 - learning_rate: 8.0000e-04
# Epoch 11/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.2627 - y_reg_z_loss: 0.2424 - y_up_auc: 0.8618 - y_up_loss: 0.0575 - y_up_prec: 0.8650 - y_up_rec: 0.6659 - val_loss: 0.1587 - val_y_reg_z_loss: 0.1195 - val_y_up_auc: 0.8457 - val_y_up_loss: 0.0623 - val_y_up_prec: 0.9057 - val_y_up_rec: 0.4615 - learning_rate: 8.0000e-04
# Epoch 12/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 0.2501 - y_reg_z_loss: 0.2302 - y_up_auc: 0.8678 - y_up_loss: 0.0553 - y_up_prec: 0.8924 - y_up_rec: 0.6444 - val_loss: 0.1486 - val_y_reg_z_loss: 0.1133 - val_y_up_auc: 0.8612 - val_y_up_loss: 0.0574 - val_y_up_prec: 0.9000 - val_y_up_rec: 0.6058 - learning_rate: 8.0000e-04
# Epoch 13/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 0.2611 - y_reg_z_loss: 0.2402 - y_up_auc: 0.8682 - y_up_loss: 0.0579 - y_up_prec: 0.8008 - y_up_rec: 0.7659 - val_loss: 0.1574 - val_y_reg_z_loss: 0.1189 - val_y_up_auc: 0.8486 - val_y_up_loss: 0.0609 - val_y_up_prec: 0.9057 - val_y_up_rec: 0.4615 - learning_rate: 8.0000e-04
# Epoch 14/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.2457 - y_reg_z_loss: 0.2272 - y_up_auc: 0.8785 - y_up_loss: 0.0535 - y_up_prec: 0.8718 - y_up_rec: 0.7173 - val_loss: 0.1600 - val_y_reg_z_loss: 0.1213 - val_y_up_auc: 0.8437 - val_y_up_loss: 0.0626 - val_y_up_prec: 0.9000 - val_y_up_rec: 0.4327 - learning_rate: 8.0000e-04
# Epoch 15/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 0.2407 - y_reg_z_loss: 0.2176 - y_up_auc: 0.8751 - y_up_loss: 0.0561 - y_up_prec: 0.8642 - y_up_rec: 0.7217 - val_loss: 0.1590 - val_y_reg_z_loss: 0.1228 - val_y_up_auc: 0.8521 - val_y_up_loss: 0.0613 - val_y_up_prec: 0.9074 - val_y_up_rec: 0.4712 - learning_rate: 8.0000e-04
# Epoch 16/120
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.2410 - y_reg_z_loss: 0.2211 - y_up_auc: 0.8828 - y_up_loss: 0.0535 - y_up_prec: 0.8358 - y_up_rec: 0.7635
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.00039999998989515007.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.2397 - y_reg_z_loss: 0.2201 - y_up_auc: 0.8831 - y_up_loss: 0.0533 - y_up_prec: 0.8364 - y_up_rec: 0.7597 - val_loss: 0.1654 - val_y_reg_z_loss: 0.1296 - val_y_up_auc: 0.8553 - val_y_up_loss: 0.0634 - val_y_up_prec: 0.9024 - val_y_up_rec: 0.3558 - learning_rate: 8.0000e-04
# Epoch 17/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.2322 - y_reg_z_loss: 0.2103 - y_up_auc: 0.8799 - y_up_loss: 0.0535 - y_up_prec: 0.8669 - y_up_rec: 0.7255 - val_loss: 0.1760 - val_y_reg_z_loss: 0.1429 - val_y_up_auc: 0.8621 - val_y_up_loss: 0.0663 - val_y_up_prec: 0.9677 - val_y_up_rec: 0.2885 - learning_rate: 4.0000e-04
# Epoch 18/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 0.2239 - y_reg_z_loss: 0.1972 - y_up_auc: 0.8734 - y_up_loss: 0.0551 - y_up_prec: 0.8821 - y_up_rec: 0.7175 - val_loss: 0.1725 - val_y_reg_z_loss: 0.1328 - val_y_up_auc: 0.8627 - val_y_up_loss: 0.0670 - val_y_up_prec: 0.9500 - val_y_up_rec: 0.3654 - learning_rate: 4.0000e-04
# Epoch 19/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.2208 - y_reg_z_loss: 0.2015 - y_up_auc: 0.8984 - y_up_loss: 0.0499 - y_up_prec: 0.9037 - y_up_rec: 0.7198 - val_loss: 0.1823 - val_y_reg_z_loss: 0.1423 - val_y_up_auc: 0.8626 - val_y_up_loss: 0.0694 - val_y_up_prec: 0.9412 - val_y_up_rec: 0.3077 - learning_rate: 4.0000e-04
# Epoch 20/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.2265 - y_reg_z_loss: 0.2071 - y_up_auc: 0.8900 - y_up_loss: 0.0510 - y_up_prec: 0.9102 - y_up_rec: 0.6812 - val_loss: 0.1764 - val_y_reg_z_loss: 0.1382 - val_y_up_auc: 0.8663 - val_y_up_loss: 0.0678 - val_y_up_prec: 0.9429 - val_y_up_rec: 0.3173 - learning_rate: 4.0000e-04
# Epoch 21/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - loss: 0.2147 - y_reg_z_loss: 0.1967 - y_up_auc: 0.9031 - y_up_loss: 0.0480 - y_up_prec: 0.8809 - y_up_rec: 0.7120 - val_loss: 0.1606 - val_y_reg_z_loss: 0.1215 - val_y_up_auc: 0.8665 - val_y_up_loss: 0.0643 - val_y_up_prec: 0.9500 - val_y_up_rec: 0.3654 - learning_rate: 4.0000e-04
# Epoch 22/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 0.2113 - y_reg_z_loss: 0.1902 - y_up_auc: 0.8998 - y_up_loss: 0.0493 - y_up_prec: 0.8920 - y_up_rec: 0.7455 - val_loss: 0.1797 - val_y_reg_z_loss: 0.1372 - val_y_up_auc: 0.8695 - val_y_up_loss: 0.0717 - val_y_up_prec: 0.9688 - val_y_up_rec: 0.2981 - learning_rate: 4.0000e-04
# Epoch 23/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 0.2159 - y_reg_z_loss: 0.1940 - y_up_auc: 0.8949 - y_up_loss: 0.0506 - y_up_prec: 0.8783 - y_up_rec: 0.7201 - val_loss: 0.1731 - val_y_reg_z_loss: 0.1319 - val_y_up_auc: 0.8722 - val_y_up_loss: 0.0689 - val_y_up_prec: 0.9697 - val_y_up_rec: 0.3077 - learning_rate: 4.0000e-04
# Epoch 24/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 0.2166 - y_reg_z_loss: 0.1984 - y_up_auc: 0.9035 - y_up_loss: 0.0483 - y_up_prec: 0.8886 - y_up_rec: 0.6856 - val_loss: 0.1673 - val_y_reg_z_loss: 0.1283 - val_y_up_auc: 0.8728 - val_y_up_loss: 0.0661 - val_y_up_prec: 0.9487 - val_y_up_rec: 0.3558 - learning_rate: 4.0000e-04
# Epoch 25/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - loss: 0.2153 - y_reg_z_loss: 0.1937 - y_up_auc: 0.8962 - y_up_loss: 0.0503 - y_up_prec: 0.8751 - y_up_rec: 0.7117 - val_loss: 0.1510 - val_y_reg_z_loss: 0.1119 - val_y_up_auc: 0.8721 - val_y_up_loss: 0.0601 - val_y_up_prec: 0.9333 - val_y_up_rec: 0.4038 - learning_rate: 4.0000e-04
# Epoch 26/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - loss: 0.1963 - y_reg_z_loss: 0.1789 - y_up_auc: 0.9158 - y_up_loss: 0.0445 - y_up_prec: 0.8870 - y_up_rec: 0.7389 - val_loss: 0.1588 - val_y_reg_z_loss: 0.1212 - val_y_up_auc: 0.8684 - val_y_up_loss: 0.0623 - val_y_up_prec: 0.9512 - val_y_up_rec: 0.3750 - learning_rate: 4.0000e-04
# Epoch 27/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.1884 - y_reg_z_loss: 0.1717 - y_up_auc: 0.9245 - y_up_loss: 0.0425 - y_up_prec: 0.8968 - y_up_rec: 0.7863 - val_loss: 0.1628 - val_y_reg_z_loss: 0.1250 - val_y_up_auc: 0.8733 - val_y_up_loss: 0.0646 - val_y_up_prec: 0.9722 - val_y_up_rec: 0.3365 - learning_rate: 4.0000e-04
# Epoch 28/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 0.1944 - y_reg_z_loss: 0.1819 - y_up_auc: 0.9315 - y_up_loss: 0.0407 - y_up_prec: 0.9276 - y_up_rec: 0.7316 - val_loss: 0.1644 - val_y_reg_z_loss: 0.1199 - val_y_up_auc: 0.8701 - val_y_up_loss: 0.0672 - val_y_up_prec: 0.9500 - val_y_up_rec: 0.3654 - learning_rate: 4.0000e-04
# Epoch 29/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.1918 - y_reg_z_loss: 0.1695 - y_up_auc: 0.9074 - y_up_loss: 0.0470 - y_up_prec: 0.8957 - y_up_rec: 0.6978 - val_loss: 0.1669 - val_y_reg_z_loss: 0.1216 - val_y_up_auc: 0.8665 - val_y_up_loss: 0.0684 - val_y_up_prec: 0.9459 - val_y_up_rec: 0.3365 - learning_rate: 4.0000e-04
# Epoch 30/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 0.2114 - y_reg_z_loss: 0.1943 - y_up_auc: 0.9124 - y_up_loss: 0.0468 - y_up_prec: 0.8998 - y_up_rec: 0.7646 - val_loss: 0.1711 - val_y_reg_z_loss: 0.1271 - val_y_up_auc: 0.8672 - val_y_up_loss: 0.0690 - val_y_up_prec: 0.9459 - val_y_up_rec: 0.3365 - learning_rate: 4.0000e-04
# Epoch 31/120
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.1957 - y_reg_z_loss: 0.1739 - y_up_auc: 0.9064 - y_up_loss: 0.0472 - y_up_prec: 0.8864 - y_up_rec: 0.7831
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.00019999999494757503.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 0.1940 - y_reg_z_loss: 0.1724 - y_up_auc: 0.9074 - y_up_loss: 0.0470 - y_up_prec: 0.8871 - y_up_rec: 0.7817 - val_loss: 0.1903 - val_y_reg_z_loss: 0.1441 - val_y_up_auc: 0.8622 - val_y_up_loss: 0.0738 - val_y_up_prec: 0.9474 - val_y_up_rec: 0.3462 - learning_rate: 4.0000e-04
# Epoch 32/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.1992 - y_reg_z_loss: 0.1845 - y_up_auc: 0.9253 - y_up_loss: 0.0431 - y_up_prec: 0.9128 - y_up_rec: 0.7584 - val_loss: 0.2036 - val_y_reg_z_loss: 0.1590 - val_y_up_auc: 0.8591 - val_y_up_loss: 0.0778 - val_y_up_prec: 0.9722 - val_y_up_rec: 0.3365 - learning_rate: 2.0000e-04
# Epoch 33/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.1705 - y_reg_z_loss: 0.1562 - y_up_auc: 0.9426 - y_up_loss: 0.0381 - y_up_prec: 0.9070 - y_up_rec: 0.7650 - val_loss: 0.1940 - val_y_reg_z_loss: 0.1497 - val_y_up_auc: 0.8587 - val_y_up_loss: 0.0765 - val_y_up_prec: 0.9730 - val_y_up_rec: 0.3462 - learning_rate: 2.0000e-04
# Epoch 34/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.1780 - y_reg_z_loss: 0.1599 - y_up_auc: 0.9254 - y_up_loss: 0.0421 - y_up_prec: 0.9202 - y_up_rec: 0.7593 - val_loss: 0.2112 - val_y_reg_z_loss: 0.1635 - val_y_up_auc: 0.8610 - val_y_up_loss: 0.0828 - val_y_up_prec: 0.9722 - val_y_up_rec: 0.3365 - learning_rate: 2.0000e-04
# Epoch 35/120
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.1720 - y_reg_z_loss: 0.1573 - y_up_auc: 0.9350 - y_up_loss: 0.0385 - y_up_prec: 0.9336 - y_up_rec: 0.7619
# Epoch 35: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.1712 - y_reg_z_loss: 0.1562 - y_up_auc: 0.9353 - y_up_loss: 0.0385 - y_up_prec: 0.9322 - y_up_rec: 0.7643 - val_loss: 0.1987 - val_y_reg_z_loss: 0.1501 - val_y_up_auc: 0.8637 - val_y_up_loss: 0.0781 - val_y_up_prec: 0.9722 - val_y_up_rec: 0.3365 - learning_rate: 2.0000e-04
# Epoch 36/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.1867 - y_reg_z_loss: 0.1730 - y_up_auc: 0.9330 - y_up_loss: 0.0403 - y_up_prec: 0.9326 - y_up_rec: 0.7678 - val_loss: 0.1973 - val_y_reg_z_loss: 0.1492 - val_y_up_auc: 0.8635 - val_y_up_loss: 0.0777 - val_y_up_prec: 0.9714 - val_y_up_rec: 0.3269 - learning_rate: 1.0000e-04
# Epoch 37/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - loss: 0.1822 - y_reg_z_loss: 0.1634 - y_up_auc: 0.9220 - y_up_loss: 0.0429 - y_up_prec: 0.8783 - y_up_rec: 0.7523 - val_loss: 0.1890 - val_y_reg_z_loss: 0.1448 - val_y_up_auc: 0.8618 - val_y_up_loss: 0.0751 - val_y_up_prec: 0.9722 - val_y_up_rec: 0.3365 - learning_rate: 1.0000e-04
#
# ===== Training HYBRID for TCB.VN | UpRatio=0.541 | EPS_UP=0.0003 =====
# Epoch 1/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 143ms/step - loss: 0.9559 - y_reg_z_loss: 0.8677 - y_up_auc: 0.5528 - y_up_loss: 0.2179 - y_up_prec: 0.6034 - y_up_rec: 0.3662 - val_loss: 0.1978 - val_y_reg_z_loss: 0.1180 - val_y_up_auc: 0.6945 - val_y_up_loss: 0.0821 - val_y_up_prec: 0.7714 - val_y_up_rec: 0.3176 - learning_rate: 8.0000e-04
# Epoch 2/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - loss: 0.4931 - y_reg_z_loss: 0.4444 - y_up_auc: 0.6586 - y_up_loss: 0.1146 - y_up_prec: 0.7146 - y_up_rec: 0.4964 - val_loss: 0.1815 - val_y_reg_z_loss: 0.1060 - val_y_up_auc: 0.7185 - val_y_up_loss: 0.0758 - val_y_up_prec: 0.7500 - val_y_up_rec: 0.3176 - learning_rate: 8.0000e-04
# Epoch 3/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.3572 - y_reg_z_loss: 0.3177 - y_up_auc: 0.7174 - y_up_loss: 0.0858 - y_up_prec: 0.7181 - y_up_rec: 0.5576 - val_loss: 0.1584 - val_y_reg_z_loss: 0.0862 - val_y_up_auc: 0.7876 - val_y_up_loss: 0.0718 - val_y_up_prec: 0.7556 - val_y_up_rec: 0.4000 - learning_rate: 8.0000e-04
# Epoch 4/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.3308 - y_reg_z_loss: 0.2919 - y_up_auc: 0.7524 - y_up_loss: 0.0811 - y_up_prec: 0.7816 - y_up_rec: 0.5787 - val_loss: 0.1597 - val_y_reg_z_loss: 0.0896 - val_y_up_auc: 0.8070 - val_y_up_loss: 0.0693 - val_y_up_prec: 0.8065 - val_y_up_rec: 0.2941 - learning_rate: 8.0000e-04
# Epoch 5/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.2742 - y_reg_z_loss: 0.2365 - y_up_auc: 0.8170 - y_up_loss: 0.0707 - y_up_prec: 0.8434 - y_up_rec: 0.6098 - val_loss: 0.1554 - val_y_reg_z_loss: 0.0833 - val_y_up_auc: 0.8259 - val_y_up_loss: 0.0685 - val_y_up_prec: 0.8036 - val_y_up_rec: 0.5294 - learning_rate: 8.0000e-04
# Epoch 6/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.2671 - y_reg_z_loss: 0.2366 - y_up_auc: 0.8292 - y_up_loss: 0.0648 - y_up_prec: 0.8011 - y_up_rec: 0.6660 - val_loss: 0.1443 - val_y_reg_z_loss: 0.0755 - val_y_up_auc: 0.8335 - val_y_up_loss: 0.0656 - val_y_up_prec: 0.7838 - val_y_up_rec: 0.6824 - learning_rate: 8.0000e-04
# Epoch 7/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step - loss: 0.2750 - y_reg_z_loss: 0.2399 - y_up_auc: 0.8211 - y_up_loss: 0.0692 - y_up_prec: 0.8250 - y_up_rec: 0.6099 - val_loss: 0.1526 - val_y_reg_z_loss: 0.0854 - val_y_up_auc: 0.8260 - val_y_up_loss: 0.0652 - val_y_up_prec: 0.8000 - val_y_up_rec: 0.4235 - learning_rate: 8.0000e-04
# Epoch 8/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - loss: 0.2653 - y_reg_z_loss: 0.2344 - y_up_auc: 0.8348 - y_up_loss: 0.0647 - y_up_prec: 0.8384 - y_up_rec: 0.6670 - val_loss: 0.1457 - val_y_reg_z_loss: 0.0787 - val_y_up_auc: 0.8338 - val_y_up_loss: 0.0643 - val_y_up_prec: 0.8125 - val_y_up_rec: 0.6118 - learning_rate: 8.0000e-04
# Epoch 9/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.2471 - y_reg_z_loss: 0.2181 - y_up_auc: 0.8464 - y_up_loss: 0.0604 - y_up_prec: 0.8496 - y_up_rec: 0.6727 - val_loss: 0.1431 - val_y_reg_z_loss: 0.0749 - val_y_up_auc: 0.8265 - val_y_up_loss: 0.0653 - val_y_up_prec: 0.8039 - val_y_up_rec: 0.4824 - learning_rate: 8.0000e-04
# Epoch 10/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.2369 - y_reg_z_loss: 0.2081 - y_up_auc: 0.8590 - y_up_loss: 0.0587 - y_up_prec: 0.8850 - y_up_rec: 0.6057 - val_loss: 0.1427 - val_y_reg_z_loss: 0.0765 - val_y_up_auc: 0.8288 - val_y_up_loss: 0.0635 - val_y_up_prec: 0.7797 - val_y_up_rec: 0.5412 - learning_rate: 8.0000e-04
# Epoch 11/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.2063 - y_reg_z_loss: 0.1808 - y_up_auc: 0.8924 - y_up_loss: 0.0512 - y_up_prec: 0.8814 - y_up_rec: 0.6717 - val_loss: 0.1452 - val_y_reg_z_loss: 0.0814 - val_y_up_auc: 0.8287 - val_y_up_loss: 0.0626 - val_y_up_prec: 0.8197 - val_y_up_rec: 0.5882 - learning_rate: 8.0000e-04
# Epoch 12/120
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.2336 - y_reg_z_loss: 0.2027 - y_up_auc: 0.8597 - y_up_loss: 0.0595 - y_up_prec: 0.8340 - y_up_rec: 0.6634
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.00039999998989515007.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.2332 - y_reg_z_loss: 0.2027 - y_up_auc: 0.8606 - y_up_loss: 0.0592 - y_up_prec: 0.8338 - y_up_rec: 0.6679 - val_loss: 0.1436 - val_y_reg_z_loss: 0.0808 - val_y_up_auc: 0.8321 - val_y_up_loss: 0.0614 - val_y_up_prec: 0.8182 - val_y_up_rec: 0.6353 - learning_rate: 8.0000e-04
# Epoch 13/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 0.2237 - y_reg_z_loss: 0.1951 - y_up_auc: 0.8740 - y_up_loss: 0.0564 - y_up_prec: 0.8590 - y_up_rec: 0.7065 - val_loss: 0.1386 - val_y_reg_z_loss: 0.0747 - val_y_up_auc: 0.8324 - val_y_up_loss: 0.0613 - val_y_up_prec: 0.7808 - val_y_up_rec: 0.6706 - learning_rate: 4.0000e-04
# Epoch 14/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - loss: 0.2031 - y_reg_z_loss: 0.1731 - y_up_auc: 0.8757 - y_up_loss: 0.0539 - y_up_prec: 0.8613 - y_up_rec: 0.6892 - val_loss: 0.1414 - val_y_reg_z_loss: 0.0742 - val_y_up_auc: 0.8310 - val_y_up_loss: 0.0662 - val_y_up_prec: 0.7347 - val_y_up_rec: 0.8471 - learning_rate: 4.0000e-04
# Epoch 15/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.2133 - y_reg_z_loss: 0.1835 - y_up_auc: 0.8774 - y_up_loss: 0.0553 - y_up_prec: 0.8398 - y_up_rec: 0.7583 - val_loss: 0.1401 - val_y_reg_z_loss: 0.0740 - val_y_up_auc: 0.8336 - val_y_up_loss: 0.0649 - val_y_up_prec: 0.7374 - val_y_up_rec: 0.8588 - learning_rate: 4.0000e-04
# Epoch 16/120
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.1916 - y_reg_z_loss: 0.1644 - y_up_auc: 0.8958 - y_up_loss: 0.0501 - y_up_prec: 0.8824 - y_up_rec: 0.7374
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.00019999999494757503.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.1915 - y_reg_z_loss: 0.1642 - y_up_auc: 0.8964 - y_up_loss: 0.0500 - y_up_prec: 0.8826 - y_up_rec: 0.7352 - val_loss: 0.1366 - val_y_reg_z_loss: 0.0726 - val_y_up_auc: 0.8275 - val_y_up_loss: 0.0626 - val_y_up_prec: 0.7222 - val_y_up_rec: 0.7647 - learning_rate: 4.0000e-04
# Epoch 17/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.1948 - y_reg_z_loss: 0.1710 - y_up_auc: 0.9011 - y_up_loss: 0.0482 - y_up_prec: 0.8709 - y_up_rec: 0.7650 - val_loss: 0.1366 - val_y_reg_z_loss: 0.0727 - val_y_up_auc: 0.8293 - val_y_up_loss: 0.0626 - val_y_up_prec: 0.7442 - val_y_up_rec: 0.7529 - learning_rate: 2.0000e-04
# Epoch 18/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.1912 - y_reg_z_loss: 0.1619 - y_up_auc: 0.8925 - y_up_loss: 0.0512 - y_up_prec: 0.8572 - y_up_rec: 0.7584 - val_loss: 0.1371 - val_y_reg_z_loss: 0.0720 - val_y_up_auc: 0.8326 - val_y_up_loss: 0.0629 - val_y_up_prec: 0.7470 - val_y_up_rec: 0.7294 - learning_rate: 2.0000e-04
#
# ===== Training HYBRID for VCB.VN | UpRatio=0.492 | EPS_UP=0.0003 =====
# Epoch 1/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 20s 130ms/step - loss: 0.6693 - y_reg_z_loss: 0.6440 - y_up_auc: 0.6028 - y_up_loss: 0.1280 - y_up_prec: 0.5618 - y_up_rec: 0.4103 - val_loss: 0.2156 - val_y_reg_z_loss: 0.1626 - val_y_up_auc: 0.7853 - val_y_up_loss: 0.0712 - val_y_up_prec: 0.7253 - val_y_up_rec: 0.7416 - learning_rate: 8.0000e-04
# Epoch 2/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.4287 - y_reg_z_loss: 0.4054 - y_up_auc: 0.7164 - y_up_loss: 0.0864 - y_up_prec: 0.7019 - y_up_rec: 0.5249 - val_loss: 0.1973 - val_y_reg_z_loss: 0.1421 - val_y_up_auc: 0.7851 - val_y_up_loss: 0.0719 - val_y_up_prec: 0.9474 - val_y_up_rec: 0.2022 - learning_rate: 8.0000e-04
# Epoch 3/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.3260 - y_reg_z_loss: 0.2974 - y_up_auc: 0.7576 - y_up_loss: 0.0733 - y_up_prec: 0.7344 - y_up_rec: 0.5155 - val_loss: 0.2134 - val_y_reg_z_loss: 0.1780 - val_y_up_auc: 0.8320 - val_y_up_loss: 0.0647 - val_y_up_prec: 0.9286 - val_y_up_rec: 0.2921 - learning_rate: 8.0000e-04
# Epoch 4/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - loss: 0.3268 - y_reg_z_loss: 0.2991 - y_up_auc: 0.7739 - y_up_loss: 0.0730 - y_up_prec: 0.7342 - y_up_rec: 0.4433 - val_loss: 0.1909 - val_y_reg_z_loss: 0.1490 - val_y_up_auc: 0.8491 - val_y_up_loss: 0.0614 - val_y_up_prec: 0.9074 - val_y_up_rec: 0.5506 - learning_rate: 8.0000e-04
# Epoch 5/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 0.2832 - y_reg_z_loss: 0.2615 - y_up_auc: 0.8271 - y_up_loss: 0.0619 - y_up_prec: 0.7811 - y_up_rec: 0.6092 - val_loss: 0.1691 - val_y_reg_z_loss: 0.1246 - val_y_up_auc: 0.8485 - val_y_up_loss: 0.0589 - val_y_up_prec: 0.8243 - val_y_up_rec: 0.6854 - learning_rate: 8.0000e-04
# Epoch 6/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.2752 - y_reg_z_loss: 0.2525 - y_up_auc: 0.8445 - y_up_loss: 0.0608 - y_up_prec: 0.7884 - y_up_rec: 0.6113 - val_loss: 0.1760 - val_y_reg_z_loss: 0.1364 - val_y_up_auc: 0.8468 - val_y_up_loss: 0.0594 - val_y_up_prec: 0.8551 - val_y_up_rec: 0.6629 - learning_rate: 8.0000e-04
# Epoch 7/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.2868 - y_reg_z_loss: 0.2616 - y_up_auc: 0.8180 - y_up_loss: 0.0645 - y_up_prec: 0.7652 - y_up_rec: 0.5779 - val_loss: 0.1766 - val_y_reg_z_loss: 0.1357 - val_y_up_auc: 0.8506 - val_y_up_loss: 0.0603 - val_y_up_prec: 0.8627 - val_y_up_rec: 0.4944 - learning_rate: 8.0000e-04
# Epoch 8/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 0.2720 - y_reg_z_loss: 0.2447 - y_up_auc: 0.8245 - y_up_loss: 0.0633 - y_up_prec: 0.8033 - y_up_rec: 0.5801 - val_loss: 0.1662 - val_y_reg_z_loss: 0.1218 - val_y_up_auc: 0.8467 - val_y_up_loss: 0.0593 - val_y_up_prec: 0.8491 - val_y_up_rec: 0.5056 - learning_rate: 8.0000e-04
# Epoch 9/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.2459 - y_reg_z_loss: 0.2240 - y_up_auc: 0.8708 - y_up_loss: 0.0554 - y_up_prec: 0.8260 - y_up_rec: 0.6618 - val_loss: 0.1610 - val_y_reg_z_loss: 0.1158 - val_y_up_auc: 0.8523 - val_y_up_loss: 0.0584 - val_y_up_prec: 0.8197 - val_y_up_rec: 0.5618 - learning_rate: 8.0000e-04
# Epoch 10/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - loss: 0.2493 - y_reg_z_loss: 0.2259 - y_up_auc: 0.8613 - y_up_loss: 0.0570 - y_up_prec: 0.8180 - y_up_rec: 0.7106 - val_loss: 0.1708 - val_y_reg_z_loss: 0.1274 - val_y_up_auc: 0.8481 - val_y_up_loss: 0.0608 - val_y_up_prec: 0.8431 - val_y_up_rec: 0.4831 - learning_rate: 8.0000e-04
# Epoch 11/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - loss: 0.2458 - y_reg_z_loss: 0.2246 - y_up_auc: 0.8720 - y_up_loss: 0.0550 - y_up_prec: 0.8456 - y_up_rec: 0.6336 - val_loss: 0.1597 - val_y_reg_z_loss: 0.1146 - val_y_up_auc: 0.8534 - val_y_up_loss: 0.0582 - val_y_up_prec: 0.8308 - val_y_up_rec: 0.6067 - learning_rate: 8.0000e-04
# Epoch 12/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.2288 - y_reg_z_loss: 0.2085 - y_up_auc: 0.8899 - y_up_loss: 0.0517 - y_up_prec: 0.8350 - y_up_rec: 0.6955 - val_loss: 0.1596 - val_y_reg_z_loss: 0.1135 - val_y_up_auc: 0.8488 - val_y_up_loss: 0.0590 - val_y_up_prec: 0.8167 - val_y_up_rec: 0.5506 - learning_rate: 8.0000e-04
# Epoch 13/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.2302 - y_reg_z_loss: 0.2104 - y_up_auc: 0.8863 - y_up_loss: 0.0516 - y_up_prec: 0.8791 - y_up_rec: 0.6838 - val_loss: 0.1610 - val_y_reg_z_loss: 0.1158 - val_y_up_auc: 0.8461 - val_y_up_loss: 0.0585 - val_y_up_prec: 0.8209 - val_y_up_rec: 0.6180 - learning_rate: 8.0000e-04
# Epoch 14/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.2305 - y_reg_z_loss: 0.2030 - y_up_auc: 0.8637 - y_up_loss: 0.0565 - y_up_prec: 0.8109 - y_up_rec: 0.6418 - val_loss: 0.1618 - val_y_reg_z_loss: 0.1152 - val_y_up_auc: 0.8420 - val_y_up_loss: 0.0588 - val_y_up_prec: 0.8219 - val_y_up_rec: 0.6742 - learning_rate: 8.0000e-04
# Epoch 15/120
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.2264 - y_reg_z_loss: 0.2056 - y_up_auc: 0.8929 - y_up_loss: 0.0516 - y_up_prec: 0.8466 - y_up_rec: 0.7552
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.00039999998989515007.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.2261 - y_reg_z_loss: 0.2050 - y_up_auc: 0.8928 - y_up_loss: 0.0516 - y_up_prec: 0.8471 - y_up_rec: 0.7542 - val_loss: 0.1575 - val_y_reg_z_loss: 0.1085 - val_y_up_auc: 0.8493 - val_y_up_loss: 0.0591 - val_y_up_prec: 0.8025 - val_y_up_rec: 0.7303 - learning_rate: 8.0000e-04
# Epoch 16/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.2084 - y_reg_z_loss: 0.1858 - y_up_auc: 0.9018 - y_up_loss: 0.0496 - y_up_prec: 0.8292 - y_up_rec: 0.7659 - val_loss: 0.1609 - val_y_reg_z_loss: 0.1126 - val_y_up_auc: 0.8445 - val_y_up_loss: 0.0603 - val_y_up_prec: 0.7882 - val_y_up_rec: 0.7528 - learning_rate: 4.0000e-04
# Epoch 17/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - loss: 0.2201 - y_reg_z_loss: 0.1964 - y_up_auc: 0.8953 - y_up_loss: 0.0523 - y_up_prec: 0.8399 - y_up_rec: 0.7759 - val_loss: 0.1606 - val_y_reg_z_loss: 0.1101 - val_y_up_auc: 0.8437 - val_y_up_loss: 0.0606 - val_y_up_prec: 0.8158 - val_y_up_rec: 0.6966 - learning_rate: 4.0000e-04
# Epoch 18/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.2175 - y_reg_z_loss: 0.1983 - y_up_auc: 0.9027 - y_up_loss: 0.0488 - y_up_prec: 0.8129 - y_up_rec: 0.7401 - val_loss: 0.1615 - val_y_reg_z_loss: 0.1132 - val_y_up_auc: 0.8418 - val_y_up_loss: 0.0600 - val_y_up_prec: 0.7857 - val_y_up_rec: 0.7416 - learning_rate: 4.0000e-04
# Epoch 19/120
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.2076 - y_reg_z_loss: 0.1921 - y_up_auc: 0.9234 - y_up_loss: 0.0450 - y_up_prec: 0.8265 - y_up_rec: 0.7924
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.00019999999494757503.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - loss: 0.2075 - y_reg_z_loss: 0.1912 - y_up_auc: 0.9223 - y_up_loss: 0.0451 - y_up_prec: 0.8299 - y_up_rec: 0.7883 - val_loss: 0.1643 - val_y_reg_z_loss: 0.1149 - val_y_up_auc: 0.8373 - val_y_up_loss: 0.0612 - val_y_up_prec: 0.7750 - val_y_up_rec: 0.6966 - learning_rate: 4.0000e-04
# Epoch 20/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.1935 - y_reg_z_loss: 0.1738 - y_up_auc: 0.9186 - y_up_loss: 0.0456 - y_up_prec: 0.8473 - y_up_rec: 0.8080 - val_loss: 0.1658 - val_y_reg_z_loss: 0.1172 - val_y_up_auc: 0.8351 - val_y_up_loss: 0.0615 - val_y_up_prec: 0.7848 - val_y_up_rec: 0.6966 - learning_rate: 2.0000e-04
# Epoch 21/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.2089 - y_reg_z_loss: 0.1892 - y_up_auc: 0.9144 - y_up_loss: 0.0478 - y_up_prec: 0.8480 - y_up_rec: 0.7802 - val_loss: 0.1646 - val_y_reg_z_loss: 0.1153 - val_y_up_auc: 0.8363 - val_y_up_loss: 0.0616 - val_y_up_prec: 0.7949 - val_y_up_rec: 0.6966 - learning_rate: 2.0000e-04
# Ticker  N_test_seq     RMSE      MAE  Directional_Acc  Precision_Up  Recall_Up    F1_Up      AUC  Best_Threshold  Val_balAcc_at_bestT  TN  FP  FN  TP
# VCB.VN         202 0.002785 0.002077         0.772277      0.771930   0.571429 0.656716 0.816000           0.450             0.793134 112  13  33  44
# TCB.VN         184 0.005836 0.004554         0.766304      0.824074   0.787611 0.805430 0.840334           0.455             0.773897  52  19  24  89
# BID.VN         202 0.004201 0.003264         0.737624      0.721519   0.647727 0.682635 0.802033           0.435             0.811981  92  22  31  57
# CTG.VN         202 0.005703 0.004700         0.688119      0.903846   0.447619 0.598726 0.812862           0.410             0.801667  92   5  58  47

# %%
# store predictions for later use (global)
pred_store = {}

# ✅ ưu tiên đúng 4 mã bạn dùng trong báo cáo
preferred = ["VCB.VN", "BID.VN", "CTG.VN", "TCB.VN"]

# lấy những mã thực sự tồn tại trong splits
tickers = [t for t in preferred if t in splits]

# nếu thiếu (ví dụ bạn train ít mã), bổ sung bằng các mã còn lại trong splits
if len(tickers) < 4:
    for t in splits.keys():
        if t not in tickers:
            tickers.append(t)
        if len(tickers) == 4:
            break

# nếu vẫn <4 thì vẽ theo số lượng thực tế
n = len(tickers)
if n == 0:
    raise ValueError("splits is empty. Bạn cần train xong và có dữ liệu trong splits trước khi plot.")

rows = 2
cols = 2
fig, axes = plt.subplots(rows, cols, figsize=(16, 8))
axes = axes.flatten()

for i in range(rows * cols):
    ax = axes[i]
    if i >= n:
        ax.axis("off")
        continue

    tk = tickers[i]
    (Xtr_seq, Xtr_aux, Xte_seq, Xte_aux, ytr, yte) = splits[tk]
    model = models[tk]
    y_mu  = meta[tk]["y_mu"]
    y_sd  = meta[tk]["y_sd"]

    # predict
    y_reg_z_pred, y_up_prob = model.predict([Xte_seq, Xte_aux], verbose=0)
    y_reg_z_pred = y_reg_z_pred.reshape(-1)
    y_up_prob    = y_up_prob.reshape(-1)

    # denormalize
    y_pred = y_reg_z_pred * y_sd + y_mu

    # save
    pred_store[tk] = {"y_true": yte, "y_pred": y_pred, "y_up_prob": y_up_prob}

    # plot
    ax.plot(yte, label="Actual Return", linewidth=1.4)
    ax.plot(y_pred, label="Predicted Return (Hybrid)", linewidth=1.4)
    ax.set_title(f"{tk} | Actual vs Hybrid Predicted Return")
    ax.set_xlabel("Test Time Index")
    ax.set_ylabel("Return")
    ax.grid(True, alpha=0.3)
    ax.legend()

plt.tight_layout()
plt.show()
