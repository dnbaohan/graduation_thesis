# %% [markdown]
# <a href="https://colab.research.google.com/github/dnbaohan/graduation_thesis/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Library

# %%
# Install required libraries
# !pip install yfinance --quiet
# !pip install scikit-learn --quiet
# !pip install scikeras --quiet
# !pip install tensorflow pandas numpy matplotlib --quiet
# !pip install TA-Lib --quiet

# %%
# =========================
# Standard Libraries
# =========================
import os
import math
import warnings
from datetime import datetime, timedelta
import pywt
import tensorflow as tf
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import (
    mean_squared_error, mean_absolute_error,
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, confusion_matrix
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import f1_score


# =========================
# Numerical & Data Handling
# =========================
import numpy as np
import pandas as pd

# =========================
# Visualization
# =========================
import matplotlib.pyplot as plt

# =========================
# Signal Processing & Statistics
# =========================
import pywt
from scipy.fft import fft, ifft
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller

# =========================
# Financial Data & Indicators
# =========================
import yfinance as yf
import talib  # Technical Analysis Library

# =========================
# Machine Learning & Preprocessing
# =========================
from sklearn.model_selection import train_test_split,TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
from sklearn.metrics import (
    mean_squared_error, mean_absolute_error, r2_score,
    precision_score, recall_score, f1_score,
    roc_auc_score, average_precision_score,
    confusion_matrix, classification_report,
    balanced_accuracy_score
)
from sklearn.utils.class_weight import compute_class_weight

# =========================
# Imbalanced Learning
# =========================
from imblearn.over_sampling import SMOTE

# =========================
# Deep Learning (TensorFlow / Keras)
# =========================
import tensorflow as tf
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from tensorflow.keras.callbacks import (
    EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
)
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import (
    Input, Dense, Dropout, BatchNormalization, LayerNormalization,
    LSTM, GRU, Bidirectional,
    Conv1D, GlobalAveragePooling1D, GlobalMaxPooling1D,
    Attention, MultiHeadAttention, Concatenate
)

# =========================
# Configuration
# =========================
plt.rcParams["figure.figsize"] = (15, 8)
warnings.filterwarnings("ignore")
np.random.seed(0)
tf.random.set_seed(0)

# =========================
# Directory Setup
# =========================
os.makedirs("results/models", exist_ok=True)
os.makedirs("results/plots", exist_ok=True)

# %% [markdown]
# # Data

# %%
start_date = "2020-01-01"
end_date   = "2025-01-01"

tickers = {
    "VCB": "VCB.VN",
    "CTG": "CTG.VN",
    "BID": "BID.VN",
    "TCB": "TCB.VN",
}

# Download dữ liệu
stocks_data = {}
for ticker, symbol in tickers.items():
    df = yf.download(symbol, start=start_date, end=end_date)
    df = df[['Open', 'High', 'Low', 'Close', 'Volume']]
    stocks_data[symbol] = df
# Hiển thị dữ liệu của tất cả mã
for symbol, df in stocks_data.items():
    print(f"Dữ liệu cổ phiếu: {symbol}")
    print(df.head(10))



# Tạo DataFrame với giá đóng cửa cho từng cổ phiếu
df_close = pd.concat({tk: d['Close'] for tk, d in stocks_data.items()}, axis=1)
df_close.columns = df_close.columns.droplevel(0)  # Đổi tên cột sau khi concat

# Tính toán tỷ lệ log return hàng ngày
daily_log_returns = np.log(df_close / df_close.shift(1))

rows = []

for ticker in daily_log_returns.columns:

    # =========================
    # Base series
    # =========================
    close  = df_close[ticker]
    ret    = daily_log_returns[ticker]
    # Ensure volume, high, and low are Series by using .squeeze() and reindexing
    volume = stocks_data[ticker]["Volume"].squeeze().reindex(close.index)
    high   = stocks_data[ticker]["High"].squeeze().reindex(close.index)
    low    = stocks_data[ticker]["Low"].squeeze().reindex(close.index)

    df_feat = pd.DataFrame({
        "date": ret.index,
        "ticker": ticker,
        "return": ret,
        "return_lag1": ret.shift(1),
        "return_lag5": ret.shift(5),
        "return_lag10": ret.shift(10)
    })

    # =========================
    # 1. Volatility
    # =========================
    df_feat["volatility_21"] = ret.rolling(21).std() * np.sqrt(252)
    df_feat["Vol_5"]  = ret.rolling(5).std()
    df_feat["Vol_10"] = ret.rolling(10).std()
    df_feat["Vol_20"] = ret.rolling(20).std()
    # # sigma proxy (shift 1 để chỉ dùng thông tin quá khứ)
    # dft["sigma"] = dft["Vol_20"].shift(1).clip(lower=1e-6).astype(np.float32)
    # # target scaled
    # dft["y_scaled"] = (dft["target"] / dft["sigma"]).astype(np.float32)



    # =========================
    # 2. RSI
    # =========================
    df_feat["RSI_14"] = talib.RSI(close, timeperiod=14)

    # =========================
    # 3. MACD
    # =========================
    macd, macd_sig, _ = talib.MACD(close, 12, 26, 9)
    df_feat["MACD"] = macd
    df_feat["MACD_signal"] = macd_sig

    # =========================
    # 4. Bollinger Bands
    # =========================
    bb_up, bb_mid, bb_low = talib.BBANDS(close, timeperiod=20)
    df_feat["BB_upper"] = bb_up
    df_feat["BB_middle"] = bb_mid
    df_feat["BB_lower"] = bb_low
    df_feat["Boll_width"] = (bb_up - bb_low) / bb_mid
    df_feat["Boll_percB"] = (close - bb_low) / (bb_up - bb_low)

    # =========================
    # 5. Moving Averages
    # =========================
    df_feat["MA_5"]  = ret.rolling(5).mean()
    df_feat["EMA_12"] = ret.ewm(span=12, adjust=False).mean()
    df_feat["EMA_26"] = ret.ewm(span=26, adjust=False).mean()
    df_feat["Trend_20"] = ret.rolling(20).mean()

    # =========================
    # 6. Regime (High/Low vol)
    # =========================
    df_feat["Regime"] = (
        df_feat["Vol_20"] > df_feat["Vol_20"].rolling(60).mean()
    ).astype(int)

    # =========================
    # 7. OBV
    # =========================
    df_feat["OBV"] = talib.OBV(close, volume)

    # =========================
    # 8. Forward returns
    # =========================
    for k in [5, 10, 21]:
        df_feat[f"ret_{k}"] = np.log(close / close.shift(k))

    # =========================
    # 9. Momentum
    # =========================
    short_mom = close / close.shift(5) - 1
    long_mom  = close / close.shift(21) - 1

    df_feat["momentum_diff"] = short_mom - long_mom
    df_feat["momentum_90"] = close / close.shift(90) - 1


    # =========================
    # 10. MA / EMA ratios
    # =========================
    df_feat["SMA20_ratio"] = close / close.rolling(20).mean() - 1
    df_feat["SMA50_ratio"] = close / close.rolling(50).mean() - 1
    df_feat["EMA12_ratio"] = close / close.ewm(span=12).mean() - 1
    df_feat["EMA26_ratio"] = close / close.ewm(span=26).mean() - 1

    # =========================
    # 11. ATR (normalized)
    # =========================
    tr = np.maximum(
        high - low,
        np.maximum(
            (high - close.shift()).abs(),
            (low - close.shift()).abs()
        )
    )
    df_feat["ATR_14"] = tr.rolling(14).mean() / close

    # =========================
    # 12. Volume
    # =========================
    log_vol = np.log(volume.replace(0, np.nan))
    df_feat["Volume_diff"] = log_vol.diff()

    rows.append(df_feat)

# =========================
# Final feature table
# =========================
features = (
    pd.concat(rows)
    .sort_values(["ticker", "date"])
    .reset_index(drop=True)
)

# 7) Target = return ngày kế tiếp
features = features.sort_values(["ticker", "date"])
features["target"] = (
    features.groupby("ticker")["return"]
            .transform(lambda s: s.shift(-1).rolling(5).mean())
)


# 8) Làm sạch dữ liệu (bỏ tất cả NaN phát sinh)
df = features.dropna().reset_index(drop=True)

# Kiểm tra kết quả cuối cùng
print("Dataset cuối cùng:", df.shape)
print(df.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Dữ liệu cổ phiếu: VCB.VN
# Price               Open          High           Low         Close   Volume
# Ticker            VCB.VN        VCB.VN        VCB.VN        VCB.VN   VCB.VN
# Date
# 2020-01-02  39747.175948  40275.960743  39526.846687  40011.566406   870270
# 2020-01-03  40320.025537  40452.224643  39614.976562  39614.976562  1207844
# 2020-01-06  39306.516379  39438.715483  38557.402344  38557.402344  1982797
# 2020-01-07  38337.073175  38733.662732  37632.024213  38689.597656  2529103
# 2020-01-08  38293.009142  38733.663786  37984.549728  38337.074219  1897570
# 2020-01-09  38645.532893  39174.321558  38645.532893  39086.191406  2040337
# 2020-01-10  39086.190369  39835.304393  38733.662017  39438.714844  3596527
# 2020-01-13  39218.388128  39570.912625  39218.388128  39394.648438  3880278
# 2020-01-14  39438.717393  39659.042780  39262.453205  39394.648438  2255442
# 2020-01-15  39482.781137  39482.781137  39130.256652  39350.582031  3379031
# Dữ liệu cổ phiếu: CTG.VN
# Price               Open          High           Low         Close     Volume
# Ticker            CTG.VN        CTG.VN        CTG.VN        CTG.VN     CTG.VN
# Date
# 2020-01-02   9902.445536  10305.176411   9878.755371  10186.725586    9069367
# 2020-01-03  10305.176339  10352.556668  10068.275655  10091.965820    7565383
# 2020-01-06  10044.585754  10281.486443   9997.205423  10115.656250    6620064
# 2020-01-07  10234.105998  10352.556824  10163.035502  10281.486328    8879516
# 2020-01-08  10210.415569  10494.696579  10091.965712  10257.795898  136795825
# 2020-01-09  10352.556861  10707.907410  10352.556861  10636.836914   19592888
# 2020-01-10  10660.527017  11371.229076  10660.527017  11158.018555   31801609
# 2020-01-13  11039.567842  11371.229192  10992.188477  10992.188477   11155134
# 2020-01-14  11015.878267  11276.468147  10992.188103  11134.328125   44334358
# 2020-01-15  11134.328653  11229.089316  11015.878790  11181.708984    9147052
# Dữ liệu cổ phiếu: BID.VN
# Price               Open          High           Low         Close   Volume
# Ticker            BID.VN        BID.VN        BID.VN        BID.VN   BID.VN
# Date
# 2020-01-02  26527.793560  27219.823378  26470.124570  27046.816406  1496500
# 2020-01-03  27306.327921  27392.830441  26931.478516  26931.478516  1035726
# 2020-01-06  26931.477914  26931.477914  26412.455078  26412.455078  1362510
# 2020-01-07  26412.455668  26931.478516  26066.441724  26931.478516   903589
# 2020-01-08  26527.793472  27623.506219  26412.455492  27162.154297  2110812
# 2020-01-09  27537.004037  28776.890240  27450.499584  28632.716797  2697943
# 2020-01-10  28632.716571  29987.940746  28603.883042  29584.257812  2583418
# 2020-01-13  28776.890533  29699.596329  28546.214566  28892.228516   934201
# 2020-01-14  28892.228516  29699.596329  28776.890533  28892.228516  1461481
# 2020-01-15  28776.889191  29584.256967  28776.889191  29411.250000  1192387
# Dữ liệu cổ phiếu: TCB.VN
# Price               Open          High           Low         Close    Volume
# Ticker            TCB.VN        TCB.VN        TCB.VN        TCB.VN    TCB.VN
# Date
# 2020-01-02  10778.707216  10916.015588  10755.822487  10893.130859   2820080
# 2020-01-03  10938.900205  10961.784933  10824.476562  10824.476562   1513400
# 2020-01-06  10710.053459  10710.053459  10549.860352  10549.860352   2325980
# 2020-01-07  10549.859489  10618.513672  10526.974761  10618.513672   4920200
# 2020-01-08  10435.436487  10549.860133  10343.897570  10412.551758   3420780
# 2020-01-09  10526.975622  10572.745081  10458.321433  10549.860352   4019680
# 2020-01-10  10526.975694  10755.822991  10526.975694  10595.629883   7358220
# 2020-01-13  10526.974571  10595.628753  10412.550934  10504.089844   1784720
# 2020-01-14  10504.090784  10549.860243  10481.206055  10481.206055   4561960
# 2020-01-15  10481.206055  10526.975513  10435.436596  10481.206055  11830560
# Dataset cuối cùng: (4547, 36)
#         date  ticker    return  return_lag1  return_lag5  return_lag10  \
# 0 2020-05-19  BID.VN  0.005128     0.007742     0.001298      0.000000
# 1 2020-05-20  BID.VN  0.001278     0.005128     0.026873      0.019636
# 2 2020-05-21  BID.VN  0.013951     0.001278     0.002522      0.042154
# 3 2020-05-22  BID.VN -0.010127     0.013951    -0.028099      0.011913
# 4 2020-05-25  BID.VN  0.008866    -0.010127     0.007742      0.013072
#
#    volatility_21     Vol_5    Vol_10    Vol_20  ...    ret_21  momentum_diff  \
# 0       0.375966  0.019775  0.018367  0.024299  ...  0.047129      -0.033990
# 1       0.375977  0.014643  0.018239  0.024180  ...  0.045730      -0.058155
# 2       0.376159  0.016371  0.014162  0.017873  ...  0.067734      -0.070081
# 3       0.282645  0.008950  0.014767  0.016140  ...  0.124485      -0.114430
# 4       0.250277  0.009094  0.014517  0.016143  ...  0.091032      -0.076024
#
#    momentum_90  SMA20_ratio  SMA50_ratio  EMA12_ratio  EMA26_ratio    ATR_14  \
# 0    -0.166311     0.055117     0.077283     0.023980     0.041833  0.031056
# 1    -0.161670     0.053552     0.083257     0.021316     0.039838  0.030104
# 2    -0.133188     0.061214     0.100851     0.030013     0.050207  0.029867
# 3    -0.158458     0.046187     0.091636     0.016564     0.036581  0.029080
# 4    -0.158174     0.050679     0.101236     0.021591     0.042273  0.029184
#
#    Volume_diff        target
# 0    -0.100422 -2.285745e-03
# 1    -0.627118  6.938894e-18
# 2     1.010765  3.594464e-03
# 3    -0.774392  3.819332e-03
# 4    -0.250203  1.430943e-02
#
# [5 rows x 36 columns]

# %%
def adf_summary_full(df):
    results = []
    numeric_cols = df.select_dtypes(include=[np.number]).columns  # chỉ lấy cột số

    for col in numeric_cols:
        series = df[col].dropna()
        if len(series) < 20:  # bỏ qua cột có quá ít quan sát
            continue
        adf_result = adfuller(series, autolag='AIC')
        pval = adf_result[1]
        stat = adf_result[0]
        crit = adf_result[4]['5%']
        results.append({
            'Variable': col,
            'ADF Statistic': round(stat, 4),
            'p-value': round(pval, 4),
            '5% Critical Value': round(crit, 4),
            'Stationary': 'Yes' if pval < 0.05 else 'No'
        })

    return pd.DataFrame(results)

# Gọi hàm trên toàn bộ dataframe của bạn
adf_table_full = adf_summary_full(df)
print(adf_table_full)

df.columns
# Out:
#          Variable  ADF Statistic  p-value  5% Critical Value Stationary
# 0          return       -11.8925   0.0000            -2.8622        Yes
# 1     return_lag1       -11.9094   0.0000            -2.8622        Yes
# 2     return_lag5       -11.9292   0.0000            -2.8622        Yes
# 3    return_lag10       -12.0856   0.0000            -2.8622        Yes
# 4   volatility_21        -7.7038   0.0000            -2.8622        Yes
# 5           Vol_5        -7.0304   0.0000            -2.8622        Yes
# 6          Vol_10        -7.1426   0.0000            -2.8622        Yes
# 7          Vol_20        -7.8243   0.0000            -2.8622        Yes
# 8          RSI_14       -13.1756   0.0000            -2.8622        Yes
# 9            MACD       -10.8881   0.0000            -2.8622        Yes
# 10    MACD_signal       -10.1030   0.0000            -2.8622        Yes
# 11       BB_upper        -0.9483   0.7716            -2.8622         No
# 12      BB_middle        -0.6742   0.8533            -2.8622         No
# 13       BB_lower        -0.9027   0.7871            -2.8622         No
# 14     Boll_width        -9.9387   0.0000            -2.8622        Yes
# 15     Boll_percB       -16.6423   0.0000            -2.8622        Yes
# 16           MA_5       -10.5486   0.0000            -2.8622        Yes
# 17         EMA_12       -10.2036   0.0000            -2.8622        Yes
# 18         EMA_26        -9.4078   0.0000            -2.8622        Yes
# 19       Trend_20       -10.9190   0.0000            -2.8622        Yes
# 20         Regime       -11.1358   0.0000            -2.8622        Yes
# 21            OBV        -2.2195   0.1992            -2.8622         No
# 22          ret_5       -10.5486   0.0000            -2.8622        Yes
# 23         ret_10        -9.9360   0.0000            -2.8622        Yes
# 24         ret_21       -10.5904   0.0000            -2.8622        Yes
# 25  momentum_diff        -9.0520   0.0000            -2.8622        Yes
# 26    momentum_90        -6.4862   0.0000            -2.8622        Yes
# 27    SMA20_ratio       -10.5529   0.0000            -2.8622        Yes
# 28    SMA50_ratio        -9.7066   0.0000            -2.8622        Yes
# 29    EMA12_ratio       -10.1994   0.0000            -2.8622        Yes
# 30    EMA26_ratio        -9.3775   0.0000            -2.8622        Yes
# 31         ATR_14        -7.5531   0.0000            -2.8622        Yes
# 32    Volume_diff       -21.2388   0.0000            -2.8622        Yes
# 33         target       -10.5445   0.0000            -2.8622        Yes
# Index(['date', 'ticker', 'return', 'return_lag1', 'return_lag5',
#        'return_lag10', 'volatility_21', 'Vol_5', 'Vol_10', 'Vol_20', 'RSI_14',
#        'MACD', 'MACD_signal', 'BB_upper', 'BB_middle', 'BB_lower',
#        'Boll_width', 'Boll_percB', 'MA_5', 'EMA_12', 'EMA_26', 'Trend_20',
#        'Regime', 'OBV', 'ret_5', 'ret_10', 'ret_21', 'momentum_diff',
#        'momentum_90', 'SMA20_ratio', 'SMA50_ratio', 'EMA12_ratio',
#        'EMA26_ratio', 'ATR_14', 'Volume_diff', 'target'],
#       dtype='object')

# %% [markdown]
# # Transformer

# %%
# ---------- Positional Encoding ----------
class PositionalEncoding(tf.keras.layers.Layer):
    def __init__(self, position: int, d_model: int):
        super().__init__()
        pos = np.arange(position)[:, np.newaxis]
        i   = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        angle_rads  = pos * angle_rates
        angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
        angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.pos_encoding = tf.constant(angle_rads[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        return x + self.pos_encoding[:, :tf.shape(x)[1], :]

def transformer_encoder(x, num_heads, key_dim, ff_dim, dropout=0.2):
    attn_out = tf.keras.layers.MultiHeadAttention(
        num_heads=num_heads, key_dim=key_dim, dropout=dropout
    )(x, x)
    attn_out = tf.keras.layers.Dropout(dropout)(attn_out)
    x = tf.keras.layers.Add()([x, attn_out])
    x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(x)

    ff = tf.keras.layers.Dense(ff_dim, activation="relu")(x)
    ff = tf.keras.layers.Dropout(dropout)(ff)
    ff = tf.keras.layers.Dense(x.shape[-1])(ff)
    x = tf.keras.layers.Add()([x, ff])
    x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(x)
    return x

# %%
def build_transformer_multitask(
    input_shape,
    d_model=64,
    num_heads=4,
    ff_dim=128,
    num_blocks=3,
    dropout=0.2,
    use_conv_frontend=True
):
    """
    input_shape: (LOOKBACK, n_features)
    outputs:
      - y_reg_z: standardized return (regression)
      - y_up: probability of Up (classification)
    """
    inputs = tf.keras.Input(shape=input_shape)

    # Project features -> d_model
    x = tf.keras.layers.Dense(d_model)(inputs)

    # Optional local-pattern front-end (often helps for financial series)
    if use_conv_frontend:
        x = tf.keras.layers.Conv1D(filters=d_model, kernel_size=3, padding="causal", activation="relu")(x)
        x = tf.keras.layers.Dropout(dropout)(x)

    x = PositionalEncoding(position=input_shape[0], d_model=d_model)(x)

    key_dim = max(8, d_model // num_heads)
    for _ in range(num_blocks):
        x = transformer_encoder(x, num_heads=num_heads, key_dim=key_dim, ff_dim=ff_dim, dropout=dropout)

    x = tf.keras.layers.GlobalAveragePooling1D()(x)
    x = tf.keras.layers.Dropout(dropout)(x)

    # Head 1: regression on standardized target
    y_reg_z = tf.keras.layers.Dense(1, name="y_reg_z")(x)

    # Head 2: direction probability
    y_up = tf.keras.layers.Dense(1, activation="sigmoid", name="y_up")(x)

    return tf.keras.Model(inputs, [y_reg_z, y_up])

# %%
def make_weighted_bce(w_pos, w_neg):
    # w_pos applies to y_true==1, w_neg applies to y_true==0
    def weighted_bce(y_true, y_pred):
        bce = tf.keras.backend.binary_crossentropy(y_true, y_pred)
        w = y_true * w_pos + (1.0 - y_true) * w_neg
        return tf.reduce_mean(bce * w)
    return weighted_bce

# %%
import numpy as np
from sklearn.metrics import f1_score

def tune_threshold(y_true_bin, y_prob, lo=0.3, hi=0.7, n=81):
    ths = np.linspace(lo, hi, n)
    best_t, best_f1 = 0.5, -1
    for t in ths:
        f1 = f1_score(y_true_bin, (y_prob > t).astype(int), zero_division=0)
        if f1 > best_f1:
            best_f1, best_t = f1, t
    return best_t, best_f1

# %%
def create_sequences(X, y, seq_len):
    X_seq, y_seq = [], []
    for i in range(seq_len, len(X)):
        X_seq.append(X[i-seq_len:i])
        y_seq.append(y[i])
    return np.array(X_seq), np.array(y_seq)

LOOKBACK = 30
non_feature = ['date', 'ticker', 'target']
feature_cols = [c for c in df.columns if c not in non_feature]

df = df.copy()
df["date"] = pd.to_datetime(df["date"])

models, scalers, histories, splits, meta = {}, {}, {}, {}, {}


# -------------------
import tensorflow as tf
import numpy as np

def focal_loss(alpha=0.5, gamma=2.0):
    """Binary focal loss for collapse-prone classification."""
    def fl(y_true, y_pred):
        eps = tf.keras.backend.epsilon()
        y_pred = tf.clip_by_value(y_pred, eps, 1.0 - eps)
        ce = -(y_true * tf.math.log(y_pred) + (1.0 - y_true) * tf.math.log(1.0 - y_pred))
        p_t = y_true * y_pred + (1.0 - y_true) * (1.0 - y_pred)
        w = alpha * y_true + (1.0 - alpha) * (1.0 - y_true)
        return tf.reduce_mean(w * tf.pow((1.0 - p_t), gamma) * ce)
    return fl

def make_direction_labels_with_mask(y, vol_proxy, k=0.3):
    """
    y: target series (float)
    vol_proxy: volatility proxy at time t (must be past-only; shift outside if needed)
    k: noise filter strength; CTG thường hợp 0.25–0.40
    Returns:
      y_up (0/1), mask (0/1) -> mask=0 means ignore this sample for classification loss
    """
    vol_proxy = np.asarray(vol_proxy, dtype=np.float32)
    y = np.asarray(y, dtype=np.float32)

    thr = k * vol_proxy
    mask = np.isfinite(y) & np.isfinite(vol_proxy) & (np.abs(y) >= thr)
    y_up = (y > 0).astype(np.float32)

    return y_up, mask.astype(np.float32)
# --------------

for tk, dft in df.groupby("ticker"):
    dft = dft.sort_values("date").reset_index(drop=True)

    X = dft[feature_cols].values.astype(np.float32)
    y = dft["target"].values.astype(np.float32)

    if len(dft) < (LOOKBACK + 80):
        print(f"⚠️ {tk}: dữ liệu quá ít ({len(dft)} dòng) -> bỏ qua")
        continue

    split_index = int(len(dft) * 0.8)
    X_train_raw, X_test_raw = X[:split_index], X[split_index:]
    y_train_raw, y_test_raw = y[:split_index], y[split_index:]

    scaler = RobustScaler()
    X_train_scaled = scaler.fit_transform(X_train_raw)
    X_test_scaled  = scaler.transform(X_test_raw)

    X_train_seq, y_train_seq = create_sequences(X_train_scaled, y_train_raw, LOOKBACK)
    X_test_seq,  y_test_seq  = create_sequences(X_test_scaled,  y_test_raw,  LOOKBACK)

    # validation from tail of train
    val_size = max(1, int(0.2 * len(X_train_seq)))
    X_tr, y_tr = X_train_seq[:-val_size], y_train_seq[:-val_size]
    X_val, y_val = X_train_seq[-val_size:], y_train_seq[-val_size:]

    # ===== 1) Standardize y on train ONLY =====
    y_mu = float(np.mean(y_tr))
    y_sd = float(np.std(y_tr) + 1e-8)
    y_tr_z  = ((y_tr  - y_mu) / y_sd).astype(np.float32)
    y_val_z = ((y_val - y_mu) / y_sd).astype(np.float32)

    # direction labels
    y_tr_up  = (y_tr > 0).astype(np.float32)
    y_val_up = (y_val > 0).astype(np.float32)

    # ===== 2) Weighted BCE to reduce collapse/bias =====
    pos = float(y_tr_up.mean())          # P(Up)
    w_pos = 0.5 / (pos + 1e-8)
    w_neg = 0.5 / (1.0 - pos + 1e-8)
    w_bce = make_weighted_bce(w_pos=w_pos, w_neg=w_neg)

    # ===== 3) Build model =====
    model = build_transformer_multitask(
        input_shape=(LOOKBACK, X_train_seq.shape[2]),
        d_model=64,
        num_heads=4,
        ff_dim=128,
        num_blocks=3,
        dropout=0.2,
        use_conv_frontend=True
    )

    # optimizer: clipnorm improves stability a lot on noisy targets
    opt = Adam(learning_rate=1e-3, clipnorm=1.0)

    model.compile(
        optimizer=opt,
        loss={
            "y_reg_z": tf.keras.losses.Huber(delta=1.0),
            "y_up": w_bce
        },
        loss_weights={"y_reg_z": 1.0, "y_up": 0.5}  # you can try 0.3–0.8
    )

    early_stop = EarlyStopping(monitor="val_loss", patience=12, restore_best_weights=True)
    rlr = ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=5, min_lr=1e-5, verbose=1)

    print(f"\n===== Training Transformer (Improved) for {tk} | UpRatio={pos:.3f} =====")
    history = model.fit(
        X_tr, {"y_reg_z": y_tr_z, "y_up": y_tr_up},
        validation_data=(X_val, {"y_reg_z": y_val_z, "y_up": y_val_up}),
        epochs=120,
        batch_size=32,   # often better than 64 for financial series
        callbacks=[early_stop, rlr],
        verbose=1
    )

    models[tk] = model
    scalers[tk] = scaler
    histories[tk] = history
    splits[tk] = (X_train_seq, X_test_seq, y_train_seq, y_test_seq)
    meta[tk] = {"y_mu": y_mu, "y_sd": y_sd, "up_ratio": pos, "w_pos": w_pos, "w_neg": w_neg}

print("\nDone. Models trained for:", list(models.keys()))
# Out:
# ===== Training Transformer (Improved) for BID.VN | UpRatio=0.524 =====
# Epoch 1/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 18s 141ms/step - loss: 1.1303 - y_reg_z_loss: 0.7360 - y_up_loss: 0.7880 - val_loss: 0.5618 - val_y_reg_z_loss: 0.2235 - val_y_up_loss: 0.7208 - learning_rate: 0.0010
# Epoch 2/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - loss: 0.8387 - y_reg_z_loss: 0.4755 - y_up_loss: 0.7257 - val_loss: 0.5484 - val_y_reg_z_loss: 0.2137 - val_y_up_loss: 0.7123 - learning_rate: 0.0010
# Epoch 3/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.8322 - y_reg_z_loss: 0.4785 - y_up_loss: 0.7068 - val_loss: 0.5825 - val_y_reg_z_loss: 0.2288 - val_y_up_loss: 0.7602 - learning_rate: 0.0010
# Epoch 4/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.7925 - y_reg_z_loss: 0.4537 - y_up_loss: 0.6769 - val_loss: 0.5888 - val_y_reg_z_loss: 0.2721 - val_y_up_loss: 0.7261 - learning_rate: 0.0010
# Epoch 5/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 0.7510 - y_reg_z_loss: 0.4111 - y_up_loss: 0.6790 - val_loss: 0.6308 - val_y_reg_z_loss: 0.2714 - val_y_up_loss: 0.7841 - learning_rate: 0.0010
# Epoch 6/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.7542 - y_reg_z_loss: 0.4275 - y_up_loss: 0.6523 - val_loss: 0.5817 - val_y_reg_z_loss: 0.2572 - val_y_up_loss: 0.7749 - learning_rate: 0.0010
# Epoch 7/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - loss: 0.6239 - y_reg_z_loss: 0.3468 - y_up_loss: 0.5540 - val_loss: 0.4992 - val_y_reg_z_loss: 0.2234 - val_y_up_loss: 0.6795 - learning_rate: 0.0010
# Epoch 8/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.5306 - y_reg_z_loss: 0.2880 - y_up_loss: 0.4849 - val_loss: 0.4455 - val_y_reg_z_loss: 0.2094 - val_y_up_loss: 0.5589 - learning_rate: 0.0010
# Epoch 9/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 0.4902 - y_reg_z_loss: 0.2594 - y_up_loss: 0.4610 - val_loss: 0.4708 - val_y_reg_z_loss: 0.2226 - val_y_up_loss: 0.5753 - learning_rate: 0.0010
# Epoch 10/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.4504 - y_reg_z_loss: 0.2388 - y_up_loss: 0.4235 - val_loss: 0.5122 - val_y_reg_z_loss: 0.2479 - val_y_up_loss: 0.6335 - learning_rate: 0.0010
# Epoch 11/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 0.4259 - y_reg_z_loss: 0.2130 - y_up_loss: 0.4251 - val_loss: 0.4924 - val_y_reg_z_loss: 0.2275 - val_y_up_loss: 0.6172 - learning_rate: 0.0010
# Epoch 12/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 0.4085 - y_reg_z_loss: 0.2110 - y_up_loss: 0.3951 - val_loss: 0.4613 - val_y_reg_z_loss: 0.2031 - val_y_up_loss: 0.6013 - learning_rate: 0.0010
# Epoch 13/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.3965 - y_reg_z_loss: 0.2033 - y_up_loss: 0.3862
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - loss: 0.3952 - y_reg_z_loss: 0.2026 - y_up_loss: 0.3850 - val_loss: 0.4981 - val_y_reg_z_loss: 0.2187 - val_y_up_loss: 0.6252 - learning_rate: 0.0010
# Epoch 14/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.3551 - y_reg_z_loss: 0.1856 - y_up_loss: 0.3391 - val_loss: 0.5495 - val_y_reg_z_loss: 0.2739 - val_y_up_loss: 0.6732 - learning_rate: 5.0000e-04
# Epoch 15/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 0.3514 - y_reg_z_loss: 0.1744 - y_up_loss: 0.3541 - val_loss: 0.5479 - val_y_reg_z_loss: 0.2755 - val_y_up_loss: 0.6645 - learning_rate: 5.0000e-04
# Epoch 16/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 0.3164 - y_reg_z_loss: 0.1600 - y_up_loss: 0.3127 - val_loss: 0.5969 - val_y_reg_z_loss: 0.2781 - val_y_up_loss: 0.7714 - learning_rate: 5.0000e-04
# Epoch 17/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.3208 - y_reg_z_loss: 0.1581 - y_up_loss: 0.3254 - val_loss: 0.5492 - val_y_reg_z_loss: 0.2626 - val_y_up_loss: 0.6903 - learning_rate: 5.0000e-04
# Epoch 18/120
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.3131 - y_reg_z_loss: 0.1627 - y_up_loss: 0.3007
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 0.3123 - y_reg_z_loss: 0.1618 - y_up_loss: 0.3008 - val_loss: 0.6081 - val_y_reg_z_loss: 0.3044 - val_y_up_loss: 0.7557 - learning_rate: 5.0000e-04
# Epoch 19/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - loss: 0.3044 - y_reg_z_loss: 0.1469 - y_up_loss: 0.3147 - val_loss: 0.6076 - val_y_reg_z_loss: 0.2858 - val_y_up_loss: 0.8008 - learning_rate: 2.5000e-04
# Epoch 20/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - loss: 0.2893 - y_reg_z_loss: 0.1496 - y_up_loss: 0.2789 - val_loss: 0.6549 - val_y_reg_z_loss: 0.3278 - val_y_up_loss: 0.8368 - learning_rate: 2.5000e-04
#
# ===== Training Transformer (Improved) for CTG.VN | UpRatio=0.511 =====
# Epoch 1/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 18s 114ms/step - loss: 1.0600 - y_reg_z_loss: 0.6331 - y_up_loss: 0.8522 - val_loss: 0.7596 - val_y_reg_z_loss: 0.3720 - val_y_up_loss: 0.8827 - learning_rate: 0.0010
# Epoch 2/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.7408 - y_reg_z_loss: 0.4059 - y_up_loss: 0.6690 - val_loss: 0.7766 - val_y_reg_z_loss: 0.3837 - val_y_up_loss: 0.9286 - learning_rate: 0.0010
# Epoch 3/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - loss: 0.7826 - y_reg_z_loss: 0.4465 - y_up_loss: 0.6715 - val_loss: 0.8062 - val_y_reg_z_loss: 0.3868 - val_y_up_loss: 0.9745 - learning_rate: 0.0010
# Epoch 4/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - loss: 0.7444 - y_reg_z_loss: 0.4116 - y_up_loss: 0.6652 - val_loss: 0.9314 - val_y_reg_z_loss: 0.4557 - val_y_up_loss: 1.1109 - learning_rate: 0.0010
# Epoch 5/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.6668 - y_reg_z_loss: 0.3476 - y_up_loss: 0.6379 - val_loss: 1.2721 - val_y_reg_z_loss: 0.7271 - val_y_up_loss: 1.2869 - learning_rate: 0.0010
# Epoch 6/120
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.6279 - y_reg_z_loss: 0.3229 - y_up_loss: 0.6100
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 0.6259 - y_reg_z_loss: 0.3221 - y_up_loss: 0.6068 - val_loss: 0.9856 - val_y_reg_z_loss: 0.5074 - val_y_up_loss: 1.0958 - learning_rate: 0.0010
# Epoch 7/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.5009 - y_reg_z_loss: 0.2497 - y_up_loss: 0.5022 - val_loss: 0.7678 - val_y_reg_z_loss: 0.2683 - val_y_up_loss: 1.1233 - learning_rate: 5.0000e-04
# Epoch 8/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.4644 - y_reg_z_loss: 0.2469 - y_up_loss: 0.4343 - val_loss: 0.6701 - val_y_reg_z_loss: 0.2273 - val_y_up_loss: 1.0047 - learning_rate: 5.0000e-04
# Epoch 9/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.4294 - y_reg_z_loss: 0.2120 - y_up_loss: 0.4345 - val_loss: 0.7335 - val_y_reg_z_loss: 0.2327 - val_y_up_loss: 1.1145 - learning_rate: 5.0000e-04
# Epoch 10/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 0.4308 - y_reg_z_loss: 0.2226 - y_up_loss: 0.4160 - val_loss: 0.7715 - val_y_reg_z_loss: 0.2730 - val_y_up_loss: 1.1376 - learning_rate: 5.0000e-04
# Epoch 11/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - loss: 0.4139 - y_reg_z_loss: 0.2085 - y_up_loss: 0.4102 - val_loss: 0.5769 - val_y_reg_z_loss: 0.1833 - val_y_up_loss: 0.8982 - learning_rate: 5.0000e-04
# Epoch 12/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.4218 - y_reg_z_loss: 0.2194 - y_up_loss: 0.4040 - val_loss: 0.6047 - val_y_reg_z_loss: 0.1676 - val_y_up_loss: 0.9720 - learning_rate: 5.0000e-04
# Epoch 13/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 0.4054 - y_reg_z_loss: 0.2010 - y_up_loss: 0.4077 - val_loss: 0.5935 - val_y_reg_z_loss: 0.1623 - val_y_up_loss: 0.9550 - learning_rate: 5.0000e-04
# Epoch 14/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 0.4376 - y_reg_z_loss: 0.2273 - y_up_loss: 0.4200 - val_loss: 0.6270 - val_y_reg_z_loss: 0.1903 - val_y_up_loss: 0.9934 - learning_rate: 5.0000e-04
# Epoch 15/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.3930 - y_reg_z_loss: 0.2013 - y_up_loss: 0.3829 - val_loss: 0.5738 - val_y_reg_z_loss: 0.1807 - val_y_up_loss: 0.8971 - learning_rate: 5.0000e-04
# Epoch 16/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - loss: 0.3891 - y_reg_z_loss: 0.2106 - y_up_loss: 0.3563 - val_loss: 0.6273 - val_y_reg_z_loss: 0.2003 - val_y_up_loss: 0.9704 - learning_rate: 5.0000e-04
# Epoch 17/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - loss: 0.3509 - y_reg_z_loss: 0.1775 - y_up_loss: 0.3463 - val_loss: 0.5808 - val_y_reg_z_loss: 0.1840 - val_y_up_loss: 0.9021 - learning_rate: 5.0000e-04
# Epoch 18/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.3454 - y_reg_z_loss: 0.1746 - y_up_loss: 0.3410 - val_loss: 0.5494 - val_y_reg_z_loss: 0.1481 - val_y_up_loss: 0.8979 - learning_rate: 5.0000e-04
# Epoch 19/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 0.3542 - y_reg_z_loss: 0.1842 - y_up_loss: 0.3394 - val_loss: 0.6341 - val_y_reg_z_loss: 0.1936 - val_y_up_loss: 0.9939 - learning_rate: 5.0000e-04
# Epoch 20/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.3316 - y_reg_z_loss: 0.1692 - y_up_loss: 0.3243 - val_loss: 0.6805 - val_y_reg_z_loss: 0.2178 - val_y_up_loss: 1.0653 - learning_rate: 5.0000e-04
# Epoch 21/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 0.3262 - y_reg_z_loss: 0.1665 - y_up_loss: 0.3187 - val_loss: 0.6092 - val_y_reg_z_loss: 0.1842 - val_y_up_loss: 0.9765 - learning_rate: 5.0000e-04
# Epoch 22/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.3301 - y_reg_z_loss: 0.1773 - y_up_loss: 0.3049 - val_loss: 0.5591 - val_y_reg_z_loss: 0.1786 - val_y_up_loss: 0.8717 - learning_rate: 5.0000e-04
# Epoch 23/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - loss: 0.3211 - y_reg_z_loss: 0.1701 - y_up_loss: 0.3015 - val_loss: 0.5049 - val_y_reg_z_loss: 0.1438 - val_y_up_loss: 0.7976 - learning_rate: 5.0000e-04
# Epoch 24/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.3340 - y_reg_z_loss: 0.1861 - y_up_loss: 0.2952 - val_loss: 0.5697 - val_y_reg_z_loss: 0.1741 - val_y_up_loss: 0.8939 - learning_rate: 5.0000e-04
# Epoch 25/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 163ms/step - loss: 0.2853 - y_reg_z_loss: 0.1433 - y_up_loss: 0.2835 - val_loss: 0.5254 - val_y_reg_z_loss: 0.1584 - val_y_up_loss: 0.8265 - learning_rate: 5.0000e-04
# Epoch 26/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 167ms/step - loss: 0.2756 - y_reg_z_loss: 0.1464 - y_up_loss: 0.2577 - val_loss: 0.5034 - val_y_reg_z_loss: 0.1529 - val_y_up_loss: 0.7983 - learning_rate: 5.0000e-04
# Epoch 27/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - loss: 0.2772 - y_reg_z_loss: 0.1449 - y_up_loss: 0.2641 - val_loss: 0.5324 - val_y_reg_z_loss: 0.1425 - val_y_up_loss: 0.8725 - learning_rate: 5.0000e-04
# Epoch 28/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - loss: 0.2829 - y_reg_z_loss: 0.1446 - y_up_loss: 0.2761 - val_loss: 0.6604 - val_y_reg_z_loss: 0.1979 - val_y_up_loss: 1.0417 - learning_rate: 5.0000e-04
# Epoch 29/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.2400 - y_reg_z_loss: 0.1110 - y_up_loss: 0.2575 - val_loss: 0.5426 - val_y_reg_z_loss: 0.1351 - val_y_up_loss: 0.9023 - learning_rate: 5.0000e-04
# Epoch 30/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 0.2695 - y_reg_z_loss: 0.1430 - y_up_loss: 0.2527 - val_loss: 0.5700 - val_y_reg_z_loss: 0.1539 - val_y_up_loss: 0.9175 - learning_rate: 5.0000e-04
# Epoch 31/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.2578 - y_reg_z_loss: 0.1393 - y_up_loss: 0.2370
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - loss: 0.2579 - y_reg_z_loss: 0.1393 - y_up_loss: 0.2373 - val_loss: 0.6536 - val_y_reg_z_loss: 0.1637 - val_y_up_loss: 1.1047 - learning_rate: 5.0000e-04
# Epoch 32/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 0.2628 - y_reg_z_loss: 0.1396 - y_up_loss: 0.2459 - val_loss: 0.6297 - val_y_reg_z_loss: 0.1692 - val_y_up_loss: 1.0365 - learning_rate: 2.5000e-04
# Epoch 33/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - loss: 0.2360 - y_reg_z_loss: 0.1228 - y_up_loss: 0.2258 - val_loss: 0.7341 - val_y_reg_z_loss: 0.1940 - val_y_up_loss: 1.2131 - learning_rate: 2.5000e-04
# Epoch 34/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.2195 - y_reg_z_loss: 0.1219 - y_up_loss: 0.1947 - val_loss: 0.5903 - val_y_reg_z_loss: 0.1489 - val_y_up_loss: 0.9837 - learning_rate: 2.5000e-04
# Epoch 35/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.2005 - y_reg_z_loss: 0.1078 - y_up_loss: 0.1852 - val_loss: 0.6476 - val_y_reg_z_loss: 0.1720 - val_y_up_loss: 1.0683 - learning_rate: 2.5000e-04
# Epoch 36/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - loss: 0.2076 - y_reg_z_loss: 0.1011 - y_up_loss: 0.2127 - val_loss: 0.4960 - val_y_reg_z_loss: 0.1280 - val_y_up_loss: 0.8104 - learning_rate: 2.5000e-04
# Epoch 37/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - loss: 0.2242 - y_reg_z_loss: 0.1240 - y_up_loss: 0.2000 - val_loss: 0.6606 - val_y_reg_z_loss: 0.1659 - val_y_up_loss: 1.1024 - learning_rate: 2.5000e-04
# Epoch 38/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.2175 - y_reg_z_loss: 0.1152 - y_up_loss: 0.2041 - val_loss: 0.6011 - val_y_reg_z_loss: 0.1633 - val_y_up_loss: 0.9706 - learning_rate: 2.5000e-04
# Epoch 39/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.1972 - y_reg_z_loss: 0.1067 - y_up_loss: 0.1806 - val_loss: 0.6097 - val_y_reg_z_loss: 0.1442 - val_y_up_loss: 1.0228 - learning_rate: 2.5000e-04
# Epoch 40/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.2317 - y_reg_z_loss: 0.1133 - y_up_loss: 0.2366 - val_loss: 0.5761 - val_y_reg_z_loss: 0.1466 - val_y_up_loss: 0.9470 - learning_rate: 2.5000e-04
# Epoch 41/120
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.2072 - y_reg_z_loss: 0.1137 - y_up_loss: 0.1871
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.2074 - y_reg_z_loss: 0.1138 - y_up_loss: 0.1872 - val_loss: 0.5585 - val_y_reg_z_loss: 0.1515 - val_y_up_loss: 0.8934 - learning_rate: 2.5000e-04
# Epoch 42/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.2094 - y_reg_z_loss: 0.1208 - y_up_loss: 0.1769 - val_loss: 0.5683 - val_y_reg_z_loss: 0.1391 - val_y_up_loss: 0.9386 - learning_rate: 1.2500e-04
# Epoch 43/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 0.2206 - y_reg_z_loss: 0.1229 - y_up_loss: 0.1948 - val_loss: 0.5702 - val_y_reg_z_loss: 0.1445 - val_y_up_loss: 0.9337 - learning_rate: 1.2500e-04
# Epoch 44/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.2078 - y_reg_z_loss: 0.1161 - y_up_loss: 0.1834 - val_loss: 0.6066 - val_y_reg_z_loss: 0.1584 - val_y_up_loss: 0.9876 - learning_rate: 1.2500e-04
# Epoch 45/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.1916 - y_reg_z_loss: 0.1010 - y_up_loss: 0.1808 - val_loss: 0.6046 - val_y_reg_z_loss: 0.1492 - val_y_up_loss: 1.0016 - learning_rate: 1.2500e-04
# Epoch 46/120
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.2081 - y_reg_z_loss: 0.1138 - y_up_loss: 0.1886
# Epoch 46: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 0.2072 - y_reg_z_loss: 0.1131 - y_up_loss: 0.1878 - val_loss: 0.5911 - val_y_reg_z_loss: 0.1503 - val_y_up_loss: 0.9660 - learning_rate: 1.2500e-04
# Epoch 47/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 0.1799 - y_reg_z_loss: 0.0975 - y_up_loss: 0.1646 - val_loss: 0.6297 - val_y_reg_z_loss: 0.1704 - val_y_up_loss: 1.0136 - learning_rate: 6.2500e-05
# Epoch 48/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - loss: 0.1894 - y_reg_z_loss: 0.1053 - y_up_loss: 0.1680 - val_loss: 0.5723 - val_y_reg_z_loss: 0.1455 - val_y_up_loss: 0.9316 - learning_rate: 6.2500e-05
#
# ===== Training Transformer (Improved) for TCB.VN | UpRatio=0.555 =====
# Epoch 1/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 17s 117ms/step - loss: 0.9958 - y_reg_z_loss: 0.6272 - y_up_loss: 0.7366 - val_loss: 0.5575 - val_y_reg_z_loss: 0.1614 - val_y_up_loss: 0.7728 - learning_rate: 0.0010
# Epoch 2/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.7101 - y_reg_z_loss: 0.3642 - y_up_loss: 0.6910 - val_loss: 0.5298 - val_y_reg_z_loss: 0.1579 - val_y_up_loss: 0.7194 - learning_rate: 0.0010
# Epoch 3/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - loss: 0.6947 - y_reg_z_loss: 0.3648 - y_up_loss: 0.6598 - val_loss: 0.5502 - val_y_reg_z_loss: 0.1698 - val_y_up_loss: 0.7361 - learning_rate: 0.0010
# Epoch 4/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 0.6546 - y_reg_z_loss: 0.3298 - y_up_loss: 0.6491 - val_loss: 0.5698 - val_y_reg_z_loss: 0.1702 - val_y_up_loss: 0.7579 - learning_rate: 0.0010
# Epoch 5/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.6257 - y_reg_z_loss: 0.3040 - y_up_loss: 0.6430 - val_loss: 0.5481 - val_y_reg_z_loss: 0.1517 - val_y_up_loss: 0.7473 - learning_rate: 0.0010
# Epoch 6/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - loss: 0.5907 - y_reg_z_loss: 0.2828 - y_up_loss: 0.6154 - val_loss: 0.5849 - val_y_reg_z_loss: 0.1692 - val_y_up_loss: 0.7799 - learning_rate: 0.0010
# Epoch 7/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - loss: 0.5830 - y_reg_z_loss: 0.2839 - y_up_loss: 0.5980
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 5s 226ms/step - loss: 0.5833 - y_reg_z_loss: 0.2846 - y_up_loss: 0.5969 - val_loss: 0.5303 - val_y_reg_z_loss: 0.1588 - val_y_up_loss: 0.7378 - learning_rate: 0.0010
# Epoch 8/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 5s 213ms/step - loss: 0.4935 - y_reg_z_loss: 0.2352 - y_up_loss: 0.5159 - val_loss: 0.5515 - val_y_reg_z_loss: 0.2148 - val_y_up_loss: 0.7285 - learning_rate: 5.0000e-04
# Epoch 9/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - loss: 0.4280 - y_reg_z_loss: 0.1990 - y_up_loss: 0.4574 - val_loss: 0.4980 - val_y_reg_z_loss: 0.1566 - val_y_up_loss: 0.7166 - learning_rate: 5.0000e-04
# Epoch 10/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - loss: 0.3889 - y_reg_z_loss: 0.1825 - y_up_loss: 0.4123 - val_loss: 0.4837 - val_y_reg_z_loss: 0.1470 - val_y_up_loss: 0.7139 - learning_rate: 5.0000e-04
# Epoch 11/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 188ms/step - loss: 0.3554 - y_reg_z_loss: 0.1668 - y_up_loss: 0.3766 - val_loss: 0.4845 - val_y_reg_z_loss: 0.1369 - val_y_up_loss: 0.7137 - learning_rate: 5.0000e-04
# Epoch 12/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 5s 198ms/step - loss: 0.3328 - y_reg_z_loss: 0.1522 - y_up_loss: 0.3609 - val_loss: 0.5088 - val_y_reg_z_loss: 0.1717 - val_y_up_loss: 0.7617 - learning_rate: 5.0000e-04
# Epoch 13/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 6s 261ms/step - loss: 0.3088 - y_reg_z_loss: 0.1458 - y_up_loss: 0.3256 - val_loss: 0.5136 - val_y_reg_z_loss: 0.1644 - val_y_up_loss: 0.7753 - learning_rate: 5.0000e-04
# Epoch 14/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - loss: 0.3029 - y_reg_z_loss: 0.1443 - y_up_loss: 0.3167 - val_loss: 0.6068 - val_y_reg_z_loss: 0.2132 - val_y_up_loss: 0.9390 - learning_rate: 5.0000e-04
# Epoch 15/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.2936 - y_reg_z_loss: 0.1332 - y_up_loss: 0.3207
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - loss: 0.2937 - y_reg_z_loss: 0.1337 - y_up_loss: 0.3196 - val_loss: 0.5685 - val_y_reg_z_loss: 0.1812 - val_y_up_loss: 0.9221 - learning_rate: 5.0000e-04
# Epoch 16/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 6s 200ms/step - loss: 0.2692 - y_reg_z_loss: 0.1244 - y_up_loss: 0.2893 - val_loss: 0.5689 - val_y_reg_z_loss: 0.1846 - val_y_up_loss: 0.9525 - learning_rate: 2.5000e-04
# Epoch 17/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 141ms/step - loss: 0.2702 - y_reg_z_loss: 0.1285 - y_up_loss: 0.2831 - val_loss: 0.5363 - val_y_reg_z_loss: 0.1472 - val_y_up_loss: 0.8788 - learning_rate: 2.5000e-04
# Epoch 18/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 142ms/step - loss: 0.2490 - y_reg_z_loss: 0.1109 - y_up_loss: 0.2761 - val_loss: 0.5655 - val_y_reg_z_loss: 0.1591 - val_y_up_loss: 0.9470 - learning_rate: 2.5000e-04
# Epoch 19/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - loss: 0.2518 - y_reg_z_loss: 0.1165 - y_up_loss: 0.2704 - val_loss: 0.6080 - val_y_reg_z_loss: 0.1820 - val_y_up_loss: 1.0469 - learning_rate: 2.5000e-04
# Epoch 20/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 0.2347 - y_reg_z_loss: 0.1147 - y_up_loss: 0.2397
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.2353 - y_reg_z_loss: 0.1155 - y_up_loss: 0.2394 - val_loss: 0.5876 - val_y_reg_z_loss: 0.1548 - val_y_up_loss: 0.9991 - learning_rate: 2.5000e-04
# Epoch 21/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.2314 - y_reg_z_loss: 0.1142 - y_up_loss: 0.2343 - val_loss: 0.5970 - val_y_reg_z_loss: 0.1782 - val_y_up_loss: 1.0394 - learning_rate: 1.2500e-04
# Epoch 22/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.2312 - y_reg_z_loss: 0.1059 - y_up_loss: 0.2503 - val_loss: 0.5938 - val_y_reg_z_loss: 0.1691 - val_y_up_loss: 1.0446 - learning_rate: 1.2500e-04
#
# ===== Training Transformer (Improved) for VCB.VN | UpRatio=0.526 =====
# Epoch 1/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 29s 176ms/step - loss: 0.9533 - y_reg_z_loss: 0.5751 - y_up_loss: 0.7559 - val_loss: 0.6973 - val_y_reg_z_loss: 0.3054 - val_y_up_loss: 0.8395 - learning_rate: 0.0010
# Epoch 2/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - loss: 0.8112 - y_reg_z_loss: 0.4637 - y_up_loss: 0.6952 - val_loss: 0.6134 - val_y_reg_z_loss: 0.2067 - val_y_up_loss: 0.8240 - learning_rate: 0.0010
# Epoch 3/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.7821 - y_reg_z_loss: 0.4432 - y_up_loss: 0.6778 - val_loss: 0.5936 - val_y_reg_z_loss: 0.2081 - val_y_up_loss: 0.7847 - learning_rate: 0.0010
# Epoch 4/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - loss: 0.7369 - y_reg_z_loss: 0.4066 - y_up_loss: 0.6607 - val_loss: 0.6211 - val_y_reg_z_loss: 0.2383 - val_y_up_loss: 0.7912 - learning_rate: 0.0010
# Epoch 5/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.6797 - y_reg_z_loss: 0.3672 - y_up_loss: 0.6254 - val_loss: 0.7116 - val_y_reg_z_loss: 0.3495 - val_y_up_loss: 0.7295 - learning_rate: 0.0010
# Epoch 6/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.5670 - y_reg_z_loss: 0.3045 - y_up_loss: 0.5254 - val_loss: 0.3895 - val_y_reg_z_loss: 0.1148 - val_y_up_loss: 0.5425 - learning_rate: 0.0010
# Epoch 7/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.4765 - y_reg_z_loss: 0.2548 - y_up_loss: 0.4437 - val_loss: 0.4098 - val_y_reg_z_loss: 0.1715 - val_y_up_loss: 0.4710 - learning_rate: 0.0010
# Epoch 8/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.4366 - y_reg_z_loss: 0.2269 - y_up_loss: 0.4197 - val_loss: 0.4981 - val_y_reg_z_loss: 0.2123 - val_y_up_loss: 0.5686 - learning_rate: 0.0010
# Epoch 9/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - loss: 0.4153 - y_reg_z_loss: 0.2173 - y_up_loss: 0.3959 - val_loss: 0.5371 - val_y_reg_z_loss: 0.2430 - val_y_up_loss: 0.5774 - learning_rate: 0.0010
# Epoch 10/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - loss: 0.4032 - y_reg_z_loss: 0.2119 - y_up_loss: 0.3824 - val_loss: 0.4762 - val_y_reg_z_loss: 0.1866 - val_y_up_loss: 0.5761 - learning_rate: 0.0010
# Epoch 11/120
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.3822 - y_reg_z_loss: 0.2042 - y_up_loss: 0.3560
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.3811 - y_reg_z_loss: 0.2032 - y_up_loss: 0.3557 - val_loss: 0.4926 - val_y_reg_z_loss: 0.1801 - val_y_up_loss: 0.6206 - learning_rate: 0.0010
# Epoch 12/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.3468 - y_reg_z_loss: 0.1767 - y_up_loss: 0.3401 - val_loss: 0.4325 - val_y_reg_z_loss: 0.1482 - val_y_up_loss: 0.5689 - learning_rate: 5.0000e-04
# Epoch 13/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.3390 - y_reg_z_loss: 0.1759 - y_up_loss: 0.3261 - val_loss: 0.4234 - val_y_reg_z_loss: 0.1347 - val_y_up_loss: 0.5755 - learning_rate: 5.0000e-04
# Epoch 14/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.3273 - y_reg_z_loss: 0.1687 - y_up_loss: 0.3173 - val_loss: 0.4633 - val_y_reg_z_loss: 0.1499 - val_y_up_loss: 0.6223 - learning_rate: 5.0000e-04
# Epoch 15/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.3322 - y_reg_z_loss: 0.1817 - y_up_loss: 0.3010 - val_loss: 0.4802 - val_y_reg_z_loss: 0.1566 - val_y_up_loss: 0.6371 - learning_rate: 5.0000e-04
# Epoch 16/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.3055 - y_reg_z_loss: 0.1654 - y_up_loss: 0.2800
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.3046 - y_reg_z_loss: 0.1648 - y_up_loss: 0.2794 - val_loss: 0.4872 - val_y_reg_z_loss: 0.1486 - val_y_up_loss: 0.6648 - learning_rate: 5.0000e-04
# Epoch 17/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - loss: 0.3112 - y_reg_z_loss: 0.1769 - y_up_loss: 0.2685 - val_loss: 0.5542 - val_y_reg_z_loss: 0.2182 - val_y_up_loss: 0.6570 - learning_rate: 2.5000e-04
# Epoch 18/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.2727 - y_reg_z_loss: 0.1506 - y_up_loss: 0.2442 - val_loss: 0.5000 - val_y_reg_z_loss: 0.1586 - val_y_up_loss: 0.6738 - learning_rate: 2.5000e-04
#
# Done. Models trained for: ['BID.VN', 'CTG.VN', 'TCB.VN', 'VCB.VN']

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import (
    mean_squared_error, mean_absolute_error,
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, confusion_matrix
)

def safe_auc(y_true_bin, y_prob):
    if len(np.unique(y_true_bin)) < 2:
        return np.nan
    return roc_auc_score(y_true_bin, y_prob)

summary_rows = []

for tk in models.keys():
    X_train_seq, X_test_seq, y_train_seq, y_test_seq = splits[tk]
    model = models[tk]
    y_mu, y_sd = meta[tk]["y_mu"], meta[tk]["y_sd"]

    # ---- predict both heads ----
    y_reg_z_pred, y_up_prob = model.predict(X_test_seq, verbose=0)
    y_reg_z_pred = y_reg_z_pred.reshape(-1)
    y_up_prob    = y_up_prob.reshape(-1)

    # inverse transform regression
    y_pred = y_reg_z_pred * y_sd + y_mu

    # regression metrics
    mse  = mean_squared_error(y_test_seq, y_pred)
    rmse = np.sqrt(mse)
    mae  = mean_absolute_error(y_test_seq, y_pred)

    # direction metrics use y_up_prob with tuned threshold (use LAST 20% of train as val proxy)
    # We'll tune threshold on the *train tail* stored in the same run:
    # (simple approach: reuse your existing X_val,y_val by re-deriving from train)
    val_size = max(1, int(0.2 * len(X_train_seq)))
    X_val = X_train_seq[-val_size:]
    y_val = y_train_seq[-val_size:]
    y_val_true = (y_val > 0).astype(int)

    _, y_val_prob = model.predict(X_val, verbose=0)
    y_val_prob = y_val_prob.reshape(-1)

    best_t, best_f1 = tune_threshold(y_val_true, y_val_prob, lo=0.3, hi=0.7, n=81)

    y_true_bin = (y_test_seq > 0).astype(int)
    y_pred_bin = (y_up_prob > best_t).astype(int)

    directional_acc = accuracy_score(y_true_bin, y_pred_bin)
    precision = precision_score(y_true_bin, y_pred_bin, zero_division=0)
    recall    = recall_score(y_true_bin, y_pred_bin, zero_division=0)
    f1        = f1_score(y_true_bin, y_pred_bin, zero_division=0)
    auc       = safe_auc(y_true_bin, y_up_prob)

    cm = confusion_matrix(y_true_bin, y_pred_bin, labels=[0,1])
    tn, fp, fn, tp = cm.ravel()

    summary_rows.append({
        "Ticker": tk,
        "N_test_seq": len(y_test_seq),
        "RMSE": rmse,
        "MAE": mae,
        "MSE": mse,
        "Directional_Acc": directional_acc,
        "Precision_Up": precision,
        "Recall_Up": recall,
        "F1_Up": f1,
        "AUC": auc,
        "Best_Threshold": best_t,
        "Val_F1_at_bestT": best_f1,
        "TN": tn, "FP": fp, "FN": fn, "TP": tp
    })

summary_df = pd.DataFrame(summary_rows).sort_values("RMSE").reset_index(drop=True)
display_cols = ["Ticker","N_test_seq","RMSE","MAE","Directional_Acc","Precision_Up","Recall_Up","F1_Up","AUC","Best_Threshold","Val_F1_at_bestT","TN","FP","FN","TP"]
print(summary_df[display_cols].to_string(index=False))

import matplotlib.pyplot as plt
import numpy as np

def plot_actual_vs_pred_all(
    tickers,
    splits,
    models,
    meta,
    df,
    n_last=200,
    figsize=(16, 8)
):
    """
    Vẽ Actual vs Predicted return cho nhiều mã (multi-panel)
    tickers: list ticker, ví dụ ["VCB.VN","BID.VN","TCB.VN","CTG.VN"]
    """

    n = len(tickers)
    nrows = int(np.ceil(n / 2))
    ncols = 2

    fig, axes = plt.subplots(nrows, ncols, figsize=figsize, sharex=False)
    axes = axes.flatten()

    for i, tk in enumerate(tickers):
        ax = axes[i]

        X_train_seq, X_test_seq, y_train_seq, y_test_seq = splits[tk]
        model = models[tk]
        y_mu, y_sd = meta[tk]["y_mu"], meta[tk]["y_sd"]

        # Predict (regression head)
        y_reg_z_pred, _ = model.predict(X_test_seq, verbose=0)
        y_pred = y_reg_z_pred.reshape(-1) * y_sd + y_mu

        # Dates corresponding to test
        dft = df[df["ticker"] == tk].sort_values("date").reset_index(drop=True)
        test_dates = dft["date"].iloc[-len(y_test_seq):].values

        # Take last N points
        if n_last is not None:
            y_test_plot = y_test_seq[-n_last:]
            y_pred_plot = y_pred[-n_last:]
            date_plot   = test_dates[-n_last:]
        else:
            y_test_plot = y_test_seq
            y_pred_plot = y_pred
            date_plot   = test_dates

        ax.plot(date_plot, y_test_plot, label="Actual", linewidth=2)
        ax.plot(date_plot, y_pred_plot, label="Predicted", linewidth=2, alpha=0.85)
        ax.axhline(0, linestyle="--", linewidth=1, alpha=0.7)

        ax.set_title(
            f"{tk} | RMSE={np.sqrt(np.mean((y_test_plot - y_pred_plot)**2)):.4f}",
            fontsize=11
        )
        ax.grid(alpha=0.3)

        if i % 2 == 0:
            ax.set_ylabel("Return")

        if i >= (nrows - 1) * ncols:
            ax.set_xlabel("Date")

        ax.legend(fontsize=9)

    # Remove empty subplots if any
    for j in range(i + 1, len(axes)):
        fig.delaxes(axes[j])

    fig.suptitle(
        "Actual vs Transformer Predicted Return (Test Set)",
        fontsize=14,
        y=1.02
    )

    plt.tight_layout()
    plt.show()

print("📊 ACTUAL vs TRANSFORMER PREDICTED RETURN")
plot_actual_vs_pred_all(
    tickers=["VCB.VN", "BID.VN", "TCB.VN", "CTG.VN"],
    splits=splits,
    models=models,
    meta=meta,
    df=df,
    n_last=200
)
# Out:
# Ticker  N_test_seq     RMSE      MAE  Directional_Acc  Precision_Up  Recall_Up    F1_Up      AUC  Best_Threshold  Val_F1_at_bestT  TN  FP  FN  TP
# VCB.VN         202 0.003192 0.002571         0.683168      0.607143   0.621951 0.614458 0.738720            0.32         0.814815  87  33  31  51
# BID.VN         202 0.004795 0.003701         0.722772      0.680851   0.711111 0.695652 0.815179            0.34         0.786408  82  30  26  64
# TCB.VN         184 0.005812 0.004806         0.701087      0.803922   0.700855 0.748858 0.778288            0.32         0.757009  47  20  35  82
# CTG.VN         202 0.007645 0.006174         0.514851      0.818182   0.085714 0.155172 0.661757            0.30         0.662857  95   2  96   9
# 📊 ACTUAL vs TRANSFORMER PREDICTED RETURN

# %% [markdown]
# # Hybrid Transformer

# %%
import numpy as np
import pandas as pd
import pywt
import tensorflow as tf
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import (
    mean_squared_error, mean_absolute_error,
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, confusion_matrix
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# =========================
# 0) Reproducibility
# =========================
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)

# =========================
# 1) Wavelet features (safe level)
# =========================
def rolling_wavelet_features(x_window, wavelet="db4", level=3):
    x = np.asarray(x_window, dtype=np.float32)
    x = x[np.isfinite(x)]
    L = len(x)

    if L < 16 or np.allclose(x, 0):
        return {
            "wav_EA": 0.0,
            **{f"wav_ED{i}": 0.0 for i in range(1, level+1)},
            "wav_detail_ratio": 0.0,
            "wav_denoised_last": 0.0
        }

    x = x - np.mean(x)

    # SAFE LEVEL
    w = pywt.Wavelet(wavelet)
    max_lvl = pywt.dwt_max_level(data_len=L, filter_len=w.dec_len)
    lvl = int(min(level, max_lvl)) if max_lvl > 0 else 1

    coeffs = pywt.wavedec(x, wavelet=wavelet, level=lvl, mode="symmetric")
    cA = coeffs[0]
    cDs = coeffs[1:]

    EA = float(np.sum(cA**2))
    ED = [float(np.sum(cd**2)) for cd in cDs]
    total = EA + sum(ED) + 1e-12
    detail_ratio = float(sum(ED) / total)

    # denoise
    cD1 = cDs[-1] if len(cDs) else np.array([0.0], dtype=np.float32)
    cD1 = cD1[np.isfinite(cD1)]
    if len(cD1) == 0:
        sigma = 1e-12
    else:
        med = np.median(cD1)
        sigma = np.median(np.abs(cD1 - med)) / 0.6745 + 1e-12

    uthresh = sigma * np.sqrt(2*np.log(L + 1e-12))

    coeffs_dn = [cA]
    for cd in cDs:
        coeffs_dn.append(pywt.threshold(cd, value=uthresh, mode="soft"))

    x_dn = pywt.waverec(coeffs_dn, wavelet=wavelet, mode="symmetric")
    denoised_last = float(x_dn[-1]) if len(x_dn) > 0 and np.isfinite(x_dn[-1]) else 0.0

    out = {"wav_EA": EA if np.isfinite(EA) else 0.0}
    ED_reversed = list(reversed(ED))  # ED1..EDlvl
    for i in range(1, level+1):
        out[f"wav_ED{i}"] = float(ED_reversed[i-1]) if i-1 < len(ED_reversed) and np.isfinite(ED_reversed[i-1]) else 0.0

    out["wav_detail_ratio"] = detail_ratio if np.isfinite(detail_ratio) else 0.0
    out["wav_denoised_last"] = denoised_last
    return out

# =========================
# 2) FFT features (add log-energy stabilization)
# =========================
def rolling_fft_features(x_window, n_top=3):
    x = np.asarray(x_window, dtype=np.float32)
    x = x[np.isfinite(x)]
    L = len(x)

    if L < 16 or np.allclose(x, 0):
        return {"fft_energy": 0.0, "fft_low_ratio": 0.0, "fft_centroid": 0.0, "fft_topk_mag": 0.0}

    x = x - np.mean(x)

    X = np.fft.rfft(x)
    mag = (np.abs(X) + 1e-12).astype(np.float32)
    power = mag**2
    total_energy = float(np.sum(power) + 1e-12)

    n_bins = len(mag)
    low_end = max(2, int(0.10 * n_bins))
    low_energy = float(np.sum(power[1:low_end]) + 1e-12)
    low_ratio = float(low_energy / total_energy)

    sum_mag = float(np.sum(mag))
    if sum_mag <= 0:
        centroid = 0.0
    else:
        freqs = np.arange(n_bins, dtype=np.float32)
        centroid = float(np.sum(freqs * mag) / (sum_mag + 1e-12))

    mag_nodc = mag.copy()
    mag_nodc[0] = 0.0
    finite_mag = mag_nodc[np.isfinite(mag_nodc)]
    k = min(n_top, max(1, n_bins-1))
    if len(finite_mag) == 0:
        topk_mag = 0.0
    else:
        k = min(k, len(finite_mag))
        topk = np.partition(finite_mag, -k)[-k:]
        topk_mag = float(np.mean(topk)) if len(topk) else 0.0

    # log energy helps stabilize scale
    return {
        "fft_energy": float(np.log(total_energy)) if np.isfinite(total_energy) else 0.0,
        "fft_low_ratio": low_ratio if np.isfinite(low_ratio) else 0.0,
        "fft_centroid": centroid if np.isfinite(centroid) else 0.0,
        "fft_topk_mag": topk_mag if np.isfinite(topk_mag) else 0.0
    }

# =========================
# 3) Aux features: avoid zero-padding -> use shorter windows early
# =========================
def add_fft_wavelet_aux_features(df_one_ticker, ret_col="return", aux_window=64, wavelet="db4", level=3):
    d = df_one_ticker.sort_values("date").reset_index(drop=True).copy()
    r = d[ret_col].astype(np.float32)
    r_past = r.shift(1)

    aux_rows = []
    for i in range(len(d)):
        # use available past length (shorter window early) instead of all-zeros
        start = max(0, i-aux_window)
        win = r_past.iloc[start:i].values
        if len(win) < 16:
            # still too short -> neutral
            aux_rows.append({**rolling_fft_features(np.zeros(16)), **rolling_wavelet_features(np.zeros(16), wavelet, level)})
        else:
            aux_rows.append({**rolling_fft_features(win), **rolling_wavelet_features(win, wavelet, level)})

    aux_df = pd.DataFrame(aux_rows)
    return pd.concat([d, aux_df], axis=1)

# =========================
# 4) Sequence builder
# =========================
def create_sequences_with_aux(X_seq_features, X_aux_features, y, seq_len):
    Xs, Xa, ys = [], [], []
    for i in range(seq_len, len(y)):
        Xs.append(X_seq_features[i-seq_len:i])
        Xa.append(X_aux_features[i])
        ys.append(y[i])
    return np.array(Xs), np.array(Xa), np.array(ys)

# =========================
# 5) Transformer (Pre-LN) + last pooling
# =========================
class PositionalEncoding(tf.keras.layers.Layer):
    def __init__(self, position: int, d_model: int):
        super().__init__()
        pos = np.arange(position)[:, np.newaxis]
        i   = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        angle_rads  = pos * angle_rates
        angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
        angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.pos_encoding = tf.constant(angle_rads[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        return x + self.pos_encoding[:, :tf.shape(x)[1], :]

def transformer_encoder_preln(x, num_heads, key_dim, ff_dim, dropout=0.2, d_model=64):
    # Pre-LN
    x_norm = tf.keras.layers.LayerNormalization(epsilon=1e-6)(x)
    attn_out = tf.keras.layers.MultiHeadAttention(num_heads=num_heads, key_dim=key_dim, dropout=dropout)(x_norm, x_norm)
    attn_out = tf.keras.layers.Dropout(dropout)(attn_out)
    x = tf.keras.layers.Add()([x, attn_out])

    x_norm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)(x)
    ff = tf.keras.layers.Dense(ff_dim, activation="relu")(x_norm2)
    ff = tf.keras.layers.Dropout(dropout)(ff)
    ff = tf.keras.layers.Dense(d_model)(ff)
    x = tf.keras.layers.Add()([x, ff])
    return x

def build_hybrid_fft_wav_transformer(
    seq_input_shape,
    aux_input_dim,
    d_model=64,
    num_heads=4,
    ff_dim=128,
    num_blocks=3,
    dropout=0.2,
    use_conv_frontend=True,
    aux_mlp_units=(64, 32)
):
    seq_in = tf.keras.Input(shape=seq_input_shape, name="seq_in")
    aux_in = tf.keras.Input(shape=(aux_input_dim,), name="aux_in")

    # Transformer branch
    x = tf.keras.layers.Dense(d_model)(seq_in)
    if use_conv_frontend:
        x = tf.keras.layers.Conv1D(filters=d_model, kernel_size=3, padding="causal", activation="relu")(x)
        x = tf.keras.layers.Dropout(dropout)(x)

    x = PositionalEncoding(position=seq_input_shape[0], d_model=d_model)(x)

    key_dim = max(8, d_model // num_heads)
    for _ in range(num_blocks):
        x = transformer_encoder_preln(x, num_heads=num_heads, key_dim=key_dim, ff_dim=ff_dim, dropout=dropout, d_model=d_model)

    # last pooling instead of GAP
    x = tf.keras.layers.Lambda(lambda t: t[:, -1, :])(x)
    x = tf.keras.layers.Dropout(dropout)(x)

    # Aux branch
    a = tf.keras.layers.LayerNormalization()(aux_in)
    for u in aux_mlp_units:
        a = tf.keras.layers.Dense(u, activation="relu")(a)
        a = tf.keras.layers.Dropout(dropout)(a)

    # Fusion
    h = tf.keras.layers.Concatenate()([x, a])
    h = tf.keras.layers.Dense(64, activation="relu")(h)
    h = tf.keras.layers.Dropout(dropout)(h)

    y_reg_z = tf.keras.layers.Dense(1, name="y_reg_z")(h)
    y_up    = tf.keras.layers.Dense(1, activation="sigmoid", name="y_up")(h)

    return tf.keras.Model([seq_in, aux_in], [y_reg_z, y_up])

# =========================
# 6) Focal loss for direction (reduces FP explosions)
# =========================
def focal_bce(gamma=2.0, alpha=0.25):
    # y_true in {0,1}
    def loss(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1.0 - 1e-7)

        bce = -(y_true * tf.math.log(y_pred) + (1.0 - y_true) * tf.math.log(1.0 - y_pred))
        p_t = y_true * y_pred + (1.0 - y_true) * (1.0 - y_pred)
        alpha_t = y_true * alpha + (1.0 - y_true) * (1.0 - alpha)
        focal = alpha_t * tf.pow((1.0 - p_t), gamma) * bce
        return tf.reduce_mean(focal)
    return loss

# =========================
# 7) Threshold tuning: optimize DA or balanced acc
# =========================
def tune_threshold_metric(y_true_bin, y_prob, lo=0.1, hi=0.9, n=161, metric="da"):
    ths = np.linspace(lo, hi, n)
    best_t, best_score = 0.5, -1

    y_true_bin = np.asarray(y_true_bin).astype(int)
    y_prob = np.asarray(y_prob).astype(float)

    for t in ths:
        y_hat = (y_prob > t).astype(int)
        if metric == "da":
            score = accuracy_score(y_true_bin, y_hat)
        elif metric == "bal_acc":
            # balanced accuracy = (TPR + TNR)/2
            tn, fp, fn, tp = confusion_matrix(y_true_bin, y_hat, labels=[0,1]).ravel()
            tpr = tp / (tp + fn + 1e-12)
            tnr = tn / (tn + fp + 1e-12)
            score = 0.5 * (tpr + tnr)
        else:  # f1
            score = f1_score(y_true_bin, y_hat, zero_division=0)

        if score > best_score:
            best_score, best_t = score, t

    return float(best_t), float(best_score)

def safe_auc(y_true_bin, y_prob):
    if len(np.unique(y_true_bin)) < 2:
        return np.nan
    return roc_auc_score(y_true_bin, y_prob)

# =========================
# 8) TRAIN + EVALUATE per ticker (with deadzone + purge gap + better early stop)
# =========================
LOOKBACK   = 30
AUX_WINDOW = 64
WAVELET    = "db4"
WAV_LEVEL  = 3

# deadzone to reduce label noise
EPS_UP = 0.0003  # bạn có thể thử 0.0002 / 0.0005

# val purge gap (avoid bleed)
VAL_GAP = 5

df = df.copy()
df["date"] = pd.to_datetime(df["date"])

non_feature = ['date', 'ticker', 'target']
base_feature_cols = [c for c in df.columns if c not in non_feature]

models, scalers, splits, meta = {}, {}, {}, {}
summary_rows = []

for tk, dft in df.groupby("ticker"):
    dft = dft.sort_values("date").reset_index(drop=True)

    dft = add_fft_wavelet_aux_features(
        dft, ret_col="return",
        aux_window=AUX_WINDOW,
        wavelet=WAVELET, level=WAV_LEVEL
    )

    aux_cols = [c for c in dft.columns if c.startswith("fft_") or c.startswith("wav_")]
    if len(aux_cols) == 0:
        raise ValueError("No aux cols found. Check prefix names.")

    X_seq_raw = dft[base_feature_cols].values.astype(np.float32)
    X_aux_raw = dft[aux_cols].values.astype(np.float32)
    y_raw     = dft["target"].values.astype(np.float32)

    if len(dft) < (LOOKBACK + 80):
        print(f"⚠️ {tk}: dữ liệu quá ít ({len(dft)} dòng) -> bỏ qua")
        continue

    split_index = int(len(dft) * 0.8)
    X_seq_train_raw, X_seq_test_raw = X_seq_raw[:split_index], X_seq_raw[split_index:]
    X_aux_train_raw, X_aux_test_raw = X_aux_raw[:split_index], X_aux_raw[split_index:]
    y_train_raw, y_test_raw         = y_raw[:split_index], y_raw[split_index:]

    seq_scaler = RobustScaler()
    aux_scaler = RobustScaler()

    X_seq_train = seq_scaler.fit_transform(X_seq_train_raw)
    X_seq_test  = seq_scaler.transform(X_seq_test_raw)

    X_aux_train = aux_scaler.fit_transform(X_aux_train_raw)
    X_aux_test  = aux_scaler.transform(X_aux_test_raw)

    Xtr_seq, Xtr_aux, ytr = create_sequences_with_aux(X_seq_train, X_aux_train, y_train_raw, LOOKBACK)
    Xte_seq, Xte_aux, yte = create_sequences_with_aux(X_seq_test,  X_aux_test,  y_test_raw,  LOOKBACK)

    # validation tail from train WITH GAP
    val_size = max(10, int(0.2 * len(Xtr_seq)))
    cut = len(Xtr_seq) - val_size
    cut2 = max(1, cut - VAL_GAP)

    X_tr_seq, X_val_seq = Xtr_seq[:cut2], Xtr_seq[cut:]
    X_tr_aux, X_val_aux = Xtr_aux[:cut2], Xtr_aux[cut:]
    y_tr, y_val         = ytr[:cut2], ytr[cut:]

    # standardize regression target on train only
    y_mu = float(np.mean(y_tr))
    y_sd = float(np.std(y_tr) + 1e-8)
    y_tr_z  = ((y_tr  - y_mu) / y_sd).astype(np.float32)
    y_val_z = ((y_val - y_mu) / y_sd).astype(np.float32)

    # direction labels with deadzone
    y_tr_up  = (y_tr > EPS_UP).astype(np.float32)
    y_val_up = (y_val > EPS_UP).astype(np.float32)

    # build model
    model = build_hybrid_fft_wav_transformer(
        seq_input_shape=(LOOKBACK, Xtr_seq.shape[2]),
        aux_input_dim=Xtr_aux.shape[1],
        d_model=64, num_heads=4, ff_dim=128, num_blocks=3,
        dropout=0.2, use_conv_frontend=True,
        aux_mlp_units=(64, 32)
    )

    # direction loss: focal
    dir_loss = focal_bce(gamma=2.0, alpha=0.35)

    opt = Adam(learning_rate=8e-4, clipnorm=1.0)
    model.compile(
        optimizer=opt,
        loss={"y_reg_z": tf.keras.losses.Huber(delta=1.0), "y_up": dir_loss},
        loss_weights={"y_reg_z": 0.8, "y_up": 1.2},
        metrics={
            "y_up": [tf.keras.metrics.AUC(name="auc"), tf.keras.metrics.Precision(name="prec"), tf.keras.metrics.Recall(name="rec")]
        }
    )

    early_stop = EarlyStopping(
        monitor="val_y_up_auc", mode="max",
        patience=10, restore_best_weights=True
    )
    rlr = ReduceLROnPlateau(
        monitor="val_y_up_auc", mode="max",
        factor=0.5, patience=4, min_lr=1e-5, verbose=1
    )

    pos = float(y_tr_up.mean())
    print(f"\n===== Training HYBRID for {tk} | UpRatio={pos:.3f} | EPS_UP={EPS_UP} =====")

    model.fit(
        [X_tr_seq, X_tr_aux], {"y_reg_z": y_tr_z, "y_up": y_tr_up},
        validation_data=([X_val_seq, X_val_aux], {"y_reg_z": y_val_z, "y_up": y_val_up}),
        epochs=120, batch_size=32,
        callbacks=[early_stop, rlr],
        verbose=1
    )

    models[tk] = model
    scalers[tk] = {"seq": seq_scaler, "aux": aux_scaler}
    splits[tk] = (Xtr_seq, Xtr_aux, Xte_seq, Xte_aux, ytr, yte)
    meta[tk] = {"y_mu": y_mu, "y_sd": y_sd, "up_ratio": pos, "eps_up": EPS_UP}

    # ===== Evaluate =====
    y_reg_z_pred, y_up_prob = model.predict([Xte_seq, Xte_aux], verbose=0)
    y_reg_z_pred = y_reg_z_pred.reshape(-1)
    y_up_prob    = y_up_prob.reshape(-1)
    y_pred = y_reg_z_pred * y_sd + y_mu

    rmse = float(np.sqrt(mean_squared_error(yte, y_pred)))
    mae  = float(mean_absolute_error(yte, y_pred))

    # tune threshold on val (optimize DA or balanced acc, not just F1)
    _, y_val_prob = model.predict([X_val_seq, X_val_aux], verbose=0)
    y_val_prob = y_val_prob.reshape(-1)
    y_val_true = (y_val > EPS_UP).astype(int)

    best_t, best_score = tune_threshold_metric(y_val_true, y_val_prob, lo=0.1, hi=0.9, n=161, metric="bal_acc")

    y_true_bin = (yte > EPS_UP).astype(int)
    y_pred_bin = (y_up_prob > best_t).astype(int)

    directional_acc = float(accuracy_score(y_true_bin, y_pred_bin))
    precision = float(precision_score(y_true_bin, y_pred_bin, zero_division=0))
    recall    = float(recall_score(y_true_bin, y_pred_bin, zero_division=0))
    f1        = float(f1_score(y_true_bin, y_pred_bin, zero_division=0))
    auc       = float(safe_auc(y_true_bin, y_up_prob))

    tn, fp, fn, tp = confusion_matrix(y_true_bin, y_pred_bin, labels=[0,1]).ravel()

    summary_rows.append({
        "Ticker": tk,
        "N_test_seq": len(yte),
        "RMSE": rmse,
        "MAE": mae,
        "Directional_Acc": directional_acc,
        "Precision_Up": precision,
        "Recall_Up": recall,
        "F1_Up": f1,
        "AUC": auc,
        "Best_Threshold": float(best_t),
        "Val_balAcc_at_bestT": float(best_score),
        "TN": int(tn), "FP": int(fp), "FN": int(fn), "TP": int(tp)
    })

summary_df = pd.DataFrame(summary_rows).sort_values("Directional_Acc", ascending=False).reset_index(drop=True)
print(summary_df.to_string(index=False))
# Out:
# ===== Training HYBRID for BID.VN | UpRatio=0.492 | EPS_UP=0.0003 =====
# Epoch 1/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 24s 149ms/step - loss: 0.9010 - y_reg_z_loss: 0.8746 - y_up_auc: 0.5353 - y_up_loss: 0.1673 - y_up_prec: 0.4706 - y_up_rec: 0.3525 - val_loss: 0.2021 - val_y_reg_z_loss: 0.1560 - val_y_up_auc: 0.8114 - val_y_up_loss: 0.0714 - val_y_up_prec: 0.9444 - val_y_up_rec: 0.1753 - learning_rate: 8.0000e-04
# Epoch 2/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 0.4582 - y_reg_z_loss: 0.4119 - y_up_auc: 0.5890 - y_up_loss: 0.1073 - y_up_prec: 0.5317 - y_up_rec: 0.3717 - val_loss: 0.1774 - val_y_reg_z_loss: 0.1190 - val_y_up_auc: 0.8340 - val_y_up_loss: 0.0717 - val_y_up_prec: 1.0000 - val_y_up_rec: 0.1546 - learning_rate: 8.0000e-04
# Epoch 3/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 0.3260 - y_reg_z_loss: 0.2858 - y_up_auc: 0.7204 - y_up_loss: 0.0812 - y_up_prec: 0.6957 - y_up_rec: 0.4372 - val_loss: 0.1677 - val_y_reg_z_loss: 0.1194 - val_y_up_auc: 0.8562 - val_y_up_loss: 0.0654 - val_y_up_prec: 0.9643 - val_y_up_rec: 0.2784 - learning_rate: 8.0000e-04
# Epoch 4/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 0.3144 - y_reg_z_loss: 0.2840 - y_up_auc: 0.7674 - y_up_loss: 0.0731 - y_up_prec: 0.7132 - y_up_rec: 0.5648 - val_loss: 0.1707 - val_y_reg_z_loss: 0.1232 - val_y_up_auc: 0.8585 - val_y_up_loss: 0.0650 - val_y_up_prec: 0.9667 - val_y_up_rec: 0.2990 - learning_rate: 8.0000e-04
# Epoch 5/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.2785 - y_reg_z_loss: 0.2522 - y_up_auc: 0.8099 - y_up_loss: 0.0643 - y_up_prec: 0.7817 - y_up_rec: 0.5497 - val_loss: 0.1771 - val_y_reg_z_loss: 0.1308 - val_y_up_auc: 0.8588 - val_y_up_loss: 0.0656 - val_y_up_prec: 0.9583 - val_y_up_rec: 0.2371 - learning_rate: 8.0000e-04
# Epoch 6/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 0.2623 - y_reg_z_loss: 0.2314 - y_up_auc: 0.8051 - y_up_loss: 0.0651 - y_up_prec: 0.8482 - y_up_rec: 0.5493 - val_loss: 0.1794 - val_y_reg_z_loss: 0.1370 - val_y_up_auc: 0.8803 - val_y_up_loss: 0.0646 - val_y_up_prec: 0.9630 - val_y_up_rec: 0.2680 - learning_rate: 8.0000e-04
# Epoch 7/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.2546 - y_reg_z_loss: 0.2272 - y_up_auc: 0.8312 - y_up_loss: 0.0609 - y_up_prec: 0.8154 - y_up_rec: 0.5451 - val_loss: 0.1622 - val_y_reg_z_loss: 0.1246 - val_y_up_auc: 0.8821 - val_y_up_loss: 0.0574 - val_y_up_prec: 0.9792 - val_y_up_rec: 0.4845 - learning_rate: 8.0000e-04
# Epoch 8/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - loss: 0.2504 - y_reg_z_loss: 0.2282 - y_up_auc: 0.8545 - y_up_loss: 0.0569 - y_up_prec: 0.7992 - y_up_rec: 0.6477 - val_loss: 0.1768 - val_y_reg_z_loss: 0.1398 - val_y_up_auc: 0.8866 - val_y_up_loss: 0.0618 - val_y_up_prec: 0.9643 - val_y_up_rec: 0.2784 - learning_rate: 8.0000e-04
# Epoch 9/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 0.2699 - y_reg_z_loss: 0.2419 - y_up_auc: 0.8226 - y_up_loss: 0.0640 - y_up_prec: 0.7766 - y_up_rec: 0.6105 - val_loss: 0.1621 - val_y_reg_z_loss: 0.1238 - val_y_up_auc: 0.8753 - val_y_up_loss: 0.0576 - val_y_up_prec: 0.9362 - val_y_up_rec: 0.4536 - learning_rate: 8.0000e-04
# Epoch 10/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.2428 - y_reg_z_loss: 0.2150 - y_up_auc: 0.8481 - y_up_loss: 0.0595 - y_up_prec: 0.8125 - y_up_rec: 0.6605 - val_loss: 0.1663 - val_y_reg_z_loss: 0.1255 - val_y_up_auc: 0.8713 - val_y_up_loss: 0.0599 - val_y_up_prec: 0.9714 - val_y_up_rec: 0.3505 - learning_rate: 8.0000e-04
# Epoch 11/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 0.2393 - y_reg_z_loss: 0.2103 - y_up_auc: 0.8409 - y_up_loss: 0.0597 - y_up_prec: 0.8388 - y_up_rec: 0.6222 - val_loss: 0.1654 - val_y_reg_z_loss: 0.1244 - val_y_up_auc: 0.8764 - val_y_up_loss: 0.0595 - val_y_up_prec: 0.9744 - val_y_up_rec: 0.3918 - learning_rate: 8.0000e-04
# Epoch 12/120
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.2358 - y_reg_z_loss: 0.2123 - y_up_auc: 0.8586 - y_up_loss: 0.0550 - y_up_prec: 0.8124 - y_up_rec: 0.6677
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.00039999998989515007.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.2353 - y_reg_z_loss: 0.2120 - y_up_auc: 0.8591 - y_up_loss: 0.0550 - y_up_prec: 0.8148 - y_up_rec: 0.6662 - val_loss: 0.1519 - val_y_reg_z_loss: 0.1110 - val_y_up_auc: 0.8677 - val_y_up_loss: 0.0554 - val_y_up_prec: 0.8551 - val_y_up_rec: 0.6082 - learning_rate: 8.0000e-04
# Epoch 13/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.2371 - y_reg_z_loss: 0.2095 - y_up_auc: 0.8612 - y_up_loss: 0.0583 - y_up_prec: 0.8254 - y_up_rec: 0.6910 - val_loss: 0.1629 - val_y_reg_z_loss: 0.1215 - val_y_up_auc: 0.8770 - val_y_up_loss: 0.0599 - val_y_up_prec: 0.9714 - val_y_up_rec: 0.3505 - learning_rate: 4.0000e-04
# Epoch 14/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.2102 - y_reg_z_loss: 0.1893 - y_up_auc: 0.8880 - y_up_loss: 0.0494 - y_up_prec: 0.8963 - y_up_rec: 0.6674 - val_loss: 0.1743 - val_y_reg_z_loss: 0.1344 - val_y_up_auc: 0.8830 - val_y_up_loss: 0.0619 - val_y_up_prec: 0.9677 - val_y_up_rec: 0.3093 - learning_rate: 4.0000e-04
# Epoch 15/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - loss: 0.2195 - y_reg_z_loss: 0.1925 - y_up_auc: 0.8610 - y_up_loss: 0.0548 - y_up_prec: 0.8600 - y_up_rec: 0.6607 - val_loss: 0.1682 - val_y_reg_z_loss: 0.1286 - val_y_up_auc: 0.8791 - val_y_up_loss: 0.0598 - val_y_up_prec: 0.9697 - val_y_up_rec: 0.3299 - learning_rate: 4.0000e-04
# Epoch 16/120
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.2064 - y_reg_z_loss: 0.1825 - y_up_auc: 0.8965 - y_up_loss: 0.0504 - y_up_prec: 0.8854 - y_up_rec: 0.6809
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.00019999999494757503.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.2074 - y_reg_z_loss: 0.1835 - y_up_auc: 0.8955 - y_up_loss: 0.0505 - y_up_prec: 0.8835 - y_up_rec: 0.6805 - val_loss: 0.1719 - val_y_reg_z_loss: 0.1346 - val_y_up_auc: 0.8747 - val_y_up_loss: 0.0595 - val_y_up_prec: 0.9730 - val_y_up_rec: 0.3711 - learning_rate: 4.0000e-04
# Epoch 17/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.2137 - y_reg_z_loss: 0.1906 - y_up_auc: 0.8883 - y_up_loss: 0.0511 - y_up_prec: 0.8774 - y_up_rec: 0.6546 - val_loss: 0.1691 - val_y_reg_z_loss: 0.1315 - val_y_up_auc: 0.8782 - val_y_up_loss: 0.0587 - val_y_up_prec: 0.9744 - val_y_up_rec: 0.3918 - learning_rate: 2.0000e-04
# Epoch 18/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - loss: 0.2071 - y_reg_z_loss: 0.1825 - y_up_auc: 0.8826 - y_up_loss: 0.0511 - y_up_prec: 0.8701 - y_up_rec: 0.6719 - val_loss: 0.1732 - val_y_reg_z_loss: 0.1370 - val_y_up_auc: 0.8774 - val_y_up_loss: 0.0592 - val_y_up_prec: 0.9730 - val_y_up_rec: 0.3711 - learning_rate: 2.0000e-04
#
# ===== Training HYBRID for CTG.VN | UpRatio=0.502 | EPS_UP=0.0003 =====
# Epoch 1/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 23s 143ms/step - loss: 0.9174 - y_reg_z_loss: 0.8575 - y_up_auc: 0.5517 - y_up_loss: 0.1933 - y_up_prec: 0.5467 - y_up_rec: 0.3875 - val_loss: 0.2434 - val_y_reg_z_loss: 0.1795 - val_y_up_auc: 0.7228 - val_y_up_loss: 0.0946 - val_y_up_prec: 1.0000 - val_y_up_rec: 0.0481 - learning_rate: 8.0000e-04
# Epoch 2/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.4581 - y_reg_z_loss: 0.4314 - y_up_auc: 0.6624 - y_up_loss: 0.0944 - y_up_prec: 0.6382 - y_up_rec: 0.4468 - val_loss: 0.1818 - val_y_reg_z_loss: 0.1275 - val_y_up_auc: 0.7811 - val_y_up_loss: 0.0734 - val_y_up_prec: 1.0000 - val_y_up_rec: 0.1827 - learning_rate: 8.0000e-04
# Epoch 3/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.3583 - y_reg_z_loss: 0.3336 - y_up_auc: 0.7625 - y_up_loss: 0.0768 - y_up_prec: 0.7192 - y_up_rec: 0.5374 - val_loss: 0.2031 - val_y_reg_z_loss: 0.1586 - val_y_up_auc: 0.8150 - val_y_up_loss: 0.0757 - val_y_up_prec: 1.0000 - val_y_up_rec: 0.0769 - learning_rate: 8.0000e-04
# Epoch 4/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.3336 - y_reg_z_loss: 0.3130 - y_up_auc: 0.7704 - y_up_loss: 0.0698 - y_up_prec: 0.7417 - y_up_rec: 0.5045 - val_loss: 0.1791 - val_y_reg_z_loss: 0.1341 - val_y_up_auc: 0.8213 - val_y_up_loss: 0.0682 - val_y_up_prec: 0.9429 - val_y_up_rec: 0.3173 - learning_rate: 8.0000e-04
# Epoch 5/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.3130 - y_reg_z_loss: 0.2946 - y_up_auc: 0.8246 - y_up_loss: 0.0647 - y_up_prec: 0.8365 - y_up_rec: 0.5795 - val_loss: 0.1864 - val_y_reg_z_loss: 0.1465 - val_y_up_auc: 0.8428 - val_y_up_loss: 0.0679 - val_y_up_prec: 1.0000 - val_y_up_rec: 0.2981 - learning_rate: 8.0000e-04
# Epoch 6/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.2916 - y_reg_z_loss: 0.2734 - y_up_auc: 0.8253 - y_up_loss: 0.0608 - y_up_prec: 0.7902 - y_up_rec: 0.6078 - val_loss: 0.1951 - val_y_reg_z_loss: 0.1546 - val_y_up_auc: 0.8404 - val_y_up_loss: 0.0720 - val_y_up_prec: 1.0000 - val_y_up_rec: 0.2115 - learning_rate: 8.0000e-04
# Epoch 7/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.2965 - y_reg_z_loss: 0.2781 - y_up_auc: 0.8303 - y_up_loss: 0.0622 - y_up_prec: 0.8327 - y_up_rec: 0.6412 - val_loss: 0.1661 - val_y_reg_z_loss: 0.1258 - val_y_up_auc: 0.8549 - val_y_up_loss: 0.0637 - val_y_up_prec: 0.9545 - val_y_up_rec: 0.4038 - learning_rate: 8.0000e-04
# Epoch 8/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.2736 - y_reg_z_loss: 0.2569 - y_up_auc: 0.8637 - y_up_loss: 0.0572 - y_up_prec: 0.8753 - y_up_rec: 0.6195 - val_loss: 0.2186 - val_y_reg_z_loss: 0.1663 - val_y_up_auc: 0.8428 - val_y_up_loss: 0.0848 - val_y_up_prec: 1.0000 - val_y_up_rec: 0.1923 - learning_rate: 8.0000e-04
# Epoch 9/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - loss: 0.2634 - y_reg_z_loss: 0.2505 - y_up_auc: 0.8812 - y_up_loss: 0.0531 - y_up_prec: 0.8862 - y_up_rec: 0.6399 - val_loss: 0.2044 - val_y_reg_z_loss: 0.1599 - val_y_up_auc: 0.8521 - val_y_up_loss: 0.0766 - val_y_up_prec: 1.0000 - val_y_up_rec: 0.2500 - learning_rate: 8.0000e-04
# Epoch 10/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 0.2423 - y_reg_z_loss: 0.2237 - y_up_auc: 0.8787 - y_up_loss: 0.0530 - y_up_prec: 0.8710 - y_up_rec: 0.6805 - val_loss: 0.1876 - val_y_reg_z_loss: 0.1474 - val_y_up_auc: 0.8437 - val_y_up_loss: 0.0721 - val_y_up_prec: 0.9333 - val_y_up_rec: 0.2692 - learning_rate: 8.0000e-04
# Epoch 11/120
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.2625 - y_reg_z_loss: 0.2471 - y_up_auc: 0.8770 - y_up_loss: 0.0540 - y_up_prec: 0.8469 - y_up_rec: 0.7288
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.00039999998989515007.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - loss: 0.2624 - y_reg_z_loss: 0.2470 - y_up_auc: 0.8750 - y_up_loss: 0.0544 - y_up_prec: 0.8468 - y_up_rec: 0.7218 - val_loss: 0.1789 - val_y_reg_z_loss: 0.1447 - val_y_up_auc: 0.8490 - val_y_up_loss: 0.0648 - val_y_up_prec: 0.9375 - val_y_up_rec: 0.4327 - learning_rate: 8.0000e-04
# Epoch 12/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.2602 - y_reg_z_loss: 0.2427 - y_up_auc: 0.8731 - y_up_loss: 0.0552 - y_up_prec: 0.8259 - y_up_rec: 0.7598 - val_loss: 0.2097 - val_y_reg_z_loss: 0.1674 - val_y_up_auc: 0.8594 - val_y_up_loss: 0.0787 - val_y_up_prec: 0.9630 - val_y_up_rec: 0.2500 - learning_rate: 4.0000e-04
# Epoch 13/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.2399 - y_reg_z_loss: 0.2191 - y_up_auc: 0.8723 - y_up_loss: 0.0541 - y_up_prec: 0.8454 - y_up_rec: 0.6606 - val_loss: 0.2016 - val_y_reg_z_loss: 0.1573 - val_y_up_auc: 0.8626 - val_y_up_loss: 0.0769 - val_y_up_prec: 0.9706 - val_y_up_rec: 0.3173 - learning_rate: 4.0000e-04
# Epoch 14/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.2430 - y_reg_z_loss: 0.2272 - y_up_auc: 0.8884 - y_up_loss: 0.0513 - y_up_prec: 0.8688 - y_up_rec: 0.6755 - val_loss: 0.2167 - val_y_reg_z_loss: 0.1743 - val_y_up_auc: 0.8617 - val_y_up_loss: 0.0784 - val_y_up_prec: 0.9697 - val_y_up_rec: 0.3077 - learning_rate: 4.0000e-04
# Epoch 15/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 131ms/step - loss: 0.2268 - y_reg_z_loss: 0.2089 - y_up_auc: 0.8947 - y_up_loss: 0.0499 - y_up_prec: 0.8827 - y_up_rec: 0.7068 - val_loss: 0.2610 - val_y_reg_z_loss: 0.2111 - val_y_up_auc: 0.8590 - val_y_up_loss: 0.0909 - val_y_up_prec: 0.9615 - val_y_up_rec: 0.2404 - learning_rate: 4.0000e-04
# Epoch 16/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.2405 - y_reg_z_loss: 0.2213 - y_up_auc: 0.8833 - y_up_loss: 0.0531 - y_up_prec: 0.8641 - y_up_rec: 0.7213 - val_loss: 0.2088 - val_y_reg_z_loss: 0.1650 - val_y_up_auc: 0.8609 - val_y_up_loss: 0.0777 - val_y_up_prec: 0.9706 - val_y_up_rec: 0.3173 - learning_rate: 4.0000e-04
# Epoch 17/120
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.2347 - y_reg_z_loss: 0.2160 - y_up_auc: 0.8872 - y_up_loss: 0.0515 - y_up_prec: 0.8657 - y_up_rec: 0.7168
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.00019999999494757503.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.2341 - y_reg_z_loss: 0.2152 - y_up_auc: 0.8872 - y_up_loss: 0.0515 - y_up_prec: 0.8664 - y_up_rec: 0.7151 - val_loss: 0.2124 - val_y_reg_z_loss: 0.1639 - val_y_up_auc: 0.8588 - val_y_up_loss: 0.0811 - val_y_up_prec: 0.9706 - val_y_up_rec: 0.3173 - learning_rate: 4.0000e-04
# Epoch 18/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.2289 - y_reg_z_loss: 0.2127 - y_up_auc: 0.9010 - y_up_loss: 0.0492 - y_up_prec: 0.8696 - y_up_rec: 0.7400 - val_loss: 0.2305 - val_y_reg_z_loss: 0.1748 - val_y_up_auc: 0.8567 - val_y_up_loss: 0.0894 - val_y_up_prec: 0.9667 - val_y_up_rec: 0.2788 - learning_rate: 2.0000e-04
# Epoch 19/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - loss: 0.2219 - y_reg_z_loss: 0.2009 - y_up_auc: 0.8918 - y_up_loss: 0.0514 - y_up_prec: 0.8634 - y_up_rec: 0.7308 - val_loss: 0.2291 - val_y_reg_z_loss: 0.1735 - val_y_up_auc: 0.8538 - val_y_up_loss: 0.0886 - val_y_up_prec: 0.9688 - val_y_up_rec: 0.2981 - learning_rate: 2.0000e-04
# Epoch 20/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - loss: 0.2126 - y_reg_z_loss: 0.1941 - y_up_auc: 0.9036 - y_up_loss: 0.0481 - y_up_prec: 0.8821 - y_up_rec: 0.7112 - val_loss: 0.2248 - val_y_reg_z_loss: 0.1699 - val_y_up_auc: 0.8563 - val_y_up_loss: 0.0874 - val_y_up_prec: 0.9722 - val_y_up_rec: 0.3365 - learning_rate: 2.0000e-04
# Epoch 21/120
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.2213 - y_reg_z_loss: 0.2064 - y_up_auc: 0.9089 - y_up_loss: 0.0468 - y_up_prec: 0.8915 - y_up_rec: 0.7400
# Epoch 21: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - loss: 0.2198 - y_reg_z_loss: 0.2049 - y_up_auc: 0.9088 - y_up_loss: 0.0469 - y_up_prec: 0.8916 - y_up_rec: 0.7381 - val_loss: 0.2126 - val_y_reg_z_loss: 0.1594 - val_y_up_auc: 0.8551 - val_y_up_loss: 0.0838 - val_y_up_prec: 0.9744 - val_y_up_rec: 0.3654 - learning_rate: 2.0000e-04
# Epoch 22/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.2142 - y_reg_z_loss: 0.1939 - y_up_auc: 0.8968 - y_up_loss: 0.0496 - y_up_prec: 0.8558 - y_up_rec: 0.7288 - val_loss: 0.2228 - val_y_reg_z_loss: 0.1671 - val_y_up_auc: 0.8540 - val_y_up_loss: 0.0876 - val_y_up_prec: 0.9737 - val_y_up_rec: 0.3558 - learning_rate: 1.0000e-04
# Epoch 23/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.2033 - y_reg_z_loss: 0.1840 - y_up_auc: 0.9083 - y_up_loss: 0.0470 - y_up_prec: 0.8873 - y_up_rec: 0.7161 - val_loss: 0.2309 - val_y_reg_z_loss: 0.1739 - val_y_up_auc: 0.8547 - val_y_up_loss: 0.0908 - val_y_up_prec: 0.9722 - val_y_up_rec: 0.3365 - learning_rate: 1.0000e-04
#
# ===== Training HYBRID for TCB.VN | UpRatio=0.541 | EPS_UP=0.0003 =====
# Epoch 1/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 23s 148ms/step - loss: 0.8385 - y_reg_z_loss: 0.7647 - y_up_auc: 0.5166 - y_up_loss: 0.1887 - y_up_prec: 0.5789 - y_up_rec: 0.4999 - val_loss: 0.1849 - val_y_reg_z_loss: 0.1109 - val_y_up_auc: 0.6694 - val_y_up_loss: 0.0824 - val_y_up_prec: 0.6977 - val_y_up_rec: 0.3529 - learning_rate: 8.0000e-04
# Epoch 2/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.4807 - y_reg_z_loss: 0.4476 - y_up_auc: 0.6150 - y_up_loss: 0.1020 - y_up_prec: 0.6421 - y_up_rec: 0.4416 - val_loss: 0.1785 - val_y_reg_z_loss: 0.1082 - val_y_up_auc: 0.7282 - val_y_up_loss: 0.0765 - val_y_up_prec: 0.7561 - val_y_up_rec: 0.3647 - learning_rate: 8.0000e-04
# Epoch 3/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.3718 - y_reg_z_loss: 0.3381 - y_up_auc: 0.6890 - y_up_loss: 0.0843 - y_up_prec: 0.6811 - y_up_rec: 0.5868 - val_loss: 0.1590 - val_y_reg_z_loss: 0.0857 - val_y_up_auc: 0.7829 - val_y_up_loss: 0.0735 - val_y_up_prec: 0.9231 - val_y_up_rec: 0.1412 - learning_rate: 8.0000e-04
# Epoch 4/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.3246 - y_reg_z_loss: 0.2897 - y_up_auc: 0.7078 - y_up_loss: 0.0771 - y_up_prec: 0.6973 - y_up_rec: 0.5288 - val_loss: 0.1643 - val_y_reg_z_loss: 0.0985 - val_y_up_auc: 0.8132 - val_y_up_loss: 0.0709 - val_y_up_prec: 0.8649 - val_y_up_rec: 0.3765 - learning_rate: 8.0000e-04
# Epoch 5/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step - loss: 0.2763 - y_reg_z_loss: 0.2481 - y_up_auc: 0.8125 - y_up_loss: 0.0647 - y_up_prec: 0.7931 - y_up_rec: 0.6432 - val_loss: 0.1491 - val_y_reg_z_loss: 0.0797 - val_y_up_auc: 0.8207 - val_y_up_loss: 0.0662 - val_y_up_prec: 0.8621 - val_y_up_rec: 0.2941 - learning_rate: 8.0000e-04
# Epoch 6/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - loss: 0.2470 - y_reg_z_loss: 0.2116 - y_up_auc: 0.8138 - y_up_loss: 0.0647 - y_up_prec: 0.8258 - y_up_rec: 0.6136 - val_loss: 0.1551 - val_y_reg_z_loss: 0.0892 - val_y_up_auc: 0.8155 - val_y_up_loss: 0.0672 - val_y_up_prec: 0.7857 - val_y_up_rec: 0.3882 - learning_rate: 8.0000e-04
# Epoch 7/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.2484 - y_reg_z_loss: 0.2141 - y_up_auc: 0.8203 - y_up_loss: 0.0641 - y_up_prec: 0.7898 - y_up_rec: 0.6385 - val_loss: 0.1432 - val_y_reg_z_loss: 0.0770 - val_y_up_auc: 0.8301 - val_y_up_loss: 0.0620 - val_y_up_prec: 0.7869 - val_y_up_rec: 0.5647 - learning_rate: 8.0000e-04
# Epoch 8/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - loss: 0.2349 - y_reg_z_loss: 0.2064 - y_up_auc: 0.8521 - y_up_loss: 0.0580 - y_up_prec: 0.8160 - y_up_rec: 0.7226 - val_loss: 0.1525 - val_y_reg_z_loss: 0.0886 - val_y_up_auc: 0.8253 - val_y_up_loss: 0.0636 - val_y_up_prec: 0.7931 - val_y_up_rec: 0.5412 - learning_rate: 8.0000e-04
# Epoch 9/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.2284 - y_reg_z_loss: 0.1998 - y_up_auc: 0.8646 - y_up_loss: 0.0571 - y_up_prec: 0.8675 - y_up_rec: 0.7273 - val_loss: 0.1566 - val_y_reg_z_loss: 0.0898 - val_y_up_auc: 0.8293 - val_y_up_loss: 0.0616 - val_y_up_prec: 0.7755 - val_y_up_rec: 0.4471 - learning_rate: 8.0000e-04
# Epoch 10/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - loss: 0.2270 - y_reg_z_loss: 0.1963 - y_up_auc: 0.8600 - y_up_loss: 0.0583 - y_up_prec: 0.8477 - y_up_rec: 0.6977 - val_loss: 0.1449 - val_y_reg_z_loss: 0.0797 - val_y_up_auc: 0.8326 - val_y_up_loss: 0.0609 - val_y_up_prec: 0.7719 - val_y_up_rec: 0.5176 - learning_rate: 8.0000e-04
# Epoch 11/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - loss: 0.2347 - y_reg_z_loss: 0.2110 - y_up_auc: 0.8650 - y_up_loss: 0.0549 - y_up_prec: 0.8249 - y_up_rec: 0.6981 - val_loss: 0.1835 - val_y_reg_z_loss: 0.1135 - val_y_up_auc: 0.8310 - val_y_up_loss: 0.0687 - val_y_up_prec: 0.8400 - val_y_up_rec: 0.2471 - learning_rate: 8.0000e-04
# Epoch 12/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - loss: 0.2322 - y_reg_z_loss: 0.2020 - y_up_auc: 0.8534 - y_up_loss: 0.0586 - y_up_prec: 0.8335 - y_up_rec: 0.6799 - val_loss: 0.1685 - val_y_reg_z_loss: 0.1001 - val_y_up_auc: 0.8334 - val_y_up_loss: 0.0654 - val_y_up_prec: 0.7949 - val_y_up_rec: 0.3647 - learning_rate: 8.0000e-04
# Epoch 13/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.2233 - y_reg_z_loss: 0.1884 - y_up_auc: 0.8518 - y_up_loss: 0.0603 - y_up_prec: 0.8623 - y_up_rec: 0.6651 - val_loss: 0.1451 - val_y_reg_z_loss: 0.0797 - val_y_up_auc: 0.8374 - val_y_up_loss: 0.0614 - val_y_up_prec: 0.8269 - val_y_up_rec: 0.5059 - learning_rate: 8.0000e-04
# Epoch 14/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.2175 - y_reg_z_loss: 0.1887 - y_up_auc: 0.8771 - y_up_loss: 0.0555 - y_up_prec: 0.8486 - y_up_rec: 0.7091 - val_loss: 0.1388 - val_y_reg_z_loss: 0.0742 - val_y_up_auc: 0.8330 - val_y_up_loss: 0.0627 - val_y_up_prec: 0.7586 - val_y_up_rec: 0.7765 - learning_rate: 8.0000e-04
# Epoch 15/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - loss: 0.1974 - y_reg_z_loss: 0.1672 - y_up_auc: 0.8804 - y_up_loss: 0.0529 - y_up_prec: 0.8386 - y_up_rec: 0.7372 - val_loss: 0.1468 - val_y_reg_z_loss: 0.0831 - val_y_up_auc: 0.8350 - val_y_up_loss: 0.0613 - val_y_up_prec: 0.8182 - val_y_up_rec: 0.5294 - learning_rate: 8.0000e-04
# Epoch 16/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - loss: 0.1940 - y_reg_z_loss: 0.1598 - y_up_auc: 0.8863 - y_up_loss: 0.0550 - y_up_prec: 0.8712 - y_up_rec: 0.6826 - val_loss: 0.1465 - val_y_reg_z_loss: 0.0830 - val_y_up_auc: 0.8273 - val_y_up_loss: 0.0609 - val_y_up_prec: 0.7746 - val_y_up_rec: 0.6471 - learning_rate: 8.0000e-04
# Epoch 17/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.1796 - y_reg_z_loss: 0.1499 - y_up_auc: 0.8978 - y_up_loss: 0.0497 - y_up_prec: 0.8642 - y_up_rec: 0.7560
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.00039999998989515007.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - loss: 0.1799 - y_reg_z_loss: 0.1502 - y_up_auc: 0.8978 - y_up_loss: 0.0497 - y_up_prec: 0.8636 - y_up_rec: 0.7568 - val_loss: 0.1587 - val_y_reg_z_loss: 0.0930 - val_y_up_auc: 0.8244 - val_y_up_loss: 0.0650 - val_y_up_prec: 0.7895 - val_y_up_rec: 0.5294 - learning_rate: 8.0000e-04
# Epoch 18/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - loss: 0.1850 - y_reg_z_loss: 0.1559 - y_up_auc: 0.8970 - y_up_loss: 0.0502 - y_up_prec: 0.8636 - y_up_rec: 0.7496 - val_loss: 0.1478 - val_y_reg_z_loss: 0.0842 - val_y_up_auc: 0.8276 - val_y_up_loss: 0.0639 - val_y_up_prec: 0.7761 - val_y_up_rec: 0.6118 - learning_rate: 4.0000e-04
# Epoch 19/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - loss: 0.1831 - y_reg_z_loss: 0.1561 - y_up_auc: 0.9039 - y_up_loss: 0.0484 - y_up_prec: 0.8523 - y_up_rec: 0.7587 - val_loss: 0.1433 - val_y_reg_z_loss: 0.0801 - val_y_up_auc: 0.8279 - val_y_up_loss: 0.0661 - val_y_up_prec: 0.7674 - val_y_up_rec: 0.7765 - learning_rate: 4.0000e-04
# Epoch 20/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - loss: 0.1751 - y_reg_z_loss: 0.1448 - y_up_auc: 0.8975 - y_up_loss: 0.0492 - y_up_prec: 0.8451 - y_up_rec: 0.8229 - val_loss: 0.1414 - val_y_reg_z_loss: 0.0793 - val_y_up_auc: 0.8265 - val_y_up_loss: 0.0641 - val_y_up_prec: 0.7703 - val_y_up_rec: 0.6706 - learning_rate: 4.0000e-04
# Epoch 21/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.1815 - y_reg_z_loss: 0.1566 - y_up_auc: 0.9044 - y_up_loss: 0.0468 - y_up_prec: 0.8436 - y_up_rec: 0.7905
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.00019999999494757503.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step - loss: 0.1811 - y_reg_z_loss: 0.1562 - y_up_auc: 0.9047 - y_up_loss: 0.0467 - y_up_prec: 0.8445 - y_up_rec: 0.7903 - val_loss: 0.1563 - val_y_reg_z_loss: 0.0893 - val_y_up_auc: 0.8284 - val_y_up_loss: 0.0662 - val_y_up_prec: 0.7692 - val_y_up_rec: 0.5882 - learning_rate: 4.0000e-04
# Epoch 22/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.1719 - y_reg_z_loss: 0.1411 - y_up_auc: 0.9032 - y_up_loss: 0.0491 - y_up_prec: 0.8707 - y_up_rec: 0.7864 - val_loss: 0.1555 - val_y_reg_z_loss: 0.0890 - val_y_up_auc: 0.8227 - val_y_up_loss: 0.0669 - val_y_up_prec: 0.7887 - val_y_up_rec: 0.6588 - learning_rate: 2.0000e-04
# Epoch 23/120
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - loss: 0.1739 - y_reg_z_loss: 0.1430 - y_up_auc: 0.8970 - y_up_loss: 0.0495 - y_up_prec: 0.8333 - y_up_rec: 0.7804 - val_loss: 0.1506 - val_y_reg_z_loss: 0.0858 - val_y_up_auc: 0.8258 - val_y_up_loss: 0.0656 - val_y_up_prec: 0.7778 - val_y_up_rec: 0.6588 - learning_rate: 2.0000e-04
#
# ===== Training HYBRID for VCB.VN | UpRatio=0.492 | EPS_UP=0.0003 =====
# Epoch 1/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 30s 158ms/step - loss: 0.8395 - y_reg_z_loss: 0.6798 - y_up_auc: 0.5301 - y_up_loss: 0.2464 - y_up_prec: 0.5058 - y_up_rec: 0.4368 - val_loss: 0.2816 - val_y_reg_z_loss: 0.2099 - val_y_up_auc: 0.7456 - val_y_up_loss: 0.1034 - val_y_up_prec: 0.0000e+00 - val_y_up_rec: 0.0000e+00 - learning_rate: 8.0000e-04
# Epoch 2/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.4657 - y_reg_z_loss: 0.4278 - y_up_auc: 0.6496 - y_up_loss: 0.1027 - y_up_prec: 0.6256 - y_up_rec: 0.4352 - val_loss: 0.3159 - val_y_reg_z_loss: 0.2621 - val_y_up_auc: 0.8002 - val_y_up_loss: 0.1026 - val_y_up_prec: 1.0000 - val_y_up_rec: 0.0225 - learning_rate: 8.0000e-04
# Epoch 3/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.3559 - y_reg_z_loss: 0.3161 - y_up_auc: 0.7001 - y_up_loss: 0.0858 - y_up_prec: 0.6661 - y_up_rec: 0.4988 - val_loss: 0.2329 - val_y_reg_z_loss: 0.1978 - val_y_up_auc: 0.7993 - val_y_up_loss: 0.0706 - val_y_up_prec: 0.7692 - val_y_up_rec: 0.1124 - learning_rate: 8.0000e-04
# Epoch 4/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.3246 - y_reg_z_loss: 0.2900 - y_up_auc: 0.7447 - y_up_loss: 0.0770 - y_up_prec: 0.7030 - y_up_rec: 0.4807 - val_loss: 0.2146 - val_y_reg_z_loss: 0.1730 - val_y_up_auc: 0.8122 - val_y_up_loss: 0.0709 - val_y_up_prec: 0.8333 - val_y_up_rec: 0.1685 - learning_rate: 8.0000e-04
# Epoch 5/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.3027 - y_reg_z_loss: 0.2816 - y_up_auc: 0.8195 - y_up_loss: 0.0644 - y_up_prec: 0.7697 - y_up_rec: 0.6050 - val_loss: 0.1767 - val_y_reg_z_loss: 0.1260 - val_y_up_auc: 0.8328 - val_y_up_loss: 0.0672 - val_y_up_prec: 0.8824 - val_y_up_rec: 0.3371 - learning_rate: 8.0000e-04
# Epoch 6/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - loss: 0.2876 - y_reg_z_loss: 0.2625 - y_up_auc: 0.8256 - y_up_loss: 0.0646 - y_up_prec: 0.7513 - y_up_rec: 0.6159 - val_loss: 0.2046 - val_y_reg_z_loss: 0.1604 - val_y_up_auc: 0.8460 - val_y_up_loss: 0.0666 - val_y_up_prec: 0.9000 - val_y_up_rec: 0.4045 - learning_rate: 8.0000e-04
# Epoch 7/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 129ms/step - loss: 0.2672 - y_reg_z_loss: 0.2415 - y_up_auc: 0.8555 - y_up_loss: 0.0614 - y_up_prec: 0.7855 - y_up_rec: 0.6779 - val_loss: 0.1983 - val_y_reg_z_loss: 0.1419 - val_y_up_auc: 0.8466 - val_y_up_loss: 0.0752 - val_y_up_prec: 0.9545 - val_y_up_rec: 0.2360 - learning_rate: 8.0000e-04
# Epoch 8/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - loss: 0.2568 - y_reg_z_loss: 0.2307 - y_up_auc: 0.8507 - y_up_loss: 0.0603 - y_up_prec: 0.7979 - y_up_rec: 0.5575 - val_loss: 0.1891 - val_y_reg_z_loss: 0.1457 - val_y_up_auc: 0.8355 - val_y_up_loss: 0.0640 - val_y_up_prec: 0.8542 - val_y_up_rec: 0.4607 - learning_rate: 8.0000e-04
# Epoch 9/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - loss: 0.2548 - y_reg_z_loss: 0.2366 - y_up_auc: 0.8745 - y_up_loss: 0.0544 - y_up_prec: 0.8713 - y_up_rec: 0.6596 - val_loss: 0.1842 - val_y_reg_z_loss: 0.1370 - val_y_up_auc: 0.8483 - val_y_up_loss: 0.0649 - val_y_up_prec: 0.8913 - val_y_up_rec: 0.4607 - learning_rate: 8.0000e-04
# Epoch 10/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.2452 - y_reg_z_loss: 0.2189 - y_up_auc: 0.8509 - y_up_loss: 0.0584 - y_up_prec: 0.7990 - y_up_rec: 0.5684 - val_loss: 0.1814 - val_y_reg_z_loss: 0.1297 - val_y_up_auc: 0.8505 - val_y_up_loss: 0.0665 - val_y_up_prec: 0.8500 - val_y_up_rec: 0.5730 - learning_rate: 8.0000e-04
# Epoch 11/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.2179 - y_reg_z_loss: 0.1956 - y_up_auc: 0.9006 - y_up_loss: 0.0511 - y_up_prec: 0.9016 - y_up_rec: 0.7292 - val_loss: 0.1838 - val_y_reg_z_loss: 0.1352 - val_y_up_auc: 0.8521 - val_y_up_loss: 0.0670 - val_y_up_prec: 0.8750 - val_y_up_rec: 0.3933 - learning_rate: 8.0000e-04
# Epoch 12/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.2443 - y_reg_z_loss: 0.2227 - y_up_auc: 0.8885 - y_up_loss: 0.0550 - y_up_prec: 0.8829 - y_up_rec: 0.6840 - val_loss: 0.1985 - val_y_reg_z_loss: 0.1423 - val_y_up_auc: 0.8522 - val_y_up_loss: 0.0731 - val_y_up_prec: 0.9167 - val_y_up_rec: 0.3708 - learning_rate: 8.0000e-04
# Epoch 13/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - loss: 0.2190 - y_reg_z_loss: 0.1967 - y_up_auc: 0.8907 - y_up_loss: 0.0512 - y_up_prec: 0.8658 - y_up_rec: 0.6789 - val_loss: 0.2054 - val_y_reg_z_loss: 0.1624 - val_y_up_auc: 0.8386 - val_y_up_loss: 0.0681 - val_y_up_prec: 0.9459 - val_y_up_rec: 0.3933 - learning_rate: 8.0000e-04
# Epoch 14/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - loss: 0.2232 - y_reg_z_loss: 0.2001 - y_up_auc: 0.8900 - y_up_loss: 0.0524 - y_up_prec: 0.8765 - y_up_rec: 0.6634 - val_loss: 0.1742 - val_y_reg_z_loss: 0.1314 - val_y_up_auc: 0.8402 - val_y_up_loss: 0.0622 - val_y_up_prec: 0.8333 - val_y_up_rec: 0.5056 - learning_rate: 8.0000e-04
# Epoch 15/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.2311 - y_reg_z_loss: 0.2099 - y_up_auc: 0.8868 - y_up_loss: 0.0525 - y_up_prec: 0.8225 - y_up_rec: 0.7454 - val_loss: 0.1933 - val_y_reg_z_loss: 0.1412 - val_y_up_auc: 0.8448 - val_y_up_loss: 0.0707 - val_y_up_prec: 0.8367 - val_y_up_rec: 0.4607 - learning_rate: 8.0000e-04
# Epoch 16/120
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.2248 - y_reg_z_loss: 0.2042 - y_up_auc: 0.9015 - y_up_loss: 0.0512 - y_up_prec: 0.8522 - y_up_rec: 0.7129
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.00039999998989515007.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.2249 - y_reg_z_loss: 0.2040 - y_up_auc: 0.9004 - y_up_loss: 0.0514 - y_up_prec: 0.8511 - y_up_rec: 0.7126 - val_loss: 0.1704 - val_y_reg_z_loss: 0.1238 - val_y_up_auc: 0.8417 - val_y_up_loss: 0.0624 - val_y_up_prec: 0.8246 - val_y_up_rec: 0.5281 - learning_rate: 8.0000e-04
# Epoch 17/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.2172 - y_reg_z_loss: 0.1976 - y_up_auc: 0.9001 - y_up_loss: 0.0492 - y_up_prec: 0.8514 - y_up_rec: 0.6995 - val_loss: 0.1690 - val_y_reg_z_loss: 0.1192 - val_y_up_auc: 0.8471 - val_y_up_loss: 0.0626 - val_y_up_prec: 0.8358 - val_y_up_rec: 0.6292 - learning_rate: 4.0000e-04
# Epoch 18/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.2038 - y_reg_z_loss: 0.1872 - y_up_auc: 0.9137 - y_up_loss: 0.0450 - y_up_prec: 0.8351 - y_up_rec: 0.7295 - val_loss: 0.1667 - val_y_reg_z_loss: 0.1161 - val_y_up_auc: 0.8412 - val_y_up_loss: 0.0619 - val_y_up_prec: 0.8194 - val_y_up_rec: 0.6629 - learning_rate: 4.0000e-04
# Epoch 19/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 0.2161 - y_reg_z_loss: 0.1943 - y_up_auc: 0.9118 - y_up_loss: 0.0504 - y_up_prec: 0.8448 - y_up_rec: 0.7687 - val_loss: 0.1650 - val_y_reg_z_loss: 0.1117 - val_y_up_auc: 0.8453 - val_y_up_loss: 0.0625 - val_y_up_prec: 0.8108 - val_y_up_rec: 0.6742 - learning_rate: 4.0000e-04
# Epoch 20/120
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.2072 - y_reg_z_loss: 0.1858 - y_up_auc: 0.9109 - y_up_loss: 0.0488 - y_up_prec: 0.8563 - y_up_rec: 0.7825
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.00019999999494757503.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.2072 - y_reg_z_loss: 0.1856 - y_up_auc: 0.9105 - y_up_loss: 0.0487 - y_up_prec: 0.8572 - y_up_rec: 0.7792 - val_loss: 0.1719 - val_y_reg_z_loss: 0.1205 - val_y_up_auc: 0.8419 - val_y_up_loss: 0.0636 - val_y_up_prec: 0.8143 - val_y_up_rec: 0.6404 - learning_rate: 4.0000e-04
# Epoch 21/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.1982 - y_reg_z_loss: 0.1768 - y_up_auc: 0.9142 - y_up_loss: 0.0471 - y_up_prec: 0.8448 - y_up_rec: 0.7921 - val_loss: 0.1779 - val_y_reg_z_loss: 0.1254 - val_y_up_auc: 0.8436 - val_y_up_loss: 0.0654 - val_y_up_prec: 0.8116 - val_y_up_rec: 0.6292 - learning_rate: 2.0000e-04
# Epoch 22/120
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 0.2040 - y_reg_z_loss: 0.1789 - y_up_auc: 0.9097 - y_up_loss: 0.0504 - y_up_prec: 0.8395 - y_up_rec: 0.8244 - val_loss: 0.1804 - val_y_reg_z_loss: 0.1263 - val_y_up_auc: 0.8431 - val_y_up_loss: 0.0665 - val_y_up_prec: 0.8333 - val_y_up_rec: 0.6180 - learning_rate: 2.0000e-04
# Ticker  N_test_seq     RMSE      MAE  Directional_Acc  Precision_Up  Recall_Up    F1_Up      AUC  Best_Threshold  Val_balAcc_at_bestT  TN  FP  FN  TP
# VCB.VN         202 0.003104 0.002273         0.772277      0.738462   0.623377 0.676056 0.832312            0.33             0.787578 108  17  29  48
# TCB.VN         184 0.005541 0.004337         0.733696      0.750000   0.849558 0.796680 0.828244            0.43             0.791544  39  32  17  96
# BID.VN         202 0.004359 0.003423         0.722772      0.728571   0.579545 0.645570 0.787978            0.41             0.799346  95  19  37  51
# CTG.VN         202 0.005899 0.004775         0.698020      0.797297   0.561905 0.659218 0.814728            0.35             0.802756  82  15  46  59

# %%
# store predictions for later use (global)
pred_store = {}

# ✅ ưu tiên đúng 4 mã bạn dùng trong báo cáo
preferred = ["VCB.VN", "BID.VN", "CTG.VN", "TCB.VN"]

# lấy những mã thực sự tồn tại trong splits
tickers = [t for t in preferred if t in splits]

# nếu thiếu (ví dụ bạn train ít mã), bổ sung bằng các mã còn lại trong splits
if len(tickers) < 4:
    for t in splits.keys():
        if t not in tickers:
            tickers.append(t)
        if len(tickers) == 4:
            break

# nếu vẫn <4 thì vẽ theo số lượng thực tế
n = len(tickers)
if n == 0:
    raise ValueError("splits is empty. Bạn cần train xong và có dữ liệu trong splits trước khi plot.")

rows = 2
cols = 2
fig, axes = plt.subplots(rows, cols, figsize=(16, 8))
axes = axes.flatten()

for i in range(rows * cols):
    ax = axes[i]
    if i >= n:
        ax.axis("off")
        continue

    tk = tickers[i]
    (Xtr_seq, Xtr_aux, Xte_seq, Xte_aux, ytr, yte) = splits[tk]
    model = models[tk]
    y_mu  = meta[tk]["y_mu"]
    y_sd  = meta[tk]["y_sd"]

    # predict
    y_reg_z_pred, y_up_prob = model.predict([Xte_seq, Xte_aux], verbose=0)
    y_reg_z_pred = y_reg_z_pred.reshape(-1)
    y_up_prob    = y_up_prob.reshape(-1)

    # denormalize
    y_pred = y_reg_z_pred * y_sd + y_mu

    # save
    pred_store[tk] = {"y_true": yte, "y_pred": y_pred, "y_up_prob": y_up_prob}

    # plot
    ax.plot(yte, label="Actual Return", linewidth=1.4)
    ax.plot(y_pred, label="Predicted Return (Hybrid)", linewidth=1.4)
    ax.set_title(f"{tk} | Actual vs Hybrid Predicted Return")
    ax.set_xlabel("Test Time Index")
    ax.set_ylabel("Return")
    ax.grid(True, alpha=0.3)
    ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Old Ver

# %% [markdown]
# ## ver 1

# %%
# # =========================
# # HYBRID: FFT + Wavelet + Transformer (Multi-input, multitask)
# # =========================

# import numpy as np
# import pandas as pd
# import pywt
# import tensorflow as tf
# from sklearn.preprocessing import RobustScaler
# from sklearn.metrics import (
#     mean_squared_error, mean_absolute_error,
#     accuracy_score, precision_score, recall_score, f1_score,
#     roc_auc_score, confusion_matrix
# )
# from tensorflow.keras.optimizers import Adam
# from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# # -------------------------
# # 1) Wavelet features (from your snippet)
# # -------------------------
# def rolling_wavelet_features(x_window, wavelet="db4", level=3):
#     """
#     DWT trên cửa sổ returns:
#       - năng lượng approx (A) và detail (D1..Dlevel)
#       - tỷ lệ năng lượng detail/total
#       - denoised_last: giá trị denoised ở điểm cuối (proxy)
#     """
#     x = np.asarray(x_window, dtype=np.float32)
#     x = x[np.isfinite(x)] # Remove NaNs from window

#     L = len(x)
#     if L < 16 or np.allclose(x, 0): # Ensure sufficient data after NaN removal
#         return {
#             "wav_EA": 0.0,
#             **{f"wav_ED{i}": 0.0 for i in range(1, level+1)},
#             "wav_detail_ratio": 0.0,
#             "wav_denoised_last": 0.0
#         }

#     x = x - np.mean(x) # Demean after NaN removal

#     coeffs = pywt.wavedec(x, wavelet=wavelet, level=level, mode="symmetric")
#     cA = coeffs[0]
#     cDs = coeffs[1:]  # [cD_level, ..., cD1]

#     EA = float(np.sum(cA**2))
#     ED = [float(np.sum(cd**2)) for cd in cDs]
#     total = EA + sum(ED) + 1e-12
#     detail_ratio = float(sum(ED) / total)

#     # denoise: soft-threshold detail coeffs (universal threshold)
#     cD1 = cDs[-1]
#     # Check for NaN in cD1 before median calculation
#     if np.all(np.isnan(cD1)) or len(cD1) == 0:
#         sigma = 1e-12
#     else:
#         sigma = np.median(np.abs(cD1 - np.median(cD1[np.isfinite(cD1)]))) / 0.6745 + 1e-12 # Calculate median only on finite values

#     uthresh = sigma * np.sqrt(2*np.log(L))

#     coeffs_dn = [cA]
#     for cd in cDs:
#         coeffs_dn.append(pywt.threshold(cd, value=uthresh, mode="soft"))

#     x_dn = pywt.waverec(coeffs_dn, wavelet=wavelet, mode="symmetric")
#     denoised_last = float(x_dn[-1]) if len(x_dn) > 0 and np.isfinite(x_dn[-1]) else 0.0 # Check for finite

#     out = {"wav_EA": EA if np.isfinite(EA) else 0.0}
#     ED_reversed = list(reversed(ED))
#     for i in range(1, level+1):
#         out[f"wav_ED{i}"] = ED_reversed[i-1] if np.isfinite(ED_reversed[i-1]) else 0.0 # Check for finite
#     out["wav_detail_ratio"] = detail_ratio if np.isfinite(detail_ratio) else 0.0
#     out["wav_denoised_last"] = denoised_last
#     return out

# # -------------------------
# # 2) FFT features
# # -------------------------
# def rolling_fft_features(x_window, n_top=3):
#     """
#     FFT trên cửa sổ returns (demean):
#       - spectral_energy: tổng năng lượng phổ
#       - low_band_ratio: tỷ lệ năng lượng tần số thấp (proxy trend/slow cycles)
#       - spectral_centroid: trọng tâm phổ
#       - topk_mag_mean: trung bình biên độ top-k tần số trội (bỏ DC)
#     """
#     x = np.asarray(x_window, dtype=np.float32)
#     x = x[np.isfinite(x)] # Remove NaNs from window

#     L = len(x)
#     if L < 16 or np.allclose(x, 0): # Ensure sufficient data after NaN removal
#         return {
#             "fft_energy": 0.0,
#             "fft_low_ratio": 0.0,
#             "fft_centroid": 0.0,
#             "fft_topk_mag": 0.0
#         }

#     x = x - np.mean(x) # Demean after NaN removal

#     # rfft -> non-negative frequencies
#     X = np.fft.rfft(x)
#     mag = np.abs(X).astype(np.float32)
#     # zero out DC component for top-k
#     mag_nodc = mag.copy()
#     if len(mag_nodc) > 0:
#         mag_nodc[0] = 0.0

#     power = mag**2
#     total_energy = float(np.sum(power) + 1e-12)

#     # define "low band": first ~10% bins (excluding DC) as proxy
#     n_bins = len(mag)
#     low_end = max(2, int(0.10 * n_bins))
#     low_energy = float(np.sum(power[1:low_end]) + 1e-12)
#     low_ratio = float(low_energy / total_energy)

#     # spectral centroid (frequency-weighted magnitude)
#     # Check for zero sum of mag to avoid division by zero
#     sum_mag = np.sum(mag)
#     if sum_mag == 0:
#         centroid = 0.0
#     else:
#         freqs = np.arange(n_bins, dtype=np.float32)
#         centroid = float(np.sum(freqs * mag) / (sum_mag + 1e-12))

#     # top-k magnitude mean
#     k = min(n_top, max(1, n_bins-1))

#     # Filter out NaNs from mag_nodc before partitioning/mean
#     finite_mag_nodc = mag_nodc[np.isfinite(mag_nodc)]

#     if len(finite_mag_nodc) == 0:
#         topk_mag = 0.0
#     else:
#         k_actual = min(k, len(finite_mag_nodc))
#         topk = np.partition(finite_mag_nodc, -k_actual)[-k_actual:]
#         topk_mag = float(np.mean(topk)) if len(topk) else 0.0

#     return {
#         "fft_energy": total_energy if np.isfinite(total_energy) else 0.0,
#         "fft_low_ratio": low_ratio if np.isfinite(low_ratio) else 0.0,
#         "fft_centroid": centroid if np.isfinite(centroid) else 0.0,
#         "fft_topk_mag": topk_mag if np.isfinite(topk_mag) else 0.0
#     }

# # -------------------------
# # 3) Build rolling FFT+Wavelet aux features (past-only)
# # -------------------------
# def add_fft_wavelet_aux_features(df_one_ticker, ret_col="return", aux_window=64, wavelet="db4", level=3):
#     """
#     Tạo aux features tại thời điểm t bằng cửa sổ returns quá khứ [t-aux_window .. t-1].
#     -> tránh leakage: dùng shift(1).
#     """
#     d = df_one_ticker.sort_values("date").reset_index(drop=True).copy()
#     r = d[ret_col].astype(np.float32)

#     # past-only series for rolling window
#     r_past = r.shift(1)

#     aux_rows = []
#     for i in range(len(d)):
#         if i < aux_window:
#             aux_rows.append({**rolling_fft_features(np.zeros(aux_window)), **rolling_wavelet_features(np.zeros(aux_window), wavelet, level)})
#         else:
#             win = r_past.iloc[i-aux_window:i].values
#             aux_rows.append({**rolling_fft_features(win), **rolling_wavelet_features(win, wavelet, level)})

#     aux_df = pd.DataFrame(aux_rows)
#     return pd.concat([d, aux_df], axis=1)

# # -------------------------
# # 4) Sequence builder: X_seq + X_aux align
# # -------------------------
# def create_sequences_with_aux(X_seq_features, X_aux_features, y, seq_len):
#     """
#     X_seq_features: (T, n_seq_feat)
#     X_aux_features: (T, n_aux_feat) -- aux at time t
#     y: (T,)
#     Create samples at index i where input sequence is [i-seq_len..i-1], target is y[i], aux is aux[i]
#     """
#     Xs, Xa, ys = [], [], []
#     for i in range(seq_len, len(y)):
#         Xs.append(X_seq_features[i-seq_len:i])
#         Xa.append(X_aux_features[i])
#         ys.append(y[i])
#     return np.array(Xs), np.array(Xa), np.array(ys)

# # -------------------------
# # 5) Transformer blocks (as yours)
# # -------------------------
# class PositionalEncoding(tf.keras.layers.Layer):
#     def __init__(self, position: int, d_model: int):
#         super().__init__()
#         pos = np.arange(position)[:, np.newaxis]
#         i   = np.arange(d_model)[np.newaxis, :]
#         angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
#         angle_rads  = pos * angle_rates
#         angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
#         angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
#         self.pos_encoding = tf.constant(angle_rads[np.newaxis, ...], dtype=tf.float32)

#     def call(self, x):
#         return x + self.pos_encoding[:, :tf.shape(x)[1], :]

# def transformer_encoder(x, num_heads, key_dim, ff_dim, dropout=0.2):
#     attn_out = tf.keras.layers.MultiHeadAttention(num_heads=num_heads, key_dim=key_dim, dropout=dropout)(x, x)
#     attn_out = tf.keras.layers.Dropout(dropout)(attn_out)
#     x = tf.keras.layers.Add()([x, attn_out])
#     x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(x)

#     ff = tf.keras.layers.Dense(ff_dim, activation="relu")(x)
#     ff = tf.keras.layers.Dropout(dropout)(ff)
#     ff = tf.keras.layers.Dense(x.shape[-1])(ff)
#     x = tf.keras.layers.Add()([x, ff])
#     x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(x)
#     return x

# # -------------------------
# # 6) Hybrid model: Transformer(seq) + MLP(aux FFT/Wavelet) -> concat -> multitask heads
# # -------------------------
# def build_hybrid_fft_wav_transformer(
#     seq_input_shape,     # (LOOKBACK, n_seq_feat)
#     aux_input_dim,       # n_aux_feat
#     d_model=64,
#     num_heads=4,
#     ff_dim=128,
#     num_blocks=3,
#     dropout=0.2,
#     use_conv_frontend=True,
#     aux_mlp_units=(64, 32)
# ):
#     seq_in = tf.keras.Input(shape=seq_input_shape, name="seq_in")
#     aux_in = tf.keras.Input(shape=(aux_input_dim,), name="aux_in")

#     # --- Transformer branch ---
#     x = tf.keras.layers.Dense(d_model)(seq_in)
#     if use_conv_frontend:
#         x = tf.keras.layers.Conv1D(filters=d_model, kernel_size=3, padding="causal", activation="relu")(x)
#         x = tf.keras.layers.Dropout(dropout)(x)

#     x = PositionalEncoding(position=seq_input_shape[0], d_model=d_model)(x)

#     key_dim = max(8, d_model // num_heads)
#     for _ in range(num_blocks):
#         x = transformer_encoder(x, num_heads=num_heads, key_dim=key_dim, ff_dim=ff_dim, dropout=dropout)

#     x = tf.keras.layers.GlobalAveragePooling1D()(x)
#     x = tf.keras.layers.Dropout(dropout)(x)

#     # --- Aux branch (FFT+Wavelet) ---
#     a = aux_in
#     a = tf.keras.layers.LayerNormalization()(a)
#     for u in aux_mlp_units:
#         a = tf.keras.layers.Dense(u, activation="relu")(a)
#         a = tf.keras.layers.Dropout(dropout)(a)

#     # --- Fusion ---
#     h = tf.keras.layers.Concatenate()([x, a])
#     h = tf.keras.layers.Dense(64, activation="relu")(h)
#     h = tf.keras.layers.Dropout(dropout)(h)

#     # Head 1: regression (standardized)
#     y_reg_z = tf.keras.layers.Dense(1, name="y_reg_z")(h)
#     # Head 2: direction
#     y_up = tf.keras.layers.Dense(1, activation="sigmoid", name="y_up")(h)

#     return tf.keras.Model([seq_in, aux_in], [y_reg_z, y_up])

# # -------------------------
# # 7) Weighted BCE + threshold tuning (reuse)
# # -------------------------
# def make_weighted_bce(w_pos, w_neg):
#     def weighted_bce(y_true, y_pred):
#         bce = tf.keras.backend.binary_crossentropy(y_true, y_pred)
#         w = y_true * w_pos + (1.0 - y_true) * w_neg
#         return tf.reduce_mean(bce * w)
#     return weighted_bce

# from sklearn.metrics import f1_score

# def tune_threshold(y_true_bin, y_prob, lo=0.2, hi=0.8, n=121):
#     ths = np.linspace(lo, hi, n)
#     best_t, best_f1 = 0.5, -1
#     for t in ths:
#         f1 = f1_score(y_true_bin, (y_prob > t).astype(int), zero_division=0)
#         if f1 > best_f1:
#             best_f1, best_t = f1, t
#     return best_t, best_f1

# def safe_auc(y_true_bin, y_prob):
#     if len(np.unique(y_true_bin)) < 2:
#         return np.nan
#     return roc_auc_score(y_true_bin, y_prob)

# # =========================
# # 8) TRAIN + EVALUATE per ticker
# # =========================
# LOOKBACK = 30
# AUX_WINDOW = 64          # cửa sổ FFT/Wavelet (thường 64/96/128)
# WAVELET = "db4"
# WAV_LEVEL = 3

# # df: your final features table must already exist, same as your pipeline:
# # required columns: ["date","ticker","target"] + your feature columns including "return"
# df = df.copy()
# df["date"] = pd.to_datetime(df["date"])

# non_feature = ['date', 'ticker', 'target']
# base_feature_cols = [c for c in df.columns if c not in non_feature]  # includes return + TA features

# models, scalers, splits, meta = {}, {}, {}, {}

# summary_rows = []

# for tk, dft in df.groupby("ticker"):
#     dft = dft.sort_values("date").reset_index(drop=True)

#     # add aux FFT+Wavelet features (past-only)
#     dft = add_fft_wavelet_aux_features(
#         dft, ret_col="return",
#         aux_window=AUX_WINDOW,
#         wavelet=WAVELET, level=WAV_LEVEL
#     )

#     aux_cols = [c for c in dft.columns if c.startswith("fft_") or c.startswith("wav_")]
#     if len(aux_cols) == 0:
#         raise ValueError("No aux cols found. Check prefix names.")

#     # build matrices
#     X_seq_raw = dft[base_feature_cols].values.astype(np.float32)
#     X_aux_raw = dft[aux_cols].values.astype(np.float32)
#     y_raw     = dft["target"].values.astype(np.float32)

#     if len(dft) < (LOOKBACK + 80):
#         print(f"⚠️ {tk}: dữ liệu quá ít ({len(dft)} dòng) -> bỏ qua")
#         continue

#     split_index = int(len(dft) * 0.8)
#     X_seq_train_raw, X_seq_test_raw = X_seq_raw[:split_index], X_seq_raw[split_index:]
#     X_aux_train_raw, X_aux_test_raw = X_aux_raw[:split_index], X_aux_raw[split_index:]
#     y_train_raw, y_test_raw         = y_raw[:split_index], y_raw[split_index:]

#     # scale seq + aux separately (robust scaling is good for finance)
#     seq_scaler = RobustScaler()
#     aux_scaler = RobustScaler()

#     X_seq_train = seq_scaler.fit_transform(X_seq_train_raw)
#     X_seq_test  = seq_scaler.transform(X_seq_test_raw)

#     X_aux_train = aux_scaler.fit_transform(X_aux_train_raw)
#     X_aux_test  = aux_scaler.transform(X_aux_test_raw)

#     # create aligned sequences
#     Xtr_seq, Xtr_aux, ytr = create_sequences_with_aux(X_seq_train, X_aux_train, y_train_raw, LOOKBACK)
#     Xte_seq, Xte_aux, yte = create_sequences_with_aux(X_seq_test,  X_aux_test,  y_test_raw,  LOOKBACK)

#     # validation tail from train
#     val_size = max(1, int(0.2 * len(Xtr_seq)))
#     X_tr_seq, X_val_seq = Xtr_seq[:-val_size], Xtr_seq[-val_size:]
#     X_tr_aux, X_val_aux = Xtr_aux[:-val_size], Xtr_aux[-val_size:]
#     y_tr, y_val         = ytr[:-val_size], ytr[-val_size:]

#     # standardize regression target on train only
#     y_mu = float(np.mean(y_tr))
#     y_sd = float(np.std(y_tr) + 1e-8)
#     y_tr_z  = ((y_tr  - y_mu) / y_sd).astype(np.float32)
#     y_val_z = ((y_val - y_mu) / y_sd).astype(np.float32)

#     # direction labels
#     y_tr_up  = (y_tr > 0).astype(np.float32)
#     y_val_up = (y_val > 0).astype(np.float32)

#     # weighted BCE
#     pos = float(y_tr_up.mean())
#     w_pos = 0.5 / (pos + 1e-8)
#     w_neg = 0.5 / (1.0 - pos + 1e-8)
#     w_bce = make_weighted_bce(w_pos=w_pos, w_neg=w_neg)

#     # build hybrid model
#     model = build_hybrid_fft_wav_transformer(
#         seq_input_shape=(LOOKBACK, Xtr_seq.shape[2]),
#         aux_input_dim=Xtr_aux.shape[1],
#         d_model=64, num_heads=4, ff_dim=128, num_blocks=3,
#         dropout=0.2, use_conv_frontend=True,
#         aux_mlp_units=(64, 32)
#     )

#     opt = Adam(learning_rate=1e-3, clipnorm=1.0)
#     model.compile(
#         optimizer=opt,
#         loss={"y_reg_z": tf.keras.losses.Huber(delta=1.0), "y_up": w_bce},
#         loss_weights={"y_reg_z": 1.0, "y_up": 0.5}
#     )

#     early_stop = EarlyStopping(monitor="val_loss", patience=12, restore_best_weights=True)
#     rlr = ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=5, min_lr=1e-5, verbose=1)

#     print(f"\n===== Training HYBRID FFT+WAV+Transformer for {tk} | UpRatio={pos:.3f} =====")
#     model.fit(
#         [X_tr_seq, X_tr_aux], {"y_reg_z": y_tr_z, "y_up": y_tr_up},
#         validation_data=([X_val_seq, X_val_aux], {"y_reg_z": y_val_z, "y_up": y_val_up}),
#         epochs=120, batch_size=32,
#         callbacks=[early_stop, rlr],
#         verbose=1
#     )

#     # store
#     models[tk] = model
#     scalers[tk] = {"seq": seq_scaler, "aux": aux_scaler}
#     splits[tk] = (Xtr_seq, Xtr_aux, Xte_seq, Xte_aux, ytr, yte)
#     meta[tk] = {"y_mu": y_mu, "y_sd": y_sd, "up_ratio": pos, "w_pos": w_pos, "w_neg": w_neg}

#     # =========================
#     # Evaluate
#     # =========================
#     y_reg_z_pred, y_up_prob = model.predict([Xte_seq, Xte_aux], verbose=0)
#     y_reg_z_pred = y_reg_z_pred.reshape(-1)
#     y_up_prob    = y_up_prob.reshape(-1)

#     y_pred = y_reg_z_pred * y_sd + y_mu

#     rmse = float(np.sqrt(mean_squared_error(yte, y_pred)))
#     mae  = float(mean_absolute_error(yte, y_pred))

#     # tune threshold on train tail (val proxy)
#     _, y_val_prob = model.predict([X_val_seq, X_val_aux], verbose=0)
#     y_val_prob = y_val_prob.reshape(-1)
#     y_val_true = (y_val > 0).astype(int)

#     best_t, best_f1 = tune_threshold(y_val_true, y_val_prob, lo=0.2, hi=0.8, n=121)

#     y_true_bin = (yte > 0).astype(int)
#     y_pred_bin = (y_up_prob > best_t).astype(int)

#     directional_acc = float(accuracy_score(y_true_bin, y_pred_bin))
#     precision = float(precision_score(y_true_bin, y_pred_bin, zero_division=0))
#     recall    = float(recall_score(y_true_bin, y_pred_bin, zero_division=0))
#     f1        = float(f1_score(y_true_bin, y_pred_bin, zero_division=0))
#     auc       = float(safe_auc(y_true_bin, y_up_prob))

#     tn, fp, fn, tp = confusion_matrix(y_true_bin, y_pred_bin, labels=[0,1]).ravel()

#     summary_rows.append({
#         "Ticker": tk,
#         "N_test_seq": len(yte),
#         "RMSE": rmse,
#         "MAE": mae,
#         "Directional_Acc": directional_acc,
#         "Precision_Up": precision,
#         "Recall_Up": recall,
#         "F1_Up": f1,
#         "AUC": auc,
#         "Best_Threshold": float(best_t),
#         "Val_F1_at_bestT": float(best_f1),
#         "TN": int(tn), "FP": int(fp), "FN": int(fn), "TP": int(tp)
#     })

# summary_df = pd.DataFrame(summary_rows).sort_values("RMSE").reset_index(drop=True)
# print(summary_df.to_string(index=False))

# print("📊 ACTUAL vs HYBRID TRANSFORMER PREDICTED RETURN (4 STOCKS)")

# import matplotlib.pyplot as plt

# # store predictions for later use (global)
# pred_store = {}

# # ✅ ưu tiên đúng 4 mã bạn dùng trong báo cáo
# preferred = ["VCB.VN", "BID.VN", "CTG.VN", "TCB.VN"]

# # lấy những mã thực sự tồn tại trong splits
# tickers = [t for t in preferred if t in splits]

# # nếu thiếu (ví dụ bạn train ít mã), bổ sung bằng các mã còn lại trong splits
# if len(tickers) < 4:
#     for t in splits.keys():
#         if t not in tickers:
#             tickers.append(t)
#         if len(tickers) == 4:
#             break

# # nếu vẫn <4 thì vẽ theo số lượng thực tế
# n = len(tickers)
# if n == 0:
#     raise ValueError("splits is empty. Bạn cần train xong và có dữ liệu trong splits trước khi plot.")

# rows = 2
# cols = 2
# fig, axes = plt.subplots(rows, cols, figsize=(16, 8))
# axes = axes.flatten()

# for i in range(rows * cols):
#     ax = axes[i]
#     if i >= n:
#         ax.axis("off")
#         continue

#     tk = tickers[i]
#     (Xtr_seq, Xtr_aux, Xte_seq, Xte_aux, ytr, yte) = splits[tk]
#     model = models[tk]
#     y_mu  = meta[tk]["y_mu"]
#     y_sd  = meta[tk]["y_sd"]

#     # predict
#     y_reg_z_pred, y_up_prob = model.predict([Xte_seq, Xte_aux], verbose=0)
#     y_reg_z_pred = y_reg_z_pred.reshape(-1)
#     y_up_prob    = y_up_prob.reshape(-1)

#     # denormalize
#     y_pred = y_reg_z_pred * y_sd + y_mu

#     # save
#     pred_store[tk] = {"y_true": yte, "y_pred": y_pred, "y_up_prob": y_up_prob}

#     # plot
#     ax.plot(yte, label="Actual Return", linewidth=1.4)
#     ax.plot(y_pred, label="Predicted Return (Hybrid)", linewidth=1.4)
#     ax.set_title(f"{tk} | Actual vs Hybrid Predicted Return")
#     ax.set_xlabel("Test Time Index")
#     ax.set_ylabel("Return")
#     ax.grid(True, alpha=0.3)
#     ax.legend()

# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## ver 2

# %%
# import numpy as np
# import pandas as pd
# import pywt
# import tensorflow as tf
# from sklearn.preprocessing import RobustScaler
# from sklearn.metrics import (
#     mean_squared_error, mean_absolute_error,
#     accuracy_score, precision_score, recall_score, f1_score,
#     roc_auc_score, confusion_matrix
# )
# from tensorflow.keras.optimizers import Adam
# from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# # =========================
# # 0) Reproducibility
# # =========================
# SEED = 42
# np.random.seed(SEED)
# tf.random.set_seed(SEED)

# # =========================
# # 1) Wavelet features (safe level)
# # =========================
# def rolling_wavelet_features(x_window, wavelet="db4", level=3):
#     x = np.asarray(x_window, dtype=np.float32)
#     x = x[np.isfinite(x)]
#     L = len(x)

#     if L < 16 or np.allclose(x, 0):
#         return {
#             "wav_EA": 0.0,
#             **{f"wav_ED{i}": 0.0 for i in range(1, level+1)},
#             "wav_detail_ratio": 0.0,
#             "wav_denoised_last": 0.0
#         }

#     x = x - np.mean(x)

#     # SAFE LEVEL
#     w = pywt.Wavelet(wavelet)
#     max_lvl = pywt.dwt_max_level(data_len=L, filter_len=w.dec_len)
#     lvl = int(min(level, max_lvl)) if max_lvl > 0 else 1

#     coeffs = pywt.wavedec(x, wavelet=wavelet, level=lvl, mode="symmetric")
#     cA = coeffs[0]
#     cDs = coeffs[1:]

#     EA = float(np.sum(cA**2))
#     ED = [float(np.sum(cd**2)) for cd in cDs]
#     total = EA + sum(ED) + 1e-12
#     detail_ratio = float(sum(ED) / total)

#     # denoise
#     cD1 = cDs[-1] if len(cDs) else np.array([0.0], dtype=np.float32)
#     cD1 = cD1[np.isfinite(cD1)]
#     if len(cD1) == 0:
#         sigma = 1e-12
#     else:
#         med = np.median(cD1)
#         sigma = np.median(np.abs(cD1 - med)) / 0.6745 + 1e-12

#     uthresh = sigma * np.sqrt(2*np.log(L + 1e-12))

#     coeffs_dn = [cA]
#     for cd in cDs:
#         coeffs_dn.append(pywt.threshold(cd, value=uthresh, mode="soft"))

#     x_dn = pywt.waverec(coeffs_dn, wavelet=wavelet, mode="symmetric")
#     denoised_last = float(x_dn[-1]) if len(x_dn) > 0 and np.isfinite(x_dn[-1]) else 0.0

#     out = {"wav_EA": EA if np.isfinite(EA) else 0.0}
#     ED_reversed = list(reversed(ED))  # ED1..EDlvl
#     for i in range(1, level+1):
#         out[f"wav_ED{i}"] = float(ED_reversed[i-1]) if i-1 < len(ED_reversed) and np.isfinite(ED_reversed[i-1]) else 0.0

#     out["wav_detail_ratio"] = detail_ratio if np.isfinite(detail_ratio) else 0.0
#     out["wav_denoised_last"] = denoised_last
#     return out

# # =========================
# # 2) FFT features (add log-energy stabilization)
# # =========================
# def rolling_fft_features(x_window, n_top=3):
#     x = np.asarray(x_window, dtype=np.float32)
#     x = x[np.isfinite(x)]
#     L = len(x)

#     if L < 16 or np.allclose(x, 0):
#         return {"fft_energy": 0.0, "fft_low_ratio": 0.0, "fft_centroid": 0.0, "fft_topk_mag": 0.0}

#     x = x - np.mean(x)

#     X = np.fft.rfft(x)
#     mag = (np.abs(X) + 1e-12).astype(np.float32)
#     power = mag**2
#     total_energy = float(np.sum(power) + 1e-12)

#     n_bins = len(mag)
#     low_end = max(2, int(0.10 * n_bins))
#     low_energy = float(np.sum(power[1:low_end]) + 1e-12)
#     low_ratio = float(low_energy / total_energy)

#     sum_mag = float(np.sum(mag))
#     if sum_mag <= 0:
#         centroid = 0.0
#     else:
#         freqs = np.arange(n_bins, dtype=np.float32)
#         centroid = float(np.sum(freqs * mag) / (sum_mag + 1e-12))

#     mag_nodc = mag.copy()
#     mag_nodc[0] = 0.0
#     finite_mag = mag_nodc[np.isfinite(mag_nodc)]
#     k = min(n_top, max(1, n_bins-1))
#     if len(finite_mag) == 0:
#         topk_mag = 0.0
#     else:
#         k = min(k, len(finite_mag))
#         topk = np.partition(finite_mag, -k)[-k:]
#         topk_mag = float(np.mean(topk)) if len(topk) else 0.0

#     # log energy helps stabilize scale
#     return {
#         "fft_energy": float(np.log(total_energy)) if np.isfinite(total_energy) else 0.0,
#         "fft_low_ratio": low_ratio if np.isfinite(low_ratio) else 0.0,
#         "fft_centroid": centroid if np.isfinite(centroid) else 0.0,
#         "fft_topk_mag": topk_mag if np.isfinite(topk_mag) else 0.0
#     }

# # =========================
# # 3) Aux features: avoid zero-padding -> use shorter windows early
# # =========================
# def add_fft_wavelet_aux_features(df_one_ticker, ret_col="return", aux_window=64, wavelet="db4", level=3):
#     d = df_one_ticker.sort_values("date").reset_index(drop=True).copy()
#     r = d[ret_col].astype(np.float32)
#     r_past = r.shift(1)

#     aux_rows = []
#     for i in range(len(d)):
#         # use available past length (shorter window early) instead of all-zeros
#         start = max(0, i-aux_window)
#         win = r_past.iloc[start:i].values
#         if len(win) < 16:
#             # still too short -> neutral
#             aux_rows.append({**rolling_fft_features(np.zeros(16)), **rolling_wavelet_features(np.zeros(16), wavelet, level)})
#         else:
#             aux_rows.append({**rolling_fft_features(win), **rolling_wavelet_features(win, wavelet, level)})

#     aux_df = pd.DataFrame(aux_rows)
#     return pd.concat([d, aux_df], axis=1)

# # =========================
# # 4) Sequence builder
# # =========================
# def create_sequences_with_aux(X_seq_features, X_aux_features, y, seq_len):
#     Xs, Xa, ys = [], [], []
#     for i in range(seq_len, len(y)):
#         Xs.append(X_seq_features[i-seq_len:i])
#         Xa.append(X_aux_features[i])
#         ys.append(y[i])
#     return np.array(Xs), np.array(Xa), np.array(ys)

# # =========================
# # 5) Transformer (Pre-LN) + last pooling
# # =========================
# class PositionalEncoding(tf.keras.layers.Layer):
#     def __init__(self, position: int, d_model: int):
#         super().__init__()
#         pos = np.arange(position)[:, np.newaxis]
#         i   = np.arange(d_model)[np.newaxis, :]
#         angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
#         angle_rads  = pos * angle_rates
#         angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
#         angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
#         self.pos_encoding = tf.constant(angle_rads[np.newaxis, ...], dtype=tf.float32)

#     def call(self, x):
#         return x + self.pos_encoding[:, :tf.shape(x)[1], :]

# def transformer_encoder_preln(x, num_heads, key_dim, ff_dim, dropout=0.2, d_model=64):
#     # Pre-LN
#     x_norm = tf.keras.layers.LayerNormalization(epsilon=1e-6)(x)
#     attn_out = tf.keras.layers.MultiHeadAttention(num_heads=num_heads, key_dim=key_dim, dropout=dropout)(x_norm, x_norm)
#     attn_out = tf.keras.layers.Dropout(dropout)(attn_out)
#     x = tf.keras.layers.Add()([x, attn_out])

#     x_norm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)(x)
#     ff = tf.keras.layers.Dense(ff_dim, activation="relu")(x_norm2)
#     ff = tf.keras.layers.Dropout(dropout)(ff)
#     ff = tf.keras.layers.Dense(d_model)(ff)
#     x = tf.keras.layers.Add()([x, ff])
#     return x

# def build_hybrid_fft_wav_transformer(
#     seq_input_shape,
#     aux_input_dim,
#     d_model=64,
#     num_heads=4,
#     ff_dim=128,
#     num_blocks=3,
#     dropout=0.2,
#     use_conv_frontend=True,
#     aux_mlp_units=(64, 32)
# ):
#     seq_in = tf.keras.Input(shape=seq_input_shape, name="seq_in")
#     aux_in = tf.keras.Input(shape=(aux_input_dim,), name="aux_in")

#     # Transformer branch
#     x = tf.keras.layers.Dense(d_model)(seq_in)
#     if use_conv_frontend:
#         x = tf.keras.layers.Conv1D(filters=d_model, kernel_size=3, padding="causal", activation="relu")(x)
#         x = tf.keras.layers.Dropout(dropout)(x)

#     x = PositionalEncoding(position=seq_input_shape[0], d_model=d_model)(x)

#     key_dim = max(8, d_model // num_heads)
#     for _ in range(num_blocks):
#         x = transformer_encoder_preln(x, num_heads=num_heads, key_dim=key_dim, ff_dim=ff_dim, dropout=dropout, d_model=d_model)

#     # last pooling instead of GAP
#     x = tf.keras.layers.Lambda(lambda t: t[:, -1, :])(x)
#     x = tf.keras.layers.Dropout(dropout)(x)

#     # Aux branch
#     a = tf.keras.layers.LayerNormalization()(aux_in)
#     for u in aux_mlp_units:
#         a = tf.keras.layers.Dense(u, activation="relu")(a)
#         a = tf.keras.layers.Dropout(dropout)(a)

#     # Fusion
#     h = tf.keras.layers.Concatenate()([x, a])
#     h = tf.keras.layers.Dense(64, activation="relu")(h)
#     h = tf.keras.layers.Dropout(dropout)(h)

#     y_reg_z = tf.keras.layers.Dense(1, name="y_reg_z")(h)
#     y_up    = tf.keras.layers.Dense(1, activation="sigmoid", name="y_up")(h)

#     return tf.keras.Model([seq_in, aux_in], [y_reg_z, y_up])

# # =========================
# # 6) Focal loss for direction (reduces FP explosions)
# # =========================
# def focal_bce(gamma=2.0, alpha=0.25):
#     # y_true in {0,1}
#     def loss(y_true, y_pred):
#         y_true = tf.cast(y_true, tf.float32)
#         y_pred = tf.clip_by_value(y_pred, 1e-7, 1.0 - 1e-7)

#         bce = -(y_true * tf.math.log(y_pred) + (1.0 - y_true) * tf.math.log(1.0 - y_pred))
#         p_t = y_true * y_pred + (1.0 - y_true) * (1.0 - y_pred)
#         alpha_t = y_true * alpha + (1.0 - y_true) * (1.0 - alpha)
#         focal = alpha_t * tf.pow((1.0 - p_t), gamma) * bce
#         return tf.reduce_mean(focal)
#     return loss

# # =========================
# # 7) Threshold tuning: optimize DA or balanced acc
# # =========================
# def tune_threshold_metric(y_true_bin, y_prob, lo=0.1, hi=0.9, n=161, metric="da"):
#     ths = np.linspace(lo, hi, n)
#     best_t, best_score = 0.5, -1

#     y_true_bin = np.asarray(y_true_bin).astype(int)
#     y_prob = np.asarray(y_prob).astype(float)

#     for t in ths:
#         y_hat = (y_prob > t).astype(int)
#         if metric == "da":
#             score = accuracy_score(y_true_bin, y_hat)
#         elif metric == "bal_acc":
#             # balanced accuracy = (TPR + TNR)/2
#             tn, fp, fn, tp = confusion_matrix(y_true_bin, y_hat, labels=[0,1]).ravel()
#             tpr = tp / (tp + fn + 1e-12)
#             tnr = tn / (tn + fp + 1e-12)
#             score = 0.5 * (tpr + tnr)
#         else:  # f1
#             score = f1_score(y_true_bin, y_hat, zero_division=0)

#         if score > best_score:
#             best_score, best_t = score, t

#     return float(best_t), float(best_score)

# def safe_auc(y_true_bin, y_prob):
#     if len(np.unique(y_true_bin)) < 2:
#         return np.nan
#     return roc_auc_score(y_true_bin, y_prob)

# # =========================
# # 8) TRAIN + EVALUATE per ticker (with deadzone + purge gap + better early stop)
# # =========================
# LOOKBACK   = 30
# AUX_WINDOW = 64
# WAVELET    = "db4"
# WAV_LEVEL  = 3

# # deadzone to reduce label noise
# EPS_UP = 0.0003  # bạn có thể thử 0.0002 / 0.0005

# # val purge gap (avoid bleed)
# VAL_GAP = 5

# df = df.copy()
# df["date"] = pd.to_datetime(df["date"])

# non_feature = ['date', 'ticker', 'target']
# base_feature_cols = [c for c in df.columns if c not in non_feature]

# models, scalers, splits, meta = {}, {}, {}, {}
# summary_rows = []

# for tk, dft in df.groupby("ticker"):
#     dft = dft.sort_values("date").reset_index(drop=True)

#     dft = add_fft_wavelet_aux_features(
#         dft, ret_col="return",
#         aux_window=AUX_WINDOW,
#         wavelet=WAVELET, level=WAV_LEVEL
#     )

#     aux_cols = [c for c in dft.columns if c.startswith("fft_") or c.startswith("wav_")]
#     if len(aux_cols) == 0:
#         raise ValueError("No aux cols found. Check prefix names.")

#     X_seq_raw = dft[base_feature_cols].values.astype(np.float32)
#     X_aux_raw = dft[aux_cols].values.astype(np.float32)
#     y_raw     = dft["target"].values.astype(np.float32)

#     if len(dft) < (LOOKBACK + 80):
#         print(f"⚠️ {tk}: dữ liệu quá ít ({len(dft)} dòng) -> bỏ qua")
#         continue

#     split_index = int(len(dft) * 0.8)
#     X_seq_train_raw, X_seq_test_raw = X_seq_raw[:split_index], X_seq_raw[split_index:]
#     X_aux_train_raw, X_aux_test_raw = X_aux_raw[:split_index], X_aux_raw[split_index:]
#     y_train_raw, y_test_raw         = y_raw[:split_index], y_raw[split_index:]

#     seq_scaler = RobustScaler()
#     aux_scaler = RobustScaler()

#     X_seq_train = seq_scaler.fit_transform(X_seq_train_raw)
#     X_seq_test  = seq_scaler.transform(X_seq_test_raw)

#     X_aux_train = aux_scaler.fit_transform(X_aux_train_raw)
#     X_aux_test  = aux_scaler.transform(X_aux_test_raw)

#     Xtr_seq, Xtr_aux, ytr = create_sequences_with_aux(X_seq_train, X_aux_train, y_train_raw, LOOKBACK)
#     Xte_seq, Xte_aux, yte = create_sequences_with_aux(X_seq_test,  X_aux_test,  y_test_raw,  LOOKBACK)

#     # validation tail from train WITH GAP
#     val_size = max(10, int(0.2 * len(Xtr_seq)))
#     cut = len(Xtr_seq) - val_size
#     cut2 = max(1, cut - VAL_GAP)

#     X_tr_seq, X_val_seq = Xtr_seq[:cut2], Xtr_seq[cut:]
#     X_tr_aux, X_val_aux = Xtr_aux[:cut2], Xtr_aux[cut:]
#     y_tr, y_val         = ytr[:cut2], ytr[cut:]

#     # standardize regression target on train only
#     y_mu = float(np.mean(y_tr))
#     y_sd = float(np.std(y_tr) + 1e-8)
#     y_tr_z  = ((y_tr  - y_mu) / y_sd).astype(np.float32)
#     y_val_z = ((y_val - y_mu) / y_sd).astype(np.float32)

#     # direction labels with deadzone
#     y_tr_up  = (y_tr > EPS_UP).astype(np.float32)
#     y_val_up = (y_val > EPS_UP).astype(np.float32)

#     # build model
#     model = build_hybrid_fft_wav_transformer(
#         seq_input_shape=(LOOKBACK, Xtr_seq.shape[2]),
#         aux_input_dim=Xtr_aux.shape[1],
#         d_model=64, num_heads=4, ff_dim=128, num_blocks=3,
#         dropout=0.2, use_conv_frontend=True,
#         aux_mlp_units=(64, 32)
#     )

#     # direction loss: focal
#     dir_loss = focal_bce(gamma=2.0, alpha=0.35)

#     opt = Adam(learning_rate=8e-4, clipnorm=1.0)
#     model.compile(
#         optimizer=opt,
#         loss={"y_reg_z": tf.keras.losses.Huber(delta=1.0), "y_up": dir_loss},
#         loss_weights={"y_reg_z": 0.8, "y_up": 1.2},
#         metrics={
#             "y_up": [tf.keras.metrics.AUC(name="auc"), tf.keras.metrics.Precision(name="prec"), tf.keras.metrics.Recall(name="rec")]
#         }
#     )

#     early_stop = EarlyStopping(
#         monitor="val_y_up_auc", mode="max",
#         patience=10, restore_best_weights=True
#     )
#     rlr = ReduceLROnPlateau(
#         monitor="val_y_up_auc", mode="max",
#         factor=0.5, patience=4, min_lr=1e-5, verbose=1
#     )

#     pos = float(y_tr_up.mean())
#     print(f"\n===== Training HYBRID for {tk} | UpRatio={pos:.3f} | EPS_UP={EPS_UP} =====")

#     model.fit(
#         [X_tr_seq, X_tr_aux], {"y_reg_z": y_tr_z, "y_up": y_tr_up},
#         validation_data=([X_val_seq, X_val_aux], {"y_reg_z": y_val_z, "y_up": y_val_up}),
#         epochs=120, batch_size=32,
#         callbacks=[early_stop, rlr],
#         verbose=1
#     )

#     models[tk] = model
#     scalers[tk] = {"seq": seq_scaler, "aux": aux_scaler}
#     splits[tk] = (Xtr_seq, Xtr_aux, Xte_seq, Xte_aux, ytr, yte)
#     meta[tk] = {"y_mu": y_mu, "y_sd": y_sd, "up_ratio": pos, "eps_up": EPS_UP}

#     # ===== Evaluate =====
#     y_reg_z_pred, y_up_prob = model.predict([Xte_seq, Xte_aux], verbose=0)
#     y_reg_z_pred = y_reg_z_pred.reshape(-1)
#     y_up_prob    = y_up_prob.reshape(-1)
#     y_pred = y_reg_z_pred * y_sd + y_mu

#     rmse = float(np.sqrt(mean_squared_error(yte, y_pred)))
#     mae  = float(mean_absolute_error(yte, y_pred))

#     # tune threshold on val (optimize DA or balanced acc, not just F1)
#     _, y_val_prob = model.predict([X_val_seq, X_val_aux], verbose=0)
#     y_val_prob = y_val_prob.reshape(-1)
#     y_val_true = (y_val > EPS_UP).astype(int)

#     best_t, best_score = tune_threshold_metric(y_val_true, y_val_prob, lo=0.1, hi=0.9, n=161, metric="bal_acc")

#     y_true_bin = (yte > EPS_UP).astype(int)
#     y_pred_bin = (y_up_prob > best_t).astype(int)

#     directional_acc = float(accuracy_score(y_true_bin, y_pred_bin))
#     precision = float(precision_score(y_true_bin, y_pred_bin, zero_division=0))
#     recall    = float(recall_score(y_true_bin, y_pred_bin, zero_division=0))
#     f1        = float(f1_score(y_true_bin, y_pred_bin, zero_division=0))
#     auc       = float(safe_auc(y_true_bin, y_up_prob))

#     tn, fp, fn, tp = confusion_matrix(y_true_bin, y_pred_bin, labels=[0,1]).ravel()

#     summary_rows.append({
#         "Ticker": tk,
#         "N_test_seq": len(yte),
#         "RMSE": rmse,
#         "MAE": mae,
#         "Directional_Acc": directional_acc,
#         "Precision_Up": precision,
#         "Recall_Up": recall,
#         "F1_Up": f1,
#         "AUC": auc,
#         "Best_Threshold": float(best_t),
#         "Val_balAcc_at_bestT": float(best_score),
#         "TN": int(tn), "FP": int(fp), "FN": int(fn), "TP": int(tp)
#     })

# summary_df = pd.DataFrame(summary_rows).sort_values("Directional_Acc", ascending=False).reset_index(drop=True)
# print(summary_df.to_string(index=False))
